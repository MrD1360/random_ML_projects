# %% [markdown]
# # Chatbot

# %% [markdown]
# seq2seq encoder-decoder using tensorflow addons for the decoder
#
#
# - dataset1 http://www.cs.cornell.edu/~cristian/memorability.html
# - dataset2 https://www.kaggle.com/grafstor/simple-dialogs-for-chatbot (plus some small chat conversations)

# %%
#some imports

import pandas as pd 
import string
import numpy as np
from tqdm import tqdm

from collections import OrderedDict

# %%
#per chat only
import json
import string
import numpy as np

from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
#importing tensorflow

import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
#select GPU

if not tf.config.list_physical_devices('GPU'):
    print("No GPU was detected.")

gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_visible_devices(gpus[1], 'GPU')
tf.config.experimental.set_memory_growth(gpus[1], enable=True)
#tf.config.gpu_options.allow_growth = True
gpus
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %% [markdown]
# ## Uploading dataset

# %%
df=pd.read_csv('archive/dialogs.txt',sep='\t')

# %%
df.head()
# Out:
#                                      Q  \
# 0               hi, how are you doing?
# 1        i'm fine. how about yourself?
# 2  i'm pretty good. thanks for asking.
# 3    no problem. so how have you been?
# 4     i've been great. what about you?
#
#                                         ANS
# 0             i'm fine. how about yourself?
# 1       i'm pretty good. thanks for asking.
# 2         no problem. so how have you been?
# 3          i've been great. what about you?
# 4  i've been good. i'm in school right now.

# %%
#uploading files

lines= open('dataset_cornel/movie_lines.txt',encoding='utf-8',errors='ignore').read().split('\n')
conversations= open('dataset_cornel/movie_conversations.txt',encoding='utf-8',errors='ignore').read().split('\n')
lines
# Out:
# ['L1045 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ They do not!',
#  'L1044 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ They do to!',
#  'L985 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I hope so.',
#  'L984 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ She okay?',
#  "L925 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Let's go.",
#  'L924 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Wow',
#  "L872 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Okay -- you're gonna need to learn how to lie.",
#  'L871 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ No',
#  'L870 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I\'m kidding.  You know how sometimes you just become this "persona"?  And you don\'t know how to quit?',
#  'L869 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Like my fear of wearing pastels?',
#  'L868 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ The "real you".',
#  'L867 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ What good stuff?',
#  "L866 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ I figured you'd get to the good stuff eventually.",
#  'L865 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Thank God!  If I had to hear one more story about your coiffure...',
#  "L864 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Me.  This endless ...blonde babble. I'm like, boring myself.",
#  'L863 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ What crap?',
#  'L862 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ do you listen to this crap?',
#  'L861 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ No...',
#  'L860 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Then Guillermo says, "If you go any lighter, you\'re gonna look like an extra on 90210."',
#  'L699 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ You always been this selfish?',
#  'L698 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ But',
#  "L697 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Then that's all you had to say.",
#  'L696 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Well, no...',
#  "L695 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ You never wanted to go out with 'me, did you?",
#  'L694 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I was?',
#  'L693 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ I looked for you back at the party, but you always seemed to be "occupied".',
#  'L663 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Tons',
#  'L662 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Have fun tonight?',
#  'L578 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ I believe we share an art instructor',
#  'L577 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ You know Chastity?',
#  'L576 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Looks like things worked out tonight, huh?',
#  'L575 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Hi.',
#  "L407 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Who knows?  All I've ever heard her say is that she'd dip before dating a guy that smokes.",
#  "L406 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ So that's the kind of guy she likes? Pretty ones?",
#  "L405 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Lesbian?  No. I found a picture of Jared Leto in one of her drawers, so I'm pretty sure she's not harboring same-sex tendencies.",
#  "L404 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ She's not a...",
#  "L403 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ I'm workin' on it. But she doesn't seem to be goin' for him.",
#  "L402 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I really, really, really wanna go, but I can't.  Not unless my sister goes.",
#  'L401 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Sure have.',
#  "L368 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Eber's Deep Conditioner every two days. And I never, ever use a blowdryer without the diffuser attachment.",
#  'L367 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ How do you get your hair to look like that?',
#  "L366 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ You're sweet.",
#  'L365 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ You have my word.  As a gentleman',
#  "L364 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I counted on you to help my cause. You and that thug are obviously failing. Aren't we ever going on our date?",
#  'L363 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ You got something on your mind?',
#  'L281 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Where?',
#  'L280 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ There.',
#  "L277 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Well, there's someone I think might be --",
#  'L276 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ How is our little Find the Wench A Date plan progressing?',
#  'L275 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Forget French.',
#  "L274 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ That's because it's such a nice one.",
#  "L273 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I don't want to know how to say that though.  I want to know useful things. Like where the good stores are.  How much does champagne cost?  Stuff like Chat.  I have never in my life had to point out my head to someone.",
#  "L272 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Right.  See?  You're ready for the quiz.",
#  "L271 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ C'esc ma tete. This is my head",
#  'L208 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Let me see what I can do.',
#  'L207 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Gosh, if only we could find Kat a boyfriend...',
#  "L206 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ That's a shame.",
#  'L205 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Unsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.',
#  'L204 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Why?',
#  'L203 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Seems like she could get a date easy enough...',
#  "L202 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ The thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does.",
#  'L201 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Cameron.',
#  "L200 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ No, no, it's my fault -- we didn't have a proper introduction ---",
#  'L199 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Forget it.',
#  "L198 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ You're asking me out.  That's so cute. What's your name again?",
#  "L197 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Okay... then how 'bout we try out some French cuisine.  Saturday?  Night?",
#  'L196 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Not the hacking and gagging and spitting part.  Please.',
#  "L195 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Well, I thought we'd start with pronunciation, if that's okay with you.",
#  'L194 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Can we make this quick?  Roxanne Korrine and Andrew Barrett are having an incredibly horrendous public break- up on the quad.  Again.',
#  'L953 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I did.',
#  "L952 +++$+++ u3 +++$+++ m0 +++$+++ CHASTITY +++$+++ You think you ' re the only sophomore at the prom?",
#  "L660 +++$+++ u3 +++$+++ m0 +++$+++ CHASTITY +++$+++ I don't have to be home 'til two.",
#  'L659 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I have to be home in twenty minutes.',
#  "L600 +++$+++ u3 +++$+++ m0 +++$+++ CHASTITY +++$+++ All I know is -- I'd give up my private line to go out with a guy like Joey.",
#  "L599 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Sometimes I wonder if the guys we're supposed to want to go out with are the ones we actually want to go out with, you know?",
#  "L598 +++$+++ u3 +++$+++ m0 +++$+++ CHASTITY +++$+++ Bianca, I don't think the highlights of dating Joey Dorsey are going to include door-opening and coat-holding.",
#  "L597 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Combination.  I don't know -- I thought he'd be different.  More of a gentleman...",
#  'L596 +++$+++ u3 +++$+++ m0 +++$+++ CHASTITY +++$+++ Is he oily or dry?',
#  "L595 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ He practically proposed when he found out we had the same dermatologist. I mean. Dr. Bonchowski is great an all, but he's not exactly relevant party conversation.",
#  'L580 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Would you mind getting me a drink, Cameron?',
#  'L579 +++$+++ u3 +++$+++ m0 +++$+++ CHASTITY +++$+++ Great',
#  'L573 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Joey.',
#  'L572 +++$+++ u3 +++$+++ m0 +++$+++ CHASTITY +++$+++ Who?',
#  'L571 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Where did he go?  He was just here.',
#  'L51 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ You might wanna think about it',
#  'L50 +++$+++ u3 +++$+++ m0 +++$+++ CHASTITY +++$+++ No.',
#  'L49 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Did you change your hair?',
#  "L760 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ You know the deal.  I can ' t go if Kat doesn't go --",
#  'L759 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Listen, I want to talk to you about the prom.',
#  "L758 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ You're concentrating awfully hard considering it's gym class.",
#  'L757 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Hi, Joey.',
#  'L756 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Hey, sweet cheeks.',
#  "L593 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ My agent says I've got a good shot at being the Prada guy next year.",
#  'L592 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Neat...',
#  "L591 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ It's a gay cruise line, but I'll be, like, wearing a uniform and stuff.",
#  'L590 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Queen Harry?',
#  'L589 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ So yeah, I\'ve got the Sears catalog thing going -- and the tube sock gig " that\'s gonna be huge.  And then I\'m up for an ad for Queen Harry next week.',
#  'L397 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Hopefully.',
#  "L396 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Exactly  So, you going to Bogey Lowenbrau's thing on Saturday?",
#  'L395 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Expensive?',
#  "L394 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ It's more",
#  'L1052 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Perm?',
#  'L1051 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Patrick -- is that- a.',
#  "L1022 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ It's just you.",
#  'L1021 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Is that woman a complete fruit-loop or is it just me?',
#  'L1011 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ No! I just wanted',
#  'L1010 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ What? To completely damage me?  To send me to therapy forever? What?',
#  'L1009 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I just wanted --',
#  'L1008 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ You set me up.',
#  'L1007 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Let go!',
#  'L983 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ So did you',
#  'L982 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ You looked beautiful last night, you know.',
#  "L914 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I guess I'll never know, will I?",
#  "L913 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Not all experiences are good, Bianca. You can't always trust the people you want to.",
#  "L912 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ God, you're just like him! Just keep me locked away in the dark, so I can't experience anything for myself",
#  'L911 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I guess I thought I was protecting you.',
#  "L910 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I'm not stupid enough to repeat your mistakes.",
#  "L909 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ That's not",
#  "L908 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ No. you didn't!  If you really thought I could make my own decisions, you would've let me go out with him instead of helping Daddy hold me hostage.",
#  'L907 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I wanted to let you make up your own mind about him.',
#  "L906 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Why didn't you tell me?",
#  'L905 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ After that, I swore I\'d never do anything just because "everyone else" was doing it.  And I haven\'t since. Except for Bogey\'s party, and my stunning gastro-intestinal display --',
#  'L904 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ But',
#  "L903 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Just once.  Afterwards, I told him I didn't want to anymore.  I wasn't ready. He got pissed.  Then he broke up with me.",
#  'L902 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ You did what?',
#  'L901 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ He said everyone was doing it.  So I did it.',
#  'L900 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ As in...',
#  'L899 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Now I do.  Back then, was a different story.',
#  'L898 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ But you hate Joey',
#  'L897 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ He was, like, a total babe',
#  'L896 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Why?',
#  'L895 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ In 9th.  For a month',
#  'L894 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ What?',
#  'L893 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Joey never told you we went out, did he?',
#  "L892 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I wish I had that luxury. I'm the only sophomore that got asked to the prom and I can't go, because you won ' t.",
#  "L891 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I do care. But I'm a firm believer in doing something for your own reasons, not someone else ' s .",
#  'L890 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Like you care.',
#  "L889 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Listen, I know you hate having to sit home because I'm not Susie High School.",
#  "L656 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ You're welcome.",
#  "L655 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I don't get you.  You act like you're too good for any of this, and then you go totally apeshit when you get here.",
#  "L602 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I really don't think I need any social advice from you right now.",
#  'L601 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Bianca, I need to talk to you -- I need to tell you --',
#  'L543 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Can we go now?',
#  'L542 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ You are so completely unbalanced.',
#  "L533 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Yeah, he's your freak friend Mandella's boyfriend.  I guess since I'm not allowed to go out, I should obsess over a dead guy, too.",
#  "L532 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ It's Shakespeare.  Maybe you've heard of him?",
#  "L531 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Like I'm supposed to know what that even means.",
#  "L530 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ At least I'm not a clouted fen- sucked hedge-pig.",
#  "L529 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Can't you forget for just one night that you're completely wretched?",
#  "L527 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Bogey Lowenstein's party is normal, but you're too busy listening to Bitches Who Need Prozac to know that.",
#  "L526 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ What's normal?",
#  "L525 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ You're ruining my life'  Because you won't be normal, I can't be normal.",
#  "L445 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I think you're a freak.  I think you do this to torture me.  And I think you suck.",
#  'L444 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ What do you think?',
#  "L443 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Oh, I thought you might have a date  I don't know why I'm bothering to ask, but are you going to Bogey Lowenstein's party Saturday night?",
#  "L442 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ It means that Gigglepuss is playing at Club Skunk and we're going.",
#  "L441 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Oh my God, does this mean you're becoming normal?",
#  'L320 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Can you at least start wearing a bra?',
#  "L319 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I have the potential to smack the crap out of you if you don't get out of my way.",
#  'L165 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Nowhere... Hi, Daddy.',
#  "L164 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Where've you been?",
#  "L923 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I have a date, Daddy.  And he ' s not a captain of oppression like some men we know.",
#  "L922 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ I'm missing something.",
#  "L884 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Fine.  I see that I'm a prisoner in my own house.  I'm not a daughter. I'm a possession!",
#  "L883 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ You're not going unless your sister goes.  End of story.",
#  'L882 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ He\'s not a "hot rod".  Whatever that is.',
#  "L881 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ It's that hot rod Joey, right? That ' s who you want me to bend my rules for?",
#  'L880 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ No, but',
#  'L879 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ The prom?  Kat has a date?',
#  "L878 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Daddy, I want to discuss the prom with you. It's tomorrow night --",
#  "L546 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ Because she'll scare them away.",
#  'L545 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Why?',
#  "L544 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ Promise me you won't talk to any boys unless your sister is present.",
#  'L540 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ Just for a minute',
#  'L539 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Daddy, no!',
#  'L538 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ Wear the belly before you go.',
#  "L537 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ It's just a party. Daddy.",
#  "L536 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ Oh, God.  It's starting.",
#  "L524 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ If Kat's not going, you're not going.",
#  'L523 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Daddy, people expect me to be there!',
#  'L521 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ It\'s just a party. Daddy, but I knew you\'d forbid me to go since "Gloria Steinem" over there isn\'t going --',
#  'L520 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ Otherwise known as an orgy?',
#  'L519 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ If you must know, we were attempting to go to a small study group of friends.',
#  "L518 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ And where're you going?",
#  'L517 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Daddy, I --',
#  'L190 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ Exactly my point',
#  "L189 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ But she doesn't want to date.",
#  "L183 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ But it's not fair -- she's a mutant, Daddy!",
#  "L182 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ Then neither will you.  And I'll get to sleep at night.",
#  'L181 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ What if she never starts dating?',
#  "L180 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ No! You're not dating until your sister starts dating.  End of discussion.",
#  "L179 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Now don't get upset. Daddy, but there's this boy... and I think he might ask...",
#  "L463 +++$+++ u1 +++$+++ m0 +++$+++ BRUCE +++$+++ Just sent 'em through.",
#  'L462 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Padua girls.  One tall, decent body. The other one kinda short and undersexed?',
#  'L461 +++$+++ u1 +++$+++ m0 +++$+++ BRUCE +++$+++ Never',
#  'L460 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Fan of a fan.  You see a couple of minors come in?',
#  "L459 +++$+++ u1 +++$+++ m0 +++$+++ BRUCE +++$+++ Didn't have you pegged for a Gigglepuss fan.  Aren't they a little too pre-teen belly-button ring for you?",
#  'L458 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Always a pleasure, Brucie.',
#  "L779 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Best case scenario, you're back on the payroll for awhile.",
#  'L778 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ You humiliated the woman! Sacrifice yourself on the altar of dignity and even the score.',
#  "L586 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ No, I ' m not.",
#  "L585 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Buttholus extremus.  But hey, you're making progress.",
#  "L584 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ The hell is that?  What kind of 'guy just picks up a girl and carries her away while you're talking to her?",
#  'L583 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Extremely unfortunate maneuver.',
#  "L500 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Hell, I've just been going over the whole thing in my head and -",
#  'L499 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ You told me that part already.',
#  "L433 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ It's her favorite band.",
#  'L432 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Assail your ears for one night.',
#  "L425 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Okay!  I wasn't sure",
#  "L424 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ He's pretty!",
#  'L419 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Dead at forty-one.',
#  'L418 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Her favorite uncle',
#  "L417 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ It's a lung cancer issue",
#  'L416 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Number one.  She hates smokers',
#  "L391 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Are you kidding?  He'll piss himself with joy.  He's the ultimate kiss ass.",
#  'L390 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Will Bogey get bent?',
#  "L389 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ In that case, we'll need to make it a school-wide blow out.",
#  'L388 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ This is it.  A golden opportunity. Patrick can ask Katarina to the party.',
#  "L245 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Like we had a choice?  Besides -- when you let the enemy think he's orchestrating the battle, you're in a position of power. We let him pretend he's calling the shots, and while he's busy setting up the plan, you have time to woo Bianca.",
#  'L244 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ You got him involved?',
#  "L225 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Hey -- I've gotta have a few clients when I get to Wall Street.",
#  'L224 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ I thought you hated those people.',
#  "L223 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ You know, if you do go out with Bianca, you'd be set.  You'd outrank everyone. Strictly A-list.  With me by your side.",
#  "L222 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ That's what I just said",
#  "L221 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Did she actually say she'd go out with you?",
#  "L220 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Forget his reputation.  Do you think we've got a plan or not?",
#  "L219 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ I'm serious, man, he's whacked.  He sold his own liver on the black market so he could buy new speakers.",
#  'L218 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ They always let felons sit in on Honors Biology?',
#  "L217 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ No kidding.  He's a criminal.  I heard he lit a state trooper on fire.  He just got out of Alcatraz...",
#  'L216 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ He seems like he thrives on danger',
#  "L215 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ What makes you think he'll do it?",
#  'L213 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ You wanna go out with him?',
#  'L212 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ What about him?',
#  "L211 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Unlikely, but even so, she still can't go out with you.  So what's the point?",
#  'L210 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ I teach her French, get to know her, dazzle her with charm and she falls in love with me.',
#  'L159 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ The mewling, rampalian wretch herself.',
#  "L158 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ That's her?  Bianca's sister?",
#  'L157 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Yeah, just a minor encounter with the shrew.',
#  'L147 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ You could consecrate with her, my friend.',
#  "L146 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ You mean I'd get a chance to talk to her?",
#  'L145 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Guess who just signed up for a tutor?',
#  "L144 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Sure do ... my Mom's from Canada",
#  'L143 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ You know French?',
#  "L142 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Joey Dorsey?  Perma-shit-grin.  I wish I could say he's a moron, but he's number twelve in the class.  And a model.  Mostly regional stuff, but he's rumored to have a big tube sock ad coming out.",
#  'L141 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ He always have that shit-eating grin?',
#  "L140 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Because they're bred to.  Their mothers liked guys like that, and their grandmothers before them. Their gene pool is rarely diluted.",
#  'L139 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Why do girls like that always like guys like that?',
#  "L92 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ I could start with your haircut, but it doesn't matter.  She's not allowed to date until her older sister does.  And that's an impossibility.",
#  'L91 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Why not?',
#  "L90 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Bianca Stratford.  Sophomore. Don't even think about it",
#  'L89 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Who is she?',
#  'L88 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ You burn, you pine, you perish?',
#  'L87 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ That girl -- I --',
#  'L78 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Yeah, but these guys have never seen a horse.  They just jack off to Clint Eastwood.',
#  "L77 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ That I'm used to.",
#  'L74 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Couple thousand. Most of them evil',
#  'L73 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ How many people go here?',
#  'L72 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Get out!',
#  'L71 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Thirty-two.',
#  'L70 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ How many people were in your old school?',
#  "L69 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Yeah.  A couple.  We're outnumbered by the cows, though.",
#  'L68 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ I was kidding. People actually live there?',
#  "L67 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ North, actually.  How'd you   ?",
#  'L66 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ So -- which Dakota you from?',
#  "L65 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ C'mon.  I'm supposed to give you the tour.",
#  'L64 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ So they tell me...',
#  'L63 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ You the new guy?',
#  'L781 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ You get the girl.',
#  "L780 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ What's the worst?",
#  'L745 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Where?',
#  'L744 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ She kissed me.',
#  "L743 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ You makin' any headway?",
#  "L741 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ She just needs time to cool off I'll give it a day.",
#  "L740 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ She hates you with the fire of a thousand suns .  That's a direct quote",
#  "L726 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I don ' t know.  I decided not to nail her when she was too drunk to remember it.",
#  "L725 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ What'd you do to her?",
#  'L625 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Then, go get her',
#  'L624 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Sure',
#  'L623 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Cameron -- do you like the girl?',
#  "L622 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ She's partial to Joey, not me",
#  "L621 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ What 're you talking about?",
#  "L620 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ It's off. The whole thing.",
#  "L619 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Cameron, I'm a little busy",
#  "L431 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Don't make me do it, man",
#  'L430 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Gigglepuss is playing there tomorrow night.',
#  "L427 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ So what does that give me?  I'm supposed to buy her some noodles and a book and sit around listening to chicks who can't play their instruments?",
#  'L426 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Okay -- Likes:  Thai food, feminist prose, and "angry, stinky girl music of the indie-rock persuasion".',
#  "L412 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ I've retrieved certain pieces of information on Miss Katarina Stratford I think you'll find helpful.",
#  "L411 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ What've you got for me?",
#  "L386 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Yeah -- we'll see.",
#  'L385 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ And he means that strictly in a non- prison-movie type of way.',
#  'L558 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ And why would I do that?',
#  'L557 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Leave my sister alone.',
#  'L556 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Your sister here?',
#  'L555 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Away.',
#  'L554 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Where ya goin?',
#  'L336 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Not at all',
#  'L335 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Hey -- do you mind?',
#  "L150 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ They're running the rest of me next month.",
#  'L149 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Yeah, and I noticed the only part of you featured in your big Kmart spread was your elbow.  Tough break.',
#  "L148 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ The vintage look is over, Kat. Haven't you been reading your Sassy?",
#  "L748 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Enough with the Barbie n' Ken shit. I know.",
#  "L747 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I don't know, Dorsey. ..the limo.-the flowers.  Another hundred for the tux --",
#  'L609 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Get her to act like a human',
#  'L608 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Do what?',
#  "L607 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ How'd you do it?",
#  "L606 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ A deal's a deal.",
#  "L605 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ It's about time.",
#  'L358 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Forget her sister, then.',
#  'L357 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Forget it.',
#  'L356 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ A hundred bucks a date.',
#  'L355 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ What?',
#  'L354 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I just upped my price',
#  'L352 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I got her under control. She just acts crazed in public to keep up the image.',
#  "L351 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Watching the bitch trash my car doesn't count as a date.",
#  "L350 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I'm on it",
#  'L349 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ When I shell out fifty, I expect results.',
#  "L301 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Fifty, and you've got your man.",
#  "L300 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Take it or leave it.  This isn't a negotiation.",
#  'L299 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Fine, thirty.',
#  "L298 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I can't take a girl like that out on twenty bucks.",
#  'L297 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ How much?',
#  "L296 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ I can't date her sister until that one gets a boyfriend.  And that's the catch. She doesn't want a boyfriend.",
#  "L295 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ You're gonna pay me to take out some girl?",
#  'L294 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ You got it, Verona.  I pick up the tab, you do the honors.',
#  "L292 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ But you'd go out with her if you had the cake?",
#  'L291 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ You need money to take a girl out',
#  'L290 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ You just said',
#  "L289 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Sure, Sparky.  I'll get right on it.",
#  'L288 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Yeah, whatever.  I want you to go out with her.',
#  'L287 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Two legs, nice rack...',
#  'L286 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ What do you think?',
#  'L285 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Yeah',
#  "L509 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Hey -- it's all for the higher good right?",
#  "L508 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ You better not fuck this up.  I'm heavily invested.",
#  'L505 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ What?  We took bathes together when we were kids.',
#  'L504 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ You and Verona?',
#  "L503 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Uh,  yeah.  We're old friend*",
#  "L502 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ I hear you're helpin' Verona.",
#  "L240 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ So what you need to do is recruit a guy who'll go out with her.  Someone who's up for the job.",
#  'L239 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Does this conversation have a purpose?',
#  "L238 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ But she can't go out with you because her sister is this insane head case and no one will go out with her. right?",
#  "L236 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ We're not.",
#  "L235 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Well, actually, I thought I'd run an idea by you.  You know, just to see if you're interested.",
#  "L234 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ We don't chat.",
#  'L233 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Nope - just came by to chat',
#  'L232 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Are you lost?',
#  'L231 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Hey.',
#  "L949 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Oh, honey -- tell me we haven't' progressed to full-on hallucinations.",
#  'L948 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ William - he asked me to meet him here.',
#  'L947 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Who?',
#  'L946 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ Have you seen him?',
#  'L755 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ Oh, good.  Something new and different for us.',
#  "L754 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ You ' re looking at this from the wrong perspective.  We're making a statement.",
#  "L753 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ Okay, okay, we won't go.  It's not like I have a dress anyway",
#  'L752 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Listen to you!  You sound like Betty, all pissed off because Archie is taking Veronica.',
#  "L751 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ Well, I guess we're not, since we don't have dates .",
#  'L750 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Can you even imagine?  Who the hell would go to this a bastion of commercial excess?',
#  'L721 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I got drunk.  I puked.  I got rejected. It was big fun.',
#  "L720 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ You didn't",
#  'L719 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I did Bianca a favor and it backfired.',
#  "L718 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ You didn't have a choice?  Where's Kat and what have you done with her?",
#  "L717 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I didn't have a choice.",
#  'L716 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ You went to the party?  I thought we were officially opposed to suburban social activity.',
#  'L491 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Who cares?',
#  "L490 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ What'd he say?",
#  'L448 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ No fear.',
#  "L447 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ You think this'll work?",
#  'L254 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ If I was Bianca, it would be, "Any school you want, precious.  Don\'t forget your tiara."',
#  'L253 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ Does it matter?',
#  "L252 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I appreciate your efforts toward a speedy death, but I'm consuming.  Do you mind?",
#  'L251 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Neither has his heterosexuality.',
#  "L250 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ That's never been proven",
#  "L249 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ William didn't even go to high school",
#  'L248 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ William would never have gone to a state school.',
#  'L247 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ So he has this huge raging fit about Sarah Lawrence and insists that I go to his male-dominated, puking frat boy, number one golf team school. I have no say at all.',
#  "L152 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ You could always go with me.  I'm sure William has some friends.",
#  'L151 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ The people at this school are so incredibly foul.',
#  "L134 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ But imagine the things he'd say during sex.",
#  "L133 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I realize that the men of this fine institution are severely lacking, but killing yourself so you can be with William Shakespeare is beyond the scope of normal teenage obsessions.  You're venturing far past daytime talk show fodder and entering the world of those who need very expensive therapy.",
#  'L132 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ An attempted slit.',
#  "L131 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ What's this?",
#  'L130 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ Just a little.',
#  'L129 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Mandella, eat.  Starving yourself is a very slow way to die.',
#  'L128 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Block E?',
#  'L127 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ He always look so',
#  "L126 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I'm sure he's completely incapable of doing anything that interesting.",
#  "L125 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ That's Pat Verona? The one who was gone for a year? I heard he was doing porn movies.",
#  'L124 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Patrick Verona   Random skid.',
#  "L123 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ Who's that?",
#  "L1043 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Don ' t you even dare. . .",
#  'L1042 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Oh, Bianca?  Can you get me my freshman yearbook?',
#  'L1041 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Because I like to torture you.',
#  'L1040 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Why is my veggie burger the only burnt object on this grill?',
#  'L1035 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Yeah, but then I fucked up. I fell for her.',
#  'L1034 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Is that right?',
#  'L1033 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Besides, I had some extra cash. Some asshole paid me to take out a really great girl.',
#  'L1032 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I thought you could use it. When you start your band.',
#  'L1031 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ A Fender Strat. You bought this?',
#  "L977 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I didn't care about the money.",
#  'L976 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Really?  What was it like?  A down payment now, then a bonus for sleeping with me?',
#  "L975 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ It wasn't like that.",
#  'L974 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ You were paid to take me out!  By -- the one person I truly hate.  I knew it was a set-up!',
#  'L973 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Wait I...',
#  'L961 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ It gets worse -- you still have your freshman yearbook?',
#  "L960 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ That ' s completely adorable!",
#  "L959 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ That's where I was last year.  She'd never lived alone -- my grandfather died -- I stayed with her.  I wasn't in jail, I don't know Marilyn Manson, and I've never slept with a Spice Girl.  I spent a year sitting next to my grandma on the couch watching Wheel of Fortune.  End of story.",
#  'L958 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ What?',
#  "L957 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ My grandmother's .",
#  "L940 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Look, I'm  -- sorry -- that I questioned your motives.  I was wrong.",
#  'L939 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Oh huh',
#  "L938 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ It's just something I had.  You know",
#  "L937 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ It's Scurvy's.  His date got convicted. Where'd you get the dress?",
#  "L936 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ How'd you get a tux at the last minute?",
#  "L857 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Nothing!  There's nothing in it for me. Just the pleasure of your company.",
#  'L856 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Answer the question, Patrick',
#  'L855 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ You need therapy.  Has anyone ever told you that?',
#  'L854 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ You tell me.',
#  'L853 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ So I have to have a motive to be with you?',
#  'L852 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Create a little drama?  Start a new rumor?  What?',
#  "L848 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Because I don't want to. It's a stupid tradition.",
#  'L847 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Why not?',
#  "L846 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ No, I won't go with you",
#  'L845 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ No what?',
#  'L844 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ No.',
#  'L843 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ You know what I mean',
#  'L842 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Is that a request or a command?',
#  'L841 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Go to the prom with me',
#  "L840 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ You're amazingly self-assured. Has anyone ever told you that?",
#  'L839 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ No one else knows',
#  'L838 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ What?',
#  "L837 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ You're sweet.  And sexy.  And completely hot for me.",
#  'L836 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ No -- something real.  Something no one else knows.',
#  'L835 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I hate peas.',
#  'L834 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Tell me something true.',
#  "L832 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I know the porn career's a lie.",
#  'L831 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Hearsay.',
#  'L830 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ The duck?',
#  'L829 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Fallacy.',
#  'L828 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ State trooper?',
#  'L825 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ For. . . ?',
#  'L824 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ You up for it?',
#  'L823 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ You never disappointed me.',
#  'L822 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ How?',
#  'L821 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Then you screwed up',
#  'L820 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Something like that',
#  "L819 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ So if you disappoint them from the start, you're covered?",
#  "L818 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I don't like to do what people expect. Then they expect it all the time and they get disappointed when you change.",
#  'L817 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Yes',
#  'L816 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Acting the way we do.',
#  "L815 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ So what's your excuse?",
#  "L814 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Yeah, well, don't let it get out",
#  'L813 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ A soft side? Who knew?',
#  'L812 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I dazzled him with my wit',
#  "L811 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ So how'd you get Chapin to look the other way?",
#  'L810 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Good call.',
#  'L809 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I figured it had to be something ridiculous to win your respect.  And piss you off.',
#  'L808 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ The Partridge Family?',
#  'L806 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Maybe.',
#  'L805 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ You want me to climb up and show you how to get down?',
#  "L804 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Forget it.  I'm stayin'.",
#  'L803 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Put your right foot there --',
#  "L802 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Try lookin' at it from this angle",
#  "L801 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ C'mon.  It's not that bad",
#  "L800 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I guess I never told you I'm afraid of heights.",
#  'L799 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Look up, sunshine',
#  'L798 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ He left!  I sprung the dickhead and he cruised on me.',
#  'L774 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Other than my upchuck reflex? Nothing.',
#  'L773 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ So what did I have an effect on ?',
#  "L772 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Don't for one minute think that you had any effect whatsoever on my panties.",
#  'L771 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Unwelcome?  I guess someone still has her panties in a twist.',
#  'L770 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Unwelcome.',
#  'L769 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Wholesome.',
#  'L768 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Pleasant?',
#  "L767 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ You 're so --",
#  'L766 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I heard there was a poetry reading.',
#  'L765 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ What are you doing here?',
#  'L764 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Excuse me, have you seen The Feminine Mystique?  I lost my copy.',
#  "L690 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ No offense, but you're sister is without.  I know everyone likes her and all, but ...",
#  'L689 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ BIANCA',
#  'L688 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Who?',
#  "L687 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ He just wants me to be someone I'm not.",
#  "L686 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ So what ' s up with your dad?  He a pain in the ass?",
#  "L684 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I'm gettin' there",
#  'L683 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Oh, so now you think you know me?',
#  "L682 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ You don't strike me as the type that would ask permission.",
#  "L681 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ My father wouldn't approve of that that",
#  'L680 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Start a band?',
#  'L679 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ This.',
#  'L678 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Do what?',
#  'L677 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I should do this.',
#  "L676 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Why'd you lie?",
# ...
#  'L1959 +++$+++ u19 +++$+++ m1 +++$+++ MARCHENA +++$+++ How can you be so certain?',
#  'L1958 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Ignorance!  I believe the Indies are no more than 750 leagues west of the Canary Islands.',
#  'L1957 +++$+++ u19 +++$+++ m1 +++$+++ MARCHENA +++$+++ How can you be so certain?  The Ocean is said to be infinite.',
#  'L1952 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ To open a new route to Asia.  At the moment there are only two ways of reaching it...',
#  'L1951 +++$+++ u19 +++$+++ m1 +++$+++ MARCHENA +++$+++ Why do you wish to sail west?',
#  'L1950 +++$+++ u19 +++$+++ m1 +++$+++ MARCHENA +++$+++ With some difficulty.  I had to promise them you were not a total fool.',
#  'L1949 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ How did you manage it?',
#  "L1948 +++$+++ u19 +++$+++ m1 +++$+++ MARCHENA +++$+++ That's what it says.",
#  "L1947 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ God... That's in a week!",
#  'L1943 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Father, I am doing what I think is the best for him.  And he has the teacher I would have chosen for myself.',
#  'L1942 +++$+++ u19 +++$+++ m1 +++$+++ MARCHENA +++$+++ Diego is a bright boy -- a pleasure to teach -- but so serious... Brothers should be raised together, Colon.  Even brothers from different mothers...',
#  'L2459 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Your Majesty -- some men are content to read about things.  I must see them with my own eyes.  I cannot be other than I am.',
#  "L2458 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ There is one thing I'd like to understand... Why do you want to go back, after all this?",
#  'L2457 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Thank you.',
#  'L2456 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ But without your brothers.  Nor are you to return to Santo Domingo or any of the other colonies.  You may explore the continent.',
#  'L2280 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ They come and go as naked as the day God created them...',
#  'L2279 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ Do they have such thoughts?',
#  'L2086 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Thirty seven, Your Majesty... And you?',
#  'L2085 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ How old are you, Senor Colon?',
#  'L2082 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ A woman?',
#  'L2081 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ I know what I see.  I see someone who doesn\'t accept the world as it is.  Who\'s not afraid.  I see a women who thinks... "What if?"...',
#  'L2080 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ You show no inclination to speak otherwise!',
#  'L2079 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ May I speak freely?',
#  'L2077 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Surely you can do anything you want.',
#  'L2076 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ I cannot ignore the verdict of my council.',
#  'L2075 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ That she was impregnable.',
#  'L2074 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ What did they say about Granada before today?',
#  'L2073 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ The ocean is uncrossable?',
#  'L2072 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ No more than the woman who said she would take Granada from the Moors.',
#  'L2071 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ I should not even be listening to you, since my council said no.  But Santangel tells me you are a man of honor and sincerity... And Sanchez, that you are not a fool.',
#  'L2389 +++$+++ u21 +++$+++ m1 +++$+++ MOXICA +++$+++ You will regret this.',
#  "L2388 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ You'll be held in detention, deprived of your privileges and possessions.  Until you are returned to Spain where you will be judged. Have you anything to say?",
#  'L2387 +++$+++ u21 +++$+++ m1 +++$+++ MOXICA +++$+++ Savagery is what monkeys understand.',
#  'L2386 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ In one act of brutality, you have created chaos.  Tribes who were fighting each other are now joining forces against us!  All that because of your criminal savagery!',
#  'L2348 +++$+++ u21 +++$+++ m1 +++$+++ MOXICA +++$+++ You did not hear me, Don Colon.  Not my horse.',
#  'L2347 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Don Moxica -- we all have to work.',
#  "L2346 +++$+++ u21 +++$+++ m1 +++$+++ MOXICA +++$+++ My horse doesn't work.",
#  "L2345 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ We can't raise the wheel without it.",
#  'L2333 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ We came here to stay!  To build! Not to start a crusade.  In this forest, there is enough danger to sweep us away in days!  So we will be brave and swallow our grief.  And in the name of those who died, we will accomplish what we came for.',
#  "L2332 +++$+++ u21 +++$+++ m1 +++$+++ MOXICA +++$+++ We don't need to know.",
#  'L2331 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ You want a war?  Fine.  We are a thousand.  They outnumber us by ten! Who will you kill?  Which tribe?',
#  "L2329 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ If you want to keep your head on your shoulders, you'll do as I say.",
#  'L2328 +++$+++ u21 +++$+++ m1 +++$+++ MOXICA +++$+++ We lost cousins, friends.  We will wash this in blood.',
#  'L2278 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ The Indians have no such word, Don Moxica.',
#  "L2277 +++$+++ u21 +++$+++ m1 +++$+++ MOXICA +++$+++ And you say this is an Indian vice? By God!  I don't see any kind of pleasure that would make this a sin.",
#  "L2492 +++$+++ u20 +++$+++ m1 +++$+++ MENDEZ +++$+++ We can't be.",
#  "L2491 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ He's drawing an isthmus... He's saying we're on an isthmus.",
#  "L2490 +++$+++ u20 +++$+++ m1 +++$+++ MENDEZ +++$+++ What's he doing?",
#  'L2165 +++$+++ u20 +++$+++ m1 +++$+++ MENDEZ +++$+++ Twenty eight.',
#  'L2164 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ What do you read?',
#  'L2160 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Come over here.',
#  "L2159 +++$+++ u20 +++$+++ m1 +++$+++ MENDEZ +++$+++ Well, I surely know what a quadrant is!  But I've never seen it used at night before.",
#  'L2158 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ And what do you think Mendez?',
#  "L2157 +++$+++ u20 +++$+++ m1 +++$+++ MENDEZ +++$+++ Well... It's the men, Sir.  They wonder how you know our position. We've lost sight from land days ago...",
#  'L2155 +++$+++ u20 +++$+++ m1 +++$+++ MENDEZ +++$+++ God be with us admiral.',
#  'L2154 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Due west, Captain Mendez.  And may God be with us...',
#  "L2211 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ You're right.  Let the men decide.",
#  'L2210 +++$+++ u22 +++$+++ m1 +++$+++ PINZON +++$+++ You tell that to them!',
#  'L2209 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Pinzon, Pinzon... All we can do now is go forward!  Think about that!',
#  'L2208 +++$+++ u22 +++$+++ m1 +++$+++ PINZON +++$+++ You bloody...',
#  'L2207 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ You never did.  You did all the talking for both of us, remember?',
#  'L2206 +++$+++ u22 +++$+++ m1 +++$+++ PINZON +++$+++ Jesus Maria!  I should have never listened to you!',
#  'L2205 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ And then what?  Half of the water has gone, the rest is nearly putrid! You know that!',
#  "L2204 +++$+++ u22 +++$+++ m1 +++$+++ PINZON +++$+++ You don't know anything!  Listen Colon, these are my ships, right? So I'm telling you we're turning back!",
#  'L2203 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ The land is there.  I know it!',
#  "L2202 +++$+++ u22 +++$+++ m1 +++$+++ PINZON +++$+++ We're lost!",
#  "L2201 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ You think I don't know that?",
#  "L2200 +++$+++ u22 +++$+++ m1 +++$+++ PINZON +++$+++ We're on the verge of a mutiny, Colon!",
#  'L2199 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ We have to keep the hopes of these men alive!',
#  'L2198 +++$+++ u22 +++$+++ m1 +++$+++ PINZON +++$+++ You must be mad...!',
#  'L2197 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Six days ago, yes.',
#  "L2196 +++$+++ u22 +++$+++ m1 +++$+++ PINZON +++$+++ You lied!  You cheated!  We're way past 750 leagues!",
#  'L2065 +++$+++ u22 +++$+++ m1 +++$+++ PINZON +++$+++ Immediately.',
#  'L2064 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Where can I meet this man?',
#  'L2462 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ Because he is not afraid of me.',
#  'L2461 +++$+++ u24 +++$+++ m1 +++$+++ SANCHEZ +++$+++ Then why?',
#  'L2460 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ I know, I should not tolerate his impertinence.',
#  'L2419 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ And who would you think of, for such a task?',
#  'L2418 +++$+++ u24 +++$+++ m1 +++$+++ SANCHEZ +++$+++ He must be replaced.',
#  'L2417 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ Then, what do you suggest, Don Sanchez?',
#  'L2415 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ Is this true, Brother Buyl?',
#  'L2414 +++$+++ u24 +++$+++ m1 +++$+++ SANCHEZ +++$+++ ... But there is worse.  He ordered the execution of five members of the nobility...',
#  "L2377 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ We weren't expecting immediate profits, were we?  We must have faith.  We must give time for time.",
#  'L2376 +++$+++ u24 +++$+++ m1 +++$+++ SANCHEZ +++$+++ Every ship returns with a cargo of sick and dying.  But with no gold! The new world proves expensive, Your Majesty.',
#  "L2116 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ Yes.  It would be a pity, wouldn't it?  Call him back!",
#  'L2115 +++$+++ u24 +++$+++ m1 +++$+++ SANCHEZ +++$+++ ... Into a monk...',
#  'L2113 +++$+++ u24 +++$+++ m1 +++$+++ SANCHEZ +++$+++ Never, Your Majesty.  Although...',
#  'L2112 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ You were right, Don Sanchez... His demands could never be granted.',
#  'L1931 +++$+++ u24 +++$+++ m1 +++$+++ SANCHEZ +++$+++ Yes, Your Majesty.',
#  'L1930 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ Is that the man I knew, Treasurer Sanchez?',
#  "L3546 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Officers, there's your killer, do your duty, arrest him!",
#  'L3545 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ ...so we kill someone famous and if we are caught, we are sent to mental hospital...',
#  "L3497 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ I don't think it's abuse, I think it's torture.",
#  "L3496 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ I'm abused.  Don't you think?",
#  'L3493 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Can I see your back?',
#  'L3492 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Out on my back when I was a small boy.',
#  'L3491 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Your father put cigarettes out on you?',
#  "L3490 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ That's what he did to me.  He put cigarettes out on me.",
#  'L3489 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Yeah, he hated me from day when I was born.  Put it out.  Can you put the cigarette out?',
#  "L3488 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Your father blamed you for your mother's blindness?",
#  'L3487 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Yeah, yeah...bad doctor gave her bad drugs which made her go blind.  And my father blamed me for her blindness...',
#  'L3486 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Back in the Czech Republic?',
#  'L3485 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Yeah, she went blind giving birth to me. She went to fucking black market doctor to induce me.',
#  'L3484 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Your mother was blind?',
#  'L3483 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ My father always degraded me.  Killed my self-esteem.  And my mother was blind.',
#  'L3482 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Tell me about yourself.  What you did as a young boy... what your parents were like.',
#  'L3481 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Give me another one, please.',
#  "L3480 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ I need to know about your background.  I need to know about your upbringing.  Why you're here.",
#  'L3479 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ What else do you need?',
#  'L3478 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ This is not about money, Emil.  I need your trust in me.',
#  "L3477 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Thirty-percent.  No more.  Or I call another lawyer.  This is the biggest case of your life.  Don't try to negotiate.  Thirty percent.  Say yes or no.",
#  "L3476 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ But it's...",
#  'L3475 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ No.  No way.',
#  'L3474 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ I would say...half.  Half is fair.',
#  "L3473 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ What's your cut?  How much?",
#  "L3472 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Look, I haven't really focused on that kind of thing.",
#  'L3471 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ What about my movie rights?  Book rights?',
#  "L3470 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Don't worry about him.  Think about yourself.",
#  'L3469 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ No, he is here.  Shit...',
#  "L3468 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Disappeared.  They're looking everywhere.  Maybe he went back to Czechoslovakia.",
#  'L3467 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ What about Oleg?',
#  "L3466 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Well, you didn't appreciate the severity of it until recently.  No question about that.",
#  'L3465 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ I was all of these.',
#  'L3464 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ ...delusions and paranoia.',
#  'L3461 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Oh, sure.',
#  'L3460 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ You bring the cigarettes?',
#  "L3459 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ I brought you some letters.  It's really fan mail.  Women mostly.  One wants to buy you clothes, another sent a check. Another wants a check.",
#  "L3396 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ I'm invoking rights - this man is represented by counsel.  I'm coming with him.",
#  'L3395 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Yes.  Yes, come with me!',
#  "L3394 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ I'm coming with you.",
#  'L3393 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Where are we going?',
#  "L3392 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Don't say anything.",
#  'L3385 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ He has the camera!  He took the movie!',
#  'L3384 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Emil.  Take it easy.  Stay with me.  Sit down.  What do you need?  What are you looking for?',
#  'L3383 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Oh no!  No!  Shit!',
#  'L3382 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Here.  I have your money.',
#  "L3381 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ I'm not your lawyer until I see the money.",
#  "L3380 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Are you my attorney?  I'm Emil.  I'm insane.",
#  'L3517 +++$+++ u34 +++$+++ m2 +++$+++ JORDY +++$+++ Daphne, I...',
#  "L3516 +++$+++ u27 +++$+++ m2 +++$+++ DAPHNE +++$+++ I don't want to drag you down with me.",
#  'L3515 +++$+++ u34 +++$+++ m2 +++$+++ JORDY +++$+++ ...Do you really want me to forget about you?',
#  'L3514 +++$+++ u27 +++$+++ m2 +++$+++ DAPHNE +++$+++ Forget about me.  You have enough problems of your own.',
#  'L3330 +++$+++ u27 +++$+++ m2 +++$+++ DAPHNE +++$+++ Pouring it out!',
#  'L3329 +++$+++ u34 +++$+++ m2 +++$+++ JORDY +++$+++ What are you doing?',
#  "L3318 +++$+++ u27 +++$+++ m2 +++$+++ DAPHNE +++$+++ I'll get my clothes.",
#  "L3317 +++$+++ u34 +++$+++ m2 +++$+++ JORDY +++$+++ I'll make some for us.",
#  'L3316 +++$+++ u27 +++$+++ m2 +++$+++ DAPHNE +++$+++ In the kitchen.',
#  'L3315 +++$+++ u34 +++$+++ m2 +++$+++ JORDY +++$+++ Do you have coffee?',
#  ...]

# %%
#preparing the dataset

conversation_index=[] #nested list of conversation indexes
for conversation in conversations:
    conversation_index.append(conversation.split('+++$+++')[-1][2:-1].replace("'","").split(','))

# %%
dict_i2text={} #index to text dictionary
for line in lines[:-1]:   #-1 cause the last one is empty
    key=line.split('+++$+++')[0][1:-1]
    dict_i2text[int(key)]=line.split('+++$+++')[-1]

ord_list_i2text = list(OrderedDict(sorted(dict_i2text.items())).items())

# %%
long_threshold=6 #max input dim

# %%
cut_dataset=14*1000 #how many items
cut_offset=0*1000   #offset

ord_list_i2text = [x for x in ord_list_i2text if not len(x[1].split())>long_threshold][cut_offset:cut_dataset+cut_offset]

ord_list_i2text
# Out:
# [(49, ' Did you change your hair?'),
#  (50, ' No.'),
#  (51, ' You might wanna think about it'),
#  (59, ' I missed you.'),
#  (62, ' With the teeth of your zipper?'),
#  (63, ' You the new guy?'),
#  (64, ' So they tell me...'),
#  (66, ' So -- which Dakota you from?'),
#  (67, " North, actually.  How'd you   ?"),
#  (71, ' Thirty-two.'),
#  (72, ' Get out!'),
#  (73, ' How many people go here?'),
#  (74, ' Couple thousand. Most of them evil'),
#  (77, " That I'm used to."),
#  (87, ' That girl -- I --'),
#  (88, ' You burn, you pine, you perish?'),
#  (89, ' Who is she?'),
#  (91, ' Why not?'),
#  (108, ' Tempestuous?'),
#  (123, " Who's that?"),
#  (124, ' Patrick Verona   Random skid.'),
#  (127, ' He always look so'),
#  (128, ' Block E?'),
#  (130, ' Just a little.'),
#  (131, " What's this?"),
#  (132, ' An attempted slit.'),
#  (141, ' He always have that shit-eating grin?'),
#  (143, ' You know French?'),
#  (158, " That's her?  Bianca's sister?"),
#  (159, ' The mewling, rampalian wretch herself.'),
#  (161, ' In the microwave.'),
#  (162, ' Make anyone cry today?'),
#  (164, " Where've you been?"),
#  (165, ' Nowhere... Hi, Daddy.'),
#  (170, " What's a synonym for throbbing?"),
#  (172, ' I know.'),
#  (174, ' You decided.'),
#  (181, ' What if she never starts dating?'),
#  (185, ' Enough!'),
#  (189, " But she doesn't want to date."),
#  (190, ' Exactly my point'),
#  (192, ' Tumescent!'),
#  (193, " You're not helping."),
#  (199, ' Forget it.'),
#  (201, ' Cameron.'),
#  (204, ' Why?'),
#  (206, " That's a shame."),
#  (212, ' What about him?'),
#  (213, ' You wanna go out with him?'),
#  (222, " That's what I just said"),
#  (224, ' I thought you hated those people.'),
#  (231, ' Hey.'),
#  (232, ' Are you lost?'),
#  (234, " We don't chat."),
#  (236, " We're not."),
#  (239, ' Does this conversation have a purpose?'),
#  (244, ' You got him involved?'),
#  (250, " That's never been proven"),
#  (251, ' Neither has his heterosexuality.'),
#  (253, ' Does it matter?'),
#  (258, ' Touch of the flu.'),
#  (262, " What's to discuss?"),
#  (275, ' Forget French.'),
#  (280, ' There.'),
#  (281, ' Where?'),
#  (285, ' Yeah'),
#  (286, ' What do you think?'),
#  (287, ' Two legs, nice rack...'),
#  (290, ' You just said'),
#  (297, ' How much?'),
#  (299, ' Fine, thirty.'),
#  (301, " Fifty, and you've got your man."),
#  (304, " I mean Wo-man.  How ya doin'?"),
#  (307, ' My mission in life.'),
#  (309, ' Pick you up Friday, then'),
#  (310, ' Oh, right.  Friday.'),
#  (322, " You hate me don't you?"),
#  (325, ' And why would I do that?'),
#  (327, ' You -- covered in my vomit.'),
#  (328, ' Seven-thirty?'),
#  (330, ' Are you following me?'),
#  (332, ' Hi'),
#  (335, ' Hey -- do you mind?'),
#  (336, ' Not at all'),
#  (338, ' My insurance does not cover PMS'),
#  (341, ' I thought you were punishing me.'),
#  (342, " Why can't we agree on this?"),
#  (343, " Because you're making decisions for me."),
#  (344, " As a parent, that's my right"),
#  (345, " So what I want doesn't matter?"),
#  (350, " I'm on it"),
#  (354, ' I just upped my price'),
#  (355, ' What?'),
#  (356, ' A hundred bucks a date.'),
#  (357, ' Forget it.'),
#  (358, ' Forget her sister, then.'),
#  (363, ' You got something on your mind?'),
#  (366, " You're sweet."),
#  (371, ' Say it'),
#  (372, ' What?'),
#  (375, ' What plan?'),
#  (381, ' So Dorsey can get the girl?'),
#  (384, " We're your guys."),
#  (386, " Yeah -- we'll see."),
#  (390, ' Will Bogey get bent?'),
#  (394, " It's more"),
#  (395, ' Expensive?'),
#  (397, ' Hopefully.'),
#  (401, ' Sure have.'),
#  (404, " She's not a..."),
#  (411, " What've you got for me?"),
#  (414, ' What?!'),
#  (415, ' Good enough.'),
#  (416, ' Number one.  She hates smokers'),
#  (417, " It's a lung cancer issue"),
#  (418, ' Her favorite uncle'),
#  (419, ' Dead at forty-one.'),
#  (421, ' Just for now.'),
#  (424, " He's pretty!"),
#  (425, " Okay!  I wasn't sure"),
#  (428, ' Ever been to Club Skunk?'),
#  (429, ' Yeah.'),
#  (430, ' Gigglepuss is playing there tomorrow night.'),
#  (431, " Don't make me do it, man"),
#  (432, ' Assail your ears for one night.'),
#  (433, " It's her favorite band."),
#  (437, " I'm likin' you guys better"),
#  (444, ' What do you think?'),
#  (447, " You think this'll work?"),
#  (448, ' No fear.'),
#  (458, ' Always a pleasure, Brucie.'),
#  (461, ' Never'),
#  (463, " Just sent 'em through."),
#  (473, ' hey.  Great show, huh?'),
#  (474, ' '),
#  (475, ' Excuse me?'),
#  (476, " That's what you want, isn't it?"),
#  (482, ' You know who The Raincoats are?'),
#  (483, " Why, don't you?"),
#  (490, " What'd he say?"),
#  (491, ' Who cares?'),
#  (499, ' You told me that part already.'),
#  (502, " I hear you're helpin' Verona."),
#  (503, " Uh,  yeah.  We're old friend*"),
#  (504, ' You and Verona?'),
#  (511, " You're completely demented."),
#  (512, ' See you next week!'),
#  (517, ' Daddy, I --'),
#  (518, " And where're you going?"),
#  (520, ' Otherwise known as an orgy?'),
#  (526, " What's normal?"),
#  (536, " Oh, God.  It's starting."),
#  (537, " It's just a party. Daddy."),
#  (538, ' Wear the belly before you go.'),
#  (539, ' Daddy, no!'),
#  (540, ' Just for a minute'),
#  (542, ' You are so completely unbalanced.'),
#  (543, ' Can we go now?'),
#  (545, ' Why?'),
#  (546, " Because she'll scare them away."),
#  (554, ' Where ya goin?'),
#  (555, ' Away.'),
#  (556, ' Your sister here?'),
#  (557, ' Leave my sister alone.'),
#  (558, ' And why would I do that?'),
#  (564, " What's this?"),
#  (567, " Funny, you're the only one"),
#  (572, ' Who?'),
#  (573, ' Joey.'),
#  (575, ' Hi.'),
#  (577, ' You know Chastity?'),
#  (579, ' Great'),
#  (583, ' Extremely unfortunate maneuver.'),
#  (586, " No, I ' m not."),
#  (590, ' Queen Harry?'),
#  (592, ' Neat...'),
#  (596, ' Is he oily or dry?'),
#  (605, " It's about time."),
#  (606, " A deal's a deal."),
#  (607, " How'd you do it?"),
#  (608, ' Do what?'),
#  (610, ' Okay?'),
#  (611, " I'm fine. I'm"),
#  (612, " You're not okay."),
#  (615, ' I know, just let me sleep'),
#  (619, " Cameron, I'm a little busy"),
#  (620, " It's off. The whole thing."),
#  (621, " What 're you talking about?"),
#  (622, " She's partial to Joey, not me"),
#  (624, ' Sure'),
#  (625, ' Then, go get her'),
#  (626, ' This is so patronizing.'),
#  (628, " Why 're you doing this?"),
#  (629, ' I told you'),
#  (630, " You don't care if I die"),
#  (631, ' Sure, I do'),
#  (632, ' Why?'),
#  (634, ' Like you could find one'),
#  (636, ' Just let me sit down.'),
#  (640, ' Who?'),
#  (641, ' Dorsey.'),
#  (642, ' I hate him.'),
#  (646, ' You know what they say'),
#  (650, ' Kat! Wake up!'),
#  (651, ' What?'),
#  (656, " You're welcome."),
#  (662, ' Have fun tonight?'),
#  (663, ' Tons'),
#  (668, " And I'm in control of it."),
#  (671, ' Busy'),
#  (672, ' Were you in jail?'),
#  (673, ' Maybe.'),
#  (674, " No, you weren't"),
#  (675, " Then why'd you ask?"),
#  (676, " Why'd you lie?"),
#  (677, ' I should do this.'),
#  (678, ' Do what?'),
#  (679, ' This.'),
#  (680, ' Start a band?'),
#  (684, " I'm gettin' there"),
#  (688, ' Who?'),
#  (689, ' BIANCA'),
#  (694, ' I was?'),
#  (696, ' Well, no...'),
#  (698, ' But'),
#  (699, ' You always been this selfish?'),
#  (717, " I didn't have a choice."),
#  (720, " You didn't"),
#  (725, " What'd you do to her?"),
#  (728, ' Hey there.  Tired of breathing?'),
#  (729, ' Hi.'),
#  (730, ' Cool pictures.  You a fan?'),
#  (731, ' Yeah.  I guess.'),
#  (732, ' You think?'),
#  (733, ' Oh yeah.'),
#  (735, ' Macbeth, right?'),
#  (736, ' Right.'),
#  (737, ' Kat a fan, too?'),
#  (738, ' Yeah...'),
#  (743, " You makin' any headway?"),
#  (744, ' She kissed me.'),
#  (745, ' Where?'),
#  (756, ' Hey, sweet cheeks.'),
#  (757, ' Hi, Joey.'),
#  (765, ' What are you doing here?'),
#  (767, " You 're so --"),
#  (768, ' Pleasant?'),
#  (769, ' Wholesome.'),
#  (770, ' Unwelcome.'),
#  (774, ' Other than my upchuck reflex? Nothing.'),
#  (775, " You were right. She's still pissed."),
#  (776, ' Sweet love, renew thy force!'),
#  (780, " What's the worst?"),
#  (781, ' You get the girl.'),
#  (799, ' Look up, sunshine'),
#  (801, " C'mon.  It's not that bad"),
#  (803, ' Put your right foot there --'),
#  (804, " Forget it.  I'm stayin'."),
#  (806, ' Maybe.'),
#  (808, ' The Partridge Family?'),
#  (810, ' Good call.'),
#  (812, ' I dazzled him with my wit'),
#  (813, ' A soft side? Who knew?'),
#  (815, " So what's your excuse?"),
#  (816, ' Acting the way we do.'),
#  (817, ' Yes'),
#  (820, ' Something like that'),
#  (821, ' Then you screwed up'),
#  (822, ' How?'),
#  (823, ' You never disappointed me.'),
#  (824, ' You up for it?'),
#  (825, ' For. . . ?'),
#  (828, ' State trooper?'),
#  (829, ' Fallacy.'),
#  (830, ' The duck?'),
#  (831, ' Hearsay.'),
#  (834, ' Tell me something true.'),
#  (835, ' I hate peas.'),
#  (838, ' What?'),
#  (839, ' No one else knows'),
#  (841, ' Go to the prom with me'),
#  (843, ' You know what I mean'),
#  (844, ' No.'),
#  (845, ' No what?'),
#  (846, " No, I won't go with you"),
#  (847, ' Why not?'),
#  (854, ' You tell me.'),
#  (856, ' Answer the question, Patrick'),
#  (861, ' No...'),
#  (862, ' do you listen to this crap?'),
#  (863, ' What crap?'),
#  (867, ' What good stuff?'),
#  (868, ' The "real you".'),
#  (869, ' Like my fear of wearing pastels?'),
#  (871, ' No'),
#  (877, ' Pirate -- no question.'),
#  (879, ' The prom?  Kat has a date?'),
#  (880, ' No, but'),
#  (890, ' Like you care.'),
#  (894, ' What?'),
#  (895, ' In 9th.  For a month'),
#  (896, ' Why?'),
#  (897, ' He was, like, a total babe'),
#  (898, ' But you hate Joey'),
#  (900, ' As in...'),
#  (902, ' You did what?'),
#  (904, ' But'),
#  (906, " Why didn't you tell me?"),
#  (909, " That's not"),
#  (918, ' Dr. Ruth?'),
#  (922, " I'm missing something."),
#  (924, ' Wow'),
#  (925, " Let's go."),
#  (926, ' Have a great time, honey!'),
#  (927, ' But -- who -- what --?'),
#  (929, ' What just happened?'),
#  (930, ' Your daughters went to the prom.'),
#  (932, ' Absolutely not.'),
#  (933, " That ' s what I thought"),
#  (939, ' Oh huh'),
#  (946, ' Have you seen him?'),
#  (947, ' Who?'),
#  (953, ' I did.'),
#  (957, " My grandmother's ."),
#  (958, ' What?'),
#  (960, " That ' s completely adorable!"),
#  (973, ' Wait I...'),
#  (975, " It wasn't like that."),
#  (977, " I didn't care about the money."),
#  (983, ' So did you'),
#  (984, ' She okay?'),
#  (985, ' I hope so.'),
#  (986, ' Was that your sister?'),
#  (988, ' Funny.'),
#  (990, ' No, Daddy.'),
#  (992, ' Parts of it.'),
#  (993, ' Which parts?'),
#  (995, ' Bianca did what?'),
#  (997, ' No -- impressed.'),
#  (999, ' When I go?'),
#  (1007, ' Let go!'),
#  (1008, ' You set me up.'),
#  (1009, ' I just wanted --'),
#  (1011, ' No! I just wanted'),
#  (1018, ' Just smack her now.'),
#  (1022, " It's just you."),
#  (1031, ' A Fender Strat. You bought this?'),
#  (1034, ' Is that right?'),
#  (1041, ' Because I like to torture you.'),
#  (1044, ' They do to!'),
#  (1045, ' They do not!'),
#  (1051, ' Patrick -- is that- a.'),
#  (1052, ' Perm?'),
#  (1931, ' Yes, Your Majesty.'),
#  (1947, " God... That's in a week!"),
#  (1948, " That's what it says."),
#  (1949, ' How did you manage it?'),
#  (1959, ' How can you be so certain?'),
#  (1961, ' Esdras is a Jew.'),
#  (1962, ' So was Christ!'),
#  (1964, " I'll try to remember that, Marchena..."),
#  (1965, ' Father Marchena!'),
#  (1966, ' Passion is something one cannot control!'),
#  (1979, ' I could be gone for years.'),
#  (1980, ' I know.'),
#  (1983, ' Are we going to argue?'),
#  (1986, ' I find that hard to believe.'),
#  (1992, ' I am, Your Eminence'),
#  (2006, ' Excellency, you are right.'),
#  (2011, ' Your life, and that of others!'),
#  (2025, ' IF-GOD-WILLS-IT!'),
#  (2028, ' The Judgment is ours!'),
#  (2040, ' Damn God!'),
#  (2041, ' Colon!'),
#  (2045, ' All of them!  Just lies!'),
#  (2046, " Colon!  Don't!"),
#  (2064, ' Where can I meet this man?'),
#  (2065, ' Immediately.'),
#  (2073, ' The ocean is uncrossable?'),
#  (2075, ' That she was impregnable.'),
#  (2079, ' May I speak freely?'),
#  (2082, ' A woman?'),
#  (2085, ' How old are you, Senor Colon?'),
#  (2086, ' Thirty seven, Your Majesty... And you?'),
#  (2103, ' No...'),
#  (2104, ' No?'),
#  (2107, " I'm not bargaining!"),
#  (2108, ' Then you are too ambitious.'),
#  (2113, ' Never, Your Majesty.  Although...'),
#  (2115, ' ... Into a monk...'),
#  (2118, ' She said yes.'),
#  (2119, ' Thank God...'),
#  (2123, " That's something you can't decide."),
#  (2127, ' I want to go with you!'),
#  (2128, " There'll be a time."),
#  (2134, ' I am listening, my son.'),
#  (2136, ' What are you saying?'),
#  (2138, ' How long?'),
#  (2144, ' I believed in you...'),
#  (2145, ' Give me absolution.'),
#  (2155, ' God be with us admiral.'),
#  (2158, ' And what do you think Mendez?'),
#  (2160, ' Come over here.'),
#  (2164, ' What do you read?'),
#  (2165, ' Twenty eight.'),
#  (2176, " He's the devil's child..."),
#  (2177, " We'll all go crazy..."),
#  (2179, ' We should have seen land.'),
#  (2197, ' Six days ago, yes.'),
#  (2198, ' You must be mad...!'),
#  (2201, " You think I don't know that?"),
#  (2202, " We're lost!"),
#  (2208, ' You bloody...'),
#  (2210, ' You tell that to them!'),
#  (2211, " You're right.  Let the men decide."),
#  (2237, ' Say not here!  Cuba!'),
#  (2239, ' Island.  Far.'),
#  (2248, ' You come!  You speak first!'),
#  (2249, ' Tell the Chief we thank him.'),
#  (2250, ' Chief knows.'),
#  (2253, ' Chief says -- how many?'),
#  (2254, ' Thousands.'),
#  (2255, ' Why?'),
#  (2256, ' To bring the word of God.'),
#  (2258, ' ... and also to bring medicine.'),
#  (2259, ' Chief says...'),
#  (2279, ' Do they have such thoughts?'),
#  (2286, ' You defend yourself admirably...'),
#  (2287, ' ... for a commoner?'),
#  (2292, ' May I ask by whom?'),
#  (2293, ' Bartolome and Giacomo Colon.'),
#  (2319, " You don't usually ask."),
#  (2332, " We don't need to know."),
#  (2342, ' He understands.'),
#  (2343, ' Ask him if he will help.'),
#  (2346, " My horse doesn't work."),
#  (2387, ' Savagery is what monkeys understand.'),
#  (2389, ' You will regret this.'),
#  (2415, ' Is this true, Brother Buyl?'),
#  (2418, ' He must be replaced.'),
#  (2421, ' Don Alonso de Bobadilla.'),
#  (2422, ' Yes... I remember...'),
#  (2423, ' My letters of appointment.'),
#  (2424, ' Appointment to what?'),
#  (2425, ' Viceroy of the West Indies.'),
#  (2429, ' How far from here?'),
#  (2439, ' I have to explore the mainland.'),
#  (2440, ' This time with me!'),
#  (2457, ' Thank you.'),
#  (2461, ' Then why?'),
#  (2464, ' Call them.'),
#  (2466, ' Look out of that window.'),
#  (2467, ' What do you see?'),
#  (2468, ' Roofs... towers, palaces... spires...'),
#  (2473, ' They took everything...'),
#  (2484, ' How are you feeling, Fernando?'),
#  (2485, ' Not bad.'),
#  (2490, " What's he doing?"),
#  (2492, " We can't be."),
#  (2500, ' Father...'),
#  (2522, ' You can see for yourself.'),
#  (2531, ' I have to disagree.'),
#  (2532, ' I knew you would.'),
#  (2533, ' New worlds create new people.'),
#  (2538, ' I am busy inside.'),
#  (2539, ' What is it, now?  Tell me...'),
#  (2541, ' What are you listening to?'),
#  (2547, ' What does he say?'),
#  (2558, ' Okay.'),
#  (2559, " Don't fool around."),
#  (2560, ' Okay.'),
#  (2561, ' Did you hear what I said?'),
#  (2564, ' Yes sir.'),
#  (2566, ' Two weeks holiday.'),
#  (2568, ' I have five-hundred dollars.'),
#  (2571, ' Yes.'),
#  (2572, ' Please join us.  Come on forward.'),
#  (2573, ' Is there a problem?'),
#  (2575, " Yes...he's my friend."),
#  (2577, ' We are both from Prague.'),
#  (2579, ' Two weeks.'),
#  (2581, " He doesn't speak English."),
#  (2582, ' I speak English.'),
#  (2584, ' New York.'),
#  (2586, ' A cheap hotel.'),
#  (2588, " I'm here for movies."),
#  (2591, ' Excuse me?'),
#  (2596, ' Jesus Christ.'),
#  (2600, ' Vodka tonic.'),
#  (2604, " Sooner or later that's everybody."),
#  (2607, " I'm not moody."),
#  (2608, " Isn't he a little moody?"),
#  (2610, ' In love?  With who?'),
#  (2611, ' How old are your kids?'),
#  (2614, ' Yeah?'),
#  (2615, " Paulie, you've got kids, right?"),
#  (2622, ' I am butcher.'),
#  (2624, ' You stuff sausage in it.'),
#  (2626, ' Dog food.'),
#  (2627, ' Are you married?'),
#  (2628, ' No.  Are you proposing?'),
#  (2630, " I'm gonna propose."),
#  (2631, ' When?'),
#  (2632, ' Tomorrow.  At lunch.'),
#  (2633, ' You ready?'),
#  (2636, " Don't speak Russian!"),
#  (2640, ' We have no money.  Come on.'),
#  (2644, " So what's unique?"),
#  (2645, ' Not what.  Who.'),
#  (2647, " That's unique."),
#  (2653, ' Ready?'),
#  (2654, ' Keep them out of my way.'),
#  (2655, ' Okay.  You ready?'),
#  (2656, ' Yeah, yeah.  Jesus.'),
#  (2666, ' Turn that off!  Get the bags.'),
#  (2670, ' What?'),
#  (2671, ' Smell like chemicals...for smoking drugs.'),
#  (2672, ' Emil???!'),
#  (2673, ' Surprise!  Surprise!'),
#  (2675, ' Did you hurt her?'),
#  (2679, ' Milos.  Get my money!'),
#  (2680, ' We spent it!'),
#  (2681, ' Ha. Ha.'),
#  (2685, ' I can get you a job.'),
#  (2686, ' A job?'),
#  (2687, ' Yes, the money is good.'),
#  (2688, ' As a plumber?!'),
#  (2689, " It's easy to learn."),
#  (2691, ' We started over, you can too.'),
#  (2702, " Fire Department?  Firemen don't carry guns."),
#  (2703, ' Oh yeah?  Guess again.'),
#  (2720, ' Oh yeah, why?'),
#  (2732, ' No.  Go ahead.'),
#  (2733, ' Thanks.  Appreciate it.'),
#  (2735, " Mouth's clean, too."),
#  (2736, ' Clean?'),
#  (2737, " Don't blow your nose!"),
#  (2739, ' But you knew that, right?'),
#  (2744, ' What was that?'),
#  (2745, ' Evidence.  Of a homicide.'),
#  (2746, ' You know what that is, right?'),
#  (2747, ' No, what is it?'),
#  (2751, " What's he looking for?"),
#  (2752, ' A timer.'),
#  (2755, ' He knew all along.'),
#  (2756, ' What??'),
#  (2760, ' How many victims are up there?'),
#  (2764, ' Is it drug related?'),
#  (2767, ' What?'),
#  (2771, ' You okay?'),
#  (2778, ' Turn that fucking thing off!'),
#  (2780, ' Speak English!'),
#  (2781, ' You said speak Czech!'),
#  (2782, ' How you erase this?'),
#  (2789, ' Whore?'),
#  (2794, ' Yeah?'),
#  (2795, ' Maybe you can be his stand-in.'),
#  (2797, ' Who did cause and origin?'),
#  (2798, ' Who do you think, Chief?!'),
#  (2802, ' Yeah, right.'),
#  (2803, ' What was that, Korfin?'),
#  (2811, ' I used an accelerant.'),
#  (2812, ' Yeah?  What kind?'),
#  (2829, ' Your doctor?'),
#  (2838, " We're in negotiations, that's correct."),
#  (2842, ' Get in the bathroom!'),
#  (2845, " Hi, I'm Honey."),
#  (2846, " Where's Czech girl?"),
#  (2851, ' Where is escort service?'),
#  (2857, ' Give me the address!!'),
#  (2864, " How long they been livin' here?"),
#  (2865, ' You hear that question, Garcia?'),
#  (2871, " Aren't you tired?"),
#  (2876, ' Watch the news?'),
#  (2877, ' Nah, I musta missed it.'),
#  (2880, ' Nah, why should you?'),
#  (2881, " I don't even watch TV."),
#  (2882, ' Good.  Good.  Commendable.'),
#  (2888, ' Pretty.'),
#  (2889, ' Hmmmm.'),
#  (2891, " Who says she's a suspect?"),
#  (2892, ' What would you call her?'),
#  (2896, ' Eastern Europe.  Like what?  Romania? Hungary?'),
#  (2899, " I'll come with you."),
#  (2902, " This isn't homicide school."),
#  (2904, " You're Polish?"),
#  (2905, ' My folks are.'),
#  (2906, ' Stay here.'),
#  (2908, ' Who is he?'),
#  (2910, ' This all you want?'),
#  (2915, ' Yes.  Both.'),
#  (2920, ' Where is she?'),
#  (2921, " Takin' a bath."),
#  (2922, ' Any I.D.?'),
#  (2924, ' Sorry...PD only.'),
#  (2925, " It's okay."),
#  (2930, ' The clerk?'),
#  (2936, ' Only one guys checked in?'),
#  (2937, ' Yeah.'),
#  (2949, " You goin' to the escort service?"),
#  (2950, ' You got any better ideas?'),
#  (2955, " I'll let you know what happens."),
#  (2958, " I'll call it... tails."),
#  (2962, ' Two heads.'),
#  (2963, ' Better than one.'),
#  (2964, " Who's there?"),
#  (2971, " What's wrong?"),
#  (2973, " Oh my G-d.  Honey!  Honey's dead?"),
#  (2977, ' No.'),
#  (2978, ' Did you tell him you did?'),
#  (2980, ' What are you saying?'),
#  (2987, ' Describe him.'),
#  (2993, ' You thirsty?'),
#  (2994, " I'm on duty."),
#  (2996, ' Of course.'),
#  (3017, ' Stay with her.'),
#  (3022, ' Are you hit?'),
#  (3023, " No.  I'm okay."),
#  (3024, " Bobby, Bobby!  Where're you hit?!"),
#  (3025, ' It hurts.  Aw, Jesus!'),
#  (3026, ' Lay down.  Stay down, Bobby.'),
#  (3037, ' Alright, cut, cut, cut.'),
#  (3038, ' Eddie, are you okay?'),
#  (3039, " Yeah.  Now's not a good time."),
#  (3040, ' Alright.'),
#  (3041, ' Alright?'),
#  (3042, ' Alright.'),
#  (3043, ' Alright.'),
#  (3044, ' Okay.'),
#  (3048, ' Go on.'),
#  (3054, ' Is that all there is?'),
#  (3056, " No, no, don't talk to Immigration!"),
#  (3057, ' Why not?'),
#  (3058, ' Something back home?'),
#  (3060, " Alright.  That's a justifiable homicide."),
#  (3061, ' Yes, but he was a cop.'),
#  (3062, ' A cop?'),
#  (3068, ' Raw deal.'),
#  (3070, ' You wanna talk to her alone?'),
#  (3071, ' Yeah.'),
#  (3073, " I don't have a girlfriend."),
#  (3074, ' My point exactly.'),
#  (3075, " I'm serious here."),
#  (3076, ' So am I.'),
#  (3079, " You know what I'm saying here."),
#  (3081, " Hey.  I'm a professional."),
#  (3084, ' Shut up.'),
#  (3085, ' Does it hurt?'),
#  (3088, " Don't want to film this?"),
#  (3092, " They won't until this is over."),
#  (3093, ' Are you married?'),
#  (3094, ' Divorced.'),
#  (3097, ' Somewhere else?'),
#  (3101, ' Hey, honey.'),
#  (3102, ' Hey.'),
#  (3107, ' Stop it.'),
#  (3109, " Alright, alright, Eddie.  Don't patronize me."),
#  (3110, " I'm not."),
#  (3116, " You're ruthless."),
#  (3117, " You're not so bad yourself."),
#  (3120, " Could be Leon's."),
#  (3127, ' Answer the phone.'),
#  (3129, ' Answer it.'),
#  (3136, " That's good."),
#  (3137, ' Yeah.'),
#  (3138, " Well, that's great."),
#  (3143, ' Promise?'),
#  (3146, ' Patronizing you... Nay, I love you.'),
#  (3147, ' I love you.'),
#  (3148, ' Okay, til tonight.'),
#  (3149, ' Tonight.'),
#  (3150, ' You promise?'),
#  (3151, ' Yeah.  I promise.'),
#  (3153, ' Yeah, yeah.  Good thing.'),
#  (3154, ' Okay.'),
#  (3155, ' See you later.  Good luck.'),
#  (3156, ' Thank you.'),
#  (3157, " Don't be late."),
#  (3159, ' So...the station is empty?'),
#  (3160, ' Yeah.  This way.'),
#  (3161, ' You considered becoming a prostitute?'),
#  (3162, ' Yes, I considered it.'),
#  (3163, ' Did you ever turn tricks before?'),
#  (3164, ' No.'),
#  (3165, ' What about back home?'),
#  (3166, ' No.'),
#  (3168, ' So you were never a prostitute?'),
#  (3169, ' What are you asking me?'),
#  (3178, ' I know.'),
#  (3183, ' What is it?'),
#  (3185, ' I did.'),
#  (3187, ' Why not?'),
#  (3188, ' Put the camera down, Oleg.'),
#  (3189, ' What is that?'),
#  (3192, ' Sit down!'),
#  (3199, " What do you mean, 'cleaned up?'"),
#  (3200, ' I let her take a shower.'),
#  (3202, ' No!  Nothing happened.'),
#  (3208, ' Oh.'),
#  (3209, ' It was my decision, not his.'),
#  (3212, ' Oh yeah...?  Alright.'),
#  (3222, ' Just a shower?'),
#  (3236, " So...who's Nicky?"),
#  (3237, ' What do you want?'),
#  (3239, " What's your accomplishment."),
#  (3240, ' I kill someone famous.'),
#  (3241, ' Then do it, asshole.'),
#  (3247, ' Good idea!'),
#  (3251, ' Cut!'),
#  (3262, ' I know.'),
#  (3264, ' Well, he...'),
#  (3266, " I'm trying to tell you."),
#  (3267, ' Alright.  Go ahead.'),
#  (3271, ' Robert...?'),
#  (3272, ' What are you doing here?'),
#  (3273, " You've got a call."),
#  (3283, " What?  It doesn't work that way."),
#  (3285, ' Wait a minute.  Wait a minute.'),
#  (3287, ' How was it?'),
#  (3288, ' Not good.'),
#  (3289, ' Did the D.A. videotape her deposition?'),
#  (3290, ' Yeah.  He finished awhile ago.'),
#  (3292, ' Yeah.'),
#  (3294, ' Okay.  But not water sports.'),
#  (3300, ' Are you alright?'),
#  (3301, " I still can't believe Eddie's gone."),
#  (3302, " I'm sorry."),
#  (3305, ' Is he your boyfriend?'),
#  (3311, " I'm glad I met you."),
#  (3313, ' You better get packed.'),
#  (3314, ' Right.'),
#  (3315, ' Do you have coffee?'),
#  (3316, ' In the kitchen.'),
#  (3317, " I'll make some for us."),
#  (3318, " I'll get my clothes."),
#  (3329, ' What are you doing?'),
#  (3330, ' Pouring it out!'),
#  (3342, ' Get outta here!'),
#  (3343, ' What the hell happened?'),
#  (3352, ' Viewer discretion advised!'),
#  (3361, " I'm serious."),
#  (3362, ' Shut up.  Look!'),
#  (3366, ' Be quiet.  Watch.'),
#  (3373, ' Credit?'),
#  (3376, ' You got that?'),
#  (3377, " No, I don't get that!"),
#  (3382, ' Here.  I have your money.'),
#  (3383, ' Oh no!  No!  Shit!'),
#  (3392, " Don't say anything."),
#  (3393, ' Where are we going?'),
#  (3394, " I'm coming with you."),
#  (3395, ' Yes.  Yes, come with me!'),
#  (3398, " I'll take him."),
#  (3399, " No way!  He's mine!"),
#  (3400, " We're takin' him.  Don't argue!"),
#  (3401, " He's my collar!"),
#  (3402, ' Well, he killed my partner!'),
#  (3413, " Don't give me that fucking shit."),
#  (3421, ' Tommy, take a walk.'),
#  (3422, ' What are you gonna do?'),
#  (3424, " Don't stoop to his level!"),
#  (3432, " You'll be my first."),
#  (3434, ' Get down on your knees.'),
#  (3435, " Where's your partner?"),
#  (3460, ' You bring the cigarettes?'),
#  (3461, ' Oh, sure.'),
#  (3464, ' ...delusions and paranoia.'),
#  (3465, ' I was all of these.'),
#  (3467, ' What about Oleg?'),
#  (3469, ' No, he is here.  Shit...'),
#  (3473, " What's your cut?  How much?"),
#  (3474, ' I would say...half.  Half is fair.'),
#  (3475, ' No.  No way.'),
#  (3476, " But it's..."),
#  (3479, ' What else do you need?'),
#  (3481, ' Give me another one, please.'),
#  (3484, ' Your mother was blind?'),
#  (3486, ' Back in the Czech Republic?'),
#  (3493, ' Can I see your back?'),
#  (3496, " I'm abused.  Don't you think?"),
#  (3503, ' End my career?'),
#  (3505, ' But Chief?  Over this??'),
#  (3517, ' Daphne, I...'),
#  (3547, ' Traitor!!'),
#  (3555, ' Let her go!  Let her go!!'),
#  (3622, ' How do you do, Mr. Miller?'),
#  (3627, " Please, it really doesn't matter."),
#  (3629, ' Yes, very pleasant.'),
#  (3630, ' Well, shall we go through Documentation?'),
#  (3631, ' Fine.'),
#  (3653, " Yes, it's coming along very well."),
#  (3672, " I'm having a party tomorrow."),
#  (3673, ' Yes, I know that sweetheart.'),
#  (3674, ' Are you coming to my party?'),
#  (3676, ' When are you coming home?'),
#  (3677, ' In three days, darling, I hope.'),
#  (3680, " Mommy's out to the hair- dresser."),
#  (3681, ' Where is Mrs. Brown?'),
#  (3682, " She's in the bathroom."),
#  (3689, ' Thank you, Daddy.'),
#  (3691, ' Yes, Daddy.'),
#  (3692, " 'Bye, 'bye, now, sweetheart."),
#  (3693, ' Goodbye, Daddy.'),
#  (3712, ' SPACE STATTION 5 - LOUNGE'),
#  (3720, ' CONTINUED'),
#  (3725, ' Are you quite sure?'),
#  (3726, ' Yes, really, thank you very much.'),
#  (3728, ' CONTINUED'),
#  (3729, " She's wonderful."),
#  (3730, ' And your charming little daughter?'),
#  (3732, " Oh, that's such a delightful age."),
#  (3733, ' How is gregor?'),
#  (3747, ' Really?'),
#  (3749, ' CONTINUED'),
#  (3753, " That's right."),
#  (3754, ' I see.'),
#  (3756, ' CONTINUED'),
#  (3759, ' Well, that does sound very odd.'),
#  (3762, ' Fortunately, they did.'),
#  (3763, " Well, I'm glad about that."),
#  (3767, ' Certainly.'),
#  (3770, ' CONTINUED'),
#  (3777, ' CONTINUED'),
#  (3797, ' Oh, thank you very much.'),
#  (3798, ' Thank you.'),
#  (3799, " Well, how's it going back there?"),
#  (3810, " I'll bet it's a fortune."),
#  (3819, ' When do we arrive at Clavius?'),
#  (3824, ' Thank you.'),
#  (3826, ' What do you mean?'),
#  (3828, ' I see.'),
#  (3904, ' Any ideas about the colour?'),
#  (3942, ' Hi. Frank... coming in, please.'),
#  (3943, ' Right. Just a sec.'),
#  (3944, ' Okay. '),
#  (3945, ' Okay, come on down.'),
#  (3964, ' Sure, what is it?'),
#  (3966, " What's up?"),
#  (3967, " It's about my salary cheques."),
#  (3968, ' Yes?'),
#  (3970, ' CONTINUED'),
#  (3974, ' Really.'),
#  (3975, ' Yes.'),
#  (3977, ' CONTINUED'),
#  (3980, " It's possible."),
#  (3984, ' No. I never did, either.'),
#  (3989, ' Oh?'),
#  (3993, ' CONTINUED'),
#  (3994, ' Well, what is it?'),
#  (3996, ' That seems very unlikely.'),
#  (3997, ' Yes, I thought so.'),
#  (3999, ' How?'),
#  (4001, " That's true."),
#  (4002, ' CONINUED'),
#  (4007, " He's got a point."),
#  (4009, ' CONTINUED'),
#  (4014, ' But not completely inconceivable?'),
#  (4015, " I suppose it isn't logically impossible."),
#  (4016, " I guess it isn't."),
#  (4018, ' CONTINUED'),
#  (4021, ' I will if I can, Frank.'),
#  (4023, ' True.'),
#  (4025, " That's true."),
#  (4028, " That's true."),
#  (4030, " That's true"),
#  (4032, " That's true."),
#  (4033, ' Thank you very much, Hal.'),
#  (4069, ' What is it, Hal?'),
#  (4097, ' Roger.'),
#  (4108, ' Five by five, Frank.'),
#  (4110, ' I understand.'),
#  (4111, ' Hal, maintain normal E.V.A. condition.'),
#  (4112, ' Roger.'),
#  (4113, ' Hal, check all airlock doors secure.'),
#  (4119, ' Opening pod bay doors.'),
#  (4159, " Well, that's something."),
#  (4169, " Yes, Hal, what's up?"),
#  (4188, " Good morning. How's it going?"),
#  (4189, ' Are you reasonably awake?'),
#  (4192, " You're kidding."),
#  (4193, ' No.'),
#  (4198, ' Two more.'),
#  (4208, ' Hal?'),
#  (4209, ' Yes.'),
#  (4220, " Sure, Dave, what's up?"),
#  (4222, ' Yes, I know.'),
#  (4266, " I'm sorry about the misunderstanding, Hal."),
#  (4267, " Well, don't worry about it."),
#  (4268, " And don't you worry about it."),
#  (4270, ' Yes, it is, Hal.'),
#  (4282, " It's the last one."),
#  (4298, ' I guess not.'),
#  (4300, ' Roger.'),
#  (4333, " Too bad about Frank, isn't it?"),
#  (4334, ' Yes, it is.'),
#  (4347, ' The antenna has to be replaced.'),
#  (4356, ' Hal, switch to manual hibernation control.'),
#  (4467, ' What am I wanted for?'),
#  (4469, " I don't think your gun's loaded..."),
#  (4471, " I still don't think it's loaded."),
#  (4472, " Hey, you're right."),
#  (4473, " You're hopeless."),
#  (4475, " I'm all wet."),
#  (4476, " What's wrong with that?"),
#  (4478, " What'd you do?"),
#  (4480, ' I guess he got the message...'),
#  (4487, " Tell me--I'm dyin' to hear it."),
#  (4493, ' How hot are they?'),
#  (4495, " How ya doin'?"),
#  (4496, " Can't complain."),
#  (4498, ' Yeah, old times.'),
#  (4499, " We'll follow you.  Take it slow,okay?"),
#  (4500, ' Sure, right.'),
#  (4501, ' I want to drive awhile.'),
#  (4502, " I ain't tired yet."),
#  (4504, ' Whaddya mean, buy?'),
#  (4505, ' Pros.'),
#  (4506, ' Pay money?'),
#  (4507, ' Yeah, dummy.  Money.'),
#  (4521, ' Maybe that makes a nice excuse.'),
#  (4530, ' Call me later.'),
#  (4531, ' You sure you want me to?'),
#  (4532, " Yeah, for some reason, I'm sure..."),
#  (4533, ' Thanks for the coffee.'),
#  (4543, ' Surprise, Luther.'),
#  (4550, ' Billy, go ahead, break it...'),
#  (4552, ' When?'),
#  (4554, ' You chickenshit punk...'),
#  (4567, ' Hey, what about me?'),
#  (4600, ' Hey...'),
#  (4601, ' Shut up.'),
#  (4604, ' Shut up.'),
#  (4609, ' Stall.'),
#  (4610, ' What do you want?'),
#  (4612, " Keep stallin'."),
#  (4613, " Alright, I'm coming...hold on."),
#  (4628, ' You lying son of a bitch...'),
#  (4636, " That's what you say, Cates..."),
#  (4637, ' Yeah.'),
#  (4639, " The truth hurts, doesn't it, buddy?"),
#  (4671, " I'll help you out."),
#  (4673, ' Shit.'),
#  (4675, ' Billy Bear...'),
#  (4677, ' Who are all these?'),
#  (4682, ' Hey ... Dick Tracy.'),
#  (4687, " One of  em's in the slam."),
#  (4690, ' Yeah, I read the report...'),
#  (4693, ' Yeah...'),
#  (4700, ' Jack?'),
#  (4701, ' Yeah?'),
#  (4703, " I'll keep it in mind."),
#  (4704, ' Great place for lunch.'),
#  (4705, ' Yeah, one of my favorites.'),
#  (4706, ' You made the front page.'),
#  (4708, ' Jack, are you okay?'),
#  (4727, ' You got a name, cop?'),
#  (4729, ' Sure, anything you want.'),
#  (4739, ' Yeah, I noticed...'),
#  (4743, ' Yeah?'),
#  (4745, " You're crazy."),
#  (4748, ' I got a lot to protect.'),
#  (4749, ' Bullshit.'),
#  (4751, " I'll think about it."),
#  (4763, ' This prison gives out $400 suits?'),
#  (4773, ' No way to start a partnership.'),
#  (4775, " Shit.  I'm already sorry."),
#  (4778, ' Yeah.'),
#  (4782, ' Luther was part of the gang?'),
#  (4783, " What gang you talkin' about, Jack?"),
#  (4792, " I'm helpin' you, huh?"),
#  (4803, ' Just throw me the Goddamn gun.'),
#  (4809, ' A cop...'),
#  (4814, ' Hey, this works pretty good.'),
#  (4815, ' Thank you.'),
#  (4816, ' Want to try it again?'),
#  (4819, " I don't know."),
#  (4822, ' When? How?'),
#  (4825, ' What do you think?'),
#  (4863, " Now, where we goin', convict?"),
#  (4866, " I don't give out the details."),
#  (4867, ' Last night, two nights ago, three?'),
#  (4868, ' Last night.'),
#  (4869, ' You have a good time?'),
#  (4873, ' Well?'),
#  (4882, ' Hey, you wanna bet?'),
#  (4888, " What are you talkin' about?"),
#  (4891, " The bet's off."),
#  (4897, ' Yeah.'),
#  (4898, ' Vodka.'),
#  (4903, " Now how's your memory doin'?"),
#  (4929, ' You made that move, huh?'),
#  (4937, ' There.'),
#  (4938, " Must be billy's girl."),
#  (4939, ' Come on.'),
#  (4959, ' How about it?'),
#  (4964, " Let's go."),
#  (4996, ' They saved your ass, convict.'),
#  (5003, ' How much?'),
#  (5004, ' Half a million.'),
#  (5005, ' Jesus.'),
#  ...]

# %%
len(ord_list_i2text)
# Out:
# 14000

# %%
question=[] #defining question and answer lists
answer=[]

# %%
#uploading q&a first dataset
for i in range(len(ord_list_i2text)-1):
    if ord_list_i2text[i][0]-ord_list_i2text[i+1][0]!=1:
        question.append(ord_list_i2text[i][1])
        answer.append(ord_list_i2text[i+1][1])

# %%
#uploading q&a second dataset
dataset2=[df['Q'],df['ANS']]

for j in range(len(dataset2[0])):
    if not (len(dataset2[0][j].split())>long_threshold or (len(dataset2[1][j].split())>long_threshold)):
        question.append(dataset2[0][j])
        answer.append(dataset2[1][j])

# %% [markdown]
# ## Prepocessing dataset
#
# - Set to lower case
# - Remove contract form
# - Remove punctuation
# - add sos and eos tokens to answers

# %%
contractions_dict = {
"im": "i am",
"dont": "do not",
"doesnt": "does not",
"theres": "there is",
"ain't": "am not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he'll've": "he will have",
"he's": "he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how is",
"i'd": "I would",
"i'd've": "I would have",
"i'll": "I will",
"i'll've": "I will have",
"i'm": "I am",
"i've": "I have",
"isn't": "is not",
"it'd": "it would",
"it'd've": "it would have",
"it'll": "it will",
"it'll've": "it will have",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she would",
"she'd've": "she would have",
"she'll": "she will",
"she'll've": "she will have",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so is",
"that'd": "that had",
"that'd've": "that would have",
"that's": "that is",
"there'd": "there would",
"there'd've": "there would have",
"there's": "there is",
"they'd": "they would",
"they'd've": "they would have",
"they'll": "they will",
"they'll've": "they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we would",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what'll've": "what will have",
"what're": "what are",
"what's": " what is",
"what've": "what have",
"when's": "when is",
"when've": "when have",
"where'd": "where did",
"where's": "where is",
"where've": "where have",
"who'll": "who will",
"who'll've": "who will have",
"who's": "who is",
"who've": "who have",
"why's": "why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you would",
"you'd've": "you would have",
"you'll": "you will",
"you'll've": "you will have",
"you're": "you are",
"you've": "you have"
}

# %%
question
# Out:
# [' Did you change your hair?',
#  ' No.',
#  ' You might wanna think about it',
#  ' I missed you.',
#  ' With the teeth of your zipper?',
#  ' You the new guy?',
#  ' So they tell me...',
#  ' So -- which Dakota you from?',
#  " North, actually.  How'd you   ?",
#  ' Thirty-two.',
#  ' Get out!',
#  ' How many people go here?',
#  ' Couple thousand. Most of them evil',
#  " That I'm used to.",
#  ' That girl -- I --',
#  ' You burn, you pine, you perish?',
#  ' Who is she?',
#  ' Why not?',
#  ' Tempestuous?',
#  " Who's that?",
#  ' Patrick Verona   Random skid.',
#  ' He always look so',
#  ' Block E?',
#  ' Just a little.',
#  " What's this?",
#  ' An attempted slit.',
#  ' He always have that shit-eating grin?',
#  ' You know French?',
#  " That's her?  Bianca's sister?",
#  ' The mewling, rampalian wretch herself.',
#  ' In the microwave.',
#  ' Make anyone cry today?',
#  " Where've you been?",
#  ' Nowhere... Hi, Daddy.',
#  " What's a synonym for throbbing?",
#  ' I know.',
#  ' You decided.',
#  ' What if she never starts dating?',
#  ' Enough!',
#  " But she doesn't want to date.",
#  ' Exactly my point',
#  ' Tumescent!',
#  " You're not helping.",
#  ' Forget it.',
#  ' Cameron.',
#  ' Why?',
#  " That's a shame.",
#  ' What about him?',
#  ' You wanna go out with him?',
#  " That's what I just said",
#  ' I thought you hated those people.',
#  ' Hey.',
#  ' Are you lost?',
#  " We don't chat.",
#  " We're not.",
#  ' Does this conversation have a purpose?',
#  ' You got him involved?',
#  " That's never been proven",
#  ' Neither has his heterosexuality.',
#  ' Does it matter?',
#  ' Touch of the flu.',
#  " What's to discuss?",
#  ' Forget French.',
#  ' There.',
#  ' Where?',
#  ' Yeah',
#  ' What do you think?',
#  ' Two legs, nice rack...',
#  ' You just said',
#  ' How much?',
#  ' Fine, thirty.',
#  " Fifty, and you've got your man.",
#  " I mean Wo-man.  How ya doin'?",
#  ' My mission in life.',
#  ' Pick you up Friday, then',
#  ' Oh, right.  Friday.',
#  " You hate me don't you?",
#  ' And why would I do that?',
#  ' You -- covered in my vomit.',
#  ' Seven-thirty?',
#  ' Are you following me?',
#  ' Hi',
#  ' Hey -- do you mind?',
#  ' Not at all',
#  ' My insurance does not cover PMS',
#  ' I thought you were punishing me.',
#  " Why can't we agree on this?",
#  " Because you're making decisions for me.",
#  " As a parent, that's my right",
#  " So what I want doesn't matter?",
#  " I'm on it",
#  ' I just upped my price',
#  ' What?',
#  ' A hundred bucks a date.',
#  ' Forget it.',
#  ' Forget her sister, then.',
#  ' You got something on your mind?',
#  " You're sweet.",
#  ' Say it',
#  ' What?',
#  ' What plan?',
#  ' So Dorsey can get the girl?',
#  " We're your guys.",
#  " Yeah -- we'll see.",
#  ' Will Bogey get bent?',
#  " It's more",
#  ' Expensive?',
#  ' Hopefully.',
#  ' Sure have.',
#  " She's not a...",
#  " What've you got for me?",
#  ' What?!',
#  ' Good enough.',
#  ' Number one.  She hates smokers',
#  " It's a lung cancer issue",
#  ' Her favorite uncle',
#  ' Dead at forty-one.',
#  ' Just for now.',
#  " He's pretty!",
#  " Okay!  I wasn't sure",
#  ' Ever been to Club Skunk?',
#  ' Yeah.',
#  ' Gigglepuss is playing there tomorrow night.',
#  " Don't make me do it, man",
#  ' Assail your ears for one night.',
#  " It's her favorite band.",
#  " I'm likin' you guys better",
#  ' What do you think?',
#  " You think this'll work?",
#  ' No fear.',
#  ' Always a pleasure, Brucie.',
#  ' Never',
#  " Just sent 'em through.",
#  ' hey.  Great show, huh?',
#  ' ',
#  ' Excuse me?',
#  " That's what you want, isn't it?",
#  ' You know who The Raincoats are?',
#  " Why, don't you?",
#  " What'd he say?",
#  ' Who cares?',
#  ' You told me that part already.',
#  " I hear you're helpin' Verona.",
#  " Uh,  yeah.  We're old friend*",
#  ' You and Verona?',
#  " You're completely demented.",
#  ' See you next week!',
#  ' Daddy, I --',
#  " And where're you going?",
#  ' Otherwise known as an orgy?',
#  " What's normal?",
#  " Oh, God.  It's starting.",
#  " It's just a party. Daddy.",
#  ' Wear the belly before you go.',
#  ' Daddy, no!',
#  ' Just for a minute',
#  ' You are so completely unbalanced.',
#  ' Can we go now?',
#  ' Why?',
#  " Because she'll scare them away.",
#  ' Where ya goin?',
#  ' Away.',
#  ' Your sister here?',
#  ' Leave my sister alone.',
#  ' And why would I do that?',
#  " What's this?",
#  " Funny, you're the only one",
#  ' Who?',
#  ' Joey.',
#  ' Hi.',
#  ' You know Chastity?',
#  ' Great',
#  ' Extremely unfortunate maneuver.',
#  " No, I ' m not.",
#  ' Queen Harry?',
#  ' Neat...',
#  ' Is he oily or dry?',
#  " It's about time.",
#  " A deal's a deal.",
#  " How'd you do it?",
#  ' Do what?',
#  ' Okay?',
#  " I'm fine. I'm",
#  " You're not okay.",
#  ' I know, just let me sleep',
#  " Cameron, I'm a little busy",
#  " It's off. The whole thing.",
#  " What 're you talking about?",
#  " She's partial to Joey, not me",
#  ' Sure',
#  ' Then, go get her',
#  ' This is so patronizing.',
#  " Why 're you doing this?",
#  ' I told you',
#  " You don't care if I die",
#  ' Sure, I do',
#  ' Why?',
#  ' Like you could find one',
#  ' Just let me sit down.',
#  ' Who?',
#  ' Dorsey.',
#  ' I hate him.',
#  ' You know what they say',
#  ' Kat! Wake up!',
#  ' What?',
#  " You're welcome.",
#  ' Have fun tonight?',
#  ' Tons',
#  " And I'm in control of it.",
#  ' Busy',
#  ' Were you in jail?',
#  ' Maybe.',
#  " No, you weren't",
#  " Then why'd you ask?",
#  " Why'd you lie?",
#  ' I should do this.',
#  ' Do what?',
#  ' This.',
#  ' Start a band?',
#  " I'm gettin' there",
#  ' Who?',
#  ' BIANCA',
#  ' I was?',
#  ' Well, no...',
#  ' But',
#  ' You always been this selfish?',
#  " I didn't have a choice.",
#  " You didn't",
#  " What'd you do to her?",
#  ' Hey there.  Tired of breathing?',
#  ' Hi.',
#  ' Cool pictures.  You a fan?',
#  ' Yeah.  I guess.',
#  ' You think?',
#  ' Oh yeah.',
#  ' Macbeth, right?',
#  ' Right.',
#  ' Kat a fan, too?',
#  ' Yeah...',
#  " You makin' any headway?",
#  ' She kissed me.',
#  ' Where?',
#  ' Hey, sweet cheeks.',
#  ' Hi, Joey.',
#  ' What are you doing here?',
#  " You 're so --",
#  ' Pleasant?',
#  ' Wholesome.',
#  ' Unwelcome.',
#  ' Other than my upchuck reflex? Nothing.',
#  " You were right. She's still pissed.",
#  ' Sweet love, renew thy force!',
#  " What's the worst?",
#  ' You get the girl.',
#  ' Look up, sunshine',
#  " C'mon.  It's not that bad",
#  ' Put your right foot there --',
#  " Forget it.  I'm stayin'.",
#  ' Maybe.',
#  ' The Partridge Family?',
#  ' Good call.',
#  ' I dazzled him with my wit',
#  ' A soft side? Who knew?',
#  " So what's your excuse?",
#  ' Acting the way we do.',
#  ' Yes',
#  ' Something like that',
#  ' Then you screwed up',
#  ' How?',
#  ' You never disappointed me.',
#  ' You up for it?',
#  ' For. . . ?',
#  ' State trooper?',
#  ' Fallacy.',
#  ' The duck?',
#  ' Hearsay.',
#  ' Tell me something true.',
#  ' I hate peas.',
#  ' What?',
#  ' No one else knows',
#  ' Go to the prom with me',
#  ' You know what I mean',
#  ' No.',
#  ' No what?',
#  " No, I won't go with you",
#  ' Why not?',
#  ' You tell me.',
#  ' Answer the question, Patrick',
#  ' No...',
#  ' do you listen to this crap?',
#  ' What crap?',
#  ' What good stuff?',
#  ' The "real you".',
#  ' Like my fear of wearing pastels?',
#  ' No',
#  ' Pirate -- no question.',
#  ' The prom?  Kat has a date?',
#  ' No, but',
#  ' Like you care.',
#  ' What?',
#  ' In 9th.  For a month',
#  ' Why?',
#  ' He was, like, a total babe',
#  ' But you hate Joey',
#  ' As in...',
#  ' You did what?',
#  ' But',
#  " Why didn't you tell me?",
#  " That's not",
#  ' Dr. Ruth?',
#  " I'm missing something.",
#  ' Wow',
#  " Let's go.",
#  ' Have a great time, honey!',
#  ' But -- who -- what --?',
#  ' What just happened?',
#  ' Your daughters went to the prom.',
#  ' Absolutely not.',
#  " That ' s what I thought",
#  ' Oh huh',
#  ' Have you seen him?',
#  ' Who?',
#  ' I did.',
#  " My grandmother's .",
#  ' What?',
#  " That ' s completely adorable!",
#  ' Wait I...',
#  " It wasn't like that.",
#  " I didn't care about the money.",
#  ' So did you',
#  ' She okay?',
#  ' I hope so.',
#  ' Was that your sister?',
#  ' Funny.',
#  ' No, Daddy.',
#  ' Parts of it.',
#  ' Which parts?',
#  ' Bianca did what?',
#  ' No -- impressed.',
#  ' When I go?',
#  ' Let go!',
#  ' You set me up.',
#  ' I just wanted --',
#  ' No! I just wanted',
#  ' Just smack her now.',
#  " It's just you.",
#  ' A Fender Strat. You bought this?',
#  ' Is that right?',
#  ' Because I like to torture you.',
#  ' They do to!',
#  ' They do not!',
#  ' Patrick -- is that- a.',
#  ' Perm?',
#  ' Yes, Your Majesty.',
#  " God... That's in a week!",
#  " That's what it says.",
#  ' How did you manage it?',
#  ' How can you be so certain?',
#  ' Esdras is a Jew.',
#  ' So was Christ!',
#  " I'll try to remember that, Marchena...",
#  ' Father Marchena!',
#  ' Passion is something one cannot control!',
#  ' I could be gone for years.',
#  ' I know.',
#  ' Are we going to argue?',
#  ' I find that hard to believe.',
#  ' I am, Your Eminence',
#  ' Excellency, you are right.',
#  ' Your life, and that of others!',
#  ' IF-GOD-WILLS-IT!',
#  ' The Judgment is ours!',
#  ' Damn God!',
#  ' Colon!',
#  ' All of them!  Just lies!',
#  " Colon!  Don't!",
#  ' Where can I meet this man?',
#  ' Immediately.',
#  ' The ocean is uncrossable?',
#  ' That she was impregnable.',
#  ' May I speak freely?',
#  ' A woman?',
#  ' How old are you, Senor Colon?',
#  ' Thirty seven, Your Majesty... And you?',
#  ' No...',
#  ' No?',
#  " I'm not bargaining!",
#  ' Then you are too ambitious.',
#  ' Never, Your Majesty.  Although...',
#  ' ... Into a monk...',
#  ' She said yes.',
#  ' Thank God...',
#  " That's something you can't decide.",
#  ' I want to go with you!',
#  " There'll be a time.",
#  ' I am listening, my son.',
#  ' What are you saying?',
#  ' How long?',
#  ' I believed in you...',
#  ' Give me absolution.',
#  ' God be with us admiral.',
#  ' And what do you think Mendez?',
#  ' Come over here.',
#  ' What do you read?',
#  ' Twenty eight.',
#  " He's the devil's child...",
#  " We'll all go crazy...",
#  ' We should have seen land.',
#  ' Six days ago, yes.',
#  ' You must be mad...!',
#  " You think I don't know that?",
#  " We're lost!",
#  ' You bloody...',
#  ' You tell that to them!',
#  " You're right.  Let the men decide.",
#  ' Say not here!  Cuba!',
#  ' Island.  Far.',
#  ' You come!  You speak first!',
#  ' Tell the Chief we thank him.',
#  ' Chief knows.',
#  ' Chief says -- how many?',
#  ' Thousands.',
#  ' Why?',
#  ' To bring the word of God.',
#  ' ... and also to bring medicine.',
#  ' Chief says...',
#  ' Do they have such thoughts?',
#  ' You defend yourself admirably...',
#  ' ... for a commoner?',
#  ' May I ask by whom?',
#  ' Bartolome and Giacomo Colon.',
#  " You don't usually ask.",
#  " We don't need to know.",
#  ' He understands.',
#  ' Ask him if he will help.',
#  " My horse doesn't work.",
#  ' Savagery is what monkeys understand.',
#  ' You will regret this.',
#  ' Is this true, Brother Buyl?',
#  ' He must be replaced.',
#  ' Don Alonso de Bobadilla.',
#  ' Yes... I remember...',
#  ' My letters of appointment.',
#  ' Appointment to what?',
#  ' Viceroy of the West Indies.',
#  ' How far from here?',
#  ' I have to explore the mainland.',
#  ' This time with me!',
#  ' Thank you.',
#  ' Then why?',
#  ' Call them.',
#  ' Look out of that window.',
#  ' What do you see?',
#  ' Roofs... towers, palaces... spires...',
#  ' They took everything...',
#  ' How are you feeling, Fernando?',
#  ' Not bad.',
#  " What's he doing?",
#  " We can't be.",
#  ' Father...',
#  ' You can see for yourself.',
#  ' I have to disagree.',
#  ' I knew you would.',
#  ' New worlds create new people.',
#  ' I am busy inside.',
#  ' What is it, now?  Tell me...',
#  ' What are you listening to?',
#  ' What does he say?',
#  ' Okay.',
#  " Don't fool around.",
#  ' Okay.',
#  ' Did you hear what I said?',
#  ' Yes sir.',
#  ' Two weeks holiday.',
#  ' I have five-hundred dollars.',
#  ' Yes.',
#  ' Please join us.  Come on forward.',
#  ' Is there a problem?',
#  " Yes...he's my friend.",
#  ' We are both from Prague.',
#  ' Two weeks.',
#  " He doesn't speak English.",
#  ' I speak English.',
#  ' New York.',
#  ' A cheap hotel.',
#  " I'm here for movies.",
#  ' Excuse me?',
#  ' Jesus Christ.',
#  ' Vodka tonic.',
#  " Sooner or later that's everybody.",
#  " I'm not moody.",
#  " Isn't he a little moody?",
#  ' In love?  With who?',
#  ' How old are your kids?',
#  ' Yeah?',
#  " Paulie, you've got kids, right?",
#  ' I am butcher.',
#  ' You stuff sausage in it.',
#  ' Dog food.',
#  ' Are you married?',
#  ' No.  Are you proposing?',
#  " I'm gonna propose.",
#  ' When?',
#  ' Tomorrow.  At lunch.',
#  ' You ready?',
#  " Don't speak Russian!",
#  ' We have no money.  Come on.',
#  " So what's unique?",
#  ' Not what.  Who.',
#  " That's unique.",
#  ' Ready?',
#  ' Keep them out of my way.',
#  ' Okay.  You ready?',
#  ' Yeah, yeah.  Jesus.',
#  ' Turn that off!  Get the bags.',
#  ' What?',
#  ' Smell like chemicals...for smoking drugs.',
#  ' Emil???!',
#  ' Surprise!  Surprise!',
#  ' Did you hurt her?',
#  ' Milos.  Get my money!',
#  ' We spent it!',
#  ' Ha. Ha.',
#  ' I can get you a job.',
#  ' A job?',
#  ' Yes, the money is good.',
#  ' As a plumber?!',
#  " It's easy to learn.",
#  ' We started over, you can too.',
#  " Fire Department?  Firemen don't carry guns.",
#  ' Oh yeah?  Guess again.',
#  ' Oh yeah, why?',
#  ' No.  Go ahead.',
#  ' Thanks.  Appreciate it.',
#  " Mouth's clean, too.",
#  ' Clean?',
#  " Don't blow your nose!",
#  ' But you knew that, right?',
#  ' What was that?',
#  ' Evidence.  Of a homicide.',
#  ' You know what that is, right?',
#  ' No, what is it?',
#  " What's he looking for?",
#  ' A timer.',
#  ' He knew all along.',
#  ' What??',
#  ' How many victims are up there?',
#  ' Is it drug related?',
#  ' What?',
#  ' You okay?',
#  ' Turn that fucking thing off!',
#  ' Speak English!',
#  ' You said speak Czech!',
#  ' How you erase this?',
#  ' Whore?',
#  ' Yeah?',
#  ' Maybe you can be his stand-in.',
#  ' Who did cause and origin?',
#  ' Who do you think, Chief?!',
#  ' Yeah, right.',
#  ' What was that, Korfin?',
#  ' I used an accelerant.',
#  ' Yeah?  What kind?',
#  ' Your doctor?',
#  " We're in negotiations, that's correct.",
#  ' Get in the bathroom!',
#  " Hi, I'm Honey.",
#  " Where's Czech girl?",
#  ' Where is escort service?',
#  ' Give me the address!!',
#  " How long they been livin' here?",
#  ' You hear that question, Garcia?',
#  " Aren't you tired?",
#  ' Watch the news?',
#  ' Nah, I musta missed it.',
#  ' Nah, why should you?',
#  " I don't even watch TV.",
#  ' Good.  Good.  Commendable.',
#  ' Pretty.',
#  ' Hmmmm.',
#  " Who says she's a suspect?",
#  ' What would you call her?',
#  ' Eastern Europe.  Like what?  Romania? Hungary?',
#  " I'll come with you.",
#  " This isn't homicide school.",
#  " You're Polish?",
#  ' My folks are.',
#  ' Stay here.',
#  ' Who is he?',
#  ' This all you want?',
#  ' Yes.  Both.',
#  ' Where is she?',
#  " Takin' a bath.",
#  ' Any I.D.?',
#  ' Sorry...PD only.',
#  " It's okay.",
#  ' The clerk?',
#  ' Only one guys checked in?',
#  ' Yeah.',
#  " You goin' to the escort service?",
#  ' You got any better ideas?',
#  " I'll let you know what happens.",
#  " I'll call it... tails.",
#  ' Two heads.',
#  ' Better than one.',
#  " Who's there?",
#  " What's wrong?",
#  " Oh my G-d.  Honey!  Honey's dead?",
#  ' No.',
#  ' Did you tell him you did?',
#  ' What are you saying?',
#  ' Describe him.',
#  ' You thirsty?',
#  " I'm on duty.",
#  ' Of course.',
#  ' Stay with her.',
#  ' Are you hit?',
#  " No.  I'm okay.",
#  " Bobby, Bobby!  Where're you hit?!",
#  ' It hurts.  Aw, Jesus!',
#  ' Lay down.  Stay down, Bobby.',
#  ' Alright, cut, cut, cut.',
#  ' Eddie, are you okay?',
#  " Yeah.  Now's not a good time.",
#  ' Alright.',
#  ' Alright?',
#  ' Alright.',
#  ' Alright.',
#  ' Okay.',
#  ' Go on.',
#  ' Is that all there is?',
#  " No, no, don't talk to Immigration!",
#  ' Why not?',
#  ' Something back home?',
#  " Alright.  That's a justifiable homicide.",
#  ' Yes, but he was a cop.',
#  ' A cop?',
#  ' Raw deal.',
#  ' You wanna talk to her alone?',
#  ' Yeah.',
#  " I don't have a girlfriend.",
#  ' My point exactly.',
#  " I'm serious here.",
#  ' So am I.',
#  " You know what I'm saying here.",
#  " Hey.  I'm a professional.",
#  ' Shut up.',
#  ' Does it hurt?',
#  " Don't want to film this?",
#  " They won't until this is over.",
#  ' Are you married?',
#  ' Divorced.',
#  ' Somewhere else?',
#  ' Hey, honey.',
#  ' Hey.',
#  ' Stop it.',
#  " Alright, alright, Eddie.  Don't patronize me.",
#  " I'm not.",
#  " You're ruthless.",
#  " You're not so bad yourself.",
#  " Could be Leon's.",
#  ' Answer the phone.',
#  ' Answer it.',
#  " That's good.",
#  ' Yeah.',
#  " Well, that's great.",
#  ' Promise?',
#  ' Patronizing you... Nay, I love you.',
#  ' I love you.',
#  ' Okay, til tonight.',
#  ' Tonight.',
#  ' You promise?',
#  ' Yeah.  I promise.',
#  ' Yeah, yeah.  Good thing.',
#  ' Okay.',
#  ' See you later.  Good luck.',
#  ' Thank you.',
#  " Don't be late.",
#  ' So...the station is empty?',
#  ' Yeah.  This way.',
#  ' You considered becoming a prostitute?',
#  ' Yes, I considered it.',
#  ' Did you ever turn tricks before?',
#  ' No.',
#  ' What about back home?',
#  ' No.',
#  ' So you were never a prostitute?',
#  ' What are you asking me?',
#  ' I know.',
#  ' What is it?',
#  ' I did.',
#  ' Why not?',
#  ' Put the camera down, Oleg.',
#  ' What is that?',
#  ' Sit down!',
#  " What do you mean, 'cleaned up?'",
#  ' I let her take a shower.',
#  ' No!  Nothing happened.',
#  ' Oh.',
#  ' It was my decision, not his.',
#  ' Oh yeah...?  Alright.',
#  ' Just a shower?',
#  " So...who's Nicky?",
#  ' What do you want?',
#  " What's your accomplishment.",
#  ' I kill someone famous.',
#  ' Then do it, asshole.',
#  ' Good idea!',
#  ' Cut!',
#  ' I know.',
#  ' Well, he...',
#  " I'm trying to tell you.",
#  ' Alright.  Go ahead.',
#  ' Robert...?',
#  ' What are you doing here?',
#  " You've got a call.",
#  " What?  It doesn't work that way.",
#  ' Wait a minute.  Wait a minute.',
#  ' How was it?',
#  ' Not good.',
#  ' Did the D.A. videotape her deposition?',
#  ' Yeah.  He finished awhile ago.',
#  ' Yeah.',
#  ' Okay.  But not water sports.',
#  ' Are you alright?',
#  " I still can't believe Eddie's gone.",
#  " I'm sorry.",
#  ' Is he your boyfriend?',
#  " I'm glad I met you.",
#  ' You better get packed.',
#  ' Right.',
#  ' Do you have coffee?',
#  ' In the kitchen.',
#  " I'll make some for us.",
#  " I'll get my clothes.",
#  ' What are you doing?',
#  ' Pouring it out!',
#  ' Get outta here!',
#  ' What the hell happened?',
#  ' Viewer discretion advised!',
#  " I'm serious.",
#  ' Shut up.  Look!',
#  ' Be quiet.  Watch.',
#  ' Credit?',
#  ' You got that?',
#  " No, I don't get that!",
#  ' Here.  I have your money.',
#  ' Oh no!  No!  Shit!',
#  " Don't say anything.",
#  ' Where are we going?',
#  " I'm coming with you.",
#  ' Yes.  Yes, come with me!',
#  " I'll take him.",
#  " No way!  He's mine!",
#  " We're takin' him.  Don't argue!",
#  " He's my collar!",
#  ' Well, he killed my partner!',
#  " Don't give me that fucking shit.",
#  ' Tommy, take a walk.',
#  ' What are you gonna do?',
#  " Don't stoop to his level!",
#  " You'll be my first.",
#  ' Get down on your knees.',
#  " Where's your partner?",
#  ' You bring the cigarettes?',
#  ' Oh, sure.',
#  ' ...delusions and paranoia.',
#  ' I was all of these.',
#  ' What about Oleg?',
#  ' No, he is here.  Shit...',
#  " What's your cut?  How much?",
#  ' I would say...half.  Half is fair.',
#  ' No.  No way.',
#  " But it's...",
#  ' What else do you need?',
#  ' Give me another one, please.',
#  ' Your mother was blind?',
#  ' Back in the Czech Republic?',
#  ' Can I see your back?',
#  " I'm abused.  Don't you think?",
#  ' End my career?',
#  ' But Chief?  Over this??',
#  ' Daphne, I...',
#  ' Traitor!!',
#  ' Let her go!  Let her go!!',
#  ' How do you do, Mr. Miller?',
#  " Please, it really doesn't matter.",
#  ' Yes, very pleasant.',
#  ' Well, shall we go through Documentation?',
#  ' Fine.',
#  " Yes, it's coming along very well.",
#  " I'm having a party tomorrow.",
#  ' Yes, I know that sweetheart.',
#  ' Are you coming to my party?',
#  ' When are you coming home?',
#  ' In three days, darling, I hope.',
#  " Mommy's out to the hair- dresser.",
#  ' Where is Mrs. Brown?',
#  " She's in the bathroom.",
#  ' Thank you, Daddy.',
#  ' Yes, Daddy.',
#  " 'Bye, 'bye, now, sweetheart.",
#  ' Goodbye, Daddy.',
#  ' SPACE STATTION 5 - LOUNGE',
#  ' CONTINUED',
#  ' Are you quite sure?',
#  ' Yes, really, thank you very much.',
#  ' CONTINUED',
#  " She's wonderful.",
#  ' And your charming little daughter?',
#  " Oh, that's such a delightful age.",
#  ' How is gregor?',
#  ' Really?',
#  ' CONTINUED',
#  " That's right.",
#  ' I see.',
#  ' CONTINUED',
#  ' Well, that does sound very odd.',
#  ' Fortunately, they did.',
#  " Well, I'm glad about that.",
#  ' Certainly.',
#  ' CONTINUED',
#  ' CONTINUED',
#  ' Oh, thank you very much.',
#  ' Thank you.',
#  " Well, how's it going back there?",
#  " I'll bet it's a fortune.",
#  ' When do we arrive at Clavius?',
#  ' Thank you.',
#  ' What do you mean?',
#  ' I see.',
#  ' Any ideas about the colour?',
#  ' Hi. Frank... coming in, please.',
#  ' Right. Just a sec.',
#  ' Okay. ',
#  ' Okay, come on down.',
#  ' Sure, what is it?',
#  " What's up?",
#  " It's about my salary cheques.",
#  ' Yes?',
#  ' CONTINUED',
#  ' Really.',
#  ' Yes.',
#  ' CONTINUED',
#  " It's possible.",
#  ' No. I never did, either.',
#  ' Oh?',
#  ' CONTINUED',
#  ' Well, what is it?',
#  ' That seems very unlikely.',
#  ' Yes, I thought so.',
#  ' How?',
#  " That's true.",
#  ' CONINUED',
#  " He's got a point.",
#  ' CONTINUED',
#  ' But not completely inconceivable?',
#  " I suppose it isn't logically impossible.",
#  " I guess it isn't.",
#  ' CONTINUED',
#  ' I will if I can, Frank.',
#  ' True.',
#  " That's true.",
#  " That's true.",
#  " That's true",
#  " That's true.",
#  ' Thank you very much, Hal.',
#  ' What is it, Hal?',
#  ' Roger.',
#  ' Five by five, Frank.',
#  ' I understand.',
#  ' Hal, maintain normal E.V.A. condition.',
#  ' Roger.',
#  ' Hal, check all airlock doors secure.',
#  ' Opening pod bay doors.',
#  " Well, that's something.",
#  " Yes, Hal, what's up?",
#  " Good morning. How's it going?",
#  ' Are you reasonably awake?',
#  " You're kidding.",
#  ' No.',
#  ' Two more.',
#  ' Hal?',
#  ' Yes.',
#  " Sure, Dave, what's up?",
#  ' Yes, I know.',
#  " I'm sorry about the misunderstanding, Hal.",
#  " Well, don't worry about it.",
#  " And don't you worry about it.",
#  ' Yes, it is, Hal.',
#  " It's the last one.",
#  ' I guess not.',
#  ' Roger.',
#  " Too bad about Frank, isn't it?",
#  ' Yes, it is.',
#  ' The antenna has to be replaced.',
#  ' Hal, switch to manual hibernation control.',
#  ' What am I wanted for?',
#  " I don't think your gun's loaded...",
#  " I still don't think it's loaded.",
#  " Hey, you're right.",
#  " You're hopeless.",
#  " I'm all wet.",
#  " What's wrong with that?",
#  " What'd you do?",
#  ' I guess he got the message...',
#  " Tell me--I'm dyin' to hear it.",
#  ' How hot are they?',
#  " How ya doin'?",
#  " Can't complain.",
#  ' Yeah, old times.',
#  " We'll follow you.  Take it slow,okay?",
#  ' Sure, right.',
#  ' I want to drive awhile.',
#  " I ain't tired yet.",
#  ' Whaddya mean, buy?',
#  ' Pros.',
#  ' Pay money?',
#  ' Yeah, dummy.  Money.',
#  ' Maybe that makes a nice excuse.',
#  ' Call me later.',
#  ' You sure you want me to?',
#  " Yeah, for some reason, I'm sure...",
#  ' Thanks for the coffee.',
#  ' Surprise, Luther.',
#  ' Billy, go ahead, break it...',
#  ' When?',
#  ' You chickenshit punk...',
#  ' Hey, what about me?',
#  ' Hey...',
#  ' Shut up.',
#  ' Shut up.',
#  ' Stall.',
#  ' What do you want?',
#  " Keep stallin'.",
#  " Alright, I'm coming...hold on.",
#  ' You lying son of a bitch...',
#  " That's what you say, Cates...",
#  ' Yeah.',
#  " The truth hurts, doesn't it, buddy?",
#  " I'll help you out.",
#  ' Shit.',
#  ' Billy Bear...',
#  ' Who are all these?',
#  ' Hey ... Dick Tracy.',
#  " One of  em's in the slam.",
#  ' Yeah, I read the report...',
#  ' Yeah...',
#  ' Jack?',
#  ' Yeah?',
#  " I'll keep it in mind.",
#  ' Great place for lunch.',
#  ' Yeah, one of my favorites.',
#  ' You made the front page.',
#  ' Jack, are you okay?',
#  ' You got a name, cop?',
#  ' Sure, anything you want.',
#  ' Yeah, I noticed...',
#  ' Yeah?',
#  " You're crazy.",
#  ' I got a lot to protect.',
#  ' Bullshit.',
#  " I'll think about it.",
#  ' This prison gives out $400 suits?',
#  ' No way to start a partnership.',
#  " Shit.  I'm already sorry.",
#  ' Yeah.',
#  ' Luther was part of the gang?',
#  " What gang you talkin' about, Jack?",
#  " I'm helpin' you, huh?",
#  ' Just throw me the Goddamn gun.',
#  ' A cop...',
#  ' Hey, this works pretty good.',
#  ' Thank you.',
#  ' Want to try it again?',
#  " I don't know.",
#  ' When? How?',
#  ' What do you think?',
#  " Now, where we goin', convict?",
#  " I don't give out the details.",
#  ' Last night, two nights ago, three?',
#  ' Last night.',
#  ' You have a good time?',
#  ' Well?',
#  ' Hey, you wanna bet?',
#  " What are you talkin' about?",
#  " The bet's off.",
#  ' Yeah.',
#  ' Vodka.',
#  " Now how's your memory doin'?",
#  ' You made that move, huh?',
#  ' There.',
#  " Must be billy's girl.",
#  ' Come on.',
#  ' How about it?',
#  " Let's go.",
#  ' They saved your ass, convict.',
#  ' How much?',
#  ' Half a million.',
#  ' Jesus.',
#  ...]

# %%
#function to expand the contractions and remove punctuation

def exp_remPunt(l):
    '''
    params: l is a list (of quest or ans)
    '''
    clean_l=[]
    table = str.maketrans(dict.fromkeys(string.punctuation))
    remove_digits = str.maketrans('', '', string.digits)

    for sent in l:
        for word in sent.split():
            if word in contractions_dict:
                sent = sent.replace(word, contractions_dict[word])  #expand
                
        sent = sent.translate(remove_digits)
        clean_l.append(sent.translate(table).lower()) #remove punt and set to lower
    
    return clean_l

# %%
question=exp_remPunt(question)
answer=exp_remPunt(answer)

# %%
answer
# Out:
# [' no',
#  ' you might wanna think about it',
#  ' i missed you',
#  ' with the teeth of your zipper',
#  ' you the new guy',
#  ' so they tell me',
#  ' so  which dakota you from',
#  ' north actually  howd you   ',
#  ' thirtytwo',
#  ' get out',
#  ' how many people go here',
#  ' couple thousand most of them evil',
#  ' that im used to',
#  ' that girl  i ',
#  ' you burn you pine you perish',
#  ' who is she',
#  ' why not',
#  ' tempestuous',
#  ' whos that',
#  ' patrick verona   random skid',
#  ' he always look so',
#  ' block e',
#  ' just a little',
#  ' whats this',
#  ' an attempted slit',
#  ' he always have that shiteating grin',
#  ' you know french',
#  ' thats her  biancas sister',
#  ' the mewling rampalian wretch herself',
#  ' in the microwave',
#  ' make anyone cry today',
#  ' whereve you been',
#  ' nowhere hi daddy',
#  ' whats a synonym for throbbing',
#  ' i know',
#  ' you decided',
#  ' what if she never starts dating',
#  ' enough',
#  ' but she does not want to date',
#  ' exactly my point',
#  ' tumescent',
#  ' youre not helping',
#  ' forget it',
#  ' cameron',
#  ' why',
#  ' thats a shame',
#  ' what about him',
#  ' you wanna go out with him',
#  ' thats what i just said',
#  ' i thought you hated those people',
#  ' hey',
#  ' are you lost',
#  ' we do not chat',
#  ' were not',
#  ' does this conversation have a purpose',
#  ' you got him involved',
#  ' thats never been proven',
#  ' neither has his heterosexuality',
#  ' does it matter',
#  ' touch of the flu',
#  ' whats to discuss',
#  ' forget french',
#  ' there',
#  ' where',
#  ' yeah',
#  ' what do you think',
#  ' two legs nice rack',
#  ' you just said',
#  ' how much',
#  ' fine thirty',
#  ' fifty and you have got your man',
#  ' i mean woman  how ya doin',
#  ' my mission in life',
#  ' pick you up friday then',
#  ' oh right  friday',
#  ' you hate me do not you',
#  ' and why would i do that',
#  ' you  covered in my vomit',
#  ' seventhirty',
#  ' are you following me',
#  ' hi',
#  ' hey  do you mind',
#  ' not at all',
#  ' my insurance does not cover pms',
#  ' i thought you were punishing me',
#  ' why cannot we agree on this',
#  ' because you are making decisions for me',
#  ' as a parent that is my right',
#  ' so what i want does not matter',
#  ' im on it',
#  ' i just upped my price',
#  ' what',
#  ' a hundred bucks a date',
#  ' forget it',
#  ' forget her sister then',
#  ' you got something on your mind',
#  ' youre sweet',
#  ' say it',
#  ' what',
#  ' what plan',
#  ' so dorsey can get the girl',
#  ' were your guys',
#  ' yeah  we will see',
#  ' will bogey get bent',
#  ' its more',
#  ' expensive',
#  ' hopefully',
#  ' sure have',
#  ' shes not a',
#  ' whatve you got for me',
#  ' what',
#  ' good enough',
#  ' number one  she hates smokers',
#  ' its a lung cancer issue',
#  ' her favorite uncle',
#  ' dead at fortyone',
#  ' just for now',
#  ' hes pretty',
#  ' okay  i was not sure',
#  ' ever been to club skunk',
#  ' yeah',
#  ' gigglepuss is playing there tomorrow night',
#  ' dont make me do it man',
#  ' assail your ears for one night',
#  ' its her favorite band',
#  ' im likin you guys better',
#  ' what do you think',
#  ' you think thisll work',
#  ' no fear',
#  ' always a pleasure brucie',
#  ' never',
#  ' just sent em through',
#  ' hey  great show huh',
#  ' ',
#  ' excuse me',
#  ' thats what you want is not it',
#  ' you know who the raincoats are',
#  ' why do not you',
#  ' whatd he say',
#  ' who cares',
#  ' you told me that part already',
#  ' i hear you are helpin verona',
#  ' uh  yeah  were old friend',
#  ' you and verona',
#  ' youre completely demented',
#  ' see you next week',
#  ' daddy i ',
#  ' and wherere you going',
#  ' otherwise known as an orgy',
#  ' whats normal',
#  ' oh god  its starting',
#  ' its just a party daddy',
#  ' wear the belly before you go',
#  ' daddy no',
#  ' just for a minute',
#  ' you are so completely unbalanced',
#  ' can we go now',
#  ' why',
#  ' because she will scare them away',
#  ' where ya goin',
#  ' away',
#  ' your sister here',
#  ' leave my sister alone',
#  ' and why would i do that',
#  ' whats this',
#  ' funny you are the only one',
#  ' who',
#  ' joey',
#  ' hi',
#  ' you know chastity',
#  ' great',
#  ' extremely unfortunate maneuver',
#  ' no i  m not',
#  ' queen harry',
#  ' neat',
#  ' is he oily or dry',
#  ' its about time',
#  ' a deals a deal',
#  ' howd you do it',
#  ' do what',
#  ' okay',
#  ' im fine im',
#  ' youre not okay',
#  ' i know just let me sleep',
#  ' cameron im a little busy',
#  ' its off the whole thing',
#  ' what re you talking about',
#  ' shes partial to joey not me',
#  ' sure',
#  ' then go get her',
#  ' this is so patronizing',
#  ' why re you doing this',
#  ' i told you',
#  ' you do not care if i die',
#  ' sure i do',
#  ' why',
#  ' like you could find one',
#  ' just let me sit down',
#  ' who',
#  ' dorsey',
#  ' i hate him',
#  ' you know what they say',
#  ' kat wake up',
#  ' what',
#  ' youre welcome',
#  ' have fun tonight',
#  ' tons',
#  ' and im in control of it',
#  ' busy',
#  ' were you in jail',
#  ' maybe',
#  ' no you were not',
#  ' then whyd you ask',
#  ' whyd you lie',
#  ' i should do this',
#  ' do what',
#  ' this',
#  ' start a band',
#  ' im gettin there',
#  ' who',
#  ' bianca',
#  ' i was',
#  ' well no',
#  ' but',
#  ' you always been this selfish',
#  ' i did not have a choice',
#  ' you did not',
#  ' whatd you do to her',
#  ' hey there  tired of breathing',
#  ' hi',
#  ' cool pictures  you a fan',
#  ' yeah  i guess',
#  ' you think',
#  ' oh yeah',
#  ' macbeth right',
#  ' right',
#  ' kat a fan too',
#  ' yeah',
#  ' you makin any headway',
#  ' she kissed me',
#  ' where',
#  ' hey sweet cheeks',
#  ' hi joey',
#  ' what are you doing here',
#  ' you re so ',
#  ' pleasant',
#  ' wholesome',
#  ' unwelcome',
#  ' other than my upchuck reflex nothing',
#  ' you were right shes still pissed',
#  ' sweet love renew thy force',
#  ' whats the worst',
#  ' you get the girl',
#  ' look up sunshine',
#  ' cmon  its not that bad',
#  ' put your right foot there ',
#  ' forget it  im stayin',
#  ' maybe',
#  ' the partridge family',
#  ' good call',
#  ' i dazzled him with my wit',
#  ' a soft side who knew',
#  ' so  what is your excuse',
#  ' acting the way we do',
#  ' yes',
#  ' something like that',
#  ' then you screwed up',
#  ' how',
#  ' you never disappointed me',
#  ' you up for it',
#  ' for   ',
#  ' state trooper',
#  ' fallacy',
#  ' the duck',
#  ' hearsay',
#  ' tell me something true',
#  ' i hate peas',
#  ' what',
#  ' no one else knows',
#  ' go to the prom with me',
#  ' you know what i mean',
#  ' no',
#  ' no what',
#  ' no i will not go with you',
#  ' why not',
#  ' you tell me',
#  ' answer the question patrick',
#  ' no',
#  ' do you listen to this crap',
#  ' what crap',
#  ' what good stuff',
#  ' the real you',
#  ' like my fear of wearing pastels',
#  ' no',
#  ' pirate  no question',
#  ' the prom  kat has a date',
#  ' no but',
#  ' like you care',
#  ' what',
#  ' in th  for a month',
#  ' why',
#  ' he was like a total babe',
#  ' but you hate joey',
#  ' as in',
#  ' you did what',
#  ' but',
#  ' why did not you tell me',
#  ' thats not',
#  ' dr ruth',
#  ' im missing something',
#  ' wow',
#  ' lets go',
#  ' have a great time honey',
#  ' but  who  what ',
#  ' what just happened',
#  ' your daughters went to the prom',
#  ' absolutely not',
#  ' that  s what i thought',
#  ' oh huh',
#  ' have you seen him',
#  ' who',
#  ' i did',
#  ' my grandmothers ',
#  ' what',
#  ' that  s completely adorable',
#  ' wait i',
#  ' it was not like that',
#  ' i did not care about the money',
#  ' so did you',
#  ' she okay',
#  ' i hope so',
#  ' was that your sister',
#  ' funny',
#  ' no daddy',
#  ' parts of it',
#  ' which parts',
#  ' bianca did what',
#  ' no  impressed',
#  ' when i go',
#  ' let go',
#  ' you set me up',
#  ' i just wanted ',
#  ' no i just wanted',
#  ' just smack her now',
#  ' its just you',
#  ' a fender strat you bought this',
#  ' is that right',
#  ' because i like to torture you',
#  ' they do to',
#  ' they do not',
#  ' patrick  is that a',
#  ' perm',
#  ' yes your majesty',
#  ' god thats in a week',
#  ' thats what it says',
#  ' how did you manage it',
#  ' how can you be so certain',
#  ' esdras is a jew',
#  ' so was christ',
#  ' ill try to remember that marchena',
#  ' father marchena',
#  ' passion is something one cannot control',
#  ' i could be gone for years',
#  ' i know',
#  ' are we going to argue',
#  ' i find that hard to believe',
#  ' i am your eminence',
#  ' excellency you are right',
#  ' your life and that of others',
#  ' ifgodwillsit',
#  ' the judgment is ours',
#  ' damn god',
#  ' colon',
#  ' all of them  just lies',
#  ' colon  dont',
#  ' where can i meet this man',
#  ' immediately',
#  ' the ocean is uncrossable',
#  ' that she was impregnable',
#  ' may i speak freely',
#  ' a woman',
#  ' how old are you senor colon',
#  ' thirty seven your majesty and you',
#  ' no',
#  ' no',
#  ' im not bargaining',
#  ' then you are too ambitious',
#  ' never your majesty  although',
#  '  into a monk',
#  ' she said yes',
#  ' thank god',
#  ' thats something you cannot decide',
#  ' i want to go with you',
#  ' therell be a time',
#  ' i am listening my son',
#  ' what are you saying',
#  ' how long',
#  ' i believed in you',
#  ' give me absolution',
#  ' god be with us admiral',
#  ' and what do you think mendez',
#  ' come over here',
#  ' what do you read',
#  ' twenty eight',
#  ' hes the devils child',
#  ' well all go crazy',
#  ' we should have seen land',
#  ' six days ago yes',
#  ' you must be mad',
#  ' you think i do not know that',
#  ' were lost',
#  ' you bloody',
#  ' you tell that to them',
#  ' youre right  let the men decide',
#  ' say not here  cuba',
#  ' island  far',
#  ' you come  you speak first',
#  ' tell the chief we thank him',
#  ' chief knows',
#  ' chief says  how many',
#  ' thousands',
#  ' why',
#  ' to bring the word of god',
#  '  and also to bring medicine',
#  ' chief says',
#  ' do they have such thoughts',
#  ' you defend yourself admirably',
#  '  for a commoner',
#  ' may i ask by whom',
#  ' bartolome and giacomo colon',
#  ' you do not usually ask',
#  ' we do not need to know',
#  ' he understands',
#  ' ask him if he will help',
#  ' my horse does not work',
#  ' savagery is what monkeys understand',
#  ' you will regret this',
#  ' is this true brother buyl',
#  ' he must be replaced',
#  ' don alonso de bobadilla',
#  ' yes i remember',
#  ' my letters of appointment',
#  ' appointment to what',
#  ' viceroy of the west indies',
#  ' how far from here',
#  ' i have to explore the mainland',
#  ' this time with me',
#  ' thank you',
#  ' then why',
#  ' call them',
#  ' look out of that window',
#  ' what do you see',
#  ' roofs towers palaces spires',
#  ' they took everything',
#  ' how are you feeling fernando',
#  ' not bad',
#  ' whats he doing',
#  ' we cannot be',
#  ' father',
#  ' you can see for yourself',
#  ' i have to disagree',
#  ' i knew you would',
#  ' new worlds create new people',
#  ' i am busy inside',
#  ' what is it now  tell me',
#  ' what are you listening to',
#  ' what does he say',
#  ' okay',
#  ' dont fool around',
#  ' okay',
#  ' did you hear what i said',
#  ' yes sir',
#  ' two weeks holiday',
#  ' i have fivehundred dollars',
#  ' yes',
#  ' please join us  come on forward',
#  ' is there a problem',
#  ' yeshes my friend',
#  ' we are both from prague',
#  ' two weeks',
#  ' he does not speak english',
#  ' i speak english',
#  ' new york',
#  ' a cheap hotel',
#  ' im here for movies',
#  ' excuse me',
#  ' jesus christ',
#  ' vodka tonic',
#  ' sooner or later that is everybody',
#  ' im not moody',
#  ' isnt he a little moody',
#  ' in love  with who',
#  ' how old are your kids',
#  ' yeah',
#  ' paulie you have got kids right',
#  ' i am butcher',
#  ' you stuff sausage in it',
#  ' dog food',
#  ' are you married',
#  ' no  are you proposing',
#  ' im gonna propose',
#  ' when',
#  ' tomorrow  at lunch',
#  ' you ready',
#  ' dont speak russian',
#  ' we have no money  come on',
#  ' so  what is unique',
#  ' not what  who',
#  ' thats unique',
#  ' ready',
#  ' keep them out of my way',
#  ' okay  you ready',
#  ' yeah yeah  jesus',
#  ' turn that off  get the bags',
#  ' what',
#  ' smell like chemicalsfor smoking drugs',
#  ' emil',
#  ' surprise  surprise',
#  ' did you hurt her',
#  ' milos  get my money',
#  ' we spent it',
#  ' ha ha',
#  ' i can get you a job',
#  ' a job',
#  ' yes the money is good',
#  ' as a plumber',
#  ' its easy to learn',
#  ' we started over you can too',
#  ' fire department  firemen do not carry guns',
#  ' oh yeah  guess again',
#  ' oh yeah why',
#  ' no  go ahead',
#  ' thanks  appreciate it',
#  ' mouths clean too',
#  ' clean',
#  ' dont blow your nose',
#  ' but you knew that right',
#  ' what was that',
#  ' evidence  of a homicide',
#  ' you know what that is right',
#  ' no what is it',
#  ' whats he looking for',
#  ' a timer',
#  ' he knew all along',
#  ' what',
#  ' how many victims are up there',
#  ' is it drug related',
#  ' what',
#  ' you okay',
#  ' turn that fucking thing off',
#  ' speak english',
#  ' you said speak czech',
#  ' how you erase this',
#  ' whore',
#  ' yeah',
#  ' maybe you can be his standin',
#  ' who did cause and origin',
#  ' who do you think chief',
#  ' yeah right',
#  ' what was that korfin',
#  ' i used an accelerant',
#  ' yeah  what kind',
#  ' your doctor',
#  ' were in negotiations that is correct',
#  ' get in the bathroom',
#  ' hi im honey',
#  ' wheres czech girl',
#  ' where is escort service',
#  ' give me the address',
#  ' how long they been livin here',
#  ' you hear that question garcia',
#  ' arent you tired',
#  ' watch the news',
#  ' nah i musta missed it',
#  ' nah why should you',
#  ' i do not even watch tv',
#  ' good  good  commendable',
#  ' pretty',
#  ' hmmmm',
#  ' who says she is a suspect',
#  ' what would you call her',
#  ' eastern europe  like what  romania hungary',
#  ' ill come with you',
#  ' this is not homicide school',
#  ' youre polish',
#  ' my folks are',
#  ' stay here',
#  ' who is he',
#  ' this all you want',
#  ' yes  both',
#  ' where is she',
#  ' takin a bath',
#  ' any id',
#  ' sorrypd only',
#  ' its okay',
#  ' the clerk',
#  ' only one guys checked in',
#  ' yeah',
#  ' you goin to the escort service',
#  ' you got any better ideas',
#  ' ill let you know what happens',
#  ' ill call it tails',
#  ' two heads',
#  ' better than one',
#  ' whos there',
#  ' whats wrong',
#  ' oh my gd  honey  honeys dead',
#  ' no',
#  ' did you tell him you did',
#  ' what are you saying',
#  ' describe him',
#  ' you thirsty',
#  ' im on duty',
#  ' of course',
#  ' stay with her',
#  ' are you hit',
#  ' no  im okay',
#  ' bobby bobby  wherere you hit',
#  ' it hurts  aw jesus',
#  ' lay down  stay down bobby',
#  ' alright cut cut cut',
#  ' eddie are you okay',
#  ' yeah  nows not a good time',
#  ' alright',
#  ' alright',
#  ' alright',
#  ' alright',
#  ' okay',
#  ' go on',
#  ' is that all there is',
#  ' no no do not talk to immigration',
#  ' why not',
#  ' something back home',
#  ' alright  thats a justifiable homicide',
#  ' yes but he was a cop',
#  ' a cop',
#  ' raw deal',
#  ' you wanna talk to her alone',
#  ' yeah',
#  ' i do not have a girlfriend',
#  ' my point exactly',
#  ' im serious here',
#  ' so am i',
#  ' you know what im saying here',
#  ' hey  im a professional',
#  ' shut up',
#  ' does it hurt',
#  ' dont want to film this',
#  ' they will not until this is over',
#  ' are you married',
#  ' divorced',
#  ' somewhere else',
#  ' hey honey',
#  ' hey',
#  ' stop it',
#  ' alright alright eddie  dont patronize me',
#  ' im not',
#  ' youre ruthless',
#  ' youre not so bad yourself',
#  ' could be leons',
#  ' answer the phone',
#  ' answer it',
#  ' thats good',
#  ' yeah',
#  ' well that is great',
#  ' promise',
#  ' patronizing you nay i love you',
#  ' i love you',
#  ' okay til tonight',
#  ' tonight',
#  ' you promise',
#  ' yeah  i promise',
#  ' yeah yeah  good thing',
#  ' okay',
#  ' see you later  good luck',
#  ' thank you',
#  ' dont be late',
#  ' sothe station is empty',
#  ' yeah  this way',
#  ' you considered becoming a prostitute',
#  ' yes i considered it',
#  ' did you ever turn tricks before',
#  ' no',
#  ' what about back home',
#  ' no',
#  ' so you were never a prostitute',
#  ' what are you asking me',
#  ' i know',
#  ' what is it',
#  ' i did',
#  ' why not',
#  ' put the camera down oleg',
#  ' what is that',
#  ' sit down',
#  ' what do you mean cleaned up',
#  ' i let her take a shower',
#  ' no  nothing happened',
#  ' oh',
#  ' it was my decision not his',
#  ' oh yeah  alright',
#  ' just a shower',
#  ' sowhos nicky',
#  ' what do you want',
#  ' whats your accomplishment',
#  ' i kill someone famous',
#  ' then do it asshole',
#  ' good idea',
#  ' cut',
#  ' i know',
#  ' well he',
#  ' im trying to tell you',
#  ' alright  go ahead',
#  ' robert',
#  ' what are you doing here',
#  ' youve got a call',
#  ' what  it does not work that way',
#  ' wait a minute  wait a minute',
#  ' how was it',
#  ' not good',
#  ' did the da videotape her deposition',
#  ' yeah  he finished awhile ago',
#  ' yeah',
#  ' okay  but not water sports',
#  ' are you alright',
#  ' i still cannot believe eddies gone',
#  ' im sorry',
#  ' is he your boyfriend',
#  ' im glad i met you',
#  ' you better get packed',
#  ' right',
#  ' do you have coffee',
#  ' in the kitchen',
#  ' ill make some for us',
#  ' ill get my clothes',
#  ' what are you doing',
#  ' pouring it out',
#  ' get outta here',
#  ' what the hell happened',
#  ' viewer discretion advised',
#  ' im serious',
#  ' shut up  look',
#  ' be quiet  watch',
#  ' credit',
#  ' you got that',
#  ' no i do not get that',
#  ' here  i have your money',
#  ' oh no  no  shit',
#  ' dont say anything',
#  ' where are we going',
#  ' im coming with you',
#  ' yes  yes come with me',
#  ' ill take him',
#  ' no way  hes mine',
#  ' were takin him  dont argue',
#  ' hes my collar',
#  ' well he killed my partner',
#  ' dont give me that fucking shit',
#  ' tommy take a walk',
#  ' what are you gonna do',
#  ' dont stoop to his level',
#  ' youll be my first',
#  ' get down on your knees',
#  ' wheres your partner',
#  ' you bring the cigarettes',
#  ' oh sure',
#  ' delusions and paranoia',
#  ' i was all of these',
#  ' what about oleg',
#  ' no he is here  shit',
#  ' whats your cut  how much',
#  ' i would sayhalf  half is fair',
#  ' no  no way',
#  ' but its',
#  ' what else do you need',
#  ' give me another one please',
#  ' your mother was blind',
#  ' back in the czech republic',
#  ' can i see your back',
#  ' im abused  dont you think',
#  ' end my career',
#  ' but chief  over this',
#  ' daphne i',
#  ' traitor',
#  ' let her go  let her go',
#  ' how do you do mr miller',
#  ' please it really does not matter',
#  ' yes very pleasant',
#  ' well shall we go through documentation',
#  ' fine',
#  ' yes it is coming along very well',
#  ' im having a party tomorrow',
#  ' yes i know that sweetheart',
#  ' are you coming to my party',
#  ' when are you coming home',
#  ' in three days darling i hope',
#  ' mommys out to the hair dresser',
#  ' where is mrs brown',
#  ' shes in the bathroom',
#  ' thank you daddy',
#  ' yes daddy',
#  ' bye bye now sweetheart',
#  ' goodbye daddy',
#  ' space stattion   lounge',
#  ' continued',
#  ' are you quite sure',
#  ' yes really thank you very much',
#  ' continued',
#  ' shes wonderful',
#  ' and your charming little daughter',
#  ' oh that is such a delightful age',
#  ' how is gregor',
#  ' really',
#  ' continued',
#  ' thats right',
#  ' i see',
#  ' continued',
#  ' well that does sound very odd',
#  ' fortunately they did',
#  ' well im glad about that',
#  ' certainly',
#  ' continued',
#  ' continued',
#  ' oh thank you very much',
#  ' thank you',
#  ' well how is it going back there',
#  ' ill bet it is a fortune',
#  ' when do we arrive at clavius',
#  ' thank you',
#  ' what do you mean',
#  ' i see',
#  ' any ideas about the colour',
#  ' hi frank coming in please',
#  ' right just a sec',
#  ' okay ',
#  ' okay come on down',
#  ' sure what is it',
#  ' whats up',
#  ' its about my salary cheques',
#  ' yes',
#  ' continued',
#  ' really',
#  ' yes',
#  ' continued',
#  ' its possible',
#  ' no i never did either',
#  ' oh',
#  ' continued',
#  ' well what is it',
#  ' that seems very unlikely',
#  ' yes i thought so',
#  ' how',
#  ' thats true',
#  ' coninued',
#  ' hes got a point',
#  ' continued',
#  ' but not completely inconceivable',
#  ' i suppose it is not logically impossible',
#  ' i guess it isnt',
#  ' continued',
#  ' i will if i can frank',
#  ' true',
#  ' thats true',
#  ' thats true',
#  ' thats true',
#  ' thats true',
#  ' thank you very much hal',
#  ' what is it hal',
#  ' roger',
#  ' five by five frank',
#  ' i understand',
#  ' hal maintain normal eva condition',
#  ' roger',
#  ' hal check all airlock doors secure',
#  ' opening pod bay doors',
#  ' well that is something',
#  ' yes hal  what is up',
#  ' good morning hows it going',
#  ' are you reasonably awake',
#  ' youre kidding',
#  ' no',
#  ' two more',
#  ' hal',
#  ' yes',
#  ' sure dave  what is up',
#  ' yes i know',
#  ' im sorry about the misunderstanding hal',
#  ' well do not worry about it',
#  ' and do not you worry about it',
#  ' yes it is hal',
#  ' its the last one',
#  ' i guess not',
#  ' roger',
#  ' too bad about frank is not it',
#  ' yes it is',
#  ' the antenna has to be replaced',
#  ' hal switch to manual hibernation control',
#  ' what am i wanted for',
#  ' i do not think your guns loaded',
#  ' i still do not think it is loaded',
#  ' hey you are right',
#  ' youre hopeless',
#  ' im all wet',
#  ' whats wrong with that',
#  ' whatd you do',
#  ' i guess he got the message',
#  ' tell meim dyin to hear it',
#  ' how hot are they',
#  ' how ya doin',
#  ' cant complain',
#  ' yeah old times',
#  ' well follow you  take it slowokay',
#  ' sure right',
#  ' i want to drive awhile',
#  ' i am not tired yet',
#  ' whaddya mean buy',
#  ' pros',
#  ' pay money',
#  ' yeah dummy  money',
#  ' maybe that makes a nice excuse',
#  ' call me later',
#  ' you sure you want me to',
#  ' yeah for some reason im sure',
#  ' thanks for the coffee',
#  ' surprise luther',
#  ' billy go ahead break it',
#  ' when',
#  ' you chickenshit punk',
#  ' hey what about me',
#  ' hey',
#  ' shut up',
#  ' shut up',
#  ' stall',
#  ' what do you want',
#  ' keep stallin',
#  ' alright im cominghold on',
#  ' you lying son of a bitch',
#  ' thats what you say cates',
#  ' yeah',
#  ' the truth hurts does not it buddy',
#  ' ill help you out',
#  ' shit',
#  ' billy bear',
#  ' who are all these',
#  ' hey  dick tracy',
#  ' one of  ems in the slam',
#  ' yeah i read the report',
#  ' yeah',
#  ' jack',
#  ' yeah',
#  ' ill keep it in mind',
#  ' great place for lunch',
#  ' yeah one of my favorites',
#  ' you made the front page',
#  ' jack are you okay',
#  ' you got a name cop',
#  ' sure anything you want',
#  ' yeah i noticed',
#  ' yeah',
#  ' youre crazy',
#  ' i got a lot to protect',
#  ' bullshit',
#  ' ill think about it',
#  ' this prison gives out  suits',
#  ' no way to start a partnership',
#  ' shit  im already sorry',
#  ' yeah',
#  ' luther was part of the gang',
#  ' what gang you talkin about jack',
#  ' im helpin you huh',
#  ' just throw me the goddamn gun',
#  ' a cop',
#  ' hey this works pretty good',
#  ' thank you',
#  ' want to try it again',
#  ' i do not know',
#  ' when how',
#  ' what do you think',
#  ' now where we goin convict',
#  ' i do not give out the details',
#  ' last night two nights ago three',
#  ' last night',
#  ' you have a good time',
#  ' well',
#  ' hey you wanna bet',
#  ' what are you talkin about',
#  ' the bets off',
#  ' yeah',
#  ' vodka',
#  ' now how is your memory doin',
#  ' you made that move huh',
#  ' there',
#  ' must be billys girl',
#  ' come on',
#  ' how about it',
#  ' lets go',
#  ' they saved your ass convict',
#  ' how much',
#  ' half a million',
#  ' jesus',
#  ' just tell me about the money',
#  ...]

# %% [markdown]
# ## Creating embeddings
#
# - create list with all the words
# - clean the list: each word must have just one occurrence (set)
# - create dicts for word to index and index to word

# %%
#create list with all the words
words_list=[]

for sent in question:
    for word in sent.split():
        words_list.append(word)
        
for sent in answer:
    for word in sent.split():
        words_list.append(word)
        
words_list = set(words_list)
vocab_len=len(words_list) #length of the vocabulary without offset

vocab_len
# Out:
# 5857

# %%
#define funct to create dicts
def index_to_word(words_list):
    
    d= { (index +3) : word for index,word in enumerate(words_list)}
    
    d[0]='<pad>'
    d[1]='<sos>'
    d[2]='<eos>'
    return d

def word_to_index(words_list):
    d= { word : (index +3) for index,word in enumerate(words_list)}
    
    d['<pad>']=0
    d['<sos>']=1
    d['<eos>']=2
    return d

# %%
dict_i2w=index_to_word(words_list) #index to word
dict_w2i=word_to_index(words_list) #word to index

# %%
#sent translation to embedding
encoder_input_data=[]
decoder_input_data=[]
decoder_output_data=[]
for sent in question:
    emb_str=[]
    for word in sent.split():
        emb_str.append(dict_w2i[word])
    encoder_input_data.append(emb_str) 
    
for sent in answer:
    emb_str=[]
    for word in sent.split():
        emb_str.append(dict_w2i[word])
    decoder_input_data.append([1]+emb_str+[2]) #ans with sos ans eos
    decoder_output_data.append(emb_str+[2]) #ans with just eos

# %%
encoder_input_data
# Out:
# [[3762, 2900, 5157, 4419, 5682],
#  [1440],
#  [2900, 2951, 2258, 5820, 2423, 3414],
#  [2459, 2873, 2900],
#  [1265, 3542, 3144, 2004, 4419, 301],
#  [2900, 3542, 1153, 5344],
#  [695, 4520, 1680, 5176],
#  [695, 1041, 1462, 2900, 4227],
#  [5508, 3255, 3498, 2900],
#  [4042],
#  [5823, 4808],
#  [3638, 2770, 1158, 596, 5460],
#  [1738, 1884, 993, 2004, 2426, 59],
#  [1159, 3537, 4872, 5488],
#  [1159, 509, 2459],
#  [2900, 1080, 2900, 2562, 2900, 2273],
#  [1377, 3907, 3328],
#  [4895, 4259],
#  [910],
#  [3820, 1159],
#  [1406, 4412, 757, 3570],
#  [1803, 2324, 219, 695],
#  [659, 2339],
#  [5540, 1054, 5064],
#  [253, 1871],
#  [3962, 2734, 536],
#  [1803, 2324, 3754, 1159, 1395, 2094],
#  [2900, 1346, 1096],
#  [1649, 3005, 5662, 30],
#  [3542, 707, 4668, 1329, 2514],
#  [1026, 3542, 2191],
#  [3678, 835, 3781, 4142],
#  [1564, 2900, 16],
#  [330, 2234, 5264],
#  [253, 1054, 5165, 1465, 4079],
#  [2459, 1346],
#  [2900, 920],
#  [2955, 1492, 3328, 4414, 2976, 4287],
#  [3257],
#  [3878, 3328, 2441, 4259, 3252, 5488, 512],
#  [5187, 2947, 1226],
#  [5458],
#  [1460, 4259, 2046],
#  [2222, 3414],
#  [3230],
#  [4895],
#  [1649, 1054, 2104],
#  [2955, 2423, 1034],
#  [2900, 2258, 596, 4808, 1265, 1034],
#  [1649, 2955, 2459, 5540, 4392],
#  [2459, 5575, 2900, 169, 1228, 1158],
#  [2219],
#  [438, 2900, 1211],
#  [4130, 4564, 4259, 2674],
#  [3725, 4259],
#  [2441, 1871, 5471, 3754, 1054, 3817],
#  [2900, 4477, 1034, 4653],
#  [1649, 4414, 16, 4818],
#  [1321, 1271, 785, 2743],
#  [2441, 3414, 3281],
#  [854, 2004, 3542, 1817],
#  [253, 5488, 5198],
#  [2222, 1096],
#  [1451],
#  [984],
#  [395],
#  [2955, 4564, 2900, 5820],
#  [1819, 551, 5671, 5308],
#  [2900, 5540, 4392],
#  [3638, 2008],
#  [324, 3885],
#  [5322, 2048, 2900, 3754, 4477, 4419, 3984],
#  [2459, 5199, 1131, 3638, 447, 3545],
#  [2947, 365, 1026, 1071],
#  [2490, 2900, 5269, 508, 3573],
#  [3908, 91, 508],
#  [2900, 61, 5176, 4564, 4259, 2900],
#  [2048, 4895, 2995, 2459, 4564, 1159],
#  [2900, 4906, 1026, 2947, 3523],
#  [1338],
#  [438, 2900, 627, 5176],
#  [2234],
#  [2219, 4564, 2900, 5046],
#  [4259, 4588, 4087],
#  [2947, 4072, 2441, 4259, 650, 3085],
#  [2459, 5575, 2900, 3725, 1830, 5176],
#  [4895, 489, 4130, 730, 2989, 1871],
#  [5047, 2900, 438, 2565, 4565, 1465, 5176],
#  [68, 1054, 608, 1159, 3907, 2947, 91],
#  [695, 2955, 2459, 3252, 2441, 4259, 3281],
#  [3537, 2989, 3414],
#  [2459, 5540, 5719, 2947, 5566],
#  [2955],
#  [1054, 5676, 2546, 1054, 512],
#  [2222, 3414],
#  [2222, 3005, 30, 3573],
#  [2900, 4477, 1508, 2989, 4419, 5046],
#  [1460, 1277],
#  [3290, 3414],
#  [2955],
#  [2955, 3630],
#  [695, 1239, 4683, 5823, 3542, 509],
#  [3725, 4419, 680],
#  [395, 4130, 1631, 1601],
#  [1631, 247, 5823, 3627],
#  [780, 5464],
#  [3080],
#  [5395],
#  [906, 3754],
#  [4577, 4259, 1054],
#  [1933, 2900, 4477, 1465, 5176],
#  [2955],
#  [2480, 3257],
#  [1424, 2859, 3328, 2765, 5477],
#  [780, 1054, 3651, 3093, 3658],
#  [3005, 3006, 4001],
#  [5755, 4588, 4815],
#  [5540, 1465, 5382],
#  [2379, 4796],
#  [5280, 2459, 1268, 4259, 906],
#  [3135, 16, 5488, 2236, 5723],
#  [395],
#  [3648, 3907, 3810, 1451, 2460, 1824],
#  [4034, 3678, 5176, 4564, 3414, 3984],
#  [41, 4419, 1048, 1465, 2859, 1824],
#  [780, 3005, 3006, 3059],
#  [3537, 1046, 2900, 680, 728],
#  [2955, 4564, 2900, 5820],
#  [2900, 5820, 5670, 1602],
#  [1440, 2799],
#  [2324, 1054, 1181, 5553],
#  [4414],
#  [5540, 4853, 4681, 4421],
#  [2219, 5375, 4885, 3602],
#  [],
#  [477, 5176],
#  [1649, 2955, 2900, 3252, 3907, 4259, 3414],
#  [2900, 1346, 1377, 3542, 4309, 438],
#  [4895, 4564, 4259, 2900],
#  [2877, 1803, 3290],
#  [1377, 3329],
#  [2900, 2597, 5176, 1159, 4126, 3802],
#  [2459, 3535, 2900, 438, 2651, 4412],
#  [3574, 395, 3725, 1690, 4020],
#  [2900, 2048, 4412],
#  [1460, 435, 4486],
#  [1601, 2900, 4898, 598],
#  [5264, 2459],
#  [2048, 1841, 2900, 4945],
#  [1996, 4802, 68, 3962, 3195],
#  [253, 3679],
#  [3908, 2719, 780, 370],
#  [780, 5540, 1054, 4233, 5264],
#  [5337, 3542, 3728, 4353, 2900, 596],
#  [5264, 1440],
#  [5540, 1465, 1054, 3298],
#  [2900, 438, 695, 435, 2630],
#  [4683, 4130, 596, 5382],
#  [4895],
#  [5047, 3328, 1631, 997, 2426, 2427],
#  [984, 447, 1187],
#  [2427],
#  [4419, 30, 5460],
#  [5341, 2947, 30, 4555],
#  [2048, 4895, 2995, 2459, 4564, 1159],
#  [253, 1871],
#  [1700, 2900, 438, 3542, 5171, 2859],
#  [1377],
#  [2927],
#  [2234],
#  [2900, 1346, 2708],
#  [5375],
#  [1846, 5183, 5784],
#  [1440, 2459, 3779, 4259],
#  [4694, 3064],
#  [2204],
#  [3907, 1803, 4205, 1853, 2384],
#  [780, 2423, 2504],
#  [1054, 1038, 1054, 161],
#  [3498, 2900, 4564, 3414],
#  [4564, 2955],
#  [5280],
#  [3537, 324, 3537],
#  [1460, 4259, 5280],
#  [2459, 1346, 5540, 1087, 5176, 3090],
#  [3230, 3537, 1054, 5064, 2872],
#  [780, 7, 3542, 1093, 3777],
#  [2955, 2319, 2900, 1583, 2423],
#  [4577, 4595, 5488, 2927, 4259, 5176],
#  [906],
#  [3573, 596, 5823, 3005],
#  [1871, 3907, 695, 2559],
#  [4895, 2319, 2900, 3960, 1871],
#  [2459, 2597, 2900],
#  [2900, 4564, 4259, 4443, 1492, 2459, 3285],
#  [906, 2459, 4564],
#  [4895],
#  [810, 2900, 2328, 946, 2859],
#  [5540, 1087, 5176, 4225, 2115],
#  [1377],
#  [1239],
#  [2459, 61, 1034],
#  [2900, 1346, 2955, 4520, 3290],
#  [1783, 805, 5269],
#  [2955],
#  [1460, 4429],
#  [3754, 709, 4284],
#  [4967],
#  [2048, 3537, 1026, 2544, 2004, 3414],
#  [2872],
#  [3725, 2900, 1026, 2358],
#  [3004],
#  [1440, 2900, 3725, 4259],
#  [3573, 4090, 2900, 896],
#  [4090, 2900, 322],
#  [2459, 755, 4564, 1871],
#  [4564, 2955],
#  [1871],
#  [3973, 1054, 3059],
#  [3537, 548, 1451],
#  [1377],
#  [4359],
#  [2459, 1268],
#  [78, 1440],
#  [3878],
#  [2900, 2324, 16, 1871, 1412],
#  [2459, 3762, 4259, 3754, 1054, 872],
#  [2900, 3762, 4259],
#  [2877, 2900, 4564, 5488, 3005],
#  [2219, 1451, 245, 2004, 5685],
#  [2234],
#  [1352, 4908, 2900, 1054, 3462],
#  [395, 2459, 2240],
#  [2900, 5820],
#  [3908, 395],
#  [3053, 91],
#  [91],
#  [1783, 1054, 3462, 3775],
#  [395],
#  [2900, 1609, 3109, 2579],
#  [3328, 4091, 5176],
#  [984],
#  [2219, 1277, 2817],
#  [2234, 2927],
#  [2955, 438, 2900, 3960, 5460],
#  [2900, 2319, 695],
#  [726],
#  [857],
#  [4314],
#  [2649, 5809, 2947, 3505, 2312, 3593],
#  [2900, 3725, 91, 4577, 3454, 2650],
#  [1277, 5115, 2652, 799, 5153],
#  [253, 3542, 514],
#  [2900, 5823, 3542, 509],
#  [219, 5269, 3697],
#  [5735, 780, 4259, 1159, 2066],
#  [5082, 4419, 91, 4390, 1451],
#  [2222, 3414, 3537, 4207],
#  [3004],
#  [3542, 4982, 54],
#  [2480, 3844],
#  [2459, 3746, 1034, 1265, 2947, 5394],
#  [1054, 2526, 5561, 1377, 3664],
#  [695, 2955, 3907, 4419, 477],
#  [1995, 3542, 4859, 4130, 4564],
#  [3436],
#  [1508, 810, 1159],
#  [3573, 2900, 5612, 5269],
#  [3638],
#  [2900, 4414, 1229, 5176],
#  [2900, 5269, 1465, 3414],
#  [1465],
#  [4109, 2806],
#  [2566],
#  [3542, 1151],
#  [2057],
#  [1680, 5176, 1508, 3023],
#  [2459, 61, 4517],
#  [2955],
#  [1440, 2859, 5648, 4532],
#  [596, 5488, 3542, 966, 1265, 5176],
#  [2900, 1346, 2955, 2459, 5199],
#  [1440],
#  [1440, 2955],
#  [1440, 2459, 1631, 4259, 596, 1265, 2900],
#  [4895, 4259],
#  [2900, 1680, 5176],
#  [4673, 3542, 3262, 1406],
#  [1440],
#  [4564, 2900, 5357, 5488, 1871, 2586],
#  [2955, 2586],
#  [2955, 2480, 497],
#  [3542, 5139, 2900],
#  [810, 2947, 2799, 2004, 1731, 1454],
#  [1440],
#  [80, 1440, 3262],
#  [3542, 966, 1783, 1271, 1054, 512],
#  [1440, 3878],
#  [810, 2900, 4443],
#  [2955],
#  [1026, 5403, 1465, 1054, 215],
#  [4895],
#  [1803, 1268, 810, 1054, 698, 3426],
#  [3878, 2900, 61, 2927],
#  [68, 1026],
#  [2900, 3762, 2955],
#  [3878],
#  [4895, 3762, 4259, 2900, 1680, 5176],
#  [1649, 4259],
#  [3094, 286],
#  [3537, 2513, 1508],
#  [842],
#  [3533, 596],
#  [3754, 1054, 5375, 2504, 4990],
#  [3878, 1377, 2955],
#  [2955, 5540, 4029],
#  [4419, 2639, 1266, 5488, 3542, 966],
#  [3185, 4259],
#  [1159, 3405, 2955, 2459, 5575],
#  [3908, 3602],
#  [3754, 2900, 898, 1034],
#  [1377],
#  [2459, 3762],
#  [2947, 3471],
#  [2955],
#  [1159, 3405, 435, 1305],
#  [1300, 2459],
#  [3414, 1268, 4259, 810, 1159],
#  [2459, 3762, 4259, 4443, 2423, 3542, 4571],
#  [695, 3762, 2900],
#  [3328, 5280],
#  [2459, 3516, 695],
#  [1268, 1159, 4419, 30],
#  [1700],
#  [1440, 5264],
#  [4410, 2004, 3414],
#  [1041, 4410],
#  [4359, 3762, 2955],
#  [1440, 2788],
#  [2575, 2459, 596],
#  [1087, 596],
#  [2900, 4206, 5176, 5269],
#  [2459, 5540, 1603],
#  [1440, 2459, 5540, 1603],
#  [5540, 19, 3005, 5382],
#  [780, 5540, 2900],
#  [1054, 673, 1166, 2900, 4707, 1871],
#  [3907, 1159, 91],
#  [5047, 2459, 810, 5488, 4475, 2900],
#  [4520, 4564, 5488],
#  [4520, 4564, 4259],
#  [1406, 3907, 1159, 1054],
#  [3081],
#  [3436, 4419, 3025],
#  [2719, 1649, 1026, 1054, 598],
#  [1649, 2955, 3414, 5405],
#  [3638, 3762, 2900, 2932, 3414],
#  [3638, 4683, 2900, 5588, 695, 2448],
#  [2897, 3907, 1054, 5333],
#  [695, 1268, 100],
#  [3293, 515, 5488, 837, 1159, 2813],
#  [3474, 2813],
#  [5714, 3907, 1508, 2859, 489, 2544],
#  [2459, 2328, 5588, 2479, 1465, 1062],
#  [2459, 1346],
#  [438, 4130, 4945, 5488, 3036],
#  [2459, 946, 1159, 2613, 5488, 3491],
#  [2459, 2659, 4419, 302],
#  [796, 2900, 438, 91],
#  [4419, 1071, 2048, 1159, 2004, 849],
#  [5345],
#  [3542, 4522, 3907, 3922],
#  [2116, 2719],
#  [1084],
#  [4087, 2004, 2426, 5540, 5835],
#  [1084, 4034],
#  [984, 4683, 2459, 461, 1871, 3984],
#  [3789],
#  [3542, 5424, 3907, 1206],
#  [1159, 3328, 1268, 1333],
#  [2249, 2459, 1404, 2474],
#  [1054, 1131],
#  [3638, 1690, 438, 2900, 3845, 1084],
#  [3885, 516, 4419, 3025, 2048, 2900],
#  [1440],
#  [1440],
#  [3537, 4259, 1348],
#  [3573, 2900, 438, 3775, 1127],
#  [4414, 4419, 3025, 981],
#  [5449, 1054, 418],
#  [3328, 4392, 3436],
#  [399, 2719],
#  [1649, 1508, 2900, 489, 3859],
#  [2459, 3252, 5488, 596, 1265, 2900],
#  [3131, 5588, 1054, 2504],
#  [2459, 2659, 4797, 2947, 4806],
#  [2955, 438, 2900, 3969],
#  [3638, 4549],
#  [2459, 2163, 1026, 2900],
#  [2637, 5176, 246],
#  [2719, 5588, 1265, 1825, 3581],
#  [2048, 2955, 4564, 2900, 5820, 996],
#  [3972, 117, 5460],
#  [2955, 4564, 2900, 1100],
#  [5103, 841],
#  [2379, 3542, 1968, 2602],
#  [78, 4087, 596, 2238],
#  [4130, 755, 3754, 898, 157],
#  [4111, 2282, 1339, 3436],
#  [2900, 3854, 5588, 628],
#  [2900, 5820, 2459, 4564, 4259, 1346, 1159],
#  [3725, 1211],
#  [2900, 579],
#  [2900, 1680, 1159, 5488, 2426],
#  [1460, 91, 1087, 3542, 46, 3859],
#  [3290, 4259, 5460, 5215],
#  [1430, 4576],
#  [2900, 3972, 2900, 1404, 3169],
#  [1680, 3542, 2403, 4130, 399, 1034],
#  [2403, 4532],
#  [2403, 5405, 3638, 2770],
#  [1675],
#  [4895],
#  [5488, 1004, 3542, 3420, 2004, 2719],
#  [2048, 5852, 5488, 1004, 4308],
#  [2403, 5405],
#  [4564, 4520, 3754, 4605, 1219],
#  [2900, 3113, 1590, 2831],
#  [1465, 1054, 4404],
#  [2249, 2459, 896, 4138, 3148],
#  [4676, 2048, 4167, 1084],
#  [2900, 4564, 4259, 3134, 896],
#  [4130, 4564, 4259, 3735, 5488, 1346],
#  [1803, 150],
#  [896, 1034, 1492, 1803, 1631, 2390],
#  [2947, 3622, 2441, 4259, 1602],
#  [5498, 3907, 2955, 3698, 3022],
#  [2900, 1631, 5496, 1871],
#  [3907, 1871, 3023, 1629, 3051],
#  [1803, 3854, 5588, 87],
#  [3666, 1950, 4267, 4197],
#  [3436, 2459, 837],
#  [2947, 2550, 2004, 3520],
#  [3520, 5488, 2955],
#  [4099, 2004, 3542, 232, 617],
#  [3638, 4576, 4227, 5460],
#  [2459, 3754, 5488, 4367, 3542, 4116],
#  [1871, 2504, 1265, 5176],
#  [399, 2900],
#  [3573, 4895],
#  [3844, 2426],
#  [219, 4808, 2004, 1159, 5707],
#  [2955, 4564, 2900, 1601],
#  [492, 2949, 4607, 4586],
#  [4520, 1030, 3689],
#  [3638, 438, 2900, 4098, 3017],
#  [4259, 2066],
#  [253, 1803, 3960],
#  [4130, 489, 5588],
#  [3474],
#  [2900, 4683, 1601, 1465, 1590],
#  [2459, 3754, 5488, 690],
#  [2459, 3664, 2900, 2995],
#  [1153, 3916, 3177, 1153, 1158],
#  [2459, 2659, 2872, 3524],
#  [2955, 3907, 3414, 5382, 1680, 5176],
#  [2955, 438, 2900, 4797, 5488],
#  [2955, 2441, 1803, 3290],
#  [5280],
#  [4034, 4648, 3297],
#  [5280],
#  [3762, 2900, 3535, 2955, 2459, 4392],
#  [3436, 3044],
#  [1819, 1771, 532],
#  [2459, 3754, 5117, 1119],
#  [3436],
#  [3906, 65, 1825, 3972, 2989, 1327],
#  [3907, 1451, 1054, 5677],
#  [5728, 2947, 4020],
#  [4130, 438, 1691, 4227, 2060],
#  [1819, 1771],
#  [1803, 2441, 4259, 1404, 5568],
#  [2459, 1404, 5568],
#  [1153, 5367],
#  [1054, 3000, 51],
#  [3537, 5460, 1465, 2768],
#  [477, 5176],
#  [3931, 100],
#  [3326, 2005],
#  [3706, 1853, 407, 1159, 3907, 4441],
#  [3537, 4259, 2857],
#  [1459, 1803, 1054, 5064, 2857],
#  [1026, 5115, 1265, 1377],
#  [3638, 1690, 438, 4419, 4542],
#  [395],
#  [424, 2900, 3754, 4477, 4542, 91],
#  [2459, 2659, 2600],
#  [2900, 497, 759, 1026, 3414],
#  [4108, 4168],
#  [438, 2900, 663],
#  [1440, 438, 2900, 5849],
#  [3537, 127, 406],
#  [2575],
#  [2460, 4588, 3151],
#  [2900, 2274],
#  [4034, 1404, 26],
#  [4130, 3754, 1440, 4571, 3972, 2989],
#  [695, 2955, 3907, 5661],
#  [4259, 2955, 1377],
#  [1649, 5661],
#  [2274],
#  [2782, 2426, 4808, 2004, 2947, 4859],
#  [5280, 2900, 2274],
#  [395, 395, 3931],
#  [1302, 1159, 7, 5823, 3542, 5262],
#  [2955],
#  [2808, 810, 2647, 3092, 2288],
#  [5832],
#  [4980, 4980],
#  [3762, 2900, 4645, 3005],
#  [1017, 5823, 2947, 4571],
#  [4130, 2293, 3414],
#  [1441, 1441],
#  [2459, 4683, 5823, 2900, 1054, 4521],
#  [1054, 4521],
#  [3436, 3542, 4571, 3907, 2480],
#  [68, 1054, 4019],
#  [780, 2721, 5488, 5699],
#  [4130, 5747, 117, 2900, 4683, 3775],
#  [1870, 1964, 2298, 4564, 4259, 581, 5081],
#  [3908, 395, 2240, 937],
#  [3908, 395, 4895],
#  [1440, 596, 991],
#  [1943, 2662, 3414],
#  [4933, 2412, 3775],
#  [2412],
#  [4034, 3744, 4419, 4928],
#  [3878, 2900, 3664, 1159, 91],
#  [2955, 1268, 1159],
#  [3315, 2004, 1054, 3797],
#  [2900, 1346, 2955, 1159, 3907, 91],
#  [1440, 2955, 3907, 3414],
#  [253, 1803, 4339, 1465],
#  [1054, 5043],
#  [1803, 3664, 4087, 1060],
#  [2955],
#  [3638, 2770, 2211, 438, 5269, 1451],
#  [3907, 3414, 4868, 917],
#  [2955],
#  [2900, 5280],
#  [1302, 1159, 5686, 3777, 7],
#  [1404, 5568],
#  [2900, 4392, 1404, 268],
#  [3638, 2900, 5060, 1871],
#  [73],
#  [395],
#  [3004, 2900, 4683, 5588, 785, 3600],
#  [1377, 3762, 3914, 2048, 4660],
#  [1377, 4564, 2900, 5820, 2403],
#  [395, 91],
#  [2955, 1268, 1159, 2543],
#  [2459, 4872, 3962, 4150],
#  [395, 2955, 2738],
#  [4419, 3641],
#  [3725, 1026, 2624, 1159, 3907, 2860],
#  [5823, 1026, 3542, 3807],
#  [2234, 3537, 4990],
#  [3155, 268, 509],
#  [984, 3907, 314, 2863],
#  [2637, 5176, 3542, 1623],
#  [3638, 4549, 4520, 16, 1428, 5460],
#  [2900, 3535, 1159, 3262, 4351],
#  [3713, 2900, 245],
#  [2388, 3542, 3847],
#  [2349, 2459, 5366, 2873, 3414],
#  [2349, 4895, 755, 2900],
#  [2459, 4564, 4259, 5632, 2388, 4569],
#  [2480, 2480, 4425],
#  [4796],
#  [2150],
#  [1377, 5405, 3328, 3907, 1054, 623],
#  [2955, 2995, 2900, 3844, 3005],
#  [4690, 4213, 810, 2955, 5722, 4963],
#  [3293, 3972, 1265, 2900],
#  [1871, 3907, 4259, 3797, 4190],
#  [1460, 3978],
#  [2947, 569, 438],
#  [4581, 5460],
#  [1377, 3907, 1803],
#  [1871, 4087, 2900, 3252],
#  [3436, 1691],
#  [984, 3907, 3328],
#  [3886, 1054, 4249],
#  [3109, 4924],
#  [3202, 5171],
#  [780, 5280],
#  [3542, 2366],
#  [5171, 2859, 680, 5005, 1026],
#  [395],
#  [2900, 1187, 5488, 3542, 314, 2863],
#  [2900, 4477, 3109, 728, 5541],
#  [3293, 1087, 2900, 1346, 2955, 440],
#  [3293, 3844, 3414, 2266],
#  [1819, 2156],
#  [728, 5809, 2859],
#  [3820, 1451],
#  [253, 308],
#  [3908, 2947, 938, 4990, 4514, 5755],
#  [1440],
#  [3762, 2900, 1680, 1034, 2900, 3762],
#  [2955, 438, 2900, 3969],
#  [3589, 1034],
#  [2900, 4580],
#  [3537, 2989, 2678],
#  [2004, 5517],
#  [4581, 1265, 3005],
#  [438, 2900, 1595],
#  [1440, 3537, 5280],
#  [3695, 3695, 1841, 2900, 1595],
#  [3414, 1588, 1593, 3931],
#  [4218, 2115, 4581, 2115, 3695],
#  [3634, 3392, 3392, 3392],
#  [3147, 438, 2900, 5280],
#  [395, 1542, 4259, 1054, 2480, 2504],
#  [3634],
#  [3634],
#  [3634],
#  [3634],
#  [5280],
#  [596, 2989],
#  [3907, 1159, 4087, 1451, 3907],
#  [1440, 1440, 4564, 4259, 4970, 5488, 1594],
#  [4895, 4259],
#  [1508, 1347, 1446],
#  [3634, 1649, 1054, 5378, 3797],
#  [3436, 3878, 1803, 1268, 1054, 5526],
#  [1054, 5526],
#  [4354, 161],
#  [2900, 2258, 4970, 5488, 3005, 4555],
#  [395],
#  [2459, 4564, 4259, 3754, 1054, 5242],
#  [2947, 1226, 5187],
#  [3537, 5542, 5460],
#  [695, 2659, 2459],
#  [2900, 1346, 2955, 3537, 3969, 5460],
#  [2219, 3537, 1054, 484],
#  [2923, 5269],
#  [2441, 3414, 4645],
#  [4034, 3252, 5488, 2055, 1871],
#  [4520, 1631, 4259, 1129, 1871, 3907, 117],
#  [438, 2900, 663],
#  [4952],
#  [4156, 5648],
#  [2219, 4990],
#  [2219],
#  [3237, 3414],
#  [3634, 3634, 3147, 4034, 204, 5176],
#  [3537, 4259],
#  [1460, 684],
#  [1460, 4259, 695, 2066, 1590],
#  [2328, 5588, 2961],
#  [4673, 3542, 5025],
#  [4673, 3414],
#  [1649, 2480],
#  [395],
#  [78, 1159, 3907, 5375],
#  [1336],
#  [2559, 2900, 703, 2459, 5115, 2900],
#  [2459, 5115, 2900],
#  [5280, 5831, 4284],
#  [4284],
#  [2900, 1336],
#  [395, 2459, 1336],
#  [395, 395, 2480, 3777],
#  [5280],
#  [1601, 2900, 407, 2480, 338],
#  [399, 2900],
#  [4034, 5588, 1717],
#  [3174, 3033, 3907, 3680],
#  [395, 1871, 4859],
#  [2900, 5314, 3947, 1054, 4566],
#  [3436, 2459, 5314, 3414],
#  [3762, 2900, 3135, 1302, 5763, 4353],
#  [1440],
#  [2955, 2423, 1347, 1446],
#  [1440],
#  [695, 2900, 3725, 4414, 1054, 4566],
#  [2955, 438, 2900, 2070, 5176],
#  [2459, 1346],
#  [2955, 3907, 3414],
#  [2459, 3762],
#  [4895, 4259],
#  [5082, 3542, 2385, 2115, 3649],
#  [2955, 3907, 1159],
#  [4225, 2115],
#  [2955, 4564, 2900, 5199, 3586, 5269],
#  [2459, 1087, 3005, 1840, 1054, 740],
#  [1440, 3593, 4029],
#  [3908],
#  [3414, 1268, 2947, 1317, 4259, 785],
#  [3908, 395, 3634],
#  [5540, 1054, 740],
#  [3444, 3438],
#  [2955, 4564, 2900, 3252],
#  [253, 4419, 5407],
#  [2459, 2620, 2938, 951],
#  [3573, 4564, 3414, 4080],
#  [2480, 2161],
#  [3392],
#  [2459, 1346],
#  [78, 1803],
#  [3537, 3408, 5488, 1680, 2900],
#  [3634, 596, 991],
#  [2247],
#  [2955, 438, 2900, 3960, 5460],
#  [2314, 4477, 1054, 3844],
#  [2955, 3414, 2441, 4259, 1602, 1159, 4859],
#  [1300, 1054, 3298, 1300, 1054, 3298],
#  [3638, 1268, 3414],
#  [4259, 2480],
#  [3762, 3542, 1655, 2741, 3005, 4459],
#  [395, 1803, 2869, 4454, 1339],
#  [395],
#  [5280, 3878, 4259, 368, 4585],
#  [438, 2900, 3634],
#  [2459, 3454, 489, 3491, 1123, 2479],
#  [3537, 941],
#  [3907, 1803, 4419, 3510],
#  [3537, 4243, 2459, 3280, 2900],
#  [2900, 728, 5823, 392],
#  [91],
#  [4564, 2900, 3754, 3058],
#  [1026, 3542, 4015],
#  [3293, 3678, 746, 1465, 1825],
#  [3293, 5823, 2947, 4862],
#  [2955, 438, 2900, 3960],
#  [2828, 3414, 4808],
#  [5823, 2862, 5460],
#  [2955, 3542, 2500, 4029],
#  [1015, 4973, 2457],
#  [3537, 5542],
#  [2923, 5269, 219],
#  [5588, 5636, 2388],
#  [2137],
#  [2900, 4477, 1159],
#  [1440, 2459, 4564, 4259, 5823, 1159],
#  [5460, 2459, 3754, 4419, 4571],
#  [3908, 1440, 1440, 1107],
#  [4034, 3290, 677],
#  [984, 438, 4130, 4945],
#  [3537, 291, 1265, 2900],
#  [3436, 3436, 3972, 1265, 5176],
#  [3293, 1840, 1034],
#  [1440, 4859, 2379, 1343],
#  [3725, 3886, 1034, 4034, 3036],
#  [2379, 2947, 3584],
#  [78, 1803, 741, 2947, 3556],
#  [4034, 2637, 5176, 1159, 5686, 1107],
#  [542, 1840, 1054, 3292],
#  [2955, 438, 2900, 127, 4564],
#  [4034, 2195, 5488, 785, 934],
#  [1147, 5588, 2947, 3169],
#  [5823, 2115, 2989, 4419, 4431],
#  [3155, 4419, 3556],
#  [2900, 1004, 3542, 386],
#  [3908, 906],
#  [1831, 2048, 1109],
#  [2459, 1268, 4087, 2004, 24],
#  [2955, 2423, 3649],
#  [1440, 1803, 3907, 5460, 1107],
#  [253, 4419, 3392, 3638, 2008],
#  [2459, 2995, 1260, 1948, 3907, 5724],
#  [1440, 1440, 4859],
#  [3878, 780],
#  [2955, 5648, 4564, 2900, 3735],
#  [2637, 5176, 859, 2859, 3906],
#  [4419, 74, 1268, 701],
#  [1347, 1026, 3542, 268, 4905],
#  [4683, 2459, 1601, 4419, 1347],
#  [3537, 5044, 4034, 2900, 5820],
#  [4306, 2947, 3519],
#  [3878, 2403, 117, 1871],
#  [258, 2459],
#  [121],
#  [1087, 3005, 596, 1087, 3005, 596],
#  [3638, 4564, 2900, 4564, 329, 3791],
#  [3906, 3414, 4378, 2441, 4259, 3281],
#  [3436, 3425, 726],
#  [78, 457, 4130, 596, 4421, 5495],
#  [324],
#  [3436, 3414, 3907, 291, 1060, 3425, 78],
#  [3537, 1144, 1054, 4233, 2460],
#  [3436, 2459, 1346, 1159, 384],
#  [438, 2900, 291, 5488, 2947, 4233],
#  [2575, 438, 2900, 291, 1446],
#  [1026, 9, 2282, 5452, 2459, 3516],
#  [2015, 4808, 5488, 3542, 5682, 5463],
#  [984, 3907, 4347, 1586],
#  [4577, 1026, 3542, 3807],
#  [399, 2900, 5264],
#  [3436, 5264],
#  [3522, 3522, 5382, 384],
#  [5618, 5264],
#  [930, 5258, 5789],
#  [5149],
#  [438, 2900, 1094, 906],
#  [3436, 4378, 399, 2900, 3425, 2008],
#  [5149],
#  [4577, 3243],
#  [2048, 4419, 2596, 5064, 540],
#  [3908, 1159, 3907, 4605, 1054, 4866, 4647],
#  [3638, 3907, 5111],
#  [4378],
#  [5149],
#  [1649, 91],
#  [2459, 1601],
#  [5149],
#  [78, 1159, 2441, 4251, 3425, 5579],
#  [661, 4520, 3762],
#  [78, 3537, 4243, 2423, 1159],
#  [4433],
#  [5149],
#  [5149],
#  [3908, 399, 2900, 3425, 2008],
#  [399, 2900],
#  [78, 3638, 3907, 3414, 4945, 1347, 1451],
#  [3293, 4226, 3414, 3907, 1054, 1113],
#  [2575, 4564, 4130, 1589, 4588, 1257],
#  [399, 2900],
#  [2955, 4564, 2900, 5199],
#  [2459, 1601],
#  [3109, 5541, 2423, 3542, 3016],
#  [2234, 3199, 291, 1026, 3906],
#  [91, 5540, 1054, 2925],
#  [5280],
#  [5280, 3972, 2989, 2115],
#  [906, 2955, 3907, 3414],
#  [253, 5269],
#  [780, 2423, 2947, 1316, 1697],
#  [3436],
#  [5149],
#  [4378],
#  [3436],
#  [5149],
#  [780, 4229],
#  [1440, 2459, 4414, 3762, 922],
#  [3908],
#  [5149],
#  [78, 2955, 3907, 3414],
#  [1159, 5783, 3425, 2398],
#  [3436, 2459, 5575, 695],
#  [3638],
#  [1649, 3023],
#  [3683],
#  [2379, 4477, 1054, 1226],
#  [5149],
#  [3878, 4259, 435, 602],
#  [2459, 1779, 3414, 3907, 4259, 2208, 1494],
#  [2459, 2240, 3414, 1459],
#  [5149],
#  [2459, 1631, 1492, 2459, 4683, 3199],
#  [3023],
#  [1649, 3023],
#  [1649, 3023],
#  [1649, 3023],
#  [1649, 3023],
#  [399, 2900, 3425, 2008, 2524],
#  [2955, 3907, 3414, 2524],
#  [5482],
#  [3934, 4138, 3934, 3199],
#  [2459, 3022],
#  [2524, 4801, 3679, 656, 5767],
#  [5482],
#  [2524, 1469, 4087, 1036, 5785, 2007],
#  [3115, 3433, 2532, 5785],
#  [78, 1159, 3907, 1508],
#  [3436, 2524, 2955, 3907, 5269],
#  [2480, 442, 4348, 3414, 4945],
#  [438, 2900, 468, 4330],
#  [1460, 4593],
#  [1440],
#  [1819, 5464],
#  [2524],
#  [3436],
#  [906, 4082, 2955, 3907, 5269],
#  [3436, 2459, 1346],
#  [3537, 941, 2423, 3542, 5718, 2524],
#  [78, 4564, 4259, 1390, 2423, 3414],
#  [2048, 4564, 4259, 2900, 1390, 2423, 3414],
#  [3436, 3414, 3907, 2524],
#  [780, 3542, 4131, 2859],
#  [2459, 2240, 4259],
#  [5482],
#  [3775, 2066, 2423, 3199, 3907, 4259, 3414],
#  [3436, 3414, 3907],
#  [3542, 3439, 1271, 5488, 5588, 87],
#  [2524, 599, 5488, 287, 4572, 2544],
#  [2955, 2659, 2459, 1603, 1465],
#  [2459, 4564, 4259, 5820, 4419, 5081, 2917],
#  [2459, 3454, 4564, 4259, 5820, 3414, 3907, 2917],
#  [2219, 2900, 438, 91],
#  [1460, 870],
#  [3537, 4087, 3895],
#  [253, 308, 1265, 1159],
#  [2877, 2900, 4564],
#  [2459, 2240, 1803, 4477, 3542, 748],
#  [1680, 3146, 3971, 5488, 3535, 3414],
#  [3638, 2561, 438, 4520],
#  [3638, 447, 3545],
#  [1402, 1765],
#  [395, 1690, 924],
#  [78, 5739, 2900, 1840, 3414, 4028],
#  [906, 91],
#  [2459, 3252, 5488, 1636, 4454],
#  [2459, 2659, 4259, 245, 4258],
#  [5698, 5199, 4343],
#  [1396],
#  [3263, 4571],
#  [395, 3481, 4571],
#  [3004, 1159, 1176, 1054, 5671, 477],
#  [3844, 5176, 407],
#  [2900, 906, 2900, 3252, 5176, 5488],
#  [395, 1465, 746, 5159, 3537, 906],
#  [1943, 1465, 3542, 3058],
#  [4980, 3957],
#  [3933, 596, 991, 1784, 3414],
#  [2575],
#  [2900, 3988, 5826],
#  [2219, 2955, 2423, 5176],
#  [2219],
#  [2923, 5269],
#  [2923, 5269],
#  [562],
#  [2955, 4564, 2900, 3252],
#  [2782, 4364],
#  [3634, 3537, 3251, 2989],
#  [2900, 1274, 4806, 2004, 1054, 4349],
#  [1649, 2955, 2900, 3290, 5524],
#  [395],
#  [3542, 168, 1588, 2441, 4259, 3414, 927],
#  [3293, 2390, 2900, 4808],
#  [1107],
#  [3933, 3282],
#  [1377, 438, 4087, 24],
#  [2219, 3375, 5804],
#  [2859, 2004, 1852, 1026, 3542, 4103],
#  [395, 2459, 1100, 3542, 316],
#  [395],
#  [717],
#  [395],
#  [3293, 2782, 3414, 1026, 5046],
#  [5375, 967, 1465, 3151],
#  [395, 2859, 2004, 2947, 62],
#  [2900, 1095, 3542, 3499, 952],
#  [717, 438, 2900, 5280],
#  [2900, 4477, 1054, 1938, 5526],
#  [906, 677, 2900, 3252],
#  [395, 2459, 1115],
#  [395],
#  [1460, 2238],
#  [2459, 4477, 1054, 199, 5488, 2061],
#  [5732],
#  [3293, 5820, 2423, 3414],
#  [1871, 674, 5172, 4808, 4665],
#  [1440, 4859, 5488, 3973, 1054, 4381],
#  [1107, 3537, 3802, 941],
#  [395],
#  [3957, 1268, 4126, 2004, 3542, 812],
#  [2955, 812, 2900, 323, 2423, 717],
#  [3537, 2651, 2900, 3602],
#  [5540, 69, 5176, 3542, 4592, 3346],
#  [1054, 5526],
#  [2219, 1871, 5663, 4796, 2480],
#  [399, 2900],
#  [3252, 5488, 515, 3414, 937],
#  [2459, 4564, 4259, 1346],
#  [2575, 3638],
#  [2955, 4564, 2900, 5820],
#  [5382, 984, 4130, 1187, 4221],
#  [2459, 4564, 4259, 2637, 4808, 3542, 5705],
#  [4131, 1824, 1819, 1775, 1339, 9],
#  [4131, 1824],
#  [2900, 3754, 1054, 2480, 2504],
#  [78],
#  [2219, 2900, 2258, 4226],
#  [2955, 438, 2900, 323, 2423],
#  [3542, 3, 7],
#  [395],
#  [3326],
#  [5382, 3638, 3907, 4419, 3696, 3545],
#  [2900, 1095, 1159, 1654, 3602],
#  [1451],
#  [3854, 5588, 1962, 509],
#  [3972, 2989],
#  [3638, 2423, 3414],
#  [3533, 596],
#  [4520, 3829, 4419, 2198, 4221],
#  [3638, 2008],
#  [1948, 1054, 3681],
#  [3931],
#  ...]

# %%
#bucketing threshold

#here it is possibile to add as many buckets as needed
buck_t1=long_threshold

#buck_tmax=max([len(x) for x in encoder_input_data]) 


b1_enc_in=[]  #bucket 1 encoder input
b1_dec_in=[]  #bucket 1 decoder input
b1_dec_out=[] #bucket 1 decoder output

for index in range(len(encoder_input_data)):
    if len(encoder_input_data[index])<=buck_t1:
        b1_enc_in.append(encoder_input_data[index])
        b1_dec_in.append(decoder_input_data[index])
        b1_dec_out.append(decoder_output_data[index])
        
b1_dec_out
# Out:
# [[1440, 2],
#  [2900, 2951, 2258, 5820, 2423, 3414, 2],
#  [2459, 2873, 2900, 2],
#  [1265, 3542, 3144, 2004, 4419, 301, 2],
#  [2900, 3542, 1153, 5344, 2],
#  [695, 4520, 1680, 5176, 2],
#  [695, 1041, 1462, 2900, 4227, 2],
#  [5508, 3255, 3498, 2900, 2],
#  [4042, 2],
#  [5823, 4808, 2],
#  [3638, 2770, 1158, 596, 5460, 2],
#  [1738, 1884, 993, 2004, 2426, 59, 2],
#  [1159, 3537, 4872, 5488, 2],
#  [1159, 509, 2459, 2],
#  [2900, 1080, 2900, 2562, 2900, 2273, 2],
#  [1377, 3907, 3328, 2],
#  [4895, 4259, 2],
#  [910, 2],
#  [3820, 1159, 2],
#  [1406, 4412, 757, 3570, 2],
#  [1803, 2324, 219, 695, 2],
#  [659, 2339, 2],
#  [5540, 1054, 5064, 2],
#  [253, 1871, 2],
#  [3962, 2734, 536, 2],
#  [1803, 2324, 3754, 1159, 1395, 2094, 2],
#  [2900, 1346, 1096, 2],
#  [1649, 3005, 5662, 30, 2],
#  [3542, 707, 4668, 1329, 2514, 2],
#  [1026, 3542, 2191, 2],
#  [3678, 835, 3781, 4142, 2],
#  [1564, 2900, 16, 2],
#  [330, 2234, 5264, 2],
#  [253, 1054, 5165, 1465, 4079, 2],
#  [2459, 1346, 2],
#  [2900, 920, 2],
#  [2955, 1492, 3328, 4414, 2976, 4287, 2],
#  [3257, 2],
#  [3878, 3328, 2441, 4259, 3252, 5488, 512, 2],
#  [5458, 2],
#  [1460, 4259, 2046, 2],
#  [2222, 3414, 2],
#  [3230, 2],
#  [4895, 2],
#  [1649, 1054, 2104, 2],
#  [2955, 2423, 1034, 2],
#  [2900, 2258, 596, 4808, 1265, 1034, 2],
#  [1649, 2955, 2459, 5540, 4392, 2],
#  [2459, 5575, 2900, 169, 1228, 1158, 2],
#  [2219, 2],
#  [438, 2900, 1211, 2],
#  [4130, 4564, 4259, 2674, 2],
#  [3725, 4259, 2],
#  [2441, 1871, 5471, 3754, 1054, 3817, 2],
#  [2900, 4477, 1034, 4653, 2],
#  [1649, 4414, 16, 4818, 2],
#  [1321, 1271, 785, 2743, 2],
#  [2441, 3414, 3281, 2],
#  [854, 2004, 3542, 1817, 2],
#  [253, 5488, 5198, 2],
#  [2222, 1096, 2],
#  [1451, 2],
#  [984, 2],
#  [395, 2],
#  [2955, 4564, 2900, 5820, 2],
#  [1819, 551, 5671, 5308, 2],
#  [2900, 5540, 4392, 2],
#  [3638, 2008, 2],
#  [324, 3885, 2],
#  [5322, 2048, 2900, 3754, 4477, 4419, 3984, 2],
#  [2947, 365, 1026, 1071, 2],
#  [2490, 2900, 5269, 508, 3573, 2],
#  [3908, 91, 508, 2],
#  [2900, 61, 5176, 4564, 4259, 2900, 2],
#  [2048, 4895, 2995, 2459, 4564, 1159, 2],
#  [2900, 4906, 1026, 2947, 3523, 2],
#  [1338, 2],
#  [438, 2900, 627, 5176, 2],
#  [2234, 2],
#  [2219, 4564, 2900, 5046, 2],
#  [4259, 4588, 4087, 2],
#  [2947, 4072, 2441, 4259, 650, 3085, 2],
#  [2459, 5575, 2900, 3725, 1830, 5176, 2],
#  [4895, 489, 4130, 730, 2989, 1871, 2],
#  [5047, 2900, 438, 2565, 4565, 1465, 5176, 2],
#  [2459, 5540, 5719, 2947, 5566, 2],
#  [2955, 2],
#  [1054, 5676, 2546, 1054, 512, 2],
#  [2222, 3414, 2],
#  [2222, 3005, 30, 3573, 2],
#  [2900, 4477, 1508, 2989, 4419, 5046, 2],
#  [1460, 1277, 2],
#  [3290, 3414, 2],
#  [2955, 2],
#  [2955, 3630, 2],
#  [695, 1239, 4683, 5823, 3542, 509, 2],
#  [3725, 4419, 680, 2],
#  [395, 4130, 1631, 1601, 2],
#  [1631, 247, 5823, 3627, 2],
#  [780, 5464, 2],
#  [3080, 2],
#  [5395, 2],
#  [906, 3754, 2],
#  [4577, 4259, 1054, 2],
#  [1933, 2900, 4477, 1465, 5176, 2],
#  [2955, 2],
#  [2480, 3257, 2],
#  [1424, 2859, 3328, 2765, 5477, 2],
#  [780, 1054, 3651, 3093, 3658, 2],
#  [3005, 3006, 4001, 2],
#  [5755, 4588, 4815, 2],
#  [5540, 1465, 5382, 2],
#  [2379, 4796, 2],
#  [5280, 2459, 1268, 4259, 906, 2],
#  [3135, 16, 5488, 2236, 5723, 2],
#  [395, 2],
#  [3648, 3907, 3810, 1451, 2460, 1824, 2],
#  [4034, 3678, 5176, 4564, 3414, 3984, 2],
#  [41, 4419, 1048, 1465, 2859, 1824, 2],
#  [780, 3005, 3006, 3059, 2],
#  [3537, 1046, 2900, 680, 728, 2],
#  [2955, 4564, 2900, 5820, 2],
#  [2900, 5820, 5670, 1602, 2],
#  [1440, 2799, 2],
#  [2324, 1054, 1181, 5553, 2],
#  [4414, 2],
#  [5540, 4853, 4681, 4421, 2],
#  [2219, 5375, 4885, 3602, 2],
#  [2],
#  [477, 5176, 2],
#  [1649, 2955, 2900, 3252, 3907, 4259, 3414, 2],
#  [4895, 4564, 4259, 2900, 2],
#  [2877, 1803, 3290, 2],
#  [1377, 3329, 2],
#  [2900, 2597, 5176, 1159, 4126, 3802, 2],
#  [2459, 3535, 2900, 438, 2651, 4412, 2],
#  [3574, 395, 3725, 1690, 4020, 2],
#  [2900, 2048, 4412, 2],
#  [1460, 435, 4486, 2],
#  [1601, 2900, 4898, 598, 2],
#  [5264, 2459, 2],
#  [2048, 1841, 2900, 4945, 2],
#  [1996, 4802, 68, 3962, 3195, 2],
#  [253, 3679, 2],
#  [3908, 2719, 780, 370, 2],
#  [780, 5540, 1054, 4233, 5264, 2],
#  [5337, 3542, 3728, 4353, 2900, 596, 2],
#  [5264, 1440, 2],
#  [5540, 1465, 1054, 3298, 2],
#  [2900, 438, 695, 435, 2630, 2],
#  [4683, 4130, 596, 5382, 2],
#  [4895, 2],
#  [5047, 3328, 1631, 997, 2426, 2427, 2],
#  [984, 447, 1187, 2],
#  [2427, 2],
#  [4419, 30, 5460, 2],
#  [5341, 2947, 30, 4555, 2],
#  [2048, 4895, 2995, 2459, 4564, 1159, 2],
#  [253, 1871, 2],
#  [1700, 2900, 438, 3542, 5171, 2859, 2],
#  [1377, 2],
#  [2927, 2],
#  [2234, 2],
#  [2900, 1346, 2708, 2],
#  [5375, 2],
#  [1846, 5183, 5784, 2],
#  [1440, 2459, 3779, 4259, 2],
#  [4694, 3064, 2],
#  [2204, 2],
#  [3907, 1803, 4205, 1853, 2384, 2],
#  [780, 2423, 2504, 2],
#  [1054, 1038, 1054, 161, 2],
#  [3498, 2900, 4564, 3414, 2],
#  [4564, 2955, 2],
#  [5280, 2],
#  [3537, 324, 3537, 2],
#  [1460, 4259, 5280, 2],
#  [2459, 1346, 5540, 1087, 5176, 3090, 2],
#  [3230, 3537, 1054, 5064, 2872, 2],
#  [780, 7, 3542, 1093, 3777, 2],
#  [2955, 2319, 2900, 1583, 2423, 2],
#  [4577, 4595, 5488, 2927, 4259, 5176, 2],
#  [906, 2],
#  [3573, 596, 5823, 3005, 2],
#  [1871, 3907, 695, 2559, 2],
#  [4895, 2319, 2900, 3960, 1871, 2],
#  [2459, 2597, 2900, 2],
#  [2900, 4564, 4259, 4443, 1492, 2459, 3285, 2],
#  [4895, 2],
#  [810, 2900, 2328, 946, 2859, 2],
#  [5540, 1087, 5176, 4225, 2115, 2],
#  [1377, 2],
#  [1239, 2],
#  [2459, 61, 1034, 2],
#  [2900, 1346, 2955, 4520, 3290, 2],
#  [1783, 805, 5269, 2],
#  [2955, 2],
#  [1460, 4429, 2],
#  [3754, 709, 4284, 2],
#  [4967, 2],
#  [2048, 3537, 1026, 2544, 2004, 3414, 2],
#  [2872, 2],
#  [3725, 2900, 1026, 2358, 2],
#  [3004, 2],
#  [1440, 2900, 3725, 4259, 2],
#  [3573, 4090, 2900, 896, 2],
#  [4090, 2900, 322, 2],
#  [2459, 755, 4564, 1871, 2],
#  [4564, 2955, 2],
#  [1871, 2],
#  [3973, 1054, 3059, 2],
#  [3537, 548, 1451, 2],
#  [1377, 2],
#  [4359, 2],
#  [2459, 1268, 2],
#  [78, 1440, 2],
#  [3878, 2],
#  [2900, 2324, 16, 1871, 1412, 2],
#  [2459, 3762, 4259, 3754, 1054, 872, 2],
#  [2900, 3762, 4259, 2],
#  [2877, 2900, 4564, 5488, 3005, 2],
#  [2219, 1451, 245, 2004, 5685, 2],
#  [2234, 2],
#  [1352, 4908, 2900, 1054, 3462, 2],
#  [395, 2459, 2240, 2],
#  [2900, 5820, 2],
#  [3908, 395, 2],
#  [3053, 91, 2],
#  [91, 2],
#  [1783, 1054, 3462, 3775, 2],
#  [395, 2],
#  [2900, 1609, 3109, 2579, 2],
#  [3328, 4091, 5176, 2],
#  [984, 2],
#  [2219, 1277, 2817, 2],
#  [2234, 2927, 2],
#  [2955, 438, 2900, 3960, 5460, 2],
#  [2900, 2319, 695, 2],
#  [726, 2],
#  [857, 2],
#  [4314, 2],
#  [2649, 5809, 2947, 3505, 2312, 3593, 2],
#  [2900, 3725, 91, 4577, 3454, 2650, 2],
#  [1277, 5115, 2652, 799, 5153, 2],
#  [253, 3542, 514, 2],
#  [2900, 5823, 3542, 509, 2],
#  [219, 5269, 3697, 2],
#  [5735, 780, 4259, 1159, 2066, 2],
#  [5082, 4419, 91, 4390, 1451, 2],
#  [2222, 3414, 3537, 4207, 2],
#  [3004, 2],
#  [3542, 4982, 54, 2],
#  [2480, 3844, 2],
#  [2459, 3746, 1034, 1265, 2947, 5394, 2],
#  [1054, 2526, 5561, 1377, 3664, 2],
#  [695, 2955, 3907, 4419, 477, 2],
#  [1995, 3542, 4859, 4130, 4564, 2],
#  [3436, 2],
#  [1508, 810, 1159, 2],
#  [3573, 2900, 5612, 5269, 2],
#  [3638, 2],
#  [2900, 4414, 1229, 5176, 2],
#  [2900, 5269, 1465, 3414, 2],
#  [1465, 2],
#  [4109, 2806, 2],
#  [2566, 2],
#  [3542, 1151, 2],
#  [2057, 2],
#  [1680, 5176, 1508, 3023, 2],
#  [2459, 61, 4517, 2],
#  [2955, 2],
#  [1440, 2859, 5648, 4532, 2],
#  [596, 5488, 3542, 966, 1265, 5176, 2],
#  [2900, 1346, 2955, 2459, 5199, 2],
#  [1440, 2],
#  [1440, 2955, 2],
#  [1440, 2459, 1631, 4259, 596, 1265, 2900, 2],
#  [2900, 1680, 5176, 2],
#  [4673, 3542, 3262, 1406, 2],
#  [1440, 2],
#  [4564, 2900, 5357, 5488, 1871, 2586, 2],
#  [2955, 2586, 2],
#  [2955, 2480, 497, 2],
#  [3542, 5139, 2900, 2],
#  [810, 2947, 2799, 2004, 1731, 1454, 2],
#  [1440, 2],
#  [80, 1440, 3262, 2],
#  [3542, 966, 1783, 1271, 1054, 512, 2],
#  [1440, 3878, 2],
#  [810, 2900, 4443, 2],
#  [2955, 2],
#  [1026, 5403, 1465, 1054, 215, 2],
#  [4895, 2],
#  [1803, 1268, 810, 1054, 698, 3426, 2],
#  [3878, 2900, 61, 2927, 2],
#  [68, 1026, 2],
#  [2900, 3762, 2955, 2],
#  [3878, 2],
#  [4895, 3762, 4259, 2900, 1680, 5176, 2],
#  [1649, 4259, 2],
#  [3094, 286, 2],
#  [3537, 2513, 1508, 2],
#  [842, 2],
#  [3533, 596, 2],
#  [3754, 1054, 5375, 2504, 4990, 2],
#  [3878, 1377, 2955, 2],
#  [2955, 5540, 4029, 2],
#  [4419, 2639, 1266, 5488, 3542, 966, 2],
#  [3185, 4259, 2],
#  [1159, 3405, 2955, 2459, 5575, 2],
#  [3908, 3602, 2],
#  [3754, 2900, 898, 1034, 2],
#  [1377, 2],
#  [2459, 3762, 2],
#  [2947, 3471, 2],
#  [2955, 2],
#  [1159, 3405, 435, 1305, 2],
#  [1300, 2459, 2],
#  [3414, 1268, 4259, 810, 1159, 2],
#  [2459, 3762, 4259, 4443, 2423, 3542, 4571, 2],
#  [3328, 5280, 2],
#  [2459, 3516, 695, 2],
#  [1268, 1159, 4419, 30, 2],
#  [1700, 2],
#  [1440, 5264, 2],
#  [4410, 2004, 3414, 2],
#  [1041, 4410, 2],
#  [4359, 3762, 2955, 2],
#  [1440, 2788, 2],
#  [2575, 2459, 596, 2],
#  [1087, 596, 2],
#  [2900, 4206, 5176, 5269, 2],
#  [2459, 5540, 1603, 2],
#  [1440, 2459, 5540, 1603, 2],
#  [5540, 19, 3005, 5382, 2],
#  [780, 5540, 2900, 2],
#  [1054, 673, 1166, 2900, 4707, 1871, 2],
#  [3907, 1159, 91, 2],
#  [5047, 2459, 810, 5488, 4475, 2900, 2],
#  [4520, 4564, 5488, 2],
#  [4520, 4564, 4259, 2],
#  [1406, 3907, 1159, 1054, 2],
#  [3081, 2],
#  [3436, 4419, 3025, 2],
#  [2719, 1649, 1026, 1054, 598, 2],
#  [1649, 2955, 3414, 5405, 2],
#  [3638, 3762, 2900, 2932, 3414, 2],
#  [3638, 4683, 2900, 5588, 695, 2448, 2],
#  [2897, 3907, 1054, 5333, 2],
#  [695, 1268, 100, 2],
#  [3293, 515, 5488, 837, 1159, 2813, 2],
#  [3474, 2813, 2],
#  [5714, 3907, 1508, 2859, 489, 2544, 2],
#  [2459, 2328, 5588, 2479, 1465, 1062, 2],
#  [2459, 1346, 2],
#  [438, 4130, 4945, 5488, 3036, 2],
#  [2459, 946, 1159, 2613, 5488, 3491, 2],
#  [2459, 2659, 4419, 302, 2],
#  [796, 2900, 438, 91, 2],
#  [4419, 1071, 2048, 1159, 2004, 849, 2],
#  [5345, 2],
#  [3542, 4522, 3907, 3922, 2],
#  [2116, 2719, 2],
#  [1084, 2],
#  [4087, 2004, 2426, 5540, 5835, 2],
#  [1084, 4034, 2],
#  [984, 4683, 2459, 461, 1871, 3984, 2],
#  [3789, 2],
#  [3542, 5424, 3907, 1206, 2],
#  [1159, 3328, 1268, 1333, 2],
#  [2249, 2459, 1404, 2474, 2],
#  [1054, 1131, 2],
#  [3638, 1690, 438, 2900, 3845, 1084, 2],
#  [3885, 516, 4419, 3025, 2048, 2900, 2],
#  [1440, 2],
#  [1440, 2],
#  [3537, 4259, 1348, 2],
#  [3573, 2900, 438, 3775, 1127, 2],
#  [4414, 4419, 3025, 981, 2],
#  [5449, 1054, 418, 2],
#  [3328, 4392, 3436, 2],
#  [399, 2719, 2],
#  [1649, 1508, 2900, 489, 3859, 2],
#  [2459, 3252, 5488, 596, 1265, 2900, 2],
#  [3131, 5588, 1054, 2504, 2],
#  [2459, 2659, 4797, 2947, 4806, 2],
#  [2955, 438, 2900, 3969, 2],
#  [3638, 4549, 2],
#  [2459, 2163, 1026, 2900, 2],
#  [2637, 5176, 246, 2],
#  [2719, 5588, 1265, 1825, 3581, 2],
#  [2048, 2955, 4564, 2900, 5820, 996, 2],
#  [3972, 117, 5460, 2],
#  [2955, 4564, 2900, 1100, 2],
#  [5103, 841, 2],
#  [2379, 3542, 1968, 2602, 2],
#  [78, 4087, 596, 2238, 2],
#  [4130, 755, 3754, 898, 157, 2],
#  [4111, 2282, 1339, 3436, 2],
#  [2900, 3854, 5588, 628, 2],
#  [2900, 5820, 2459, 4564, 4259, 1346, 1159, 2],
#  [2900, 579, 2],
#  [2900, 1680, 1159, 5488, 2426, 2],
#  [1460, 91, 1087, 3542, 46, 3859, 2],
#  [3290, 4259, 5460, 5215, 2],
#  [1430, 4576, 2],
#  [2900, 3972, 2900, 1404, 3169, 2],
#  [1680, 3542, 2403, 4130, 399, 1034, 2],
#  [2403, 4532, 2],
#  [2403, 5405, 3638, 2770, 2],
#  [1675, 2],
#  [4895, 2],
#  [5488, 1004, 3542, 3420, 2004, 2719, 2],
#  [2048, 5852, 5488, 1004, 4308, 2],
#  [2403, 5405, 2],
#  [4564, 4520, 3754, 4605, 1219, 2],
#  [2900, 3113, 1590, 2831, 2],
#  [1465, 1054, 4404, 2],
#  [2249, 2459, 896, 4138, 3148, 2],
#  [4676, 2048, 4167, 1084, 2],
#  [2900, 4564, 4259, 3134, 896, 2],
#  [4130, 4564, 4259, 3735, 5488, 1346, 2],
#  [1803, 150, 2],
#  [896, 1034, 1492, 1803, 1631, 2390, 2],
#  [2947, 3622, 2441, 4259, 1602, 2],
#  [5498, 3907, 2955, 3698, 3022, 2],
#  [2900, 1631, 5496, 1871, 2],
#  [3907, 1871, 3023, 1629, 3051, 2],
#  [1803, 3854, 5588, 87, 2],
#  [3666, 1950, 4267, 4197, 2],
#  [3436, 2459, 837, 2],
#  [2947, 2550, 2004, 3520, 2],
#  [3520, 5488, 2955, 2],
#  [4099, 2004, 3542, 232, 617, 2],
#  [3638, 4576, 4227, 5460, 2],
#  [2459, 3754, 5488, 4367, 3542, 4116, 2],
#  [1871, 2504, 1265, 5176, 2],
#  [399, 2900, 2],
#  [3573, 4895, 2],
#  [3844, 2426, 2],
#  [219, 4808, 2004, 1159, 5707, 2],
#  [2955, 4564, 2900, 1601, 2],
#  [492, 2949, 4607, 4586, 2],
#  [4520, 1030, 3689, 2],
#  [3638, 438, 2900, 4098, 3017, 2],
#  [4259, 2066, 2],
#  [253, 1803, 3960, 2],
#  [4130, 489, 5588, 2],
#  [3474, 2],
#  [2900, 4683, 1601, 1465, 1590, 2],
#  [2459, 3754, 5488, 690, 2],
#  [2459, 3664, 2900, 2995, 2],
#  [1153, 3916, 3177, 1153, 1158, 2],
#  [2459, 2659, 2872, 3524, 2],
#  [2955, 3907, 3414, 5382, 1680, 5176, 2],
#  [2955, 438, 2900, 4797, 5488, 2],
#  [2955, 2441, 1803, 3290, 2],
#  [5280, 2],
#  [4034, 4648, 3297, 2],
#  [5280, 2],
#  [3762, 2900, 3535, 2955, 2459, 4392, 2],
#  [3436, 3044, 2],
#  [1819, 1771, 532, 2],
#  [2459, 3754, 5117, 1119, 2],
#  [3436, 2],
#  [3906, 65, 1825, 3972, 2989, 1327, 2],
#  [3907, 1451, 1054, 5677, 2],
#  [5728, 2947, 4020, 2],
#  [4130, 438, 1691, 4227, 2060, 2],
#  [1819, 1771, 2],
#  [1803, 2441, 4259, 1404, 5568, 2],
#  [2459, 1404, 5568, 2],
#  [1153, 5367, 2],
#  [1054, 3000, 51, 2],
#  [3537, 5460, 1465, 2768, 2],
#  [477, 5176, 2],
#  [3931, 100, 2],
#  [3326, 2005, 2],
#  [3706, 1853, 407, 1159, 3907, 4441, 2],
#  [3537, 4259, 2857, 2],
#  [1459, 1803, 1054, 5064, 2857, 2],
#  [1026, 5115, 1265, 1377, 2],
#  [3638, 1690, 438, 4419, 4542, 2],
#  [395, 2],
#  [424, 2900, 3754, 4477, 4542, 91, 2],
#  [2459, 2659, 2600, 2],
#  [2900, 497, 759, 1026, 3414, 2],
#  [4108, 4168, 2],
#  [438, 2900, 663, 2],
#  [1440, 438, 2900, 5849, 2],
#  [3537, 127, 406, 2],
#  [2575, 2],
#  [2460, 4588, 3151, 2],
#  [2900, 2274, 2],
#  [4034, 1404, 26, 2],
#  [4130, 3754, 1440, 4571, 3972, 2989, 2],
#  [695, 2955, 3907, 5661, 2],
#  [4259, 2955, 1377, 2],
#  [1649, 5661, 2],
#  [2274, 2],
#  [2782, 2426, 4808, 2004, 2947, 4859, 2],
#  [5280, 2900, 2274, 2],
#  [395, 395, 3931, 2],
#  [1302, 1159, 7, 5823, 3542, 5262, 2],
#  [2955, 2],
#  [2808, 810, 2647, 3092, 2288, 2],
#  [5832, 2],
#  [4980, 4980, 2],
#  [3762, 2900, 4645, 3005, 2],
#  [1017, 5823, 2947, 4571, 2],
#  [4130, 2293, 3414, 2],
#  [1441, 1441, 2],
#  [2459, 4683, 5823, 2900, 1054, 4521, 2],
#  [1054, 4521, 2],
#  [3436, 3542, 4571, 3907, 2480, 2],
#  [68, 1054, 4019, 2],
#  [780, 2721, 5488, 5699, 2],
#  [4130, 5747, 117, 2900, 4683, 3775, 2],
#  [1870, 1964, 2298, 4564, 4259, 581, 5081, 2],
#  [3908, 395, 4895, 2],
#  [1440, 596, 991, 2],
#  [1943, 2662, 3414, 2],
#  [4933, 2412, 3775, 2],
#  [2412, 2],
#  [4034, 3744, 4419, 4928, 2],
#  [3878, 2900, 3664, 1159, 91, 2],
#  [2955, 1268, 1159, 2],
#  [3315, 2004, 1054, 3797, 2],
#  [2900, 1346, 2955, 1159, 3907, 91, 2],
#  [1440, 2955, 3907, 3414, 2],
#  [253, 1803, 4339, 1465, 2],
#  [1054, 5043, 2],
#  [1803, 3664, 4087, 1060, 2],
#  [2955, 2],
#  [3638, 2770, 2211, 438, 5269, 1451, 2],
#  [3907, 3414, 4868, 917, 2],
#  [2955, 2],
#  [2900, 5280, 2],
#  [1302, 1159, 5686, 3777, 7, 2],
#  [1404, 5568, 2],
#  [2900, 4392, 1404, 268, 2],
#  [3638, 2900, 5060, 1871, 2],
#  [73, 2],
#  [395, 2],
#  [3004, 2900, 4683, 5588, 785, 3600, 2],
#  [1377, 3762, 3914, 2048, 4660, 2],
#  [1377, 4564, 2900, 5820, 2403, 2],
#  [395, 91, 2],
#  [2955, 1268, 1159, 2543, 2],
#  [2459, 4872, 3962, 4150, 2],
#  [395, 2955, 2738, 2],
#  [4419, 3641, 2],
#  [3725, 1026, 2624, 1159, 3907, 2860, 2],
#  [5823, 1026, 3542, 3807, 2],
#  [2234, 3537, 4990, 2],
#  [3155, 268, 509, 2],
#  [984, 3907, 314, 2863, 2],
#  [2637, 5176, 3542, 1623, 2],
#  [3638, 4549, 4520, 16, 1428, 5460, 2],
#  [2900, 3535, 1159, 3262, 4351, 2],
#  [3713, 2900, 245, 2],
#  [2388, 3542, 3847, 2],
#  [2349, 2459, 5366, 2873, 3414, 2],
#  [2349, 4895, 755, 2900, 2],
#  [2459, 4564, 4259, 5632, 2388, 4569, 2],
#  [2480, 2480, 4425, 2],
#  [4796, 2],
#  [2150, 2],
#  [1377, 5405, 3328, 3907, 1054, 623, 2],
#  [2955, 2995, 2900, 3844, 3005, 2],
#  [4690, 4213, 810, 2955, 5722, 4963, 2],
#  [3293, 3972, 1265, 2900, 2],
#  [1871, 3907, 4259, 3797, 4190, 2],
#  [1460, 3978, 2],
#  [2947, 569, 438, 2],
#  [4581, 5460, 2],
#  [1377, 3907, 1803, 2],
#  [1871, 4087, 2900, 3252, 2],
#  [3436, 1691, 2],
#  [984, 3907, 3328, 2],
#  [3886, 1054, 4249, 2],
#  [3109, 4924, 2],
#  [3202, 5171, 2],
#  [780, 5280, 2],
#  [3542, 2366, 2],
#  [5171, 2859, 680, 5005, 1026, 2],
#  [395, 2],
#  [2900, 1187, 5488, 3542, 314, 2863, 2],
#  [2900, 4477, 3109, 728, 5541, 2],
#  [3293, 1087, 2900, 1346, 2955, 440, 2],
#  [3293, 3844, 3414, 2266, 2],
#  [1819, 2156, 2],
#  [728, 5809, 2859, 2],
#  [3820, 1451, 2],
#  [253, 308, 2],
#  [3908, 2947, 938, 4990, 4514, 5755, 2],
#  [1440, 2],
#  [3762, 2900, 1680, 1034, 2900, 3762, 2],
#  [2955, 438, 2900, 3969, 2],
#  [3589, 1034, 2],
#  [2900, 4580, 2],
#  [3537, 2989, 2678, 2],
#  [2004, 5517, 2],
#  [4581, 1265, 3005, 2],
#  [438, 2900, 1595, 2],
#  [1440, 3537, 5280, 2],
#  [3695, 3695, 1841, 2900, 1595, 2],
#  [3414, 1588, 1593, 3931, 2],
#  [4218, 2115, 4581, 2115, 3695, 2],
#  [3634, 3392, 3392, 3392, 2],
#  [3147, 438, 2900, 5280, 2],
#  [395, 1542, 4259, 1054, 2480, 2504, 2],
#  [3634, 2],
#  [3634, 2],
#  [3634, 2],
#  [3634, 2],
#  [5280, 2],
#  [596, 2989, 2],
#  [3907, 1159, 4087, 1451, 3907, 2],
#  [1440, 1440, 4564, 4259, 4970, 5488, 1594, 2],
#  [1508, 1347, 1446, 2],
#  [3634, 1649, 1054, 5378, 3797, 2],
#  [3436, 3878, 1803, 1268, 1054, 5526, 2],
#  [1054, 5526, 2],
#  [4354, 161, 2],
#  [2900, 2258, 4970, 5488, 3005, 4555, 2],
#  [395, 2],
#  [2459, 4564, 4259, 3754, 1054, 5242, 2],
#  [2947, 1226, 5187, 2],
#  [3537, 5542, 5460, 2],
#  [695, 2659, 2459, 2],
#  [2900, 1346, 2955, 3537, 3969, 5460, 2],
#  [2219, 3537, 1054, 484, 2],
#  [2923, 5269, 2],
#  [2441, 3414, 4645, 2],
#  [4034, 3252, 5488, 2055, 1871, 2],
#  [4520, 1631, 4259, 1129, 1871, 3907, 117, 2],
#  [4952, 2],
#  [4156, 5648, 2],
#  [2219, 4990, 2],
#  [2219, 2],
#  [3237, 3414, 2],
#  [3634, 3634, 3147, 4034, 204, 5176, 2],
#  [3537, 4259, 2],
#  [1460, 684, 2],
#  [1460, 4259, 695, 2066, 1590, 2],
#  [2328, 5588, 2961, 2],
#  [4673, 3542, 5025, 2],
#  [4673, 3414, 2],
#  [1649, 2480, 2],
#  [395, 2],
#  [78, 1159, 3907, 5375, 2],
#  [1336, 2],
#  [2559, 2900, 703, 2459, 5115, 2900, 2],
#  [2459, 5115, 2900, 2],
#  [5280, 5831, 4284, 2],
#  [4284, 2],
#  [2900, 1336, 2],
#  [395, 2459, 1336, 2],
#  [395, 395, 2480, 3777, 2],
#  [5280, 2],
#  [1601, 2900, 407, 2480, 338, 2],
#  [399, 2900, 2],
#  [4034, 5588, 1717, 2],
#  [3174, 3033, 3907, 3680, 2],
#  [395, 1871, 4859, 2],
#  [2900, 5314, 3947, 1054, 4566, 2],
#  [3436, 2459, 5314, 3414, 2],
#  [3762, 2900, 3135, 1302, 5763, 4353, 2],
#  [1440, 2],
#  [2955, 2423, 1347, 1446, 2],
#  [1440, 2],
#  [695, 2900, 3725, 4414, 1054, 4566, 2],
#  [2955, 438, 2900, 2070, 5176, 2],
#  [2459, 1346, 2],
#  [2955, 3907, 3414, 2],
#  [2459, 3762, 2],
#  [4895, 4259, 2],
#  [5082, 3542, 2385, 2115, 3649, 2],
#  [2955, 3907, 1159, 2],
#  [4225, 2115, 2],
#  [2955, 4564, 2900, 5199, 3586, 5269, 2],
#  [2459, 1087, 3005, 1840, 1054, 740, 2],
#  [1440, 3593, 4029, 2],
#  [3908, 2],
#  [3414, 1268, 2947, 1317, 4259, 785, 2],
#  [3908, 395, 3634, 2],
#  [5540, 1054, 740, 2],
#  [3444, 3438, 2],
#  [2955, 4564, 2900, 3252, 2],
#  [253, 4419, 5407, 2],
#  [2459, 2620, 2938, 951, 2],
#  [3573, 4564, 3414, 4080, 2],
#  [2480, 2161, 2],
#  [3392, 2],
#  [2459, 1346, 2],
#  [78, 1803, 2],
#  [3537, 3408, 5488, 1680, 2900, 2],
#  [3634, 596, 991, 2],
#  [2247, 2],
#  [2955, 438, 2900, 3960, 5460, 2],
#  [2314, 4477, 1054, 3844, 2],
#  [2955, 3414, 2441, 4259, 1602, 1159, 4859, 2],
#  [3638, 1268, 3414, 2],
#  [4259, 2480, 2],
#  [3762, 3542, 1655, 2741, 3005, 4459, 2],
#  [395, 1803, 2869, 4454, 1339, 2],
#  [395, 2],
#  [5280, 3878, 4259, 368, 4585, 2],
#  [438, 2900, 3634, 2],
#  [2459, 3454, 489, 3491, 1123, 2479, 2],
#  [3537, 941, 2],
#  [3907, 1803, 4419, 3510, 2],
#  [3537, 4243, 2459, 3280, 2900, 2],
#  [2900, 728, 5823, 392, 2],
#  [91, 2],
#  [4564, 2900, 3754, 3058, 2],
#  [1026, 3542, 4015, 2],
#  [3293, 3678, 746, 1465, 1825, 2],
#  [3293, 5823, 2947, 4862, 2],
#  [2955, 438, 2900, 3960, 2],
#  [2828, 3414, 4808, 2],
#  [5823, 2862, 5460, 2],
#  [2955, 3542, 2500, 4029, 2],
#  [1015, 4973, 2457, 2],
#  [3537, 5542, 2],
#  [2923, 5269, 219, 2],
#  [5588, 5636, 2388, 2],
#  [2137, 2],
#  [2900, 4477, 1159, 2],
#  [1440, 2459, 4564, 4259, 5823, 1159, 2],
#  [5460, 2459, 3754, 4419, 4571, 2],
#  [3908, 1440, 1440, 1107, 2],
#  [4034, 3290, 677, 2],
#  [984, 438, 4130, 4945, 2],
#  [3537, 291, 1265, 2900, 2],
#  [3436, 3436, 3972, 1265, 5176, 2],
#  [3293, 1840, 1034, 2],
#  [1440, 4859, 2379, 1343, 2],
#  [3725, 3886, 1034, 4034, 3036, 2],
#  [2379, 2947, 3584, 2],
#  [78, 1803, 741, 2947, 3556, 2],
#  [4034, 2637, 5176, 1159, 5686, 1107, 2],
#  [542, 1840, 1054, 3292, 2],
#  [2955, 438, 2900, 127, 4564, 2],
#  [4034, 2195, 5488, 785, 934, 2],
#  [1147, 5588, 2947, 3169, 2],
#  [5823, 2115, 2989, 4419, 4431, 2],
#  [3155, 4419, 3556, 2],
#  [2900, 1004, 3542, 386, 2],
#  [3908, 906, 2],
#  [1831, 2048, 1109, 2],
#  [2459, 1268, 4087, 2004, 24, 2],
#  [2955, 2423, 3649, 2],
#  [1440, 1803, 3907, 5460, 1107, 2],
#  [253, 4419, 3392, 3638, 2008, 2],
#  [2459, 2995, 1260, 1948, 3907, 5724, 2],
#  [1440, 1440, 4859, 2],
#  [3878, 780, 2],
#  [2955, 5648, 4564, 2900, 3735, 2],
#  [2637, 5176, 859, 2859, 3906, 2],
#  [4419, 74, 1268, 701, 2],
#  [1347, 1026, 3542, 268, 4905, 2],
#  [4683, 2459, 1601, 4419, 1347, 2],
#  [3537, 5044, 4034, 2900, 5820, 2],
#  [4306, 2947, 3519, 2],
#  [3878, 2403, 117, 1871, 2],
#  [258, 2459, 2],
#  [121, 2],
#  [1087, 3005, 596, 1087, 3005, 596, 2],
#  [3638, 4564, 2900, 4564, 329, 3791, 2],
#  [3906, 3414, 4378, 2441, 4259, 3281, 2],
#  [3436, 3425, 726, 2],
#  [78, 457, 4130, 596, 4421, 5495, 2],
#  [324, 2],
#  [3436, 3414, 3907, 291, 1060, 3425, 78, 2],
#  [3436, 2459, 1346, 1159, 384, 2],
#  [438, 2900, 291, 5488, 2947, 4233, 2],
#  [2575, 438, 2900, 291, 1446, 2],
#  [1026, 9, 2282, 5452, 2459, 3516, 2],
#  [2015, 4808, 5488, 3542, 5682, 5463, 2],
#  [984, 3907, 4347, 1586, 2],
#  [4577, 1026, 3542, 3807, 2],
#  [399, 2900, 5264, 2],
#  [3436, 5264, 2],
#  [3522, 3522, 5382, 384, 2],
#  [5618, 5264, 2],
#  [930, 5258, 5789, 2],
#  [5149, 2],
#  [438, 2900, 1094, 906, 2],
#  [3436, 4378, 399, 2900, 3425, 2008, 2],
#  [5149, 2],
#  [4577, 3243, 2],
#  [2048, 4419, 2596, 5064, 540, 2],
#  [3908, 1159, 3907, 4605, 1054, 4866, 4647, 2],
#  [4378, 2],
#  [5149, 2],
#  [1649, 91, 2],
#  [2459, 1601, 2],
#  [5149, 2],
#  [78, 1159, 2441, 4251, 3425, 5579, 2],
#  [661, 4520, 3762, 2],
#  [78, 3537, 4243, 2423, 1159, 2],
#  [4433, 2],
#  [5149, 2],
#  [5149, 2],
#  [3908, 399, 2900, 3425, 2008, 2],
#  [399, 2900, 2],
#  [78, 3638, 3907, 3414, 4945, 1347, 1451, 2],
#  [2575, 4564, 4130, 1589, 4588, 1257, 2],
#  [399, 2900, 2],
#  [2955, 4564, 2900, 5199, 2],
#  [2459, 1601, 2],
#  [3109, 5541, 2423, 3542, 3016, 2],
#  [2234, 3199, 291, 1026, 3906, 2],
#  [91, 5540, 1054, 2925, 2],
#  [5280, 2],
#  [5280, 3972, 2989, 2115, 2],
#  [906, 2955, 3907, 3414, 2],
#  [253, 5269, 2],
#  [780, 2423, 2947, 1316, 1697, 2],
#  [3436, 2],
#  [5149, 2],
#  [4378, 2],
#  [3436, 2],
#  [5149, 2],
#  [780, 4229, 2],
#  [1440, 2459, 4414, 3762, 922, 2],
#  [3908, 2],
#  [5149, 2],
#  [78, 2955, 3907, 3414, 2],
#  [1159, 5783, 3425, 2398, 2],
#  [3436, 2459, 5575, 695, 2],
#  [3638, 2],
#  [1649, 3023, 2],
#  [3683, 2],
#  [2379, 4477, 1054, 1226, 2],
#  [5149, 2],
#  [3878, 4259, 435, 602, 2],
#  [2459, 1779, 3414, 3907, 4259, 2208, 1494, 2],
#  [5149, 2],
#  [2459, 1631, 1492, 2459, 4683, 3199, 2],
#  [3023, 2],
#  [1649, 3023, 2],
#  [1649, 3023, 2],
#  [1649, 3023, 2],
#  [1649, 3023, 2],
#  [399, 2900, 3425, 2008, 2524, 2],
#  [2955, 3907, 3414, 2524, 2],
#  [5482, 2],
#  [3934, 4138, 3934, 3199, 2],
#  [2459, 3022, 2],
#  [2524, 4801, 3679, 656, 5767, 2],
#  [5482, 2],
#  [2524, 1469, 4087, 1036, 5785, 2007, 2],
#  [3115, 3433, 2532, 5785, 2],
#  [78, 1159, 3907, 1508, 2],
#  [3436, 2524, 2955, 3907, 5269, 2],
#  [2480, 442, 4348, 3414, 4945, 2],
#  [438, 2900, 468, 4330, 2],
#  [1460, 4593, 2],
#  [1440, 2],
#  [1819, 5464, 2],
#  [2524, 2],
#  [3436, 2],
#  [906, 4082, 2955, 3907, 5269, 2],
#  [3436, 2459, 1346, 2],
#  [3537, 941, 2423, 3542, 5718, 2524, 2],
#  [78, 4564, 4259, 1390, 2423, 3414, 2],
#  [2048, 4564, 4259, 2900, 1390, 2423, 3414, 2],
#  [780, 3542, 4131, 2859, 2],
#  [2459, 2240, 4259, 2],
#  [5482, 2],
#  [3775, 2066, 2423, 3199, 3907, 4259, 3414, 2],
#  [3542, 3439, 1271, 5488, 5588, 87, 2],
#  [2524, 599, 5488, 287, 4572, 2544, 2],
#  [2955, 2659, 2459, 1603, 1465, 2],
#  [2459, 4564, 4259, 5820, 4419, 5081, 2917, 2],
#  [1460, 870, 2],
#  [3537, 4087, 3895, 2],
#  [253, 308, 1265, 1159, 2],
#  [2877, 2900, 4564, 2],
#  [2459, 2240, 1803, 4477, 3542, 748, 2],
#  [1680, 3146, 3971, 5488, 3535, 3414, 2],
#  [3638, 2561, 438, 4520, 2],
#  [3638, 447, 3545, 2],
#  [1402, 1765, 2],
#  [395, 1690, 924, 2],
#  [78, 5739, 2900, 1840, 3414, 4028, 2],
#  [906, 91, 2],
#  [2459, 3252, 5488, 1636, 4454, 2],
#  [2459, 2659, 4259, 245, 4258, 2],
#  [5698, 5199, 4343, 2],
#  [1396, 2],
#  [3263, 4571, 2],
#  [395, 3481, 4571, 2],
#  [3004, 1159, 1176, 1054, 5671, 477, 2],
#  [3844, 5176, 407, 2],
#  [2900, 906, 2900, 3252, 5176, 5488, 2],
#  [395, 1465, 746, 5159, 3537, 906, 2],
#  [1943, 1465, 3542, 3058, 2],
#  [4980, 3957, 2],
#  [3933, 596, 991, 1784, 3414, 2],
#  [2575, 2],
#  [2900, 3988, 5826, 2],
#  [2219, 2955, 2423, 5176, 2],
#  [2219, 2],
#  [2923, 5269, 2],
#  [2923, 5269, 2],
#  [562, 2],
#  [2955, 4564, 2900, 3252, 2],
#  [2782, 4364, 2],
#  [3634, 3537, 3251, 2989, 2],
#  [2900, 1274, 4806, 2004, 1054, 4349, 2],
#  [1649, 2955, 2900, 3290, 5524, 2],
#  [395, 2],
#  [3542, 168, 1588, 2441, 4259, 3414, 927, 2],
#  [1107, 2],
#  [3933, 3282, 2],
#  [1377, 438, 4087, 24, 2],
#  [2219, 3375, 5804, 2],
#  [2859, 2004, 1852, 1026, 3542, 4103, 2],
#  [395, 2459, 1100, 3542, 316, 2],
#  [395, 2],
#  [717, 2],
#  [395, 2],
#  [3293, 2782, 3414, 1026, 5046, 2],
#  [5375, 967, 1465, 3151, 2],
#  [395, 2859, 2004, 2947, 62, 2],
#  [2900, 1095, 3542, 3499, 952, 2],
#  [717, 438, 2900, 5280, 2],
#  [2900, 4477, 1054, 1938, 5526, 2],
#  [906, 677, 2900, 3252, 2],
#  [395, 2459, 1115, 2],
#  [395, 2],
#  [1460, 2238, 2],
#  [2459, 4477, 1054, 199, 5488, 2061, 2],
#  [5732, 2],
#  [3293, 5820, 2423, 3414, 2],
#  [1871, 674, 5172, 4808, 4665, 2],
#  [1440, 4859, 5488, 3973, 1054, 4381, 2],
#  [1107, 3537, 3802, 941, 2],
#  [395, 2],
#  [3957, 1268, 4126, 2004, 3542, 812, 2],
#  [2955, 812, 2900, 323, 2423, 717, 2],
#  [3537, 2651, 2900, 3602, 2],
#  [5540, 69, 5176, 3542, 4592, 3346, 2],
#  [1054, 5526, 2],
#  [2219, 1871, 5663, 4796, 2480, 2],
#  [399, 2900, 2],
#  [3252, 5488, 515, 3414, 937, 2],
#  [2459, 4564, 4259, 1346, 2],
#  [2575, 3638, 2],
#  [2955, 4564, 2900, 5820, 2],
#  [5382, 984, 4130, 1187, 4221, 2],
#  [2459, 4564, 4259, 2637, 4808, 3542, 5705, 2],
#  [4131, 1824, 2],
#  [2900, 3754, 1054, 2480, 2504, 2],
#  [78, 2],
#  [2219, 2900, 2258, 4226, 2],
#  [2955, 438, 2900, 323, 2423, 2],
#  [3542, 3, 7, 2],
#  [395, 2],
#  [3326, 2],
#  [5382, 3638, 3907, 4419, 3696, 3545, 2],
#  [2900, 1095, 1159, 1654, 3602, 2],
#  [1451, 2],
#  [3854, 5588, 1962, 509, 2],
#  [3972, 2989, 2],
#  [3638, 2423, 3414, 2],
#  [3533, 596, 2],
#  [4520, 3829, 4419, 2198, 4221, 2],
#  [3638, 2008, 2],
#  [1948, 1054, 3681, 2],
#  [3931, 2],
#  [5540, 1680, 5176, 2423, 3542, 4571, 2],
#  [2379, 2387, 4419, 4571, 2],
#  [4130, 5780, 2],
#  [4259, 3208, 4221, 2],
#  [3155, 3542, 4571, 2],
#  [91, 3556, 2],
#  [395, 91, 2],
#  [3155, 3542, 4592, 744, 2],
#  [2900, 5540, 266, 4138, 3414, 2],
#  [1107, 2],
#  [2955, 2],
#  [5366, 4477, 746, 2111, 1359, 2],
#  [395, 2],
#  [1938, 2],
#  [4496, 2],
#  [1871, 3907, 9, 1062, 1690, 2],
#  [395, 4031, 16, 2872, 2],
#  [4130, 4564, 4259, 3192, 4681, 447, 1346, 2],
#  [5375, 5540, 5375, 2],
#  [1159, 2659, 4259, 4962, 1649, 4871, 5326, 2],
#  [1440, 2025, 2],
#  [2900, 4581, 1265, 5176, 2],
#  [1440, 4859, 2],
#  [2955, 3542, 2573, 4029, 2],
#  [2459, 1211, 2426, 1159, 3907, 2955, 4029, 2],
#  ...]

# %%
len(b1_dec_out)
# Out:
# 14873

# %%
#function to find max len of decoder input
def get_max_(l):
    return max([len(sent) for sent in l])

# %%
#padding encoder and decoder inputs
b1_dec_len=get_max_(b1_dec_in)

b1_enc_in = pad_sequences(b1_enc_in,buck_t1, padding='post')
b1_dec_in = pad_sequences(b1_dec_in,b1_dec_len, padding='post')
b1_dec_out = pad_sequences(b1_dec_out,b1_dec_len, padding='post')

b1_dec_len
# Out:
# 10

# %%
b1_dec_in.shape,b1_enc_in.shape
# Out:
# ((14873, 10), (14873, 6))

# %% [markdown]
# ## Create dataset

# %%
#imports and variables to create the dataset

batch_size=64 #batch size for training

# %%
dataset = tf.data.Dataset.from_tensor_slices((b1_enc_in, b1_dec_in,b1_dec_out))#
dataset= dataset.shuffle(len(b1_enc_in)).batch(batch_size, drop_remainder=True)
dataset
# Out:
# <BatchDataset shapes: ((64, 6), (64, 10), (64, 10)), types: (tf.int32, tf.int32, tf.int32)>

# %% [markdown]
# ## Building models
#
# - define model for training
# - define model for inference
#  DA MODIFICAER

# %%
lat_dim=512  #used later

# %%
import chatbot_models_class as cb

# %%
encoder_=cb.encoder_model(lat_dim=lat_dim,vocab_len=vocab_len)
decoder_=cb.decoder_model(lat_dim=lat_dim,batch_size=batch_size,vocab_len=vocab_len,buck_t1=buck_t1)

# %% [markdown]
# ## Training the models

# %%
#define training vaiables
n_epochs=20
steps_per_epoch= len(b1_enc_in) //batch_size

# %%
#get spare categorical crossentropy from logits and mask the pads so they are not considered in the loss
def custom_loss(labels,pred):

    
    loss_fun=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True,reduction='none')
    loss=loss_fun(y_true=labels, y_pred=pred)
    
    #masking zeros
    mask = tf.cast(tf.logical_not(tf.math.equal(labels,0)),dtype=tf.float32)
    
    return tf.reduce_mean(mask*loss)

# %%
#define optimizers
opt_a=tf.keras.optimizers.Adam()
opt_r=tf.keras.optimizers.RMSprop()

# %%
metrics_=[tf.keras.metrics.Accuracy()]
mean_loss=tf.keras.metrics.Mean()

# %%
#custom training loop

for epoch in range(1,n_epochs+1):
    print("Epoch {}/{} \n".format(epoch,n_epochs))
    step_counter=0

    for enc_inp_batch,dec_in_batch, dec_out_batch in dataset.take(steps_per_epoch):
        step_counter+=1
        #print("\r", end="")
        with tf.GradientTape() as tape:
            encoder_embedding=encoder_.encoder_embedding_layer(enc_inp_batch)
            encoder_output,enc_state_h,enc_state_c =encoder_.encoder(encoder_embedding,
                                                                    initial_state=[tf.zeros((batch_size, lat_dim*2)), tf.zeros((batch_size, lat_dim*2))])
            
            decoder_embedding=decoder_.decoder_embedding_layer(dec_in_batch)
            
            #setup memory 
            decoder_.attention_mechanism.setup_memory(encoder_output)
            
            decoder_initial_state = decoder_.get_initial_states(batch_size,enc_state_h,enc_state_c)
                
            #compute model output    
            model_output,_,_=decoder_.training_decoder(decoder_embedding,
                                                       initial_state=decoder_initial_state,
                                                       sequence_length=batch_size*[len(b1_dec_out[0])]
                                                      )
            logits=model_output.rnn_output
            
            main_loss = custom_loss(dec_out_batch,logits)
            loss= tf.add_n([main_loss]+encoder_.losses+decoder_.losses)
        
        variables = encoder_.trainable_variables + decoder_.trainable_variables  
        gradients=tape.gradient(loss,variables)
        
        #optimizer
        opt_r.apply_gradients(zip(gradients,variables))
        
        
        mean_loss(loss)
        

        
        #metrics
        for metric in metrics_:
            metric(dec_out_batch,tf.argmax(logits,axis=2))
        
        
        display_print_loss="".join(["{:.4f}".format(m.result()) for m in [mean_loss]])
        display_print_acc="".join("{:.4f}".format(m.result().numpy()) for m in metrics_)
        
        print("\r"+"loss:"+display_print_loss+"  _  metrics:"+display_print_acc+"  -  iteration:"+str(step_counter), end="  ")
        
        #print("mean_loss",mean_loss)#,"metrics",metrics, "\n")
        
    for metric in [mean_loss]+metrics_:
        metric.reset_states()
# Out:
# Epoch 1/20
#
# loss:2.4991  _  metrics:0.1091  -  iteration:232  Epoch 2/20
#
# loss:2.2216  _  metrics:0.1228  -  iteration:232  Epoch 3/20
#
# loss:2.1250  _  metrics:0.1301  -  iteration:232  Epoch 4/20
#
# loss:2.0447  _  metrics:0.1374  -  iteration:232  Epoch 5/20
#
# loss:1.9627  _  metrics:0.1449  -  iteration:232  Epoch 6/20
#
# loss:1.8718  _  metrics:0.1550  -  iteration:232  Epoch 7/20
#
# loss:1.7664  _  metrics:0.1668  -  iteration:232  Epoch 8/20
#
# loss:1.6547  _  metrics:0.1803  -  iteration:232  Epoch 9/20
#
# loss:1.5397  _  metrics:0.1955  -  iteration:232  Epoch 10/20
#
# loss:1.4218  _  metrics:0.2110  -  iteration:232  Epoch 11/20
#
# loss:1.3118  _  metrics:0.2277  -  iteration:232  Epoch 12/20
#
# loss:1.2158  _  metrics:0.2425  -  iteration:232  Epoch 13/20
#
# loss:1.1312  _  metrics:0.2560  -  iteration:232  Epoch 14/20
#
# loss:1.0502  _  metrics:0.2695  -  iteration:232  Epoch 15/20
#
# loss:0.9835  _  metrics:0.2814  -  iteration:232  Epoch 16/20
#
# loss:0.9291  _  metrics:0.2898  -  iteration:232  Epoch 17/20
#
# loss:0.8826  _  metrics:0.2985  -  iteration:232  Epoch 18/20
#
# loss:0.8525  _  metrics:0.3039  -  iteration:232  Epoch 19/20
#
# loss:0.8300  _  metrics:0.3086  -  iteration:232  Epoch 20/20
#
# loss:0.8122  _  metrics:0.3114  -  iteration:232

# %%
#saving weights

encoder_.save_weights('models_Att/encoder_att_weights_inv_input')
decoder_.save_weights('models_Att/decoder_att_weights_inv_input')

# %% [markdown]
# ## Saving Dictionaries

# %%
import json

a_file = open("dict_w2i_chatbot.json", "w")

json.dump(dict_w2i, a_file)

a_file.close()

a_file = open("dict_i2w_chatbot.json", "w")

json.dump(dict_i2w, a_file)

a_file.close()

a_file = open("contractions_dict.json", "w")

json.dump(contractions_dict, a_file)

a_file.close()

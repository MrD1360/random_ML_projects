# %% [markdown]
# # Chatbot

# %% [markdown]
# This notebook provides an implementation of a seq2seq encoder-decoder for a conversational chatbot with no attention.
#
# ### Approach
#
# - Upload datasets: 2 datasets have been used in order to have a mix between movie conversations and "small talk"
# - Define Q & A
# - Extend contracted forms using a dict
# - Clean strings
# - Create embeddings
# - Padding strings
# - Reverse encoder input
# - Define seq2seq model
#
#
# ### Dataset references
# - dataset1: https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html
# - dataset2: https://www.kaggle.com/grafstor/simple-dialogs-for-chatbot
#
# ### Results
# The model achieve an accuracy of 0.20

# %%
#some imports

import pandas as pd 
import string
import numpy as np

from collections import OrderedDict

# %%
#importing tensorflow

import tensorflow as tf

from tensorflow import keras

from tensorflow.keras import backend as K

from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
#select GPU

if not tf.config.list_physical_devices('GPU'):
    print("No GPU was detected.")

gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_visible_devices(gpus[1], 'GPU')
tf.config.experimental.set_memory_growth(gpus[1], enable=True)
#tf.config.gpu_options.allow_growth = True
gpus
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %% [markdown]
# ## Uploading dataset

# %%
df=pd.read_csv('archive/dialogs.txt',sep='\t')

# %%
df.head()
# Out:
#                                      Q  \
# 0               hi, how are you doing?
# 1        i'm fine. how about yourself?
# 2  i'm pretty good. thanks for asking.
# 3    no problem. so how have you been?
# 4     i've been great. what about you?
#
#                                         ANS
# 0             i'm fine. how about yourself?
# 1       i'm pretty good. thanks for asking.
# 2         no problem. so how have you been?
# 3          i've been great. what about you?
# 4  i've been good. i'm in school right now.

# %%
#uploading files

lines= open('dataset_cornel/movie_lines.txt',encoding='utf-8',errors='ignore').read().split('\n')
conversations= open('dataset_cornel/movie_conversations.txt',encoding='utf-8',errors='ignore').read().split('\n')
lines
# Out:
# ['L1045 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ They do not!',
#  'L1044 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ They do to!',
#  'L985 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I hope so.',
#  'L984 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ She okay?',
#  "L925 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Let's go.",
#  'L924 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Wow',
#  "L872 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Okay -- you're gonna need to learn how to lie.",
#  'L871 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ No',
#  'L870 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I\'m kidding.  You know how sometimes you just become this "persona"?  And you don\'t know how to quit?',
#  'L869 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Like my fear of wearing pastels?',
#  'L868 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ The "real you".',
#  'L867 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ What good stuff?',
#  "L866 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ I figured you'd get to the good stuff eventually.",
#  'L865 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Thank God!  If I had to hear one more story about your coiffure...',
#  "L864 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Me.  This endless ...blonde babble. I'm like, boring myself.",
#  'L863 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ What crap?',
#  'L862 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ do you listen to this crap?',
#  'L861 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ No...',
#  'L860 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Then Guillermo says, "If you go any lighter, you\'re gonna look like an extra on 90210."',
#  'L699 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ You always been this selfish?',
#  'L698 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ But',
#  "L697 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Then that's all you had to say.",
#  'L696 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Well, no...',
#  "L695 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ You never wanted to go out with 'me, did you?",
#  'L694 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I was?',
#  'L693 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ I looked for you back at the party, but you always seemed to be "occupied".',
#  'L663 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Tons',
#  'L662 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Have fun tonight?',
#  'L578 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ I believe we share an art instructor',
#  'L577 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ You know Chastity?',
#  'L576 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Looks like things worked out tonight, huh?',
#  'L575 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Hi.',
#  "L407 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Who knows?  All I've ever heard her say is that she'd dip before dating a guy that smokes.",
#  "L406 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ So that's the kind of guy she likes? Pretty ones?",
#  "L405 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Lesbian?  No. I found a picture of Jared Leto in one of her drawers, so I'm pretty sure she's not harboring same-sex tendencies.",
#  "L404 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ She's not a...",
#  "L403 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ I'm workin' on it. But she doesn't seem to be goin' for him.",
#  "L402 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I really, really, really wanna go, but I can't.  Not unless my sister goes.",
#  'L401 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Sure have.',
#  "L368 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Eber's Deep Conditioner every two days. And I never, ever use a blowdryer without the diffuser attachment.",
#  'L367 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ How do you get your hair to look like that?',
#  "L366 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ You're sweet.",
#  'L365 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ You have my word.  As a gentleman',
#  "L364 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I counted on you to help my cause. You and that thug are obviously failing. Aren't we ever going on our date?",
#  'L363 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ You got something on your mind?',
#  'L281 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Where?',
#  'L280 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ There.',
#  "L277 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Well, there's someone I think might be --",
#  'L276 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ How is our little Find the Wench A Date plan progressing?',
#  'L275 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Forget French.',
#  "L274 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ That's because it's such a nice one.",
#  "L273 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I don't want to know how to say that though.  I want to know useful things. Like where the good stores are.  How much does champagne cost?  Stuff like Chat.  I have never in my life had to point out my head to someone.",
#  "L272 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Right.  See?  You're ready for the quiz.",
#  "L271 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ C'esc ma tete. This is my head",
#  'L208 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Let me see what I can do.',
#  'L207 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Gosh, if only we could find Kat a boyfriend...',
#  "L206 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ That's a shame.",
#  'L205 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Unsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.',
#  'L204 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Why?',
#  'L203 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Seems like she could get a date easy enough...',
#  "L202 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ The thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does.",
#  'L201 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Cameron.',
#  "L200 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ No, no, it's my fault -- we didn't have a proper introduction ---",
#  'L199 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Forget it.',
#  "L198 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ You're asking me out.  That's so cute. What's your name again?",
#  "L197 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Okay... then how 'bout we try out some French cuisine.  Saturday?  Night?",
#  'L196 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Not the hacking and gagging and spitting part.  Please.',
#  "L195 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Well, I thought we'd start with pronunciation, if that's okay with you.",
#  'L194 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Can we make this quick?  Roxanne Korrine and Andrew Barrett are having an incredibly horrendous public break- up on the quad.  Again.',
#  'L953 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I did.',
#  "L952 +++$+++ u3 +++$+++ m0 +++$+++ CHASTITY +++$+++ You think you ' re the only sophomore at the prom?",
#  "L660 +++$+++ u3 +++$+++ m0 +++$+++ CHASTITY +++$+++ I don't have to be home 'til two.",
#  'L659 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I have to be home in twenty minutes.',
#  "L600 +++$+++ u3 +++$+++ m0 +++$+++ CHASTITY +++$+++ All I know is -- I'd give up my private line to go out with a guy like Joey.",
#  "L599 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Sometimes I wonder if the guys we're supposed to want to go out with are the ones we actually want to go out with, you know?",
#  "L598 +++$+++ u3 +++$+++ m0 +++$+++ CHASTITY +++$+++ Bianca, I don't think the highlights of dating Joey Dorsey are going to include door-opening and coat-holding.",
#  "L597 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Combination.  I don't know -- I thought he'd be different.  More of a gentleman...",
#  'L596 +++$+++ u3 +++$+++ m0 +++$+++ CHASTITY +++$+++ Is he oily or dry?',
#  "L595 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ He practically proposed when he found out we had the same dermatologist. I mean. Dr. Bonchowski is great an all, but he's not exactly relevant party conversation.",
#  'L580 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Would you mind getting me a drink, Cameron?',
#  'L579 +++$+++ u3 +++$+++ m0 +++$+++ CHASTITY +++$+++ Great',
#  'L573 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Joey.',
#  'L572 +++$+++ u3 +++$+++ m0 +++$+++ CHASTITY +++$+++ Who?',
#  'L571 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Where did he go?  He was just here.',
#  'L51 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ You might wanna think about it',
#  'L50 +++$+++ u3 +++$+++ m0 +++$+++ CHASTITY +++$+++ No.',
#  'L49 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Did you change your hair?',
#  "L760 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ You know the deal.  I can ' t go if Kat doesn't go --",
#  'L759 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Listen, I want to talk to you about the prom.',
#  "L758 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ You're concentrating awfully hard considering it's gym class.",
#  'L757 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Hi, Joey.',
#  'L756 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Hey, sweet cheeks.',
#  "L593 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ My agent says I've got a good shot at being the Prada guy next year.",
#  'L592 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Neat...',
#  "L591 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ It's a gay cruise line, but I'll be, like, wearing a uniform and stuff.",
#  'L590 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Queen Harry?',
#  'L589 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ So yeah, I\'ve got the Sears catalog thing going -- and the tube sock gig " that\'s gonna be huge.  And then I\'m up for an ad for Queen Harry next week.',
#  'L397 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Hopefully.',
#  "L396 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Exactly  So, you going to Bogey Lowenbrau's thing on Saturday?",
#  'L395 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Expensive?',
#  "L394 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ It's more",
#  'L1052 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Perm?',
#  'L1051 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Patrick -- is that- a.',
#  "L1022 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ It's just you.",
#  'L1021 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Is that woman a complete fruit-loop or is it just me?',
#  'L1011 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ No! I just wanted',
#  'L1010 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ What? To completely damage me?  To send me to therapy forever? What?',
#  'L1009 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I just wanted --',
#  'L1008 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ You set me up.',
#  'L1007 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Let go!',
#  'L983 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ So did you',
#  'L982 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ You looked beautiful last night, you know.',
#  "L914 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I guess I'll never know, will I?",
#  "L913 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Not all experiences are good, Bianca. You can't always trust the people you want to.",
#  "L912 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ God, you're just like him! Just keep me locked away in the dark, so I can't experience anything for myself",
#  'L911 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I guess I thought I was protecting you.',
#  "L910 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I'm not stupid enough to repeat your mistakes.",
#  "L909 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ That's not",
#  "L908 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ No. you didn't!  If you really thought I could make my own decisions, you would've let me go out with him instead of helping Daddy hold me hostage.",
#  'L907 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I wanted to let you make up your own mind about him.',
#  "L906 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Why didn't you tell me?",
#  'L905 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ After that, I swore I\'d never do anything just because "everyone else" was doing it.  And I haven\'t since. Except for Bogey\'s party, and my stunning gastro-intestinal display --',
#  'L904 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ But',
#  "L903 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Just once.  Afterwards, I told him I didn't want to anymore.  I wasn't ready. He got pissed.  Then he broke up with me.",
#  'L902 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ You did what?',
#  'L901 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ He said everyone was doing it.  So I did it.',
#  'L900 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ As in...',
#  'L899 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Now I do.  Back then, was a different story.',
#  'L898 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ But you hate Joey',
#  'L897 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ He was, like, a total babe',
#  'L896 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Why?',
#  'L895 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ In 9th.  For a month',
#  'L894 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ What?',
#  'L893 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Joey never told you we went out, did he?',
#  "L892 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I wish I had that luxury. I'm the only sophomore that got asked to the prom and I can't go, because you won ' t.",
#  "L891 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I do care. But I'm a firm believer in doing something for your own reasons, not someone else ' s .",
#  'L890 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Like you care.',
#  "L889 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Listen, I know you hate having to sit home because I'm not Susie High School.",
#  "L656 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ You're welcome.",
#  "L655 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I don't get you.  You act like you're too good for any of this, and then you go totally apeshit when you get here.",
#  "L602 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I really don't think I need any social advice from you right now.",
#  'L601 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Bianca, I need to talk to you -- I need to tell you --',
#  'L543 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Can we go now?',
#  'L542 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ You are so completely unbalanced.',
#  "L533 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Yeah, he's your freak friend Mandella's boyfriend.  I guess since I'm not allowed to go out, I should obsess over a dead guy, too.",
#  "L532 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ It's Shakespeare.  Maybe you've heard of him?",
#  "L531 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Like I'm supposed to know what that even means.",
#  "L530 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ At least I'm not a clouted fen- sucked hedge-pig.",
#  "L529 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Can't you forget for just one night that you're completely wretched?",
#  "L527 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Bogey Lowenstein's party is normal, but you're too busy listening to Bitches Who Need Prozac to know that.",
#  "L526 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ What's normal?",
#  "L525 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ You're ruining my life'  Because you won't be normal, I can't be normal.",
#  "L445 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I think you're a freak.  I think you do this to torture me.  And I think you suck.",
#  'L444 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ What do you think?',
#  "L443 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Oh, I thought you might have a date  I don't know why I'm bothering to ask, but are you going to Bogey Lowenstein's party Saturday night?",
#  "L442 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ It means that Gigglepuss is playing at Club Skunk and we're going.",
#  "L441 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Oh my God, does this mean you're becoming normal?",
#  'L320 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Can you at least start wearing a bra?',
#  "L319 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I have the potential to smack the crap out of you if you don't get out of my way.",
#  'L165 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Nowhere... Hi, Daddy.',
#  "L164 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Where've you been?",
#  "L923 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I have a date, Daddy.  And he ' s not a captain of oppression like some men we know.",
#  "L922 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ I'm missing something.",
#  "L884 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Fine.  I see that I'm a prisoner in my own house.  I'm not a daughter. I'm a possession!",
#  "L883 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ You're not going unless your sister goes.  End of story.",
#  'L882 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ He\'s not a "hot rod".  Whatever that is.',
#  "L881 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ It's that hot rod Joey, right? That ' s who you want me to bend my rules for?",
#  'L880 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ No, but',
#  'L879 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ The prom?  Kat has a date?',
#  "L878 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Daddy, I want to discuss the prom with you. It's tomorrow night --",
#  "L546 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ Because she'll scare them away.",
#  'L545 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Why?',
#  "L544 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ Promise me you won't talk to any boys unless your sister is present.",
#  'L540 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ Just for a minute',
#  'L539 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Daddy, no!',
#  'L538 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ Wear the belly before you go.',
#  "L537 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ It's just a party. Daddy.",
#  "L536 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ Oh, God.  It's starting.",
#  "L524 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ If Kat's not going, you're not going.",
#  'L523 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Daddy, people expect me to be there!',
#  'L521 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ It\'s just a party. Daddy, but I knew you\'d forbid me to go since "Gloria Steinem" over there isn\'t going --',
#  'L520 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ Otherwise known as an orgy?',
#  'L519 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ If you must know, we were attempting to go to a small study group of friends.',
#  "L518 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ And where're you going?",
#  'L517 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Daddy, I --',
#  'L190 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ Exactly my point',
#  "L189 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ But she doesn't want to date.",
#  "L183 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ But it's not fair -- she's a mutant, Daddy!",
#  "L182 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ Then neither will you.  And I'll get to sleep at night.",
#  'L181 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ What if she never starts dating?',
#  "L180 +++$+++ u11 +++$+++ m0 +++$+++ WALTER +++$+++ No! You're not dating until your sister starts dating.  End of discussion.",
#  "L179 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Now don't get upset. Daddy, but there's this boy... and I think he might ask...",
#  "L463 +++$+++ u1 +++$+++ m0 +++$+++ BRUCE +++$+++ Just sent 'em through.",
#  'L462 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Padua girls.  One tall, decent body. The other one kinda short and undersexed?',
#  'L461 +++$+++ u1 +++$+++ m0 +++$+++ BRUCE +++$+++ Never',
#  'L460 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Fan of a fan.  You see a couple of minors come in?',
#  "L459 +++$+++ u1 +++$+++ m0 +++$+++ BRUCE +++$+++ Didn't have you pegged for a Gigglepuss fan.  Aren't they a little too pre-teen belly-button ring for you?",
#  'L458 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Always a pleasure, Brucie.',
#  "L779 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Best case scenario, you're back on the payroll for awhile.",
#  'L778 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ You humiliated the woman! Sacrifice yourself on the altar of dignity and even the score.',
#  "L586 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ No, I ' m not.",
#  "L585 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Buttholus extremus.  But hey, you're making progress.",
#  "L584 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ The hell is that?  What kind of 'guy just picks up a girl and carries her away while you're talking to her?",
#  'L583 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Extremely unfortunate maneuver.',
#  "L500 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Hell, I've just been going over the whole thing in my head and -",
#  'L499 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ You told me that part already.',
#  "L433 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ It's her favorite band.",
#  'L432 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Assail your ears for one night.',
#  "L425 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Okay!  I wasn't sure",
#  "L424 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ He's pretty!",
#  'L419 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Dead at forty-one.',
#  'L418 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Her favorite uncle',
#  "L417 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ It's a lung cancer issue",
#  'L416 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Number one.  She hates smokers',
#  "L391 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Are you kidding?  He'll piss himself with joy.  He's the ultimate kiss ass.",
#  'L390 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Will Bogey get bent?',
#  "L389 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ In that case, we'll need to make it a school-wide blow out.",
#  'L388 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ This is it.  A golden opportunity. Patrick can ask Katarina to the party.',
#  "L245 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Like we had a choice?  Besides -- when you let the enemy think he's orchestrating the battle, you're in a position of power. We let him pretend he's calling the shots, and while he's busy setting up the plan, you have time to woo Bianca.",
#  'L244 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ You got him involved?',
#  "L225 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Hey -- I've gotta have a few clients when I get to Wall Street.",
#  'L224 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ I thought you hated those people.',
#  "L223 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ You know, if you do go out with Bianca, you'd be set.  You'd outrank everyone. Strictly A-list.  With me by your side.",
#  "L222 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ That's what I just said",
#  "L221 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Did she actually say she'd go out with you?",
#  "L220 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Forget his reputation.  Do you think we've got a plan or not?",
#  "L219 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ I'm serious, man, he's whacked.  He sold his own liver on the black market so he could buy new speakers.",
#  'L218 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ They always let felons sit in on Honors Biology?',
#  "L217 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ No kidding.  He's a criminal.  I heard he lit a state trooper on fire.  He just got out of Alcatraz...",
#  'L216 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ He seems like he thrives on danger',
#  "L215 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ What makes you think he'll do it?",
#  'L213 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ You wanna go out with him?',
#  'L212 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ What about him?',
#  "L211 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Unlikely, but even so, she still can't go out with you.  So what's the point?",
#  'L210 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ I teach her French, get to know her, dazzle her with charm and she falls in love with me.',
#  'L159 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ The mewling, rampalian wretch herself.',
#  "L158 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ That's her?  Bianca's sister?",
#  'L157 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Yeah, just a minor encounter with the shrew.',
#  'L147 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ You could consecrate with her, my friend.',
#  "L146 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ You mean I'd get a chance to talk to her?",
#  'L145 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Guess who just signed up for a tutor?',
#  "L144 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Sure do ... my Mom's from Canada",
#  'L143 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ You know French?',
#  "L142 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Joey Dorsey?  Perma-shit-grin.  I wish I could say he's a moron, but he's number twelve in the class.  And a model.  Mostly regional stuff, but he's rumored to have a big tube sock ad coming out.",
#  'L141 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ He always have that shit-eating grin?',
#  "L140 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Because they're bred to.  Their mothers liked guys like that, and their grandmothers before them. Their gene pool is rarely diluted.",
#  'L139 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Why do girls like that always like guys like that?',
#  "L92 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ I could start with your haircut, but it doesn't matter.  She's not allowed to date until her older sister does.  And that's an impossibility.",
#  'L91 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Why not?',
#  "L90 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Bianca Stratford.  Sophomore. Don't even think about it",
#  'L89 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Who is she?',
#  'L88 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ You burn, you pine, you perish?',
#  'L87 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ That girl -- I --',
#  'L78 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Yeah, but these guys have never seen a horse.  They just jack off to Clint Eastwood.',
#  "L77 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ That I'm used to.",
#  'L74 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Couple thousand. Most of them evil',
#  'L73 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ How many people go here?',
#  'L72 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Get out!',
#  'L71 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Thirty-two.',
#  'L70 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ How many people were in your old school?',
#  "L69 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Yeah.  A couple.  We're outnumbered by the cows, though.",
#  'L68 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ I was kidding. People actually live there?',
#  "L67 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ North, actually.  How'd you   ?",
#  'L66 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ So -- which Dakota you from?',
#  "L65 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ C'mon.  I'm supposed to give you the tour.",
#  'L64 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ So they tell me...',
#  'L63 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ You the new guy?',
#  'L781 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ You get the girl.',
#  "L780 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ What's the worst?",
#  'L745 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Where?',
#  'L744 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ She kissed me.',
#  "L743 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ You makin' any headway?",
#  "L741 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ She just needs time to cool off I'll give it a day.",
#  "L740 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ She hates you with the fire of a thousand suns .  That's a direct quote",
#  "L726 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I don ' t know.  I decided not to nail her when she was too drunk to remember it.",
#  "L725 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ What'd you do to her?",
#  'L625 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Then, go get her',
#  'L624 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Sure',
#  'L623 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Cameron -- do you like the girl?',
#  "L622 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ She's partial to Joey, not me",
#  "L621 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ What 're you talking about?",
#  "L620 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ It's off. The whole thing.",
#  "L619 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Cameron, I'm a little busy",
#  "L431 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Don't make me do it, man",
#  'L430 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Gigglepuss is playing there tomorrow night.',
#  "L427 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ So what does that give me?  I'm supposed to buy her some noodles and a book and sit around listening to chicks who can't play their instruments?",
#  'L426 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Okay -- Likes:  Thai food, feminist prose, and "angry, stinky girl music of the indie-rock persuasion".',
#  "L412 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ I've retrieved certain pieces of information on Miss Katarina Stratford I think you'll find helpful.",
#  "L411 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ What've you got for me?",
#  "L386 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Yeah -- we'll see.",
#  'L385 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ And he means that strictly in a non- prison-movie type of way.',
#  'L558 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ And why would I do that?',
#  'L557 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Leave my sister alone.',
#  'L556 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Your sister here?',
#  'L555 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Away.',
#  'L554 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Where ya goin?',
#  'L336 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Not at all',
#  'L335 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Hey -- do you mind?',
#  "L150 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ They're running the rest of me next month.",
#  'L149 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Yeah, and I noticed the only part of you featured in your big Kmart spread was your elbow.  Tough break.',
#  "L148 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ The vintage look is over, Kat. Haven't you been reading your Sassy?",
#  "L748 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Enough with the Barbie n' Ken shit. I know.",
#  "L747 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I don't know, Dorsey. ..the limo.-the flowers.  Another hundred for the tux --",
#  'L609 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Get her to act like a human',
#  'L608 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Do what?',
#  "L607 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ How'd you do it?",
#  "L606 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ A deal's a deal.",
#  "L605 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ It's about time.",
#  'L358 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Forget her sister, then.',
#  'L357 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Forget it.',
#  'L356 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ A hundred bucks a date.',
#  'L355 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ What?',
#  'L354 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I just upped my price',
#  'L352 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I got her under control. She just acts crazed in public to keep up the image.',
#  "L351 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Watching the bitch trash my car doesn't count as a date.",
#  "L350 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I'm on it",
#  'L349 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ When I shell out fifty, I expect results.',
#  "L301 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Fifty, and you've got your man.",
#  "L300 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Take it or leave it.  This isn't a negotiation.",
#  'L299 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Fine, thirty.',
#  "L298 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I can't take a girl like that out on twenty bucks.",
#  'L297 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ How much?',
#  "L296 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ I can't date her sister until that one gets a boyfriend.  And that's the catch. She doesn't want a boyfriend.",
#  "L295 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ You're gonna pay me to take out some girl?",
#  'L294 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ You got it, Verona.  I pick up the tab, you do the honors.',
#  "L292 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ But you'd go out with her if you had the cake?",
#  'L291 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ You need money to take a girl out',
#  'L290 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ You just said',
#  "L289 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Sure, Sparky.  I'll get right on it.",
#  'L288 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Yeah, whatever.  I want you to go out with her.',
#  'L287 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Two legs, nice rack...',
#  'L286 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ What do you think?',
#  'L285 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Yeah',
#  "L509 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Hey -- it's all for the higher good right?",
#  "L508 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ You better not fuck this up.  I'm heavily invested.",
#  'L505 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ What?  We took bathes together when we were kids.',
#  'L504 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ You and Verona?',
#  "L503 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Uh,  yeah.  We're old friend*",
#  "L502 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ I hear you're helpin' Verona.",
#  "L240 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ So what you need to do is recruit a guy who'll go out with her.  Someone who's up for the job.",
#  'L239 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Does this conversation have a purpose?',
#  "L238 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ But she can't go out with you because her sister is this insane head case and no one will go out with her. right?",
#  "L236 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ We're not.",
#  "L235 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Well, actually, I thought I'd run an idea by you.  You know, just to see if you're interested.",
#  "L234 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ We don't chat.",
#  'L233 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Nope - just came by to chat',
#  'L232 +++$+++ u4 +++$+++ m0 +++$+++ JOEY +++$+++ Are you lost?',
#  'L231 +++$+++ u7 +++$+++ m0 +++$+++ MICHAEL +++$+++ Hey.',
#  "L949 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Oh, honey -- tell me we haven't' progressed to full-on hallucinations.",
#  'L948 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ William - he asked me to meet him here.',
#  'L947 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Who?',
#  'L946 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ Have you seen him?',
#  'L755 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ Oh, good.  Something new and different for us.',
#  "L754 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ You ' re looking at this from the wrong perspective.  We're making a statement.",
#  "L753 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ Okay, okay, we won't go.  It's not like I have a dress anyway",
#  'L752 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Listen to you!  You sound like Betty, all pissed off because Archie is taking Veronica.',
#  "L751 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ Well, I guess we're not, since we don't have dates .",
#  'L750 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Can you even imagine?  Who the hell would go to this a bastion of commercial excess?',
#  'L721 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I got drunk.  I puked.  I got rejected. It was big fun.',
#  "L720 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ You didn't",
#  'L719 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I did Bianca a favor and it backfired.',
#  "L718 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ You didn't have a choice?  Where's Kat and what have you done with her?",
#  "L717 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I didn't have a choice.",
#  'L716 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ You went to the party?  I thought we were officially opposed to suburban social activity.',
#  'L491 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Who cares?',
#  "L490 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ What'd he say?",
#  'L448 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ No fear.',
#  "L447 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ You think this'll work?",
#  'L254 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ If I was Bianca, it would be, "Any school you want, precious.  Don\'t forget your tiara."',
#  'L253 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ Does it matter?',
#  "L252 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I appreciate your efforts toward a speedy death, but I'm consuming.  Do you mind?",
#  'L251 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Neither has his heterosexuality.',
#  "L250 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ That's never been proven",
#  "L249 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ William didn't even go to high school",
#  'L248 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ William would never have gone to a state school.',
#  'L247 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ So he has this huge raging fit about Sarah Lawrence and insists that I go to his male-dominated, puking frat boy, number one golf team school. I have no say at all.',
#  "L152 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ You could always go with me.  I'm sure William has some friends.",
#  'L151 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ The people at this school are so incredibly foul.',
#  "L134 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ But imagine the things he'd say during sex.",
#  "L133 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I realize that the men of this fine institution are severely lacking, but killing yourself so you can be with William Shakespeare is beyond the scope of normal teenage obsessions.  You're venturing far past daytime talk show fodder and entering the world of those who need very expensive therapy.",
#  'L132 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ An attempted slit.',
#  "L131 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ What's this?",
#  'L130 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ Just a little.',
#  'L129 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Mandella, eat.  Starving yourself is a very slow way to die.',
#  'L128 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Block E?',
#  'L127 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ He always look so',
#  "L126 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I'm sure he's completely incapable of doing anything that interesting.",
#  "L125 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ That's Pat Verona? The one who was gone for a year? I heard he was doing porn movies.",
#  'L124 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Patrick Verona   Random skid.',
#  "L123 +++$+++ u6 +++$+++ m0 +++$+++ MANDELLA +++$+++ Who's that?",
#  "L1043 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Don ' t you even dare. . .",
#  'L1042 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Oh, Bianca?  Can you get me my freshman yearbook?',
#  'L1041 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Because I like to torture you.',
#  'L1040 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Why is my veggie burger the only burnt object on this grill?',
#  'L1035 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Yeah, but then I fucked up. I fell for her.',
#  'L1034 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Is that right?',
#  'L1033 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Besides, I had some extra cash. Some asshole paid me to take out a really great girl.',
#  'L1032 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I thought you could use it. When you start your band.',
#  'L1031 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ A Fender Strat. You bought this?',
#  "L977 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I didn't care about the money.",
#  'L976 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Really?  What was it like?  A down payment now, then a bonus for sleeping with me?',
#  "L975 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ It wasn't like that.",
#  'L974 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ You were paid to take me out!  By -- the one person I truly hate.  I knew it was a set-up!',
#  'L973 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Wait I...',
#  'L961 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ It gets worse -- you still have your freshman yearbook?',
#  "L960 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ That ' s completely adorable!",
#  "L959 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ That's where I was last year.  She'd never lived alone -- my grandfather died -- I stayed with her.  I wasn't in jail, I don't know Marilyn Manson, and I've never slept with a Spice Girl.  I spent a year sitting next to my grandma on the couch watching Wheel of Fortune.  End of story.",
#  'L958 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ What?',
#  "L957 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ My grandmother's .",
#  "L940 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Look, I'm  -- sorry -- that I questioned your motives.  I was wrong.",
#  'L939 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Oh huh',
#  "L938 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ It's just something I had.  You know",
#  "L937 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ It's Scurvy's.  His date got convicted. Where'd you get the dress?",
#  "L936 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ How'd you get a tux at the last minute?",
#  "L857 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Nothing!  There's nothing in it for me. Just the pleasure of your company.",
#  'L856 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Answer the question, Patrick',
#  'L855 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ You need therapy.  Has anyone ever told you that?',
#  'L854 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ You tell me.',
#  'L853 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ So I have to have a motive to be with you?',
#  'L852 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Create a little drama?  Start a new rumor?  What?',
#  "L848 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Because I don't want to. It's a stupid tradition.",
#  'L847 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Why not?',
#  "L846 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ No, I won't go with you",
#  'L845 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ No what?',
#  'L844 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ No.',
#  'L843 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ You know what I mean',
#  'L842 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Is that a request or a command?',
#  'L841 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Go to the prom with me',
#  "L840 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ You're amazingly self-assured. Has anyone ever told you that?",
#  'L839 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ No one else knows',
#  'L838 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ What?',
#  "L837 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ You're sweet.  And sexy.  And completely hot for me.",
#  'L836 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ No -- something real.  Something no one else knows.',
#  'L835 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I hate peas.',
#  'L834 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Tell me something true.',
#  "L832 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I know the porn career's a lie.",
#  'L831 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Hearsay.',
#  'L830 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ The duck?',
#  'L829 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Fallacy.',
#  'L828 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ State trooper?',
#  'L825 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ For. . . ?',
#  'L824 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ You up for it?',
#  'L823 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ You never disappointed me.',
#  'L822 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ How?',
#  'L821 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Then you screwed up',
#  'L820 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Something like that',
#  "L819 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ So if you disappoint them from the start, you're covered?",
#  "L818 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I don't like to do what people expect. Then they expect it all the time and they get disappointed when you change.",
#  'L817 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Yes',
#  'L816 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Acting the way we do.',
#  "L815 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ So what's your excuse?",
#  "L814 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Yeah, well, don't let it get out",
#  'L813 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ A soft side? Who knew?',
#  'L812 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I dazzled him with my wit',
#  "L811 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ So how'd you get Chapin to look the other way?",
#  'L810 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Good call.',
#  'L809 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I figured it had to be something ridiculous to win your respect.  And piss you off.',
#  'L808 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ The Partridge Family?',
#  'L806 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Maybe.',
#  'L805 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ You want me to climb up and show you how to get down?',
#  "L804 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Forget it.  I'm stayin'.",
#  'L803 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Put your right foot there --',
#  "L802 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Try lookin' at it from this angle",
#  "L801 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ C'mon.  It's not that bad",
#  "L800 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I guess I never told you I'm afraid of heights.",
#  'L799 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Look up, sunshine',
#  'L798 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ He left!  I sprung the dickhead and he cruised on me.',
#  'L774 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Other than my upchuck reflex? Nothing.',
#  'L773 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ So what did I have an effect on ?',
#  "L772 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Don't for one minute think that you had any effect whatsoever on my panties.",
#  'L771 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Unwelcome?  I guess someone still has her panties in a twist.',
#  'L770 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Unwelcome.',
#  'L769 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Wholesome.',
#  'L768 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Pleasant?',
#  "L767 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ You 're so --",
#  'L766 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I heard there was a poetry reading.',
#  'L765 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ What are you doing here?',
#  'L764 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Excuse me, have you seen The Feminine Mystique?  I lost my copy.',
#  "L690 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ No offense, but you're sister is without.  I know everyone likes her and all, but ...",
#  'L689 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ BIANCA',
#  'L688 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Who?',
#  "L687 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ He just wants me to be someone I'm not.",
#  "L686 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ So what ' s up with your dad?  He a pain in the ass?",
#  "L684 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ I'm gettin' there",
#  'L683 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Oh, so now you think you know me?',
#  "L682 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ You don't strike me as the type that would ask permission.",
#  "L681 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ My father wouldn't approve of that that",
#  'L680 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Start a band?',
#  'L679 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ This.',
#  'L678 +++$+++ u9 +++$+++ m0 +++$+++ PATRICK +++$+++ Do what?',
#  'L677 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ I should do this.',
#  "L676 +++$+++ u5 +++$+++ m0 +++$+++ KAT +++$+++ Why'd you lie?",
# ...
#  'L1959 +++$+++ u19 +++$+++ m1 +++$+++ MARCHENA +++$+++ How can you be so certain?',
#  'L1958 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Ignorance!  I believe the Indies are no more than 750 leagues west of the Canary Islands.',
#  'L1957 +++$+++ u19 +++$+++ m1 +++$+++ MARCHENA +++$+++ How can you be so certain?  The Ocean is said to be infinite.',
#  'L1952 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ To open a new route to Asia.  At the moment there are only two ways of reaching it...',
#  'L1951 +++$+++ u19 +++$+++ m1 +++$+++ MARCHENA +++$+++ Why do you wish to sail west?',
#  'L1950 +++$+++ u19 +++$+++ m1 +++$+++ MARCHENA +++$+++ With some difficulty.  I had to promise them you were not a total fool.',
#  'L1949 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ How did you manage it?',
#  "L1948 +++$+++ u19 +++$+++ m1 +++$+++ MARCHENA +++$+++ That's what it says.",
#  "L1947 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ God... That's in a week!",
#  'L1943 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Father, I am doing what I think is the best for him.  And he has the teacher I would have chosen for myself.',
#  'L1942 +++$+++ u19 +++$+++ m1 +++$+++ MARCHENA +++$+++ Diego is a bright boy -- a pleasure to teach -- but so serious... Brothers should be raised together, Colon.  Even brothers from different mothers...',
#  'L2459 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Your Majesty -- some men are content to read about things.  I must see them with my own eyes.  I cannot be other than I am.',
#  "L2458 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ There is one thing I'd like to understand... Why do you want to go back, after all this?",
#  'L2457 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Thank you.',
#  'L2456 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ But without your brothers.  Nor are you to return to Santo Domingo or any of the other colonies.  You may explore the continent.',
#  'L2280 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ They come and go as naked as the day God created them...',
#  'L2279 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ Do they have such thoughts?',
#  'L2086 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Thirty seven, Your Majesty... And you?',
#  'L2085 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ How old are you, Senor Colon?',
#  'L2082 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ A woman?',
#  'L2081 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ I know what I see.  I see someone who doesn\'t accept the world as it is.  Who\'s not afraid.  I see a women who thinks... "What if?"...',
#  'L2080 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ You show no inclination to speak otherwise!',
#  'L2079 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ May I speak freely?',
#  'L2077 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Surely you can do anything you want.',
#  'L2076 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ I cannot ignore the verdict of my council.',
#  'L2075 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ That she was impregnable.',
#  'L2074 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ What did they say about Granada before today?',
#  'L2073 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ The ocean is uncrossable?',
#  'L2072 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ No more than the woman who said she would take Granada from the Moors.',
#  'L2071 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ I should not even be listening to you, since my council said no.  But Santangel tells me you are a man of honor and sincerity... And Sanchez, that you are not a fool.',
#  'L2389 +++$+++ u21 +++$+++ m1 +++$+++ MOXICA +++$+++ You will regret this.',
#  "L2388 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ You'll be held in detention, deprived of your privileges and possessions.  Until you are returned to Spain where you will be judged. Have you anything to say?",
#  'L2387 +++$+++ u21 +++$+++ m1 +++$+++ MOXICA +++$+++ Savagery is what monkeys understand.',
#  'L2386 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ In one act of brutality, you have created chaos.  Tribes who were fighting each other are now joining forces against us!  All that because of your criminal savagery!',
#  'L2348 +++$+++ u21 +++$+++ m1 +++$+++ MOXICA +++$+++ You did not hear me, Don Colon.  Not my horse.',
#  'L2347 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Don Moxica -- we all have to work.',
#  "L2346 +++$+++ u21 +++$+++ m1 +++$+++ MOXICA +++$+++ My horse doesn't work.",
#  "L2345 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ We can't raise the wheel without it.",
#  'L2333 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ We came here to stay!  To build! Not to start a crusade.  In this forest, there is enough danger to sweep us away in days!  So we will be brave and swallow our grief.  And in the name of those who died, we will accomplish what we came for.',
#  "L2332 +++$+++ u21 +++$+++ m1 +++$+++ MOXICA +++$+++ We don't need to know.",
#  'L2331 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ You want a war?  Fine.  We are a thousand.  They outnumber us by ten! Who will you kill?  Which tribe?',
#  "L2329 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ If you want to keep your head on your shoulders, you'll do as I say.",
#  'L2328 +++$+++ u21 +++$+++ m1 +++$+++ MOXICA +++$+++ We lost cousins, friends.  We will wash this in blood.',
#  'L2278 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ The Indians have no such word, Don Moxica.',
#  "L2277 +++$+++ u21 +++$+++ m1 +++$+++ MOXICA +++$+++ And you say this is an Indian vice? By God!  I don't see any kind of pleasure that would make this a sin.",
#  "L2492 +++$+++ u20 +++$+++ m1 +++$+++ MENDEZ +++$+++ We can't be.",
#  "L2491 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ He's drawing an isthmus... He's saying we're on an isthmus.",
#  "L2490 +++$+++ u20 +++$+++ m1 +++$+++ MENDEZ +++$+++ What's he doing?",
#  'L2165 +++$+++ u20 +++$+++ m1 +++$+++ MENDEZ +++$+++ Twenty eight.',
#  'L2164 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ What do you read?',
#  'L2160 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Come over here.',
#  "L2159 +++$+++ u20 +++$+++ m1 +++$+++ MENDEZ +++$+++ Well, I surely know what a quadrant is!  But I've never seen it used at night before.",
#  'L2158 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ And what do you think Mendez?',
#  "L2157 +++$+++ u20 +++$+++ m1 +++$+++ MENDEZ +++$+++ Well... It's the men, Sir.  They wonder how you know our position. We've lost sight from land days ago...",
#  'L2155 +++$+++ u20 +++$+++ m1 +++$+++ MENDEZ +++$+++ God be with us admiral.',
#  'L2154 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Due west, Captain Mendez.  And may God be with us...',
#  "L2211 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ You're right.  Let the men decide.",
#  'L2210 +++$+++ u22 +++$+++ m1 +++$+++ PINZON +++$+++ You tell that to them!',
#  'L2209 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Pinzon, Pinzon... All we can do now is go forward!  Think about that!',
#  'L2208 +++$+++ u22 +++$+++ m1 +++$+++ PINZON +++$+++ You bloody...',
#  'L2207 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ You never did.  You did all the talking for both of us, remember?',
#  'L2206 +++$+++ u22 +++$+++ m1 +++$+++ PINZON +++$+++ Jesus Maria!  I should have never listened to you!',
#  'L2205 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ And then what?  Half of the water has gone, the rest is nearly putrid! You know that!',
#  "L2204 +++$+++ u22 +++$+++ m1 +++$+++ PINZON +++$+++ You don't know anything!  Listen Colon, these are my ships, right? So I'm telling you we're turning back!",
#  'L2203 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ The land is there.  I know it!',
#  "L2202 +++$+++ u22 +++$+++ m1 +++$+++ PINZON +++$+++ We're lost!",
#  "L2201 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ You think I don't know that?",
#  "L2200 +++$+++ u22 +++$+++ m1 +++$+++ PINZON +++$+++ We're on the verge of a mutiny, Colon!",
#  'L2199 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ We have to keep the hopes of these men alive!',
#  'L2198 +++$+++ u22 +++$+++ m1 +++$+++ PINZON +++$+++ You must be mad...!',
#  'L2197 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Six days ago, yes.',
#  "L2196 +++$+++ u22 +++$+++ m1 +++$+++ PINZON +++$+++ You lied!  You cheated!  We're way past 750 leagues!",
#  'L2065 +++$+++ u22 +++$+++ m1 +++$+++ PINZON +++$+++ Immediately.',
#  'L2064 +++$+++ u16 +++$+++ m1 +++$+++ COLUMBUS +++$+++ Where can I meet this man?',
#  'L2462 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ Because he is not afraid of me.',
#  'L2461 +++$+++ u24 +++$+++ m1 +++$+++ SANCHEZ +++$+++ Then why?',
#  'L2460 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ I know, I should not tolerate his impertinence.',
#  'L2419 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ And who would you think of, for such a task?',
#  'L2418 +++$+++ u24 +++$+++ m1 +++$+++ SANCHEZ +++$+++ He must be replaced.',
#  'L2417 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ Then, what do you suggest, Don Sanchez?',
#  'L2415 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ Is this true, Brother Buyl?',
#  'L2414 +++$+++ u24 +++$+++ m1 +++$+++ SANCHEZ +++$+++ ... But there is worse.  He ordered the execution of five members of the nobility...',
#  "L2377 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ We weren't expecting immediate profits, were we?  We must have faith.  We must give time for time.",
#  'L2376 +++$+++ u24 +++$+++ m1 +++$+++ SANCHEZ +++$+++ Every ship returns with a cargo of sick and dying.  But with no gold! The new world proves expensive, Your Majesty.',
#  "L2116 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ Yes.  It would be a pity, wouldn't it?  Call him back!",
#  'L2115 +++$+++ u24 +++$+++ m1 +++$+++ SANCHEZ +++$+++ ... Into a monk...',
#  'L2113 +++$+++ u24 +++$+++ m1 +++$+++ SANCHEZ +++$+++ Never, Your Majesty.  Although...',
#  'L2112 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ You were right, Don Sanchez... His demands could never be granted.',
#  'L1931 +++$+++ u24 +++$+++ m1 +++$+++ SANCHEZ +++$+++ Yes, Your Majesty.',
#  'L1930 +++$+++ u18 +++$+++ m1 +++$+++ ISABEL +++$+++ Is that the man I knew, Treasurer Sanchez?',
#  "L3546 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Officers, there's your killer, do your duty, arrest him!",
#  'L3545 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ ...so we kill someone famous and if we are caught, we are sent to mental hospital...',
#  "L3497 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ I don't think it's abuse, I think it's torture.",
#  "L3496 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ I'm abused.  Don't you think?",
#  'L3493 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Can I see your back?',
#  'L3492 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Out on my back when I was a small boy.',
#  'L3491 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Your father put cigarettes out on you?',
#  "L3490 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ That's what he did to me.  He put cigarettes out on me.",
#  'L3489 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Yeah, he hated me from day when I was born.  Put it out.  Can you put the cigarette out?',
#  "L3488 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Your father blamed you for your mother's blindness?",
#  'L3487 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Yeah, yeah...bad doctor gave her bad drugs which made her go blind.  And my father blamed me for her blindness...',
#  'L3486 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Back in the Czech Republic?',
#  'L3485 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Yeah, she went blind giving birth to me. She went to fucking black market doctor to induce me.',
#  'L3484 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Your mother was blind?',
#  'L3483 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ My father always degraded me.  Killed my self-esteem.  And my mother was blind.',
#  'L3482 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Tell me about yourself.  What you did as a young boy... what your parents were like.',
#  'L3481 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Give me another one, please.',
#  "L3480 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ I need to know about your background.  I need to know about your upbringing.  Why you're here.",
#  'L3479 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ What else do you need?',
#  'L3478 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ This is not about money, Emil.  I need your trust in me.',
#  "L3477 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Thirty-percent.  No more.  Or I call another lawyer.  This is the biggest case of your life.  Don't try to negotiate.  Thirty percent.  Say yes or no.",
#  "L3476 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ But it's...",
#  'L3475 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ No.  No way.',
#  'L3474 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ I would say...half.  Half is fair.',
#  "L3473 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ What's your cut?  How much?",
#  "L3472 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Look, I haven't really focused on that kind of thing.",
#  'L3471 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ What about my movie rights?  Book rights?',
#  "L3470 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Don't worry about him.  Think about yourself.",
#  'L3469 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ No, he is here.  Shit...',
#  "L3468 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Disappeared.  They're looking everywhere.  Maybe he went back to Czechoslovakia.",
#  'L3467 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ What about Oleg?',
#  "L3466 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Well, you didn't appreciate the severity of it until recently.  No question about that.",
#  'L3465 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ I was all of these.',
#  'L3464 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ ...delusions and paranoia.',
#  'L3461 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Oh, sure.',
#  'L3460 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ You bring the cigarettes?',
#  "L3459 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ I brought you some letters.  It's really fan mail.  Women mostly.  One wants to buy you clothes, another sent a check. Another wants a check.",
#  "L3396 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ I'm invoking rights - this man is represented by counsel.  I'm coming with him.",
#  'L3395 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Yes.  Yes, come with me!',
#  "L3394 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ I'm coming with you.",
#  'L3393 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Where are we going?',
#  "L3392 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Don't say anything.",
#  'L3385 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ He has the camera!  He took the movie!',
#  'L3384 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ Emil.  Take it easy.  Stay with me.  Sit down.  What do you need?  What are you looking for?',
#  'L3383 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Oh no!  No!  Shit!',
#  'L3382 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Here.  I have your money.',
#  "L3381 +++$+++ u26 +++$+++ m2 +++$+++ CUTLER +++$+++ I'm not your lawyer until I see the money.",
#  "L3380 +++$+++ u30 +++$+++ m2 +++$+++ EMIL +++$+++ Are you my attorney?  I'm Emil.  I'm insane.",
#  'L3517 +++$+++ u34 +++$+++ m2 +++$+++ JORDY +++$+++ Daphne, I...',
#  "L3516 +++$+++ u27 +++$+++ m2 +++$+++ DAPHNE +++$+++ I don't want to drag you down with me.",
#  'L3515 +++$+++ u34 +++$+++ m2 +++$+++ JORDY +++$+++ ...Do you really want me to forget about you?',
#  'L3514 +++$+++ u27 +++$+++ m2 +++$+++ DAPHNE +++$+++ Forget about me.  You have enough problems of your own.',
#  'L3330 +++$+++ u27 +++$+++ m2 +++$+++ DAPHNE +++$+++ Pouring it out!',
#  'L3329 +++$+++ u34 +++$+++ m2 +++$+++ JORDY +++$+++ What are you doing?',
#  "L3318 +++$+++ u27 +++$+++ m2 +++$+++ DAPHNE +++$+++ I'll get my clothes.",
#  "L3317 +++$+++ u34 +++$+++ m2 +++$+++ JORDY +++$+++ I'll make some for us.",
#  'L3316 +++$+++ u27 +++$+++ m2 +++$+++ DAPHNE +++$+++ In the kitchen.',
#  'L3315 +++$+++ u34 +++$+++ m2 +++$+++ JORDY +++$+++ Do you have coffee?',
#  ...]

# %%
#preparing the dataset

conversation_index=[] #nested list of conversation indexes
for conversation in conversations:
    conversation_index.append(conversation.split('+++$+++')[-1][2:-1].replace("'","").split(','))

# %%
dict_i2text={} #index to text dictionary
for line in lines[:-1]:   #-1 cause the last one is empty
    key=line.split('+++$+++')[0][1:-1]
    dict_i2text[int(key)]=line.split('+++$+++')[-1]

ord_list_i2text = list(OrderedDict(sorted(dict_i2text.items())).items())

# %%
#cleaning from long sentences

long_threshold=8 

cut_dataset=7*1000
cut_offset=5*1000

ord_list_i2text = [x for x in ord_list_i2text if not len(x[1].split())>long_threshold][cut_offset:cut_dataset+cut_offset]

ord_list_i2text
# Out:
# [(26292, ' Look, I told you...'),
#  (26303, ' Thank you, Officer Ripley.  That will be...'),
#  (26309, ' You are a head case.  Have a donut.'),
#  (26312, " Why won't you check out LV-426?"),
#  (26314, ' What are you talking about. What people?'),
#  (26316, ' How many colonists?'),
#  (26317, ' Sixty, maybe seventy families.'),
#  (26318, ' Sweet Jesus.'),
#  (26322, ' Yeah.  What?'),
#  (26325, ' So what do I tell this guy?'),
#  (26355, " No.  There's no way!"),
#  (26356, ' Hear me out...'),
#  (26362, " What about you?  What's your interest in this?"),
#  (26364, ' Yeah, yeah.  I saw the commercial.'),
#  (26366, " That's right."),
#  (26367, ' Running loaders, forklifts, that sort of thing?'),
#  (26370, ' If I go.'),
#  (26376, ' Yello?  Oh, Ripley.  Hi...'),
#  (26378, " That's the plan.  My word on it."),
#  (26385, " This floor's freezing."),
#  (26387, ' Would you, Sir?'),
#  (26388, ' Hey, Vasquez...you ever been mistaken for a man?'),
#  (26389, ' No.  Have you?'),
#  (26398, " Whoooah!  No shit?  I'm impressed."),
#  (26399, " Let's go...let's go.  Cycle through!"),
#  (26400, " Hey, 'Top.'  What's the op?"),
#  (26418, ' Sir?'),
#  (26419, ' Yes, Hicks?'),
#  (26420, " Hudson, Sir.  He's Hicks."),
#  (26421, " What's the question?"),
#  (26430, ' Sounds like you, Hicks.'),
#  (26438, ' Fuck you.'),
#  (26439, ' Anytime.  Anywhere.'),
#  (26441, " I hope you're right.  I really do."),
#  (26443, ' Are there any questions?  Hudson?'),
#  (26447, ' Still nothing from the colony?'),
#  (26448, ' Dead on all channels.'),
#  (26459, ' Save it.'),
#  (26460, ' Sure, Hicks.'),
#  (26467, ' How may drops is this for you, Lieutenant?'),
#  (26468, ' Thirty-eight...simulated.'),
#  (26473, " ...that's better.  Pan it around a bit."),
#  (26475, ' That the atmosphere processor?'),
#  (26477, ' Hold at forty.  Slow circle of the complex.'),
#  (26478, ' The structure seems intact.  They have power.'),
#  (26479, " Okay, let's do it."),
#  (26485, ' Ten seconds, people.  Look sharp!'),
#  (26487, " Vasquez, take point.  Let's move."),
#  (26503, " ...We're coming in."),
#  (26504, " He's coming in.  I feel safer already."),
#  (26506, ' Sir, the CPU is on-line.'),
#  (26507, " Okay, stand by in operations.  Let's go."),
#  (26513, " It's insured."),
#  (26525, ' Poor bastard.'),
#  (26527, ' One of us?'),
#  (26528, ' Apone...where are your people? Anybody in D-Block?'),
#  (26540, ' Where are your parents?  You have to try...'),
#  (26541, ' Gorman!  Give it a rest would you.'),
#  (26549, " What's he scanning for?"),
#  (26554, ' What did you say?'),
#  (26558, " Casey.  She's my only friend."),
#  (26559, ' What about me?'),
#  (26560, " I don't want you for a friend."),
#  (26561, ' Why not?'),
#  (26565, " They're dead."),
#  (26567, ' You promise?'),
#  (26568, ' Cross my heart.'),
#  (26569, ' And hope to die?'),
#  (26572, ' Alive?'),
#  (26578, " The 'maze'?  You mean the air ducts?"),
#  (26580, " You're really something, ace."),
#  (26584, ' You tell me.  I only work here.'),
#  (26585, ' What is it?'),
#  (26586, " I don't know."),
#  (26587, ' Proceed inside.'),
#  (26594, " They're right under the primary heat exchangers."),
#  (26597, " She's right."),
#  (26598, ' So.'),
#  (26599, ' So...then the fusion containment shuts down.'),
#  (26600, ' So?  So?'),
#  (26601, " We're talking thermonuclear explosion."),
#  (26605, ' Flame-units only.  I want rifles slung.'),
#  (26606, " Let's go.  Pull 'em out."),
#  (26614, ' Movement!'),
#  (26615, ' Position?'),
#  (26616, " Can't lock up..."),
#  (26617, ' Talk to me, Hudson.'),
#  (26618, ' Uh, seems to be in front and behind.'),
#  (26626, " Let's get the fuck out of here!"),
#  (26627, ' Not that tunnel, the other one!'),
#  (26629, ' GET THEM OUT OF THERE!  DO IT NOW!'),
#  (26630, ' Shut up.  Just shut up!'),
#  (26632, ' Say again?  All after incinerators?'),
#  (26638, ' I told them to fall back...'),
#  (26639, " They're but off!  Do something!"),
#  (26659, ' Looks like it stung him.'),
#  (26660, " Hey...hey!  Look, Crowe and Dietrich aren't dead, man."),
#  (26663, " Oh, God.  Jesus.  This ain't happening."),
#  (26669, ' Why not?'),
#  (26673, ' Bullshit!'),
#  (26674, ' Yeah, bullshit.  Watch us.'),
#  (26678, ' You son of a bitch.'),
#  (26679, " Don't make me pull rank, Ripley."),
#  (26681, ' Corporal Hicks!?'),
#  (26694, ' Are you finished?  You okay?'),
#  (26695, " I guess we're not leaving, right?"),
#  (26696, " I'm sorry, Newt."),
#  (26703, ' About seventeen days.'),
#  (26716, ' Aye-firmative.'),
#  (26723, ' Thanks.'),
#  (26724, " Uh, what's next?"),
#  (26726, " I don't want to...I have scary dreams."),
#  (26730, ' Oh.  Sorry, Newt.'),
#  (26732, " Yes, there are, aren't there."),
#  (26733, ' Why do they tell little kids that?'),
#  (26735, ' Did one of those things grow inside her?'),
#  (26736, " I don't know, Newt.  That's the truth."),
#  (26738, " No, it's different, honey."),
#  (26739, ' Did you ever have a baby?'),
#  (26740, ' Yes.  A little girl.'),
#  (26741, ' Where is she?'),
#  (26742, ' Gone.'),
#  (26743, ' You mean dead.'),
#  (26746, " Don't go!  Please."),
#  (26753, ' Yes.  That follows.'),
#  (26758, ' Could it be intelligent?'),
#  (26767, ' Now, wait a second --'),
#  (26774, ' Sorry to disappoint you.'),
#  (26783, " That's it.  See it?  Emergency venting."),
#  (26784, ' How long until it blows?'),
#  (26786, ' We got problems.'),
#  (26788, " And it's too late to shut it down?"),
#  (26791, ' Hudson, give us a break.'),
#  (26795, " Think of what?  We're fucked."),
#  (26800, " I'll go."),
#  (26801, ' What?'),
#  (26808, ' See you soon.'),
#  (26809, " They're in the approach corridor."),
#  (26810, ' On my way.'),
#  (26812, ' Now many?'),
#  (26818, " Maybe we got 'em demoralized."),
#  (26821, " They'll get us."),
#  (26822, ' Maybe.  Maybe not.'),
#  (26830, " What's this?"),
#  (26833, " Yeah.  I've noticed."),
#  (26834, ' How do you feel?'),
#  (26836, ' Forget it.'),
#  (26842, ' Newt.  Newt, wake up.'),
#  (26843, ' Wah...?  Where are...?'),
#  (26844, " Sssh.  Don't move.  We're in trouble."),
#  (26850, " Mommy...I mean, Ripley...I'm scared."),
#  (26851, ' I know, honey.  Me too.'),
#  (26853, ' The corner!  Ready?'),
#  (26854, ' Do it!'),
#  (26859, " Wait a minute.  We'd know about it."),
#  (26864, " Let's waste him.  No offense."),
#  (26866, ' They cut the power.'),
#  (26871, " It's inside the complex."),
#  (26872, " You're just reading me."),
#  (26876, " It's game time."),
#  (26879, ' Just get back here!'),
#  (26881, ' Range twenty meters.'),
#  (26882, ' Seal the door.'),
#  (26883, ' Seventeen meters.'),
#  (26884, " Let's get these things lit."),
#  (26886, " We didn't miss anything."),
#  (26887, ' Fifteen meters.'),
#  (26890, " They're right on us.  Vasquez, how you doing?"),
#  (26891, ' Nine meters.  Eight.'),
#  (26892, " Can't be.  That's inside the room!"),
#  (26893, " It's readin' right.  Look!"),
#  (26894, " Well you're not reading it right!"),
#  (26895, ' Six meters.  Five.  What the fu --'),
#  (26897, ' Burke!  Open the door!'),
#  (26898, ' Look!'),
#  (26899, " Let's go!  Let's go!"),
#  (26900, " Fuckin' A!"),
#  (26902, ' Locked.'),
#  (26903, ' Stand back.'),
#  (26910, ' Come on.  Crawl faster.'),
#  (26912, ' Sure.  Go left.'),
#  (26921, " This way.  Come on, we're almost there!"),
#  (26922, ' Newt, wait!'),
#  (26937, " No!  No!  She's alive!  We have to --"),
#  (26940, ' HOW MUCH TIME?'),
#  (26941, ' PLENTY!  TWENTY-SIX MINUTES!'),
#  (26942, " WE'RE NOT LEAVING!"),
#  (26943, ' Ripley...'),
#  (26946, " Hicks, don't let him leave."),
#  (26947, " We ain't going anywhere."),
#  (26950, ' Ellen.'),
#  (26951, " Don't be long, Ellen."),
#  (26956, " I knew you'd come."),
#  (26971, ' You did okay, Bishop.'),
#  (26972, ' Well, thanks, I --'),
#  (26978, ' Mommy...Mommy?'),
#  (26979, ' Right here, baby.  Right here.'),
#  (26980, ' Are we going to sleep now?'),
#  (26981, " That's right."),
#  (26982, ' Can we dream?'),
#  (26983, ' Yes, honey.  I think we both can.'),
#  (26987, ' Better tell the boss.'),
#  (26999, " Where'd you leave them?"),
#  (27001, ' MarsCo went belly-up on the Dow Jones.'),
#  (27002, ' Shit.  When?'),
#  (27004, ' Fucking great.  I invested some money in them.'),
#  (27005, ' You win some, you loose some.'),
#  (27013, ' Sounds like a couple of escape shuttles.'),
#  (27014, " That's what we thought."),
#  (27016, ' Done it already.  Nothing matches.'),
#  (27018, ' Jesus.'),
#  (27020, ' Tactical nukes, maybe?'),
#  (27021, " Where're they headed?"),
#  (27024, " Fort Powell.  What do we tell 'em?"),
#  (27029, " Nice howitzer you've got there."),
#  (27030, ' Thanks.'),
#  (27041, " Miss Noguchi!  You're wanted in admin."),
#  (27042, ' Thanks.'),
#  (27044, ' When?'),
#  (27047, ' Already working on it.'),
#  (27052, ' Okay, give me the numbers.'),
#  (27053, " They've changed their heading again."),
#  (27054, ' Compensate!'),
#  (27055, ' Punch me in a solution for their delta-vee.'),
#  (27056, ' What do you need?'),
#  (27057, ' A three-second burn to port, on my mark.'),
#  (27058, " It's on the board."),
#  (27059, ' Picking up velocity.'),
#  (27060, ' Match it!'),
#  (27070, " Hey, boss.  Wondered where you'd gotten to."),
#  (27074, ' Not too much of the socializing type, then?'),
#  (27077, ' Is that a fact.'),
#  (27080, ' Four.'),
#  (27081, ' And before that?'),
#  (27082, ' Six month stint on Datus.'),
#  (27083, ' Only six?'),
#  (27084, " What is this?  'Twenty Questions'?"),
#  (27087, ' What is that?'),
#  (27088, " Real man' drink."),
#  (27089, ' Seltzer?'),
#  (27090, ' Want some?'),
#  (27092, " Any luck raising Ackland's party?"),
#  (27095, " 'We'?  You wanna fly out there with me?"),
#  (27096, ' Sure.  Do me good to stretch my legs.'),
#  (27099, " Do you think Ackland'll sit tight?"),
#  (27102, ' Nada. No radiation... no movement... nothing.'),
#  (27105, " It's a rhino."),
#  (27106, ' Is it dead?'),
#  (27108, " Yeah, it's fine."),
#  (27110, " I told you we... what's that?"),
#  (27112, " Bloody big if it is.  Top's open."),
#  (27115, " Let's get back and call this in."),
#  (27116, ' Wait a minute.'),
#  (27137, ' Oh man...'),
#  (27139, ' Minh...'),
#  (27140, ' Yep...'),
#  (27151, ' Yeah.  Somebody won.'),
#  (27152, ' Check out the tent.'),
#  (27153, " I've found Ackland!"),
#  (27154, ' Hold on...'),
#  (27161, " What's the problem?"),
#  (27164, ' Appreciate that.'),
#  (27170, ' Agreed.'),
#  (27173, ' What do you mean?'),
#  (27177, ' Think I spoke too soon...'),
#  (27186, ' Headache?  Dehydration?'),
#  (27204, ' Can I... um... have some water?  Please?'),
#  (27205, ' Sure.'),
#  (27206, ' Do you believe him?'),
#  (27213, ' And...?'),
#  (27214, ' And, nothing.  They checked out just fine.'),
#  (27227, ' What is it?'),
#  (27229, ' Do you want a tablet?'),
#  (27232, ' Better?'),
#  (27233, ' Yeah...'),
#  (27235, ' What happened?'),
#  (27237, " What's going on?"),
#  (27239, ' Force the door.'),
#  (27248, ' What is that?'),
#  (27250, ' Where does that lead to?'),
#  (27252, " You've checked that end?"),
#  (27259, ' Okay.'),
#  (27266, ' So, what do you think?'),
#  (27268, " C'mon, man.  One more sweep."),
#  (27273, ' Listen to what?'),
#  (27275, ' De Vries?'),
#  (27276, ' Yeah?'),
#  (27278, ' Something spooking the rhinos?'),
#  (27279, ' I dunno.'),
#  (27291, ' Hey, Guttierez?'),
#  (27292, ' What?'),
#  (27293, ' Take a look at this.'),
#  (27294, " One of 'em must have escaped."),
#  (27296, " There's no way a rhino'd survive that drop."),
#  (27298, " That's a fact."),
#  (27299, ' Whoa, wait a minute...'),
#  (27300, ' What?'),
#  (27301, ' Just got a reading...'),
#  (27302, " How's it going?"),
#  (27303, " Yeah, 'Good Evening' to you, too."),
#  (27305, ' You should hit the sack, too.'),
#  (27307, " What time's sundown?"),
#  (27308, " 'Bout five minutes."),
#  (27309, ' Give me a yell is something happens.'),
#  (27310, ' You got it, cowboy.'),
#  (27315, ' Forget it, man.'),
#  (27316, " C'mon De Vries.  Think of the bonus."),
#  (27318, ' What the hell are you doing?'),
#  (27321, ' Alright, okay.  Look...'),
#  (27322, ' What?'),
#  (27323, " I'll come with you."),
#  (27324, " But I'm going first..."),
#  (27325, ' Anything you say, Mammacitta.'),
#  (27326, ' Careful of that edging there...'),
#  (27327, ' Yeah, I got it.'),
#  (27329, ' Still got him?'),
#  (27336, ' Hold it, hold it...'),
#  (27337, " What's wrong?"),
#  (27338, " I'm picking up another signal."),
#  (27339, ' What?  Where?'),
#  (27340, ' Just behind us, over to the right.'),
#  (27341, " Can't see a thing.  Are you sure?"),
#  (27342, ' Yeah, I...'),
#  (27343, ' Wait.  Lost it.'),
#  (27344, ' How?'),
#  (27345, ' I dunno.  Might be a glitch.'),
#  (27346, " Oh, man.  That's no glitch!"),
#  (27347, " It's alright, it's cool..."),
#  (27348, ' Is it still moving?'),
#  (27392, ' What?'),
#  (27393, " I'm out of ammo.  Get inside, get inside!"),
#  (27398, ' Seal everything now!'),
#  (27399, " What's happening?"),
#  (27400, " Cassie, thank Christ!  We're under attack."),
#  (27401, " We're what!?"),
#  (27404, ' How many of them are there?'),
#  (27405, ' Too many.'),
#  (27422, " That's the wrong way!"),
#  (27423, " Detour.  Other way's blocked..."),
#  (27434, ' Hurry it up.'),
#  (27435, " Don't wait for me!"),
#  (27445, " It's too late!"),
#  (27446, ' Nooooo!'),
#  (27452, ' How many... how many people are missing?'),
#  (27454, " What's our weapons situation?"),
#  (27456, ' Auto-shop?'),
#  (27457, " Auto-shop's sealed, but those boys are cut-off."),
#  (27458, ' Has anybody talked to them?'),
#  (27459, ' Not yet.'),
#  (27460, ' Do it.'),
#  (27463, ' They knocked out the external feeds.'),
#  (27464, ' Looks like it.'),
#  (27466, ' Give or take.'),
#  (27467, " We're not gonna make it, are we?"),
#  (27470, ' Well... try the headset.'),
#  (27483, ' Oh, man...'),
#  (27490, ' Which mean physically going outside.'),
#  (27492, ' Is this the suit?'),
#  (27493, ' Uh-huh.'),
#  (27504, ' How much air-time have I got?'),
#  (27506, ' Deal.'),
#  (27509, ' Sounds great.'),
#  (27511, ' What?  Why?'),
#  (27513, ' How tight are these shafts?'),
#  (27515, " There's still time to back-out."),
#  (27520, ' Thanks.'),
#  (27523, ' Sorry.  Two green enabling buttons...'),
#  (27532, ' Are you alright?'),
#  (27533, " What?  What's wrong?  What is it?"),
#  (27550, ' Where is she?'),
#  (27551, " Comin' up the Central Reservoir."),
#  (27554, ' I found it...'),
#  (27555, ' And?'),
#  (27556, ' Drains right into the Central Reservoir.'),
#  (27557, ' Get her on-line.  Now!'),
#  (27559, " I can't reach her.  Too much signal break-up."),
#  (27560, ' Keep trying!'),
#  (27570, " Okay, we're in business."),
#  (27571, ' Right.  Auto-shop, you all set?'),
#  (27574, " Okay, I'm out of here!"),
#  (27575, ' Blow those suckers, Driscoll!'),
#  (27589, ' But...'),
#  (27595, ' Couple more seconds!'),
#  (27612, ' What can I do?'),
#  (27614, " I... I can't!"),
#  (27615, ' You have to...'),
#  (27616, ' No!'),
#  (27659, " Why should you think I wouldn't be?"),
#  (27662, ' Not at all.'),
#  (27666, " Bill Sampson? He's - he's a director."),
#  (27667, " He's the best."),
#  (27669, ' Oh, no. I see the play.'),
#  (27671, " Standing room doesn't cost much. I manage."),
#  (27672, " I'm going to take you to Margo..."),
#  (27673, ' Oh, no...'),
#  (27674, " She's got to meet you-"),
#  (27676, " There isn't another like you, there couldn't be-"),
#  (27679, ' Eve. Eve Harrington.'),
#  (27683, ' Hi.  Hello, darling-'),
#  (27685, ' How was the concert?'),
#  (27686, ' Loud.'),
#  (27687, ' Lemme fix you a drink.'),
#  (27688, ' No thanks, Birdie.'),
#  (27691, ' It was Fort Sumter they fired on-'),
#  (27692, ' I never played Fort Sumter.'),
#  (27694, ' That was way back...'),
#  (27696, ' You need new girdles.'),
#  (27697, ' Buy some.'),
#  (27698, ' The same size?'),
#  (27699, ' Of course!'),
#  (27701, ' Margo does not play a lunatic, Birdie.'),
#  (27703, " It's the tight girdle that does it."),
#  (27705, " - 'at's my loyal little woman."),
#  (27707, ' Easy, now...'),
#  (27710, " Ain't it the truth?"),
#  (27713, " They're your fans, your audience-"),
#  (27716, " You've what?"),
#  (27717, " She's just outside the door."),
#  (27718, ' The heave-ho.'),
#  (27724, " I thought you'd forgotten about me."),
#  (27725, ' Not at all.  Margo, this is Eve Harrington.'),
#  (27726, ' How do you do, my dear.'),
#  (27727, ' Oh, brother.'),
#  (27728, ' Hello, Miss Channing.'),
#  (27729, ' My husband...'),
#  (27730, ' Hello, Miss Harrington.'),
#  (27731, ' How do you do, Mr. Richards.'),
#  (27733, ' Oh, brother.'),
#  (27734, ' Miss Coonan...'),
#  (27739, " Dear Birdie. Won't you sit down, Miss Worthington?"),
#  (27740, ' Harrington.'),
#  (27741, " I'm so sorry... Harrington. Won't you sit down?"),
#  (27745, " No, thank you.  Yes. I've seen every performance."),
#  (27747, " I'd like anything Miss Channing played..."),
#  (27748, ' Would you, really? How sweet-'),
#  (27751, ' Of course it is.'),
#  (27752, " How'd hear about it?"),
#  (27756, ' There are other plays...'),
#  (27760, ' If I only knew how...'),
#  (27761, ' Try...'),
#  (27762, ' Well...'),
#  (27764, " 'Remembrance'."),
#  (27765, ' Did you see it here in New York?'),
#  (27768, " Eve... why don't you start at the beginning?"),
#  (27769, " It couldn't possibly interest you."),
#  (27772, ' Not at all...'),
#  (27780, ' Thank you so much.'),
#  (27782, ' Show me a human and I might have!'),
#  (27783, ' Bill...'),
#  (27785, ' Bill-'),
#  (27787, " Only in some ways. You're prettier..."),
#  (27788, " I'm a junk yard."),
#  (27789, ' Bill!'),
#  (27790, ' Huh?'),
#  (27791, ' This is Eve Harrington.'),
#  (27793, ' Heaven help me, I love a psychotic.'),
#  (27794, " Hello, what's your name?"),
#  (27795, ' Eve. Eve Harrington.'),
#  (27796, " You've already met."),
#  (27797, ' Where?'),
#  (27798, ' Right here. A minute ago.'),
#  (27799, " That's nice."),
#  (27800, ' She, too, is a great admirer of yours.'),
#  (27801, ' Imagine. All this admiration in just one room.'),
#  (27803, " You're not going, are you?"),
#  (27805, " No, don't go..."),
#  (27808, " Well - if I'm not in the way..."),
#  (27809, " I won't be a minute."),
#  (27812, ' Good luck, genius...'),
#  (27813, " Geniuses don't need good luck.  I do."),
#  (27817, " I'll be at the old stand, tomorrow matinee-"),
#  (27818, ' Not just that way. As a friend...'),
#  (27819, " I'd like that."),
#  (27820, " It's been a real pleasure, Eve."),
#  (27821, ' I hope so, Mr. Richards. Good night...'),
#  (27824, " You said forty-seven minutes. You'll never make it."),
#  (27831, ' Why?'),
#  (27832, ' I just wondered.'),
#  (27833, ' Just wondered what?'),
#  (27834, ' Why.'),
#  (27835, ' Why what?'),
#  (27836, ' Why you have to go out there.'),
#  (27837, " I don't have to. I want to."),
#  (27838, ' Is it the money?'),
#  (27839, ' Eighty percent of it will go for taxes.'),
#  (27842, ' I just asked a simple question.'),
#  (27844, " But Hollywood. You mustn't stay there."),
#  (27845, " It's only one picture deal."),
#  (27846, ' So few come back...'),
#  (27848, ' I read George Jean Nathan every week.'),
#  (27849, ' Also Addison deWitt.'),
#  (27850, ' Every day.'),
#  (27851, " You didn't have to tell me."),
#  (27858, " Where's my coat?"),
#  (27861, " Can't keep his eyes off my legs."),
#  (27862, ' Like a nylon lemon peel-'),
#  (27866, ' Kill the people.  Got your key?'),
#  (27867, ' See you home...'),
#  (27869, ' Ah...'),
#  (27872, ' Of course not.'),
#  (27873, " She's quite a girl, that what's-her name..."),
#  (27874, " Eve. I'd forgotten they grew that way..."),
#  (27877, ' I told her. I sounded off.'),
#  (27879, ' Take care of yourself out there...'),
#  (27881, ' Bill...'),
#  (27882, ' Huh?'),
#  (27883, " Don't get stuck on some glamour puss-"),
#  (27884, " I'll try."),
#  (27886, " Everybody can't be Gregory Peck."),
#  (27890, ' And cut that out right now.'),
#  (27892, " As of this moment you're six years old..."),
#  (27894, ' Thanks for your help... good luck.'),
#  (27895, ' Goodbye, Mr. Sampson.'),
#  (27896, ' Knit me a muffler.'),
#  (27897, ' Call me when you get in...'),
#  (27906, ' What - again?'),
#  (27912, " Well, teacher's away and actors will be actors..."),
#  (27916, ' Something maybe grew a size bigger.'),
#  (27920, " Well, you've done so much... what's new?"),
#  (27921, ' The curtains. I made them myself.'),
#  (27922, " They are lovely. Aren't they lovely, Birdie?"),
#  (27927, ' No trouble at all.'),
#  (27929, ' Behind in your dues? How much?'),
#  (27930, " I haven't got a union. I'm slave labor."),
#  (27931, ' Well?'),
#  (27933, ' Oh-oh.'),
#  (27937, ' Hello..'),
#  (27939, ' Call, what call?'),
#  (27940, ' It this Templeton 89970? Miss Margo Channing?'),
#  (27941, " That's right, but I don't understand-"),
#  (27943, ' I placed...?'),
#  (27944, ' Go ahead, please...'),
#  (27946, " What a thoughtful, ever-lovin' thing to do-"),
#  (27947, ' Bill? Have I gone crazy, Bill?'),
#  (27948, " You're my girl, aren't you?"),
#  (27949, ' That I am...'),
#  (27950, " Then you're crazy."),
#  (27951, ' When - when are you coming back?'),
#  (27954, ' You in a hurry?'),
#  (27959, ' Sing it?'),
#  (27961, " Bill... Bill, it's your birthday."),
#  (27963, ' Happy birthday, darling...'),
#  (27965, ' Many happy returns of the day...'),
#  (27966, " I get a party, don't I?"),
#  (27969, ' She did...?'),
#  (27971, ' Yeah... I will.'),
#  (27972, ' How is Eve? Okay?'),
#  (27973, ' Okay.'),
#  (27974, ' I love you...'),
#  (27975, " I'll check with Eve..."),
#  (27976, ' What?'),
#  (27977, ' I love you too. Good night, darling-'),
#  (27978, ' See you...'),
#  (27979, ' Birdie-'),
#  (27980, ' Hmm?'),
#  (27981, " You don't like Eve, do you?"),
#  (27982, ' Do you want an argument or an answer?'),
#  (27983, ' An answer.'),
#  (27984, ' No.'),
#  (27985, ' Why not?'),
#  (27986, ' Now you want an argument.'),
#  (27987, ' She works hard.'),
#  (27988, " Night an' day."),
#  (27989, " She's loyal and efficient-"),
#  (27990, ' Like an agent with one client.'),
#  (27991, " She thinks only for me...  ... doesn't she?"),
#  (27993, ' How do you mean that?'),
#  (28003, " I've got it."),
#  (28005, ' Right here.'),
#  (28007, " That's my job.  See you at tea time..."),
#  (28009, ' Oh, golly. And I forgot to tell you-'),
#  (28010, ' Yes, dear. You forgot all about it.'),
#  (28019, ' Hollywood.'),
#  (28023, ' Mrs. Richards.'),
#  (28024, ' Karen.'),
#  (28028, " ... you want to be Margo's new understudy."),
#  (28031, ' The show must go on.'),
#  (28033, ' Do you think Miss Channing would approve?'),
#  (28034, ' I think she would cheer.'),
#  (28035, ' But Mr. Richards and Mr. Sampson-'),
#  (28036, " They'll do as they're told."),
#  (28038, ' Of course.'),
#  (28039, " You won't forget it?"),
#  (28040, " I won't forget."),
#  (28043, ' But she just got here...'),
#  (28045, ' What did you expect - live sables?'),
#  (28061, ' This answer satisfies me a hundred percent.'),
#  (28075, ' Yes. Yes, it does.'),
#  (28079, " I'm sorry, I didn't mean to-"),
#  (28082, ' Margo, really...'),
#  (28085, ' How about calling it a night?'),
#  (28087, " It's a good thought."),
#  (28088, " It won't play."),
#  (28090, ' Happy little housewife...'),
#  (28091, ' Cut it out.'),
#  (28094, ' Hear, hear...'),
#  (28095, " Now let's not get into a big hassle-"),
#  (28098, ' Need any help?'),
#  (28100, " If you'd like."),
#  (28101, " I wouldn't like."),
#  (28105, ' Coming?'),
#  (28106, ' In a minute...'),
#  (28116, ' And too many of them are produced.'),
#  (28117, " Let's go sit by the piano."),
#  (28120, " No, Eve, I won't forget..."),
#  (28123, ' You all put together?'),
#  (28131, ' Late for what?'),
#  (28132, " Don't be dense. The party."),
#  (28139, " I'd like to hear it."),
#  (28141, ' Of course.'),
#  (28143, ' I thought you were going to be late-'),
#  (28144, " When I'm guest of honor?"),
#  (28145, ' I had no idea you were even here.'),
#  (28147, ' That never stopped you before.'),
#  (28149, " She's a girl of so many interests."),
#  (28150, " It's a pretty rare quality these days."),
#  (28151, " She's a girl of so many rare qualities."),
#  (28152, ' So she seems.'),
#  (28157, " I don't think that's funny!"),
#  (28159, ' Twenty minutes!'),
#  (28160, ' Thirty minutes, forty minutes! What of it?'),
#  (28164, ' For instance what?'),
#  (28165, ' For instance - you!'),
#  (28167, ' - guilty.'),
#  (28169, ' What about her teeth? What about her fangs?'),
#  (28178, ' May I have your coat?'),
#  (28179, " Don't bother, I can take it up myself..."),
#  (28180, ' Please...'),
#  (28182, ' ... Among so many quiet qualities.'),
#  (28184, " I'm so happy you're happy."),
#  (28188, ' How about me what?'),
#  (28189, ' Supposed you dropped dead. What about your inventory?'),
#  (28190, " I ain't gonna die. Not with a hit."),
#  (28192, ' Thank you.'),
#  (28193, ' Nothing, really...'),
#  (28197, ' What is he talking about?'),
#  (28198, ' Macbeth.'),
#  (28206, ' I do not. How do you do?'),
#  (28207, " We never met. That's why."),
#  (28209, ' Good evening, Mr. deWitt.'),
#  (28210, ' I had no idea you knew each other.'),
#  (28212, " That's how you met me. In passing."),
#  (28216, ' We have that in common.'),
#  (28217, ' Then you two must have a long talk-'),
#  (28221, ' Why do they always look like unhappy rabbits?'),
#  (28224, ' Amen.'),
#  (28225, ' "Liebestraum."'),
#  (28226, ' I just played it.'),
#  (28227, ' Play it again.'),
#  (28228, ' But that was the fourth straight time.'),
#  (28230, ' No. You\'re just crazy about "Liebestraum."'),
#  (28231, ' "Liebestraum."'),
#  (28236, " Wouldn't you feel more natural taking a bow?"),
#  (28237, ' You know nothing about feelings, natural or unnatural.'),
#  (28242, ' No heart to burn.'),
#  (28249, ' Miss Caswell?  What?'),
#  (28253, " When's the audition?"),
#  (28254, ' A couple of weeks.'),
#  (28256, ' Would you?'),
#  (28257, ' Anything to help you out, Max.'),
#  (28258, ' This is real cooperation. I appreciate it.'),
#  (28260, ' All you got to do is name it.'),
#  (28261, ' Give Eve Harrington job in you office.'),
#  (28262, " You get quick action, don't you?"),
#  (28265, ' But what could she do?'),
#  (28267, ' Well...'),
#  (28270, ' Promise.'),
#  (28271, ' I promise.'),
#  (28272, " That's my Max."),
#  (28274, ' Where is she?'),
#  (28275, ' Up in the room.'),
#  (28277, " Who's left out there?"),
#  (28282, ' When you do, let me in on it.'),
#  (28283, ' I will.'),
#  (28284, " How's the new one coming?"),
#  (28285, ' The play? All right, I guess...'),
#  (28286, ' "Cora." She\'s - still a girl of twenty?'),
#  (28287, " Twentyish. It isn't important."),
#  (28289, ' How do you mean?'),
#  (28290, " Don't be evasive."),
#  (28291, " Margo, you haven't got any age."),
#  (28304, " The ladies' - shall we say - lounge?"),
#  (28305, ' Being violently ill to her tummy.'),
#  (28311, ' Naturally enough, your understudy.'),
#  (28314, ' Eve! My understudy...'),
#  (28315, " Didn't you know?"),
#  (28316, ' Of course I knew.'),
#  (28317, ' It just slipped your mind.'),
#  (28318, ' How... how was Miss Caswell?'),
#  (28319, " Frankly, I don't remember."),
#  (28320, ' Just slipped your mind.'),
#  (28322, ' Was she that bad?'),
#  (28324, ' I take it she read well.'),
#  (28326, ' How nice.'),
#  (28327, " In time she'll be what you are."),
#  (28334, ' Feeling better, my dear?'),
#  (28340, ' Hello, Miss Channing.'),
#  (28342, " It's all over."),
#  (28343, " What's all over?"),
#  (28344, ' The audition.'),
#  (28346, " She's your understudy."),
#  (28351, ' Really, Eve? Why?'),
#  (28353, ' Why not?'),
#  (28356, ' What fire and music?'),
#  (28357, " You wouldn't understand.  How was Miss Caswell?"),
#  (28361, " You'd have been proud of her."),
#  (28362, " I'm sure."),
#  (28363, ' She was a revelation...'),
#  (28364, ' To you, too?'),
#  (28365, ' What do you mean?'),
#  (28367, " That's beside the point."),
#  (28369, ' Addison-!'),
#  (28370, ' So full of meaning, fire and music!'),
#  (28374, ' Not mouse, never mouse! If anything - rat!'),
#  (28377, ' I never said it was!'),
#  (28386, ' Are you breaking the contract?'),
#  (28387, ' Answer my question!'),
#  (28389, " I didn't hear you."),
#  (28390, " I said I'm a dying man!"),
#  (28396, ' Who?'),
#  (28397, ' The kid. Junior.'),
#  (28398, ' Gone.'),
#  (28399, ' I must have frightened her away.'),
#  (28400, " I wouldn't be surprised. Sometimes you frighten me."),
#  (28402, " Don't mix your metaphors."),
#  (28403, ' I mix what I like.'),
#  (28404, ' Okay. Mix.'),
#  (28406, ' What a body, what a voice.'),
#  (28408, " The gong rang. The fight's over. Calm down."),
#  (28409, ' I will not calm down!'),
#  (28410, " Don't calm down."),
#  (28411, " You're being terribly tolerant, aren't you?"),
#  (28412, " I'm trying terribly hard."),
#  (28414, ' Here we go...'),
#  (28416, " Now don't get carried away-"),
#  (28418, " You've been all through that with Lloyd-"),
#  (28421, ' Paranoiac!'),
#  (28427, " It's obvious you're not a woman."),
#  (28428, " I've been aware of that for some time."),
#  (28429, ' Well, I am.'),
#  (28430, " I'll say."),
#  (28431, " Don't be condescending."),
#  (28434, " Margo, let's make peace."),
#  (28435, ' The terms are too high. Unconditional surrender.'),
#  (28437, " It's not nonsense."),
#  (28439, ' I wish it were.'),
#  (28446, ' That suddenly makes the whole thing believable.'),
#  (28448, ' Lloyd, what happened...?'),
#  (28450, ' Margo, again...'),
#  (28452, " That's on time for Margo."),
#  (28454, " It's just possible she didn't..."),
#  (28456, " - don't run out of adjectives, dear."),
#  (28458, " Margo hasn't done badly by it."),
#  (28460, " It's going to be a cozy weekend."),
#  (28461, ' What is?'),
#  (28472, ' What time is it?'),
#  (28478, ' Peace and quit is for libraries.'),
#  (28479, ' Lloyd, be careful...'),
#  (28481, " Karen and I just don't want an accident-"),
#  (28482, ' I have no intention of having an accident!'),
#  (28487, ' Incredible.'),
#  (28488, ' How much time have we?'),
#  (28489, ' Roughly ten minutes.'),
#  (28490, ' How far to the station?'),
#  (28491, ' Three or four miles...'),
#  (28496, " You'll break your neck on that ice."),
#  (28498, " Don't joke about such things."),
#  (28501, ' Thank you, Lloyd. Godspeed.'),
#  (28506, ' Do you want it on?'),
#  (28507, " It doesn't matter."),
#  (28508, ' I detest cheap sentiment.'),
#  (28509, " Karen.  I haven't been pleasant this weekend."),
#  (28510, " We've all seemed a little tense lately..."),
#  (28514, " You're Margo. Just - Margo."),
#  (28516, ' What about Bill?'),
#  (28517, ' What about Bill?'),
#  (28518, " He's in love with you."),
#  (28520, ' Why should he - and why should you?'),
#  (28524, ' Not to you. Not to Bill.'),
#  (28525, " Isn't that what they always say?"),
#  (28529, ' Well...'),
#  (28532, ' About what?'),
#  (28540, ' Are you proud of me, Bill?'),
#  (28542, " You shouldn't have had any doubts."),
#  (28544, ' Is that what you want me to be?'),
#  (28545, " I'm talking about you. And what you want."),
#  (28546, ' So am I.'),
#  (28547, ' What have I got to do with it?'),
#  (28548, ' Everything.'),
#  (28550, " Don't run away, Bill."),
#  (28551, ' From what would I be running?'),
#  (28553, " I'm for it."),
#  (28557, " Your make-up's a little heavy."),
#  (28558, ' - and for you.'),
#  (28559, " You're quite a girl."),
#  (28560, ' You think?'),
#  (28561, " I'm in love with Margo. Hadn't you heard?"),
#  (28562, ' You hear all kinds of things.'),
#  (28564, ' Find out.'),
#  (28567, ' May I come in?'),
#  (28568, ' Certainly, Mr. deWitt...'),
#  (28570, " I consider myself lucky they didn't throw things."),
#  (28573, " You're more than modest."),
#  (28576, ' Please do.'),
#  (28581, " It needn't be."),
#  (28583, ' I am somebody.'),
#  (28589, " I'm not enough for a paragraph."),
#  (28591, " That's right."),
#  (28593, ' Yes. I do.'),
#  (28595, ' Yes. The Shubert.'),
#  (28597, ' Eddie...'),
#  (28598, ' Eddie what?'),
#  (28601, ' You take charge.'),
#  (28602, ' I believe I will.'),
#  (28609, ' She was magnificent.'),
#  (28610, " Then you've heard too."),
#  (28611, ' I was there. An eyewitness.'),
#  (28613, ' A happy coincidence.'),
#  (28614, " We're having lunch with a movie talent scout."),
#  (28615, " They certainly don't waste much time."),
#  (28619, ' Margo.'),
#  (28620, ' Margo? Lunching in public?'),
#  (28622, ' She may be later than you think...'),
#  (28625, " I just can't believe it."),
#  (28627, " I can't believe Eve said those things!"),
#  (28629, " Lloyd says it's a publicity release..."),
#  (28634, ' Maybe just a little around the edges.'),
#  (28636, " Where'd you get all that information?"),
#  (28637, ' Eve.'),
#  (28638, ' Eve?'),
#  (28640, ' That was a pity...'),
#  (28642, ' I wonder why.'),
#  (28645, " That's quite a change of subject."),
#  (28647, " I'm trying hard to follow you."),
#  (28649, " I'm beginning to catch up."),
#  (28650, ' If we could cast it properly, that is...'),
#  (28653, " Now you're quoting Addison. Or Eve."),
#  (28655, ' Eve would ask Abbott to give her Costello.'),
#  (28657, ' With gestures, of course.'),
#  (28660, ' Now just a minute-'),
#  (28662, ' Now just a minute!'),
#  (28671, " I'm glad Bill's back."),
#  (28672, " They'd die without each other."),
#  (28674, ' Such as?'),
#  (28678, ' Hear, hear...'),
#  (28680, ' He does not exaggerate. I was good.'),
#  (28681, ' You were great.'),
#  (28683, ' Too bad.'),
#  (28687, ' To Margo. To my bride-to-be.'),
#  (28688, ' Glory Hallelujah.'),
#  (28689, ' Well of all-'),
#  (28690, ' Margo!'),
#  (28692, ' When? When are you going to do it?'),
#  (28694, ' Yes, sir.'),
#  (28699, ' What are you going to wear?'),
#  (28700, ' Something simple. A fur coat over a nightgown...'),
#  (28715, ' After all, maybe she just wants to apologize...'),
#  (28720, ' Well... all right.'),
#  (28723, " I was wondering whether you'd come at all.."),
#  (28725, " I don't expect you to be pleasant."),
#  (28726, " I don't intend to be."),
#  (28727, " Can't we sit down? Just for a minute..."),
#  (28729, " There can't be very much-"),
#  (28730, ' Oh, but there is-'),
#  (28732, " Why shouldn't you?  Please sit down."),
#  (28738, " Let's not get over-dramatic."),
#  (28740, " Eve... don't cry."),
#  (28741, " I'm not crying."),
#  (28744, ' But the raves about your performance-'),
#  (28745, " - an understudy's performance."),
#  (28747, " He's not my friend. You were my friends..."),
#  (28748, ' He can help you.'),
#  (28751, " I'll never get over it."),
#  (28753, ' I wish I could believe that.'),
#  (28756, ' I think I know...'),
#  (28757, ' Something most important you can do.'),
#  (28762, ' You talk just as Addison said you did.'),
#  (28765, ' Addison wants me to play it.'),
#  (28766, ' Over my dead body...'),
#  (28770, ' Hungry?'),
#  (28771, ' Just some coffee.'),
#  (28772, " I'm not surprised. After all that humble pie..."),
#  (28778, ' Just like that, eh?'),
#  (28779, ' Just like that.'),
#  (28781, " I don't think that's funny."),
#  (28782, " It wasn't meant to be."),
#  (28786, ' - well? What happened?'),
#  (28787, ' Nothing much. She apologized.'),
#  (28788, ' With tears?'),
#  (28789, ' With tears.'),
#  (28791, ' Check.'),
#  (28792, ' Very classy stuff, lots of technique-'),
#  (28794, ' Not much.'),
#  (28795, ' Groom-  - may I have a wedding present?'),
#  (28796, ' What would you like? Texas?'),
#  (28799, " You've got it backwards. Even for Wilkes-Barre."),
#  (28802, ' You know, she probably means well, after all...'),
#  (28803, ' She is a louse.'),
#  (28804, ' Never try to outguess Margo.'),
#  (28805, ' Groom.'),
#  (28806, ' Yes, dear.'),
#  (28807, " You know what I'm going to be?"),
#  (28808, ' A cowboy.'),
#  (28809, ' A married lady.'),
#  (28810, ' With the paper to prove it.'),
#  (28812, ' I remember.'),
#  (28813, " You'll be there, won't you."),
#  (28814, ' Often enough to keep the franchise.'),
#  (28816, ' That depends.'),
#  (28817, ' I mean really, deeply angry...'),
#  (28818, " I don't think I could be."),
#  (28819, ' Well. I don\'t want to play "Cora."'),
#  (28824, " What's so funny?"),
#  (28825, ' Nothing...'),
#  (28826, ' Nothing?'),
#  (28827, " Everything... everything's so funny..."),
#  (28832, " Who is it? What's it all about?"),
#  (28843, " I'm a human being, I've got some!"),
#  (28850, ' What a day - what a heavenly day...'),
#  (28851, ' D-day.'),
#  (28852, ' Just like it.'),
#  (28855, ' Are you that sure of tomorrow?'),
#  (28856, " Aren't you?"),
#  (28857, ' Frankly - yes.'),
#  (28859, ' All paved with diamonds and gold?'),
#  (28860, ' You know me better than that.'),
#  (28861, ' Paved with what, then?'),
#  (28862, ' Stars.'),
#  (28863, ' What time?'),
#  (28864, ' Almost four.'),
#  (28866, " You could sleep, too, couldn't you?"),
#  (28867, ' Why not?'),
#  (28869, " Why'd call me a killer?"),
#  (28874, ' Also with the reluctant compliments of Max Fabian.'),
#  (28878, " We're?"),
#  (28879, ' Lloyd and I.'),
#  (28881, ' Addison...'),
#  (28885, " I didn't mean just the Theater."),
#  (28886, ' What else?'),
#  (28891, " I'm in love with Lloyd!"),
#  (28893, ' You have no right to say such things!'),
#  (28896, ' ... and Karen.'),
#  (28897, " She doesn't know."),
#  (28898, ' She knows enough not to be here.'),
#  (28904, ' You sat and talked until it was light...'),
#  (28908, ' What do you take me for?'),
#  (28913, ' I never intended you to be.'),
#  (28914, ' Yes, you did. You still do.'),
#  (28917, ' Champion to champion.'),
#  (28921, ' What do you mean by that?'),
#  (28923, ' What have you got to do with it?'),
#  (28925, " I can't believe my ears..."),
#  (28926, ' A dull cliche.'),
#  (28937, ' What of it?'),
#  (28939, ' What of it?'),
#  (28941, ' She never proved anything, not a thing!'),
#  (28944, ' She was a liar, she was a liar!'),
#  (28949, " That's not true!"),
#  (28952, ' No-no-no...'),
#  (28956, ' Then say so.'),
#  (28957, ' Yes, Addison.'),
#  (28959, ' Yes, Addison.'),
#  (28977, ' Congratulations, Eve.'),
#  (28978, ' Thank you, Karen.'),
#  (28980, ' As soon as the peasants stop pawing her.'),
#  (28982, " I don't suppose there's a drink left..."),
#  (28983, " You can have one at Max's."),
#  (28984, " I don't think I'm going."),
#  (28985, ' Why not?'),
#  (28986, " Because I don't want to."),
#  (28988, " No, it's not.  It's for this."),
#  (28989, " It's the same thing, isn't it?"),
#  (28991, " You're being childish."),
#  (28992, " I'm tired. I want to go home."),
#  (28994, ' Who are you?'),
#  (28995, ' Miss Harrington...'),
#  (28996, ' What are you doing here?'),
#  (28997, ' I - I guess I fell asleep.'),
#  (28999, ' How did you get in here?'),
#  (29001, ' You were just looking around...'),
#  (29002, " That's all."),
#  (29003, ' What for?'),
#  (29004, " You probably won't believe me."),
#  (29005, ' Probably not.'),
#  (29006, ' It was for my report.'),
#  (29007, ' What report? To whom?'),
#  (29009, " I've heard of them."),
#  (29011, " Erasmus Hall. That's in Brooklyn, isn't it?"),
#  (29014, ' I might.'),
#  (29016, " The maid'll fix it in the morning."),
#  (29017, " I'll just pick up the broken glass."),
#  (29018, " Don't bother."),
#  (29020, ' Subway.'),
#  (29021, ' How long does it take?'),
#  (29024, " I don't care if I never get home."),
#  (29025, " That's the door."),
#  (29026, " You rest. I'll get it..."),
#  (29027, ' Hello, there. Who are you?'),
#  (29030, ' How do you know my name?'),
#  (29031, " It's a very famous name, Mr. deWitt."),
#  ...]

# %%
len(ord_list_i2text)
# Out:
# 7000

# %%
question=[] #defining question and answer lists
answer=[]

for i in range(len(ord_list_i2text)-1):
    if ord_list_i2text[i][0]-ord_list_i2text[i+1][0]!=1:
        question.append(ord_list_i2text[i][1])
        answer.append(ord_list_i2text[i+1][1])

# %%
dataset2=[df['Q'],df['ANS']]

for j in range(len(dataset2[0])):
    if not (len(dataset2[0][j].split())>long_threshold or (len(dataset2[1][j].split())>long_threshold)):
        question.append(dataset2[0][j])
        answer.append(dataset2[1][j])

# %%
len(question),len(answer)
# Out:
# (9382, 9382)

# %% [markdown]
# ## Prepocessing dataset
#
# - Set to lower case
# - Remove contract form
# - Remove punctuation
# - add sos and eos tokens to answers

# %%
contractions_dict = {
"im": "i am",
"dont": "do not",
"doesnt": "does not",
"theres": "there is",
"ain't": "am not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he'll've": "he will have",
"he's": "he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how is",
"i'd": "I would",
"i'd've": "I would have",
"i'll": "I will",
"i'll've": "I will have",
"i'm": "I am",
"i've": "I have",
"isn't": "is not",
"it'd": "it would",
"it'd've": "it would have",
"it'll": "it will",
"it'll've": "it will have",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she would",
"she'd've": "she would have",
"she'll": "she will",
"she'll've": "she will have",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so is",
"that'd": "that had",
"that'd've": "that would have",
"that's": "that is",
"there'd": "there would",
"there'd've": "there would have",
"there's": "there is",
"they'd": "they would",
"they'd've": "they would have",
"they'll": "they will",
"they'll've": "they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we would",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what'll've": "what will have",
"what're": "what are",
"what's": " what is",
"what've": "what have",
"when's": "when is",
"when've": "when have",
"where'd": "where did",
"where's": "where is",
"where've": "where have",
"who'll": "who will",
"who'll've": "who will have",
"who's": "who is",
"who've": "who have",
"why's": "why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you would",
"you'd've": "you would have",
"you'll": "you will",
"you'll've": "you will have",
"you're": "you are",
"you've": "you have"
}

# %%
question
# Out:
# [' Look, I told you...',
#  ' Thank you, Officer Ripley.  That will be...',
#  ' You are a head case.  Have a donut.',
#  " Why won't you check out LV-426?",
#  ' What are you talking about. What people?',
#  ' How many colonists?',
#  ' Sixty, maybe seventy families.',
#  ' Sweet Jesus.',
#  ' Yeah.  What?',
#  ' So what do I tell this guy?',
#  " No.  There's no way!",
#  ' Hear me out...',
#  " What about you?  What's your interest in this?",
#  ' Yeah, yeah.  I saw the commercial.',
#  " That's right.",
#  ' Running loaders, forklifts, that sort of thing?',
#  ' If I go.',
#  ' Yello?  Oh, Ripley.  Hi...',
#  " That's the plan.  My word on it.",
#  " This floor's freezing.",
#  ' Would you, Sir?',
#  ' Hey, Vasquez...you ever been mistaken for a man?',
#  ' No.  Have you?',
#  " Whoooah!  No shit?  I'm impressed.",
#  " Let's go...let's go.  Cycle through!",
#  " Hey, 'Top.'  What's the op?",
#  ' Sir?',
#  ' Yes, Hicks?',
#  " Hudson, Sir.  He's Hicks.",
#  " What's the question?",
#  ' Sounds like you, Hicks.',
#  ' Fuck you.',
#  ' Anytime.  Anywhere.',
#  " I hope you're right.  I really do.",
#  ' Are there any questions?  Hudson?',
#  ' Still nothing from the colony?',
#  ' Dead on all channels.',
#  ' Save it.',
#  ' Sure, Hicks.',
#  ' How may drops is this for you, Lieutenant?',
#  ' Thirty-eight...simulated.',
#  " ...that's better.  Pan it around a bit.",
#  ' That the atmosphere processor?',
#  ' Hold at forty.  Slow circle of the complex.',
#  ' The structure seems intact.  They have power.',
#  " Okay, let's do it.",
#  ' Ten seconds, people.  Look sharp!',
#  " Vasquez, take point.  Let's move.",
#  " ...We're coming in.",
#  " He's coming in.  I feel safer already.",
#  ' Sir, the CPU is on-line.',
#  " Okay, stand by in operations.  Let's go.",
#  " It's insured.",
#  ' Poor bastard.',
#  ' One of us?',
#  ' Apone...where are your people? Anybody in D-Block?',
#  ' Where are your parents?  You have to try...',
#  ' Gorman!  Give it a rest would you.',
#  " What's he scanning for?",
#  ' What did you say?',
#  " Casey.  She's my only friend.",
#  ' What about me?',
#  " I don't want you for a friend.",
#  ' Why not?',
#  " They're dead.",
#  ' You promise?',
#  ' Cross my heart.',
#  ' And hope to die?',
#  ' Alive?',
#  " The 'maze'?  You mean the air ducts?",
#  " You're really something, ace.",
#  ' You tell me.  I only work here.',
#  ' What is it?',
#  " I don't know.",
#  ' Proceed inside.',
#  " They're right under the primary heat exchangers.",
#  " She's right.",
#  ' So.',
#  ' So...then the fusion containment shuts down.',
#  ' So?  So?',
#  " We're talking thermonuclear explosion.",
#  ' Flame-units only.  I want rifles slung.',
#  " Let's go.  Pull 'em out.",
#  ' Movement!',
#  ' Position?',
#  " Can't lock up...",
#  ' Talk to me, Hudson.',
#  ' Uh, seems to be in front and behind.',
#  " Let's get the fuck out of here!",
#  ' Not that tunnel, the other one!',
#  ' GET THEM OUT OF THERE!  DO IT NOW!',
#  ' Shut up.  Just shut up!',
#  ' Say again?  All after incinerators?',
#  ' I told them to fall back...',
#  " They're but off!  Do something!",
#  ' Looks like it stung him.',
#  " Hey...hey!  Look, Crowe and Dietrich aren't dead, man.",
#  " Oh, God.  Jesus.  This ain't happening.",
#  ' Why not?',
#  ' Bullshit!',
#  ' Yeah, bullshit.  Watch us.',
#  ' You son of a bitch.',
#  " Don't make me pull rank, Ripley.",
#  ' Corporal Hicks!?',
#  ' Are you finished?  You okay?',
#  " I guess we're not leaving, right?",
#  " I'm sorry, Newt.",
#  ' About seventeen days.',
#  ' Aye-firmative.',
#  ' Thanks.',
#  " Uh, what's next?",
#  " I don't want to...I have scary dreams.",
#  ' Oh.  Sorry, Newt.',
#  " Yes, there are, aren't there.",
#  ' Why do they tell little kids that?',
#  ' Did one of those things grow inside her?',
#  " I don't know, Newt.  That's the truth.",
#  " No, it's different, honey.",
#  ' Did you ever have a baby?',
#  ' Yes.  A little girl.',
#  ' Where is she?',
#  ' Gone.',
#  ' You mean dead.',
#  " Don't go!  Please.",
#  ' Yes.  That follows.',
#  ' Could it be intelligent?',
#  ' Now, wait a second --',
#  ' Sorry to disappoint you.',
#  " That's it.  See it?  Emergency venting.",
#  ' How long until it blows?',
#  ' We got problems.',
#  " And it's too late to shut it down?",
#  ' Hudson, give us a break.',
#  " Think of what?  We're fucked.",
#  " I'll go.",
#  ' What?',
#  ' See you soon.',
#  " They're in the approach corridor.",
#  ' On my way.',
#  ' Now many?',
#  " Maybe we got 'em demoralized.",
#  " They'll get us.",
#  ' Maybe.  Maybe not.',
#  " What's this?",
#  " Yeah.  I've noticed.",
#  ' How do you feel?',
#  ' Forget it.',
#  ' Newt.  Newt, wake up.',
#  ' Wah...?  Where are...?',
#  " Sssh.  Don't move.  We're in trouble.",
#  " Mommy...I mean, Ripley...I'm scared.",
#  ' I know, honey.  Me too.',
#  ' The corner!  Ready?',
#  ' Do it!',
#  " Wait a minute.  We'd know about it.",
#  " Let's waste him.  No offense.",
#  ' They cut the power.',
#  " It's inside the complex.",
#  " You're just reading me.",
#  " It's game time.",
#  ' Just get back here!',
#  ' Range twenty meters.',
#  ' Seal the door.',
#  ' Seventeen meters.',
#  " Let's get these things lit.",
#  " We didn't miss anything.",
#  ' Fifteen meters.',
#  " They're right on us.  Vasquez, how you doing?",
#  ' Nine meters.  Eight.',
#  " Can't be.  That's inside the room!",
#  " It's readin' right.  Look!",
#  " Well you're not reading it right!",
#  ' Six meters.  Five.  What the fu --',
#  ' Burke!  Open the door!',
#  ' Look!',
#  " Let's go!  Let's go!",
#  " Fuckin' A!",
#  ' Locked.',
#  ' Stand back.',
#  ' Come on.  Crawl faster.',
#  ' Sure.  Go left.',
#  " This way.  Come on, we're almost there!",
#  ' Newt, wait!',
#  " No!  No!  She's alive!  We have to --",
#  ' HOW MUCH TIME?',
#  ' PLENTY!  TWENTY-SIX MINUTES!',
#  " WE'RE NOT LEAVING!",
#  ' Ripley...',
#  " Hicks, don't let him leave.",
#  " We ain't going anywhere.",
#  ' Ellen.',
#  " Don't be long, Ellen.",
#  " I knew you'd come.",
#  ' You did okay, Bishop.',
#  ' Well, thanks, I --',
#  ' Mommy...Mommy?',
#  ' Right here, baby.  Right here.',
#  ' Are we going to sleep now?',
#  " That's right.",
#  ' Can we dream?',
#  ' Yes, honey.  I think we both can.',
#  ' Better tell the boss.',
#  " Where'd you leave them?",
#  ' MarsCo went belly-up on the Dow Jones.',
#  ' Shit.  When?',
#  ' Fucking great.  I invested some money in them.',
#  ' You win some, you loose some.',
#  ' Sounds like a couple of escape shuttles.',
#  " That's what we thought.",
#  ' Done it already.  Nothing matches.',
#  ' Jesus.',
#  ' Tactical nukes, maybe?',
#  " Where're they headed?",
#  " Fort Powell.  What do we tell 'em?",
#  " Nice howitzer you've got there.",
#  ' Thanks.',
#  " Miss Noguchi!  You're wanted in admin.",
#  ' Thanks.',
#  ' When?',
#  ' Already working on it.',
#  ' Okay, give me the numbers.',
#  " They've changed their heading again.",
#  ' Compensate!',
#  ' Punch me in a solution for their delta-vee.',
#  ' What do you need?',
#  ' A three-second burn to port, on my mark.',
#  " It's on the board.",
#  ' Picking up velocity.',
#  ' Match it!',
#  " Hey, boss.  Wondered where you'd gotten to.",
#  ' Not too much of the socializing type, then?',
#  ' Is that a fact.',
#  ' Four.',
#  ' And before that?',
#  ' Six month stint on Datus.',
#  ' Only six?',
#  " What is this?  'Twenty Questions'?",
#  ' What is that?',
#  " Real man' drink.",
#  ' Seltzer?',
#  ' Want some?',
#  " Any luck raising Ackland's party?",
#  " 'We'?  You wanna fly out there with me?",
#  ' Sure.  Do me good to stretch my legs.',
#  " Do you think Ackland'll sit tight?",
#  ' Nada. No radiation... no movement... nothing.',
#  " It's a rhino.",
#  ' Is it dead?',
#  " Yeah, it's fine.",
#  " I told you we... what's that?",
#  " Bloody big if it is.  Top's open.",
#  " Let's get back and call this in.",
#  ' Wait a minute.',
#  ' Oh man...',
#  ' Minh...',
#  ' Yep...',
#  ' Yeah.  Somebody won.',
#  ' Check out the tent.',
#  " I've found Ackland!",
#  ' Hold on...',
#  " What's the problem?",
#  ' Appreciate that.',
#  ' Agreed.',
#  ' What do you mean?',
#  ' Think I spoke too soon...',
#  ' Headache?  Dehydration?',
#  ' Can I... um... have some water?  Please?',
#  ' Sure.',
#  ' Do you believe him?',
#  ' And...?',
#  ' And, nothing.  They checked out just fine.',
#  ' What is it?',
#  ' Do you want a tablet?',
#  ' Better?',
#  ' Yeah...',
#  ' What happened?',
#  " What's going on?",
#  ' Force the door.',
#  ' What is that?',
#  ' Where does that lead to?',
#  " You've checked that end?",
#  ' Okay.',
#  ' So, what do you think?',
#  " C'mon, man.  One more sweep.",
#  ' Listen to what?',
#  ' De Vries?',
#  ' Yeah?',
#  ' Something spooking the rhinos?',
#  ' I dunno.',
#  ' Hey, Guttierez?',
#  ' What?',
#  ' Take a look at this.',
#  " One of 'em must have escaped.",
#  " There's no way a rhino'd survive that drop.",
#  " That's a fact.",
#  ' Whoa, wait a minute...',
#  ' What?',
#  ' Just got a reading...',
#  " How's it going?",
#  " Yeah, 'Good Evening' to you, too.",
#  ' You should hit the sack, too.',
#  " What time's sundown?",
#  " 'Bout five minutes.",
#  ' Give me a yell is something happens.',
#  ' You got it, cowboy.',
#  ' Forget it, man.',
#  " C'mon De Vries.  Think of the bonus.",
#  ' What the hell are you doing?',
#  ' Alright, okay.  Look...',
#  ' What?',
#  " I'll come with you.",
#  " But I'm going first...",
#  ' Anything you say, Mammacitta.',
#  ' Careful of that edging there...',
#  ' Yeah, I got it.',
#  ' Still got him?',
#  ' Hold it, hold it...',
#  " What's wrong?",
#  " I'm picking up another signal.",
#  ' What?  Where?',
#  ' Just behind us, over to the right.',
#  " Can't see a thing.  Are you sure?",
#  ' Yeah, I...',
#  ' Wait.  Lost it.',
#  ' How?',
#  ' I dunno.  Might be a glitch.',
#  " Oh, man.  That's no glitch!",
#  " It's alright, it's cool...",
#  ' Is it still moving?',
#  ' What?',
#  " I'm out of ammo.  Get inside, get inside!",
#  ' Seal everything now!',
#  " What's happening?",
#  " Cassie, thank Christ!  We're under attack.",
#  " We're what!?",
#  ' How many of them are there?',
#  ' Too many.',
#  " That's the wrong way!",
#  " Detour.  Other way's blocked...",
#  ' Hurry it up.',
#  " Don't wait for me!",
#  " It's too late!",
#  ' Nooooo!',
#  ' How many... how many people are missing?',
#  " What's our weapons situation?",
#  ' Auto-shop?',
#  " Auto-shop's sealed, but those boys are cut-off.",
#  ' Has anybody talked to them?',
#  ' Not yet.',
#  ' Do it.',
#  ' They knocked out the external feeds.',
#  ' Looks like it.',
#  ' Give or take.',
#  " We're not gonna make it, are we?",
#  ' Well... try the headset.',
#  ' Oh, man...',
#  ' Which mean physically going outside.',
#  ' Is this the suit?',
#  ' Uh-huh.',
#  ' How much air-time have I got?',
#  ' Deal.',
#  ' Sounds great.',
#  ' What?  Why?',
#  ' How tight are these shafts?',
#  " There's still time to back-out.",
#  ' Thanks.',
#  ' Sorry.  Two green enabling buttons...',
#  ' Are you alright?',
#  " What?  What's wrong?  What is it?",
#  ' Where is she?',
#  " Comin' up the Central Reservoir.",
#  ' I found it...',
#  ' And?',
#  ' Drains right into the Central Reservoir.',
#  ' Get her on-line.  Now!',
#  " I can't reach her.  Too much signal break-up.",
#  ' Keep trying!',
#  " Okay, we're in business.",
#  ' Right.  Auto-shop, you all set?',
#  " Okay, I'm out of here!",
#  ' Blow those suckers, Driscoll!',
#  ' But...',
#  ' Couple more seconds!',
#  ' What can I do?',
#  " I... I can't!",
#  ' You have to...',
#  ' No!',
#  " Why should you think I wouldn't be?",
#  ' Not at all.',
#  " Bill Sampson? He's - he's a director.",
#  " He's the best.",
#  ' Oh, no. I see the play.',
#  " Standing room doesn't cost much. I manage.",
#  " I'm going to take you to Margo...",
#  ' Oh, no...',
#  " She's got to meet you-",
#  " There isn't another like you, there couldn't be-",
#  ' Eve. Eve Harrington.',
#  ' Hi.  Hello, darling-',
#  ' How was the concert?',
#  ' Loud.',
#  ' Lemme fix you a drink.',
#  ' No thanks, Birdie.',
#  ' It was Fort Sumter they fired on-',
#  ' I never played Fort Sumter.',
#  ' That was way back...',
#  ' You need new girdles.',
#  ' Buy some.',
#  ' The same size?',
#  ' Of course!',
#  ' Margo does not play a lunatic, Birdie.',
#  " It's the tight girdle that does it.",
#  " - 'at's my loyal little woman.",
#  ' Easy, now...',
#  " Ain't it the truth?",
#  " They're your fans, your audience-",
#  " You've what?",
#  " She's just outside the door.",
#  ' The heave-ho.',
#  " I thought you'd forgotten about me.",
#  ' Not at all.  Margo, this is Eve Harrington.',
#  ' How do you do, my dear.',
#  ' Oh, brother.',
#  ' Hello, Miss Channing.',
#  ' My husband...',
#  ' Hello, Miss Harrington.',
#  ' How do you do, Mr. Richards.',
#  ' Oh, brother.',
#  ' Miss Coonan...',
#  " Dear Birdie. Won't you sit down, Miss Worthington?",
#  ' Harrington.',
#  " I'm so sorry... Harrington. Won't you sit down?",
#  " No, thank you.  Yes. I've seen every performance.",
#  " I'd like anything Miss Channing played...",
#  ' Would you, really? How sweet-',
#  ' Of course it is.',
#  " How'd hear about it?",
#  ' There are other plays...',
#  ' If I only knew how...',
#  ' Try...',
#  ' Well...',
#  " 'Remembrance'.",
#  ' Did you see it here in New York?',
#  " Eve... why don't you start at the beginning?",
#  " It couldn't possibly interest you.",
#  ' Not at all...',
#  ' Thank you so much.',
#  ' Show me a human and I might have!',
#  ' Bill...',
#  ' Bill-',
#  " Only in some ways. You're prettier...",
#  " I'm a junk yard.",
#  ' Bill!',
#  ' Huh?',
#  ' This is Eve Harrington.',
#  ' Heaven help me, I love a psychotic.',
#  " Hello, what's your name?",
#  ' Eve. Eve Harrington.',
#  " You've already met.",
#  ' Where?',
#  ' Right here. A minute ago.',
#  " That's nice.",
#  ' She, too, is a great admirer of yours.',
#  ' Imagine. All this admiration in just one room.',
#  " You're not going, are you?",
#  " No, don't go...",
#  " Well - if I'm not in the way...",
#  " I won't be a minute.",
#  ' Good luck, genius...',
#  " Geniuses don't need good luck.  I do.",
#  " I'll be at the old stand, tomorrow matinee-",
#  ' Not just that way. As a friend...',
#  " I'd like that.",
#  " It's been a real pleasure, Eve.",
#  ' I hope so, Mr. Richards. Good night...',
#  " You said forty-seven minutes. You'll never make it.",
#  ' Why?',
#  ' I just wondered.',
#  ' Just wondered what?',
#  ' Why.',
#  ' Why what?',
#  ' Why you have to go out there.',
#  " I don't have to. I want to.",
#  ' Is it the money?',
#  ' Eighty percent of it will go for taxes.',
#  ' I just asked a simple question.',
#  " But Hollywood. You mustn't stay there.",
#  " It's only one picture deal.",
#  ' So few come back...',
#  ' I read George Jean Nathan every week.',
#  ' Also Addison deWitt.',
#  ' Every day.',
#  " You didn't have to tell me.",
#  " Where's my coat?",
#  " Can't keep his eyes off my legs.",
#  ' Like a nylon lemon peel-',
#  ' Kill the people.  Got your key?',
#  ' See you home...',
#  ' Ah...',
#  ' Of course not.',
#  " She's quite a girl, that what's-her name...",
#  " Eve. I'd forgotten they grew that way...",
#  ' I told her. I sounded off.',
#  ' Take care of yourself out there...',
#  ' Bill...',
#  ' Huh?',
#  " Don't get stuck on some glamour puss-",
#  " I'll try.",
#  " Everybody can't be Gregory Peck.",
#  ' And cut that out right now.',
#  " As of this moment you're six years old...",
#  ' Thanks for your help... good luck.',
#  ' Goodbye, Mr. Sampson.',
#  ' Knit me a muffler.',
#  ' Call me when you get in...',
#  ' What - again?',
#  " Well, teacher's away and actors will be actors...",
#  ' Something maybe grew a size bigger.',
#  " Well, you've done so much... what's new?",
#  ' The curtains. I made them myself.',
#  " They are lovely. Aren't they lovely, Birdie?",
#  ' No trouble at all.',
#  ' Behind in your dues? How much?',
#  " I haven't got a union. I'm slave labor.",
#  ' Well?',
#  ' Oh-oh.',
#  ' Hello..',
#  ' Call, what call?',
#  ' It this Templeton 89970? Miss Margo Channing?',
#  " That's right, but I don't understand-",
#  ' I placed...?',
#  ' Go ahead, please...',
#  " What a thoughtful, ever-lovin' thing to do-",
#  ' Bill? Have I gone crazy, Bill?',
#  " You're my girl, aren't you?",
#  ' That I am...',
#  " Then you're crazy.",
#  ' When - when are you coming back?',
#  ' You in a hurry?',
#  ' Sing it?',
#  " Bill... Bill, it's your birthday.",
#  ' Happy birthday, darling...',
#  ' Many happy returns of the day...',
#  " I get a party, don't I?",
#  ' She did...?',
#  ' Yeah... I will.',
#  ' How is Eve? Okay?',
#  ' Okay.',
#  ' I love you...',
#  " I'll check with Eve...",
#  ' What?',
#  ' I love you too. Good night, darling-',
#  ' See you...',
#  ' Birdie-',
#  ' Hmm?',
#  " You don't like Eve, do you?",
#  ' Do you want an argument or an answer?',
#  ' An answer.',
#  ' No.',
#  ' Why not?',
#  ' Now you want an argument.',
#  ' She works hard.',
#  " Night an' day.",
#  " She's loyal and efficient-",
#  ' Like an agent with one client.',
#  " She thinks only for me...  ... doesn't she?",
#  ' How do you mean that?',
#  " I've got it.",
#  ' Right here.',
#  " That's my job.  See you at tea time...",
#  ' Oh, golly. And I forgot to tell you-',
#  ' Yes, dear. You forgot all about it.',
#  ' Hollywood.',
#  ' Mrs. Richards.',
#  ' Karen.',
#  " ... you want to be Margo's new understudy.",
#  ' The show must go on.',
#  ' Do you think Miss Channing would approve?',
#  ' I think she would cheer.',
#  ' But Mr. Richards and Mr. Sampson-',
#  " They'll do as they're told.",
#  ' Of course.',
#  " You won't forget it?",
#  " I won't forget.",
#  ' But she just got here...',
#  ' What did you expect - live sables?',
#  ' This answer satisfies me a hundred percent.',
#  ' Yes. Yes, it does.',
#  " I'm sorry, I didn't mean to-",
#  ' Margo, really...',
#  ' How about calling it a night?',
#  " It's a good thought.",
#  " It won't play.",
#  ' Happy little housewife...',
#  ' Cut it out.',
#  ' Hear, hear...',
#  " Now let's not get into a big hassle-",
#  ' Need any help?',
#  " If you'd like.",
#  " I wouldn't like.",
#  ' Coming?',
#  ' In a minute...',
#  ' And too many of them are produced.',
#  " Let's go sit by the piano.",
#  " No, Eve, I won't forget...",
#  ' You all put together?',
#  ' Late for what?',
#  " Don't be dense. The party.",
#  " I'd like to hear it.",
#  ' Of course.',
#  ' I thought you were going to be late-',
#  " When I'm guest of honor?",
#  ' I had no idea you were even here.',
#  ' That never stopped you before.',
#  " She's a girl of so many interests.",
#  " It's a pretty rare quality these days.",
#  " She's a girl of so many rare qualities.",
#  ' So she seems.',
#  " I don't think that's funny!",
#  ' Twenty minutes!',
#  ' Thirty minutes, forty minutes! What of it?',
#  ' For instance what?',
#  ' For instance - you!',
#  ' - guilty.',
#  ' What about her teeth? What about her fangs?',
#  ' May I have your coat?',
#  " Don't bother, I can take it up myself...",
#  ' Please...',
#  ' ... Among so many quiet qualities.',
#  " I'm so happy you're happy.",
#  ' How about me what?',
#  ' Supposed you dropped dead. What about your inventory?',
#  " I ain't gonna die. Not with a hit.",
#  ' Thank you.',
#  ' Nothing, really...',
#  ' What is he talking about?',
#  ' Macbeth.',
#  ' I do not. How do you do?',
#  " We never met. That's why.",
#  ' Good evening, Mr. deWitt.',
#  ' I had no idea you knew each other.',
#  " That's how you met me. In passing.",
#  ' We have that in common.',
#  ' Then you two must have a long talk-',
#  ' Why do they always look like unhappy rabbits?',
#  ' Amen.',
#  ' "Liebestraum."',
#  ' I just played it.',
#  ' Play it again.',
#  ' But that was the fourth straight time.',
#  ' No. You\'re just crazy about "Liebestraum."',
#  ' "Liebestraum."',
#  " Wouldn't you feel more natural taking a bow?",
#  ' You know nothing about feelings, natural or unnatural.',
#  ' No heart to burn.',
#  ' Miss Caswell?  What?',
#  " When's the audition?",
#  ' A couple of weeks.',
#  ' Would you?',
#  ' Anything to help you out, Max.',
#  ' This is real cooperation. I appreciate it.',
#  ' All you got to do is name it.',
#  ' Give Eve Harrington job in you office.',
#  " You get quick action, don't you?",
#  ' But what could she do?',
#  ' Well...',
#  ' Promise.',
#  ' I promise.',
#  " That's my Max.",
#  ' Where is she?',
#  ' Up in the room.',
#  " Who's left out there?",
#  ' When you do, let me in on it.',
#  ' I will.',
#  " How's the new one coming?",
#  ' The play? All right, I guess...',
#  ' "Cora." She\'s - still a girl of twenty?',
#  " Twentyish. It isn't important.",
#  ' How do you mean?',
#  " Don't be evasive.",
#  " Margo, you haven't got any age.",
#  " The ladies' - shall we say - lounge?",
#  ' Being violently ill to her tummy.',
#  ' Naturally enough, your understudy.',
#  ' Eve! My understudy...',
#  " Didn't you know?",
#  ' Of course I knew.',
#  ' It just slipped your mind.',
#  ' How... how was Miss Caswell?',
#  " Frankly, I don't remember.",
#  ' Just slipped your mind.',
#  ' Was she that bad?',
#  ' I take it she read well.',
#  ' How nice.',
#  " In time she'll be what you are.",
#  ' Feeling better, my dear?',
#  ' Hello, Miss Channing.',
#  " It's all over.",
#  " What's all over?",
#  ' The audition.',
#  " She's your understudy.",
#  ' Really, Eve? Why?',
#  ' Why not?',
#  ' What fire and music?',
#  " You wouldn't understand.  How was Miss Caswell?",
#  " You'd have been proud of her.",
#  " I'm sure.",
#  ' She was a revelation...',
#  ' To you, too?',
#  ' What do you mean?',
#  " That's beside the point.",
#  ' Addison-!',
#  ' So full of meaning, fire and music!',
#  ' Not mouse, never mouse! If anything - rat!',
#  ' I never said it was!',
#  ' Are you breaking the contract?',
#  ' Answer my question!',
#  " I didn't hear you.",
#  " I said I'm a dying man!",
#  ' Who?',
#  ' The kid. Junior.',
#  ' Gone.',
#  ' I must have frightened her away.',
#  " I wouldn't be surprised. Sometimes you frighten me.",
#  " Don't mix your metaphors.",
#  ' I mix what I like.',
#  ' Okay. Mix.',
#  ' What a body, what a voice.',
#  " The gong rang. The fight's over. Calm down.",
#  ' I will not calm down!',
#  " Don't calm down.",
#  " You're being terribly tolerant, aren't you?",
#  " I'm trying terribly hard.",
#  ' Here we go...',
#  " Now don't get carried away-",
#  " You've been all through that with Lloyd-",
#  ' Paranoiac!',
#  " It's obvious you're not a woman.",
#  " I've been aware of that for some time.",
#  ' Well, I am.',
#  " I'll say.",
#  " Don't be condescending.",
#  " Margo, let's make peace.",
#  ' The terms are too high. Unconditional surrender.',
#  " It's not nonsense.",
#  ' I wish it were.',
#  ' That suddenly makes the whole thing believable.',
#  ' Lloyd, what happened...?',
#  ' Margo, again...',
#  " That's on time for Margo.",
#  " It's just possible she didn't...",
#  " - don't run out of adjectives, dear.",
#  " Margo hasn't done badly by it.",
#  " It's going to be a cozy weekend.",
#  ' What is?',
#  ' What time is it?',
#  ' Peace and quit is for libraries.',
#  ' Lloyd, be careful...',
#  " Karen and I just don't want an accident-",
#  ' I have no intention of having an accident!',
#  ' Incredible.',
#  ' How much time have we?',
#  ' Roughly ten minutes.',
#  ' How far to the station?',
#  ' Three or four miles...',
#  " You'll break your neck on that ice.",
#  " Don't joke about such things.",
#  ' Thank you, Lloyd. Godspeed.',
#  ' Do you want it on?',
#  " It doesn't matter.",
#  ' I detest cheap sentiment.',
#  " Karen.  I haven't been pleasant this weekend.",
#  " We've all seemed a little tense lately...",
#  " You're Margo. Just - Margo.",
#  ' What about Bill?',
#  ' What about Bill?',
#  " He's in love with you.",
#  ' Why should he - and why should you?',
#  ' Not to you. Not to Bill.',
#  " Isn't that what they always say?",
#  ' Well...',
#  ' About what?',
#  ' Are you proud of me, Bill?',
#  " You shouldn't have had any doubts.",
#  ' Is that what you want me to be?',
#  " I'm talking about you. And what you want.",
#  ' So am I.',
#  ' What have I got to do with it?',
#  ' Everything.',
#  " Don't run away, Bill.",
#  ' From what would I be running?',
#  " I'm for it.",
#  " Your make-up's a little heavy.",
#  ' - and for you.',
#  " You're quite a girl.",
#  ' You think?',
#  " I'm in love with Margo. Hadn't you heard?",
#  ' You hear all kinds of things.',
#  ' Find out.',
#  ' May I come in?',
#  ' Certainly, Mr. deWitt...',
#  " I consider myself lucky they didn't throw things.",
#  " You're more than modest.",
#  ' Please do.',
#  " It needn't be.",
#  ' I am somebody.',
#  " I'm not enough for a paragraph.",
#  " That's right.",
#  ' Yes. I do.',
#  ' Yes. The Shubert.',
#  ' Eddie...',
#  ' Eddie what?',
#  ' You take charge.',
#  ' I believe I will.',
#  ' She was magnificent.',
#  " Then you've heard too.",
#  ' I was there. An eyewitness.',
#  ' A happy coincidence.',
#  " We're having lunch with a movie talent scout.",
#  " They certainly don't waste much time.",
#  ' Margo.',
#  ' Margo? Lunching in public?',
#  ' She may be later than you think...',
#  " I just can't believe it.",
#  " I can't believe Eve said those things!",
#  " Lloyd says it's a publicity release...",
#  ' Maybe just a little around the edges.',
#  " Where'd you get all that information?",
#  ' Eve.',
#  ' Eve?',
#  ' That was a pity...',
#  ' I wonder why.',
#  " That's quite a change of subject.",
#  " I'm trying hard to follow you.",
#  " I'm beginning to catch up.",
#  ' If we could cast it properly, that is...',
#  " Now you're quoting Addison. Or Eve.",
#  ' Eve would ask Abbott to give her Costello.',
#  ' With gestures, of course.',
#  ' Now just a minute-',
#  ' Now just a minute!',
#  " I'm glad Bill's back.",
#  " They'd die without each other.",
#  ' Such as?',
#  ' Hear, hear...',
#  ' He does not exaggerate. I was good.',
#  ' You were great.',
#  ' Too bad.',
#  ' To Margo. To my bride-to-be.',
#  ' Glory Hallelujah.',
#  ' Well of all-',
#  ' Margo!',
#  ' When? When are you going to do it?',
#  ' Yes, sir.',
#  ' What are you going to wear?',
#  ' Something simple. A fur coat over a nightgown...',
#  ' After all, maybe she just wants to apologize...',
#  ' Well... all right.',
#  " I was wondering whether you'd come at all..",
#  " I don't expect you to be pleasant.",
#  " I don't intend to be.",
#  " Can't we sit down? Just for a minute...",
#  " There can't be very much-",
#  ' Oh, but there is-',
#  " Why shouldn't you?  Please sit down.",
#  " Let's not get over-dramatic.",
#  " Eve... don't cry.",
#  " I'm not crying.",
#  ' But the raves about your performance-',
#  " - an understudy's performance.",
#  " He's not my friend. You were my friends...",
#  ' He can help you.',
#  " I'll never get over it.",
#  ' I wish I could believe that.',
#  ' I think I know...',
#  ' Something most important you can do.',
#  ' You talk just as Addison said you did.',
#  ' Addison wants me to play it.',
#  ' Over my dead body...',
#  ' Hungry?',
#  ' Just some coffee.',
#  " I'm not surprised. After all that humble pie...",
#  ' Just like that, eh?',
#  ' Just like that.',
#  " I don't think that's funny.",
#  " It wasn't meant to be.",
#  ' - well? What happened?',
#  ' Nothing much. She apologized.',
#  ' With tears?',
#  ' With tears.',
#  ' Check.',
#  ' Very classy stuff, lots of technique-',
#  ' Not much.',
#  ' Groom-  - may I have a wedding present?',
#  ' What would you like? Texas?',
#  " You've got it backwards. Even for Wilkes-Barre.",
#  ' You know, she probably means well, after all...',
#  ' She is a louse.',
#  ' Never try to outguess Margo.',
#  ' Groom.',
#  ' Yes, dear.',
#  " You know what I'm going to be?",
#  ' A cowboy.',
#  ' A married lady.',
#  ' With the paper to prove it.',
#  ' I remember.',
#  " You'll be there, won't you.",
#  ' Often enough to keep the franchise.',
#  ' That depends.',
#  ' I mean really, deeply angry...',
#  " I don't think I could be.",
#  ' Well. I don\'t want to play "Cora."',
#  " What's so funny?",
#  ' Nothing...',
#  ' Nothing?',
#  " Everything... everything's so funny...",
#  " Who is it? What's it all about?",
#  " I'm a human being, I've got some!",
#  ' What a day - what a heavenly day...',
#  ' D-day.',
#  ' Just like it.',
#  ' Are you that sure of tomorrow?',
#  " Aren't you?",
#  ' Frankly - yes.',
#  ' All paved with diamonds and gold?',
#  ' You know me better than that.',
#  ' Paved with what, then?',
#  ' Stars.',
#  ' What time?',
#  ' Almost four.',
#  " You could sleep, too, couldn't you?",
#  ' Why not?',
#  " Why'd call me a killer?",
#  ' Also with the reluctant compliments of Max Fabian.',
#  " We're?",
#  ' Lloyd and I.',
#  ' Addison...',
#  " I didn't mean just the Theater.",
#  ' What else?',
#  " I'm in love with Lloyd!",
#  ' You have no right to say such things!',
#  ' ... and Karen.',
#  " She doesn't know.",
#  ' She knows enough not to be here.',
#  ' You sat and talked until it was light...',
#  ' What do you take me for?',
#  ' I never intended you to be.',
#  ' Yes, you did. You still do.',
#  ' Champion to champion.',
#  ' What do you mean by that?',
#  ' What have you got to do with it?',
#  " I can't believe my ears...",
#  ' A dull cliche.',
#  ' What of it?',
#  ' What of it?',
#  ' She never proved anything, not a thing!',
#  ' She was a liar, she was a liar!',
#  " That's not true!",
#  ' No-no-no...',
#  ' Then say so.',
#  ' Yes, Addison.',
#  ' Yes, Addison.',
#  ' Congratulations, Eve.',
#  ' Thank you, Karen.',
#  ' As soon as the peasants stop pawing her.',
#  " I don't suppose there's a drink left...",
#  " You can have one at Max's.",
#  " I don't think I'm going.",
#  ' Why not?',
#  " Because I don't want to.",
#  " No, it's not.  It's for this.",
#  " It's the same thing, isn't it?",
#  " You're being childish.",
#  " I'm tired. I want to go home.",
#  ' Who are you?',
#  ' Miss Harrington...',
#  ' What are you doing here?',
#  ' I - I guess I fell asleep.',
#  ' How did you get in here?',
#  ' You were just looking around...',
#  " That's all.",
#  ' What for?',
#  " You probably won't believe me.",
#  ' Probably not.',
#  ' It was for my report.',
#  ' What report? To whom?',
#  " I've heard of them.",
#  " Erasmus Hall. That's in Brooklyn, isn't it?",
#  ' I might.',
#  " The maid'll fix it in the morning.",
#  " I'll just pick up the broken glass.",
#  " Don't bother.",
#  ' Subway.',
#  ' How long does it take?',
#  " I don't care if I never get home.",
#  " That's the door.",
#  " You rest. I'll get it...",
#  ' Hello, there. Who are you?',
#  ' How do you know my name?',
#  " It's a very famous name, Mr. deWitt.",
#  ...]

# %%
# to set each string to lowerstring_list = [each_string.lower() for each_string in string_list]

# %%
#function to expand the contractions and remove punctuation

def exp_remPunt(l):
    '''
    params: l is a list (of quest or ans)
    '''
    clean_l=[]
    table = str.maketrans(dict.fromkeys(string.punctuation))
    remove_digits = str.maketrans('', '', string.digits)

    for sent in l:
        for word in sent.split():
            if word in contractions_dict:
                sent = sent.replace(word, contractions_dict[word])  #expand
                
        sent = sent.translate(remove_digits)
        clean_l.append(sent.translate(table).lower()) #remove punt and set to lower
    
    return clean_l

# %%
question=exp_remPunt(question)
answer=exp_remPunt(answer)

# %%
answer
# Out:
# [' thank you officer ripley  that will be',
#  ' you are a head case  have a donut',
#  ' why will not you check out lv',
#  ' what are you talking about what people',
#  ' how many colonists',
#  ' sixty maybe seventy families',
#  ' sweet jesus',
#  ' yeah  what',
#  ' so what do i tell this guy',
#  ' no  theres no way',
#  ' hear me out',
#  ' what about you  whats your interest in this',
#  ' yeah yeah  i saw the commercial',
#  ' thats right',
#  ' running loaders forklifts that sort of thing',
#  ' if i go',
#  ' yello  oh ripley  hi',
#  ' thats the plan  my word on it',
#  ' this floors freezing',
#  ' would you sir',
#  ' hey vasquezyou ever been mistaken for a man',
#  ' no  have you',
#  ' whoooah  no shit  im impressed',
#  ' lets golets go  cycle through',
#  ' hey top  whats the op',
#  ' sir',
#  ' yes hicks',
#  ' hudson sir  hes hicks',
#  ' whats the question',
#  ' sounds like you hicks',
#  ' fuck you',
#  ' anytime  anywhere',
#  ' i hope you are right  i really do',
#  ' are there any questions  hudson',
#  ' still nothing from the colony',
#  ' dead on all channels',
#  ' save it',
#  ' sure hicks',
#  ' how may drops is this for you lieutenant',
#  ' thirtyeightsimulated',
#  ' thats better  pan it around a bit',
#  ' that the atmosphere processor',
#  ' hold at forty  slow circle of the complex',
#  ' the structure seems intact  they have power',
#  ' okay let us do it',
#  ' ten seconds people  look sharp',
#  ' vasquez take point  lets move',
#  ' were coming in',
#  ' hes coming in  i feel safer already',
#  ' sir the cpu is online',
#  ' okay stand by in operations  lets go',
#  ' its insured',
#  ' poor bastard',
#  ' one of us',
#  ' aponewhere are your people anybody in dblock',
#  ' where are your parents  you have to try',
#  ' gorman  give it a rest would you',
#  ' whats he scanning for',
#  ' what did you say',
#  ' casey  shes my only friend',
#  ' what about me',
#  ' i do not want you for a friend',
#  ' why not',
#  ' theyre dead',
#  ' you promise',
#  ' cross my heart',
#  ' and hope to die',
#  ' alive',
#  ' the maze  you mean the air ducts',
#  ' youre really something ace',
#  ' you tell me  i only work here',
#  ' what is it',
#  ' i do not know',
#  ' proceed inside',
#  ' theyre right under the primary heat exchangers',
#  ' shes right',
#  ' so',
#  ' sothen the fusion containment shuts down',
#  ' so  so',
#  ' were talking thermonuclear explosion',
#  ' flameunits only  i want rifles slung',
#  ' lets go  pull em out',
#  ' movement',
#  ' position',
#  ' cant lock up',
#  ' talk to me hudson',
#  ' uh seems to be in front and behind',
#  ' lets get the fuck out of here',
#  ' not that tunnel the other one',
#  ' get them out of there  do it now',
#  ' shut up  just shut up',
#  ' say again  all after incinerators',
#  ' i told them to fall back',
#  ' theyre but off  do something',
#  ' looks like it stung him',
#  ' heyhey  look crowe and dietrich are not dead man',
#  ' oh god  jesus  this am not happening',
#  ' why not',
#  ' bullshit',
#  ' yeah bullshit  watch us',
#  ' you son of a bitch',
#  ' dont make me pull rank ripley',
#  ' corporal hicks',
#  ' are you finished  you okay',
#  ' i guess we are not leaving right',
#  ' im sorry newt',
#  ' about seventeen days',
#  ' ayefirmative',
#  ' thanks',
#  ' uh  what is next',
#  ' i do not want toi have scary dreams',
#  ' oh  sorry newt',
#  ' yes there are are not there',
#  ' why do they tell little kids that',
#  ' did one of those things grow inside her',
#  ' i do not know newt  thats the truth',
#  ' no it is different honey',
#  ' did you ever have a baby',
#  ' yes  a little girl',
#  ' where is she',
#  ' gone',
#  ' you mean dead',
#  ' dont go  please',
#  ' yes  that follows',
#  ' could it be intelligent',
#  ' now wait a second ',
#  ' sorry to disappoint you',
#  ' thats it  see it  emergency venting',
#  ' how long until it blows',
#  ' we got problems',
#  ' and it is too late to shut it down',
#  ' hudson give us a break',
#  ' think of what  were fucked',
#  ' ill go',
#  ' what',
#  ' see you soon',
#  ' theyre in the approach corridor',
#  ' on my way',
#  ' now many',
#  ' maybe we got em demoralized',
#  ' theyll get us',
#  ' maybe  maybe not',
#  ' whats this',
#  ' yeah  ive noticed',
#  ' how do you feel',
#  ' forget it',
#  ' newt  newt wake up',
#  ' wah  where are',
#  ' sssh  dont move  were in trouble',
#  ' mommyi mean ripleyim scared',
#  ' i know honey  me too',
#  ' the corner  ready',
#  ' do it',
#  ' wait a minute  wed know about it',
#  ' lets waste him  no offense',
#  ' they cut the power',
#  ' its inside the complex',
#  ' youre just reading me',
#  ' its game time',
#  ' just get back here',
#  ' range twenty meters',
#  ' seal the door',
#  ' seventeen meters',
#  ' lets get these things lit',
#  ' we did not miss anything',
#  ' fifteen meters',
#  ' theyre right on us  vasquez how you doing',
#  ' nine meters  eight',
#  ' cant be  thats inside the room',
#  ' its readin right  look',
#  ' well you are not reading it right',
#  ' six meters  five  what the fu ',
#  ' burke  open the door',
#  ' look',
#  ' lets go  lets go',
#  ' fuckin a',
#  ' locked',
#  ' stand back',
#  ' come on  crawl faster',
#  ' sure  go left',
#  ' this way  come on we are almost there',
#  ' newt wait',
#  ' no  no  shes alive  we have to ',
#  ' how much time',
#  ' plenty  twentysix minutes',
#  ' were not leaving',
#  ' ripley',
#  ' hicks do not let him leave',
#  ' we am not going anywhere',
#  ' ellen',
#  ' dont be long ellen',
#  ' i knew you would come',
#  ' you did okay bishop',
#  ' well thanks i ',
#  ' mommymommy',
#  ' right here baby  right here',
#  ' are we going to sleep now',
#  ' thats right',
#  ' can we dream',
#  ' yes honey  i think we both can',
#  ' better tell the boss',
#  ' whered you leave them',
#  ' marsco went bellyup on the dow jones',
#  ' shit  when',
#  ' fucking great  i invested some money in them',
#  ' you win some you loose some',
#  ' sounds like a couple of escape shuttles',
#  ' thats what we thought',
#  ' done it already  nothing matches',
#  ' jesus',
#  ' tactical nukes maybe',
#  ' wherere they headed',
#  ' fort powell  what do we tell em',
#  ' nice howitzer you have got there',
#  ' thanks',
#  ' miss noguchi  youre wanted in admin',
#  ' thanks',
#  ' when',
#  ' already working on it',
#  ' okay give me the numbers',
#  ' theyve changed their heading again',
#  ' compensate',
#  ' punch me in a solution for their deltavee',
#  ' what do you need',
#  ' a threesecond burn to port on my mark',
#  ' its on the board',
#  ' picking up velocity',
#  ' match it',
#  ' hey boss  wondered where you would gotten to',
#  ' not too much of the socializing type then',
#  ' is that a fact',
#  ' four',
#  ' and before that',
#  ' six month stint on datus',
#  ' only six',
#  ' what is this  twenty questions',
#  ' what is that',
#  ' real man drink',
#  ' seltzer',
#  ' want some',
#  ' any luck raising acklands party',
#  ' we  you wanna fly out there with me',
#  ' sure  do me good to stretch my legs',
#  ' do you think acklandll sit tight',
#  ' nada no radiation no movement nothing',
#  ' its a rhino',
#  ' is it dead',
#  ' yeah it is fine',
#  ' i told you we  what is that',
#  ' bloody big if it is  tops open',
#  ' lets get back and call this in',
#  ' wait a minute',
#  ' oh man',
#  ' minh',
#  ' yep',
#  ' yeah  somebody won',
#  ' check out the tent',
#  ' ive found ackland',
#  ' hold on',
#  ' whats the problem',
#  ' appreciate that',
#  ' agreed',
#  ' what do you mean',
#  ' think i spoke too soon',
#  ' headache  dehydration',
#  ' can i um have some water  please',
#  ' sure',
#  ' do you believe him',
#  ' and',
#  ' and nothing  they checked out just fine',
#  ' what is it',
#  ' do you want a tablet',
#  ' better',
#  ' yeah',
#  ' what happened',
#  ' whats going on',
#  ' force the door',
#  ' what is that',
#  ' where does that lead to',
#  ' youve checked that end',
#  ' okay',
#  ' so what do you think',
#  ' cmon man  one more sweep',
#  ' listen to what',
#  ' de vries',
#  ' yeah',
#  ' something spooking the rhinos',
#  ' i dunno',
#  ' hey guttierez',
#  ' what',
#  ' take a look at this',
#  ' one of em must have escaped',
#  ' theres no way a rhinod survive that drop',
#  ' thats a fact',
#  ' whoa wait a minute',
#  ' what',
#  ' just got a reading',
#  ' hows it going',
#  ' yeah good evening to you too',
#  ' you should hit the sack too',
#  ' what times sundown',
#  ' bout five minutes',
#  ' give me a yell is something happens',
#  ' you got it cowboy',
#  ' forget it man',
#  ' cmon de vries  think of the bonus',
#  ' what the hell are you doing',
#  ' alright okay  look',
#  ' what',
#  ' ill come with you',
#  ' but im going first',
#  ' anything you say mammacitta',
#  ' careful of that edging there',
#  ' yeah i got it',
#  ' still got him',
#  ' hold it hold it',
#  ' whats wrong',
#  ' im picking up another signal',
#  ' what  where',
#  ' just behind us over to the right',
#  ' cant see a thing  are you sure',
#  ' yeah i',
#  ' wait  lost it',
#  ' how',
#  ' i dunno  might be a glitch',
#  ' oh man  thats no glitch',
#  ' its alright it is cool',
#  ' is it still moving',
#  ' what',
#  ' im out of ammo  get inside get inside',
#  ' seal everything now',
#  ' whats happening',
#  ' cassie thank christ  were under attack',
#  ' were what',
#  ' how many of them are there',
#  ' too many',
#  ' thats the wrong way',
#  ' detour  other ways blocked',
#  ' hurry it up',
#  ' dont wait for me',
#  ' its too late',
#  ' nooooo',
#  ' how many how many people are missing',
#  ' whats our weapons situation',
#  ' autoshop',
#  ' autoshops sealed but those boys are cutoff',
#  ' has anybody talked to them',
#  ' not yet',
#  ' do it',
#  ' they knocked out the external feeds',
#  ' looks like it',
#  ' give or take',
#  ' were not gonna make it are we',
#  ' well try the headset',
#  ' oh man',
#  ' which mean physically going outside',
#  ' is this the suit',
#  ' uhhuh',
#  ' how much airtime have i got',
#  ' deal',
#  ' sounds great',
#  ' what  why',
#  ' how tight are these shafts',
#  ' theres still time to backout',
#  ' thanks',
#  ' sorry  two green enabling buttons',
#  ' are you alright',
#  ' what  whats wrong  what is it',
#  ' where is she',
#  ' comin up the central reservoir',
#  ' i found it',
#  ' and',
#  ' drains right into the central reservoir',
#  ' get her online  now',
#  ' i cannot reach her  too much signal breakup',
#  ' keep trying',
#  ' okay we are in business',
#  ' right  autoshop you all set',
#  ' okay im out of here',
#  ' blow those suckers driscoll',
#  ' but',
#  ' couple more seconds',
#  ' what can i do',
#  ' i i cant',
#  ' you have to',
#  ' no',
#  ' why should you think i would not be',
#  ' not at all',
#  ' bill sampson hes  he is a director',
#  ' hes the best',
#  ' oh no i see the play',
#  ' standing room does not cost much i manage',
#  ' im going to take you to margo',
#  ' oh no',
#  ' shes got to meet you',
#  ' there is not another like you there could not be',
#  ' eve eve harrington',
#  ' hi  hello darling',
#  ' how was the concert',
#  ' loud',
#  ' lemme fix you a drink',
#  ' no thanks birdie',
#  ' it was fort sumter they fired on',
#  ' i never played fort sumter',
#  ' that was way back',
#  ' you need new girdles',
#  ' buy some',
#  ' the same size',
#  ' of course',
#  ' margo does not play a lunatic birdie',
#  ' its the tight girdle that does it',
#  '  ats my loyal little woman',
#  ' easy now',
#  ' aint it the truth',
#  ' theyre your fans your audience',
#  ' youve what',
#  ' shes just outside the door',
#  ' the heaveho',
#  ' i thought you would forgotten about me',
#  ' not at all  margo this is eve harrington',
#  ' how do you do my dear',
#  ' oh brother',
#  ' hello miss channing',
#  ' my husband',
#  ' hello miss harrington',
#  ' how do you do mr richards',
#  ' oh brother',
#  ' miss coonan',
#  ' dear birdie wont you sit down miss worthington',
#  ' harrington',
#  ' im so sorry harrington wont you sit down',
#  ' no thank you  yes ive seen every performance',
#  ' id like anything miss channing played',
#  ' would you really how sweet',
#  ' of course it is',
#  ' howd hear about it',
#  ' there are other plays',
#  ' if i only knew how',
#  ' try',
#  ' well',
#  ' remembrance',
#  ' did you see it here in new york',
#  ' eve why do not you start at the beginning',
#  ' it could not possibly interest you',
#  ' not at all',
#  ' thank you so much',
#  ' show me a human and i might have',
#  ' bill',
#  ' bill',
#  ' only in some ways youre prettier',
#  ' im a junk yard',
#  ' bill',
#  ' huh',
#  ' this is eve harrington',
#  ' heaven help me i love a psychotic',
#  ' hello  what is your name',
#  ' eve eve harrington',
#  ' youve already met',
#  ' where',
#  ' right here a minute ago',
#  ' thats nice',
#  ' she too is a great admirer of yours',
#  ' imagine all this admiration in just one room',
#  ' youre not going are you',
#  ' no do not go',
#  ' well  if im not in the way',
#  ' i will not be a minute',
#  ' good luck genius',
#  ' geniuses do not need good luck  i do',
#  ' ill be at the old stand tomorrow matinee',
#  ' not just that way as a friend',
#  ' id like that',
#  ' its been a real pleasure eve',
#  ' i hope so mr richards good night',
#  ' you said fortyseven minutes youll never make it',
#  ' why',
#  ' i just wondered',
#  ' just wondered what',
#  ' why',
#  ' why what',
#  ' why you have to go out there',
#  ' i do not have to i want to',
#  ' is it the money',
#  ' eighty percent of it will go for taxes',
#  ' i just asked a simple question',
#  ' but hollywood you must not stay there',
#  ' its only one picture deal',
#  ' so few come back',
#  ' i read george jean nathan every week',
#  ' also addison dewitt',
#  ' every day',
#  ' you did not have to tell me',
#  ' wheres my coat',
#  ' cant keep his eyes off my legs',
#  ' like a nylon lemon peel',
#  ' kill the people  got your key',
#  ' see you home',
#  ' ah',
#  ' of course not',
#  ' shes quite a girl that whatsher name',
#  ' eve id forgotten they grew that way',
#  ' i told her i sounded off',
#  ' take care of yourself out there',
#  ' bill',
#  ' huh',
#  ' dont get stuck on some glamour puss',
#  ' ill try',
#  ' everybody cannot be gregory peck',
#  ' and cut that out right now',
#  ' as of this moment you are six years old',
#  ' thanks for your help good luck',
#  ' goodbye mr sampson',
#  ' knit me a muffler',
#  ' call me when you get in',
#  ' what  again',
#  ' well teachers away and actors will be actors',
#  ' something maybe grew a size bigger',
#  ' well you have done so much  what is new',
#  ' the curtains i made them myself',
#  ' they are lovely arent they lovely birdie',
#  ' no trouble at all',
#  ' behind in your dues how much',
#  ' i have not got a union im slave labor',
#  ' well',
#  ' ohoh',
#  ' hello',
#  ' call what call',
#  ' it this templeton  miss margo channing',
#  ' thats right but i do not understand',
#  ' i placed',
#  ' go ahead please',
#  ' what a thoughtful everlovin thing to do',
#  ' bill have i gone crazy bill',
#  ' youre my girl are not you',
#  ' that i am',
#  ' then you are crazy',
#  ' when  when are you coming back',
#  ' you in a hurry',
#  ' sing it',
#  ' bill bill it is your birthday',
#  ' happy birthday darling',
#  ' many happy returns of the day',
#  ' i get a party do not i',
#  ' she did',
#  ' yeah i will',
#  ' how is eve okay',
#  ' okay',
#  ' i love you',
#  ' ill check with eve',
#  ' what',
#  ' i love you too good night darling',
#  ' see you',
#  ' birdie',
#  ' hmm',
#  ' you do not like eve do you',
#  ' do you want an argument or an answer',
#  ' an answer',
#  ' no',
#  ' why not',
#  ' now you want an argument',
#  ' she works hard',
#  ' night an day',
#  ' shes loyal and efficient',
#  ' like an agent with one client',
#  ' she thinks only for me   does not she',
#  ' how do you mean that',
#  ' ive got it',
#  ' right here',
#  ' thats my job  see you at tea time',
#  ' oh golly and i forgot to tell you',
#  ' yes dear you forgot all about it',
#  ' hollywood',
#  ' mrs richards',
#  ' karen',
#  '  you want to be margos new understudy',
#  ' the show must go on',
#  ' do you think miss channing would approve',
#  ' i think she would cheer',
#  ' but mr richards and mr sampson',
#  ' theyll do as they are told',
#  ' of course',
#  ' you will not forget it',
#  ' i will not forget',
#  ' but she just got here',
#  ' what did you expect  live sables',
#  ' this answer satisfies me a hundred percent',
#  ' yes yes it does',
#  ' im sorry i did not mean to',
#  ' margo really',
#  ' how about calling it a night',
#  ' its a good thought',
#  ' it will not play',
#  ' happy little housewife',
#  ' cut it out',
#  ' hear hear',
#  ' now let us not get into a big hassle',
#  ' need any help',
#  ' if you would like',
#  ' i would not like',
#  ' coming',
#  ' in a minute',
#  ' and too many of them are produced',
#  ' lets go sit by the piano',
#  ' no eve i will not forget',
#  ' you all put together',
#  ' late for what',
#  ' dont be dense the party',
#  ' id like to hear it',
#  ' of course',
#  ' i thought you were going to be late',
#  ' when im guest of honor',
#  ' i had no idea you were even here',
#  ' that never stopped you before',
#  ' shes a girl of so many interests',
#  ' its a pretty rare quality these days',
#  ' shes a girl of so many rare qualities',
#  ' so she seems',
#  ' i do not think that is funny',
#  ' twenty minutes',
#  ' thirty minutes forty minutes what of it',
#  ' for instance what',
#  ' for instance  you',
#  '  guilty',
#  ' what about her teeth what about her fangs',
#  ' may i have your coat',
#  ' dont bother i can take it up myself',
#  ' please',
#  '  among so many quiet qualities',
#  ' im so happy you are happy',
#  ' how about me what',
#  ' supposed you dropped dead what about your inventory',
#  ' i am not gonna die not with a hit',
#  ' thank you',
#  ' nothing really',
#  ' what is he talking about',
#  ' macbeth',
#  ' i do not how do you do',
#  ' we never met thats why',
#  ' good evening mr dewitt',
#  ' i had no idea you knew each other',
#  ' thats how you met me in passing',
#  ' we have that in common',
#  ' then you two must have a long talk',
#  ' why do they always look like unhappy rabbits',
#  ' amen',
#  ' liebestraum',
#  ' i just played it',
#  ' play it again',
#  ' but that was the fourth straight time',
#  ' no youre just crazy about liebestraum',
#  ' liebestraum',
#  ' wouldnt you feel more natural taking a bow',
#  ' you know nothing about feelings natural or unnatural',
#  ' no heart to burn',
#  ' miss caswell  what',
#  ' whens the audition',
#  ' a couple of weeks',
#  ' would you',
#  ' anything to help you out max',
#  ' this is real cooperation i appreciate it',
#  ' all you got to do is name it',
#  ' give eve harrington job in you office',
#  ' you get quick action do not you',
#  ' but what could she do',
#  ' well',
#  ' promise',
#  ' i promise',
#  ' thats my max',
#  ' where is she',
#  ' up in the room',
#  ' whos left out there',
#  ' when you do let me in on it',
#  ' i will',
#  ' hows the new one coming',
#  ' the play all right i guess',
#  ' cora shes  still a girl of twenty',
#  ' twentyish it is not important',
#  ' how do you mean',
#  ' dont be evasive',
#  ' margo you have not got any age',
#  ' the ladies  shall we say  lounge',
#  ' being violently ill to her tummy',
#  ' naturally enough your understudy',
#  ' eve my understudy',
#  ' didnt you know',
#  ' of course i knew',
#  ' it just slipped your mind',
#  ' how how was miss caswell',
#  ' frankly i do not remember',
#  ' just slipped your mind',
#  ' was she that bad',
#  ' i take it she read well',
#  ' how nice',
#  ' in time she will be what you are',
#  ' feeling better my dear',
#  ' hello miss channing',
#  ' its all over',
#  ' whats all over',
#  ' the audition',
#  ' shes your understudy',
#  ' really eve why',
#  ' why not',
#  ' what fire and music',
#  ' you would not understand  how was miss caswell',
#  ' youd have been proud of her',
#  ' im sure',
#  ' she was a revelation',
#  ' to you too',
#  ' what do you mean',
#  ' thats beside the point',
#  ' addison',
#  ' so full of meaning fire and music',
#  ' not mouse never mouse if anything  rat',
#  ' i never said it was',
#  ' are you breaking the contract',
#  ' answer my question',
#  ' i did not hear you',
#  ' i said im a dying man',
#  ' who',
#  ' the kid junior',
#  ' gone',
#  ' i must have frightened her away',
#  ' i would not be surprised sometimes you frighten me',
#  ' dont mix your metaphors',
#  ' i mix what i like',
#  ' okay mix',
#  ' what a body what a voice',
#  ' the gong rang the fights over calm down',
#  ' i will not calm down',
#  ' dont calm down',
#  ' youre being terribly tolerant are not you',
#  ' im trying terribly hard',
#  ' here we go',
#  ' now do not get carried away',
#  ' youve been all through that with lloyd',
#  ' paranoiac',
#  ' its obvious you are not a woman',
#  ' ive been aware of that for some time',
#  ' well i am',
#  ' ill say',
#  ' dont be condescending',
#  ' margo let us make peace',
#  ' the terms are too high unconditional surrender',
#  ' its not nonsense',
#  ' i wish it were',
#  ' that suddenly makes the whole thing believable',
#  ' lloyd what happened',
#  ' margo again',
#  ' thats on time for margo',
#  ' its just possible she didnt',
#  '  do not run out of adjectives dear',
#  ' margo has not done badly by it',
#  ' its going to be a cozy weekend',
#  ' what is',
#  ' what time is it',
#  ' peace and quit is for libraries',
#  ' lloyd be careful',
#  ' karen and i just do not want an accident',
#  ' i have no intention of having an accident',
#  ' incredible',
#  ' how much time have we',
#  ' roughly ten minutes',
#  ' how far to the station',
#  ' three or four miles',
#  ' youll break your neck on that ice',
#  ' dont joke about such things',
#  ' thank you lloyd godspeed',
#  ' do you want it on',
#  ' it does not matter',
#  ' i detest cheap sentiment',
#  ' karen  i have not been pleasant this weekend',
#  ' weve all seemed a little tense lately',
#  ' youre margo just  margo',
#  ' what about bill',
#  ' what about bill',
#  ' hes in love with you',
#  ' why should he  and why should you',
#  ' not to you not to bill',
#  ' isnt that what they always say',
#  ' well',
#  ' about what',
#  ' are you proud of me bill',
#  ' you should not have had any doubts',
#  ' is that what you want me to be',
#  ' im talking about you and what you want',
#  ' so am i',
#  ' what have i got to do with it',
#  ' everything',
#  ' dont run away bill',
#  ' from what would i be running',
#  ' im for it',
#  ' your makeups a little heavy',
#  '  and for you',
#  ' youre quite a girl',
#  ' you think',
#  ' im in love with margo hadnt you heard',
#  ' you hear all kinds of things',
#  ' find out',
#  ' may i come in',
#  ' certainly mr dewitt',
#  ' i consider myself lucky they did not throw things',
#  ' youre more than modest',
#  ' please do',
#  ' it need not be',
#  ' i am somebody',
#  ' im not enough for a paragraph',
#  ' thats right',
#  ' yes i do',
#  ' yes the shubert',
#  ' eddie',
#  ' eddie what',
#  ' you take charge',
#  ' i believe i will',
#  ' she was magnificent',
#  ' then you have heard too',
#  ' i was there an eyewitness',
#  ' a happy coincidence',
#  ' were having lunch with a movie talent scout',
#  ' they certainly do not waste much time',
#  ' margo',
#  ' margo lunching in public',
#  ' she may be later than you think',
#  ' i just cannot believe it',
#  ' i cannot believe eve said those things',
#  ' lloyd says it is a publicity release',
#  ' maybe just a little around the edges',
#  ' whered you get all that information',
#  ' eve',
#  ' eve',
#  ' that was a pity',
#  ' i wonder why',
#  ' thats quite a change of subject',
#  ' im trying hard to follow you',
#  ' im beginning to catch up',
#  ' if we could cast it properly that is',
#  ' now you are quoting addison or eve',
#  ' eve would ask abbott to give her costello',
#  ' with gestures of course',
#  ' now just a minute',
#  ' now just a minute',
#  ' im glad bills back',
#  ' theyd die without each other',
#  ' such as',
#  ' hear hear',
#  ' he does not exaggerate i was good',
#  ' you were great',
#  ' too bad',
#  ' to margo to my bridetobe',
#  ' glory hallelujah',
#  ' well of all',
#  ' margo',
#  ' when when are you going to do it',
#  ' yes sir',
#  ' what are you going to wear',
#  ' something simple a fur coat over a nightgown',
#  ' after all maybe she just wants to apologize',
#  ' well all right',
#  ' i was wondering whether you would come at all',
#  ' i do not expect you to be pleasant',
#  ' i do not intend to be',
#  ' cant we sit down just for a minute',
#  ' there cannot be very much',
#  ' oh but there is',
#  ' why should not you  please sit down',
#  ' lets not get overdramatic',
#  ' eve do not cry',
#  ' im not crying',
#  ' but the raves about your performance',
#  '  an understudys performance',
#  ' hes not my friend you were my friends',
#  ' he can help you',
#  ' ill never get over it',
#  ' i wish i could believe that',
#  ' i think i know',
#  ' something most important you can do',
#  ' you talk just as addison said you did',
#  ' addison wants me to play it',
#  ' over my dead body',
#  ' hungry',
#  ' just some coffee',
#  ' im not surprised after all that humble pie',
#  ' just like that eh',
#  ' just like that',
#  ' i do not think that is funny',
#  ' it was not meant to be',
#  '  well what happened',
#  ' nothing much she apologized',
#  ' with tears',
#  ' with tears',
#  ' check',
#  ' very classy stuff lots of technique',
#  ' not much',
#  ' groom   may i have a wedding present',
#  ' what would you like texas',
#  ' youve got it backwards even for wilkesbarre',
#  ' you know she probably means well after all',
#  ' she is a louse',
#  ' never try to outguess margo',
#  ' groom',
#  ' yes dear',
#  ' you know what im going to be',
#  ' a cowboy',
#  ' a married lady',
#  ' with the paper to prove it',
#  ' i remember',
#  ' youll be there will not you',
#  ' often enough to keep the franchise',
#  ' that depends',
#  ' i mean really deeply angry',
#  ' i do not think i could be',
#  ' well i do not want to play cora',
#  ' whats so funny',
#  ' nothing',
#  ' nothing',
#  ' everything everythings so funny',
#  ' who is it whats it all about',
#  ' im a human being ive got some',
#  ' what a day  what a heavenly day',
#  ' dday',
#  ' just like it',
#  ' are you that sure of tomorrow',
#  ' arent you',
#  ' frankly  yes',
#  ' all paved with diamonds and gold',
#  ' you know me better than that',
#  ' paved with what then',
#  ' stars',
#  ' what time',
#  ' almost four',
#  ' you could sleep too could not you',
#  ' why not',
#  ' whyd call me a killer',
#  ' also with the reluctant compliments of max fabian',
#  ' were',
#  ' lloyd and i',
#  ' addison',
#  ' i did not mean just the theater',
#  ' what else',
#  ' im in love with lloyd',
#  ' you have no right to say such things',
#  '  and karen',
#  ' she does not know',
#  ' she knows enough not to be here',
#  ' you sat and talked until it was light',
#  ' what do you take me for',
#  ' i never intended you to be',
#  ' yes you did you still do',
#  ' champion to champion',
#  ' what do you mean by that',
#  ' what have you got to do with it',
#  ' i cannot believe my ears',
#  ' a dull cliche',
#  ' what of it',
#  ' what of it',
#  ' she never proved anything not a thing',
#  ' she was a liar she was a liar',
#  ' thats not true',
#  ' nonono',
#  ' then say so',
#  ' yes addison',
#  ' yes addison',
#  ' congratulations eve',
#  ' thank you karen',
#  ' as soon as the peasants stop pawing her',
#  ' i do not suppose there is a drink left',
#  ' you can have one at maxs',
#  ' i do not think im going',
#  ' why not',
#  ' because i do not want to',
#  ' no it is not  its for this',
#  ' its the same thing is not it',
#  ' youre being childish',
#  ' im tired i want to go home',
#  ' who are you',
#  ' miss harrington',
#  ' what are you doing here',
#  ' i  i guess i fell asleep',
#  ' how did you get in here',
#  ' you were just looking around',
#  ' thats all',
#  ' what for',
#  ' you probably will not believe me',
#  ' probably not',
#  ' it was for my report',
#  ' what report to whom',
#  ' ive heard of them',
#  ' erasmus hall thats in brooklyn is not it',
#  ' i might',
#  ' the maidll fix it in the morning',
#  ' ill just pick up the broken glass',
#  ' dont bother',
#  ' subway',
#  ' how long does it take',
#  ' i do not care if i never get home',
#  ' thats the door',
#  ' you rest ill get it',
#  ' hello there who are you',
#  ' how do you know my name',
#  ' its a very famous name mr dewitt',
#  ' and what is your name',
#  ...]

# %% [markdown]
# ## Creating embeddings
#
# - create list with all the words
# - clean the list: each word must have just one occurrence (set)
# - create dicts for word to index and index to word

# %%
#create list with all the words
words_list=[]

for sent in question:
    for word in sent.split():
        words_list.append(word)
        
for sent in answer:
    for word in sent.split():
        words_list.append(word)
        
words_list = set(words_list)
vocab_len=len(words_list) #length of the vocabulary without offset

vocab_len
# Out:
# 4630

# %%
#define funct to create dicts
def index_to_word(words_list):
    
    d= { (index +3) : word for index,word in enumerate(words_list)}
    
    d[0]='<pad>'
    d[1]='<sos>'
    d[2]='<eos>'
    return d

def word_to_index(words_list):
    d= { word : (index +3) for index,word in enumerate(words_list)}
    
    d['<pad>']=0
    d['<sos>']=1
    d['<eos>']=2
    return d

# %%
dict_i2w=index_to_word(words_list) #index to word
dict_w2i=word_to_index(words_list) #word to index

# %%
#sent translation to embedding
encoder_input_data=[]
decoder_input_data=[]
decoder_output_data=[]
for sent in question:
    emb_str=[]
    for word in sent.split():
        emb_str.append(dict_w2i[word])
    encoder_input_data.append(emb_str) #quest
    
for sent in answer:
    emb_str=[]
    for word in sent.split():
        emb_str.append(dict_w2i[word])
    decoder_input_data.append([1]+emb_str+[2]) #ans with sos ans eos
    decoder_output_data.append(emb_str+[2]) #ans with just eos

# %%
decoder_output_data
# Out:
# [[1262, 1209, 1412, 4090, 3825, 353, 3269, 2],
#  [1209, 4160, 3595, 4253, 809, 387, 3595, 2988, 2],
#  [4486, 353, 1204, 1209, 439, 752, 960, 2],
#  [1139, 4160, 1209, 49, 2893, 1139, 1578, 2],
#  [966, 1694, 1374, 2],
#  [4025, 3424, 1095, 1771, 2],
#  [939, 3166, 2],
#  [2782, 1139, 2],
#  [2731, 1139, 3830, 1484, 2185, 1399, 2670, 2],
#  [2565, 4438, 2565, 985, 2],
#  [4551, 3192, 752, 2],
#  [1139, 2893, 1209, 2997, 3378, 2042, 3766, 1399, 2],
#  [2782, 2782, 1484, 4206, 2484, 671, 2],
#  [1263, 3989, 2],
#  [1134, 3588, 3892, 3825, 4333, 784, 1375, 2],
#  [4619, 1484, 293, 2],
#  [277, 4039, 4090, 3973, 2],
#  [1263, 2484, 123, 1640, 2926, 4273, 502, 2],
#  [1399, 4580, 1463, 2],
#  [1184, 1209, 4596, 2],
#  [1152, 3933, 2575, 2645, 2891, 4067, 3595, 2203, 2],
#  [2565, 387, 1209, 2],
#  [2627, 2565, 2293, 967, 3783, 2],
#  [1770, 4173, 293, 1708, 1637, 2],
#  [1152, 3250, 2997, 2484, 2381, 2],
#  [4596, 2],
#  [4349, 1933, 2],
#  [3949, 4596, 2160, 1933, 2],
#  [2997, 2484, 1165, 2],
#  [3726, 2309, 1209, 1933, 2],
#  [1749, 1209, 2],
#  [1798, 1583, 2],
#  [1484, 4102, 1209, 4160, 3989, 1484, 3006, 3830, 2],
#  [4160, 3518, 3020, 2778, 3949, 2],
#  [2666, 2557, 3769, 2484, 964, 2],
#  [2933, 4273, 2420, 3369, 2],
#  [2531, 502, 2],
#  [3886, 1933, 2],
#  [966, 1871, 3565, 155, 1399, 4067, 1209, 1489, 2],
#  [480, 2],
#  [1263, 4279, 3105, 502, 827, 3595, 2655, 2],
#  [3825, 2484, 3460, 4386, 2],
#  [3714, 524, 4027, 4293, 601, 784, 2484, 961, 2],
#  [2484, 2760, 3355, 3084, 2145, 387, 1366, 2],
#  [664, 3184, 4072, 3830, 502, 2],
#  [3031, 2027, 1578, 4222, 2964, 2],
#  [2793, 3607, 3261, 1770, 1160, 2],
#  [307, 2614, 3766, 2],
#  [2160, 2614, 3766, 1484, 1650, 1506, 3606, 2],
#  [4596, 2484, 2240, 155, 3313, 2],
#  [664, 3656, 3279, 3766, 3807, 1770, 293, 2],
#  [1599, 2981, 2],
#  [2189, 2411, 2],
#  [3765, 784, 4072, 2],
#  [405, 4160, 3378, 1578, 2523, 3766, 1292, 2],
#  [876, 4160, 3378, 3815, 1209, 387, 755, 3899, 2],
#  [2856, 3173, 502, 3595, 3979, 1184, 1209, 2],
#  [2997, 3411, 811, 4067, 2],
#  [1139, 3179, 1209, 1648, 2],
#  [4171, 4588, 1640, 954, 2122, 2],
#  [1139, 2893, 3192, 2],
#  [1484, 3830, 1204, 1634, 1209, 4067, 3595, 2122, 2],
#  [4486, 1204, 2],
#  [2982, 2933, 2],
#  [1209, 1633, 2],
#  [4153, 1640, 4308, 2],
#  [86, 4102, 755, 871, 2],
#  [2226, 2],
#  [2484, 3396, 1209, 1024, 2484, 2071, 1073, 2],
#  [4487, 3006, 2410, 4069, 2],
#  [1209, 2185, 3192, 1484, 954, 4295, 201, 2],
#  [1139, 155, 502, 2],
#  [1484, 3830, 1204, 1949, 2],
#  [865, 832, 2],
#  [2982, 3989, 697, 2484, 2475, 4591, 1254, 2],
#  [4588, 3989, 2],
#  [2731, 2],
#  [2697, 2484, 4127, 3223, 207, 3966, 2],
#  [2731, 2731, 2],
#  [307, 49, 791, 1035, 2],
#  [2777, 954, 1484, 1634, 3129, 4110, 2],
#  [1770, 293, 2726, 979, 752, 2],
#  [4071, 2],
#  [4032, 2],
#  [2176, 1965, 2801, 2],
#  [1847, 755, 3192, 3949, 2],
#  [3903, 3355, 755, 3269, 3766, 4019, 86, 315, 2],
#  [1770, 2163, 2484, 1749, 752, 784, 201, 2],
#  [1204, 3825, 789, 2484, 3058, 3765, 2],
#  [2163, 1918, 752, 784, 3518, 3830, 502, 1896, 2],
#  [3488, 2801, 3226, 3488, 2801, 2],
#  [1648, 1425, 2420, 1586, 4360, 2],
#  [1484, 1138, 1918, 755, 897, 2248, 2],
#  [2982, 3454, 1630, 3830, 2410, 2],
#  [3638, 2309, 502, 1235, 2694, 2],
#  [2028, 4222, 2352, 86, 633, 4160, 1204, 2933, 2203, 2],
#  [4039, 2998, 3166, 1399, 3674, 1204, 990, 2],
#  [4486, 1204, 2],
#  [2656, 2],
#  [2782, 2656, 3888, 4072, 2],
#  [1209, 2106, 784, 3595, 2899, 2],
#  [2180, 2684, 3192, 2726, 3371, 4090, 2],
#  [2062, 1933, 2],
#  [4160, 1209, 743, 1209, 664, 2],
#  [1484, 450, 3113, 4160, 1204, 2321, 3989, 2],
#  [967, 400, 71, 2],
#  [2893, 3180, 3787, 2],
#  [2962, 2],
#  [2783, 2],
#  [3903, 1139, 155, 2796, 2],
#  [1484, 3830, 1204, 1634, 4562, 387, 1105, 3274, 2],
#  [4039, 400, 71, 2],
#  [4349, 3518, 4160, 4160, 1204, 3518, 2],
#  [4486, 3830, 2145, 2185, 3468, 3222, 3825, 2],
#  [3179, 3765, 784, 3578, 1454, 4533, 832, 3271, 2],
#  [1484, 3830, 1204, 1949, 71, 1263, 2484, 471, 2],
#  [2565, 502, 155, 3560, 3974, 2],
#  [3179, 1209, 2575, 387, 3595, 4270, 2],
#  [4349, 3595, 3468, 2200, 2],
#  [876, 155, 1950, 2],
#  [4015, 2],
#  [1209, 1024, 2933, 2],
#  [2180, 293, 1958, 2],
#  [4349, 3825, 723, 2],
#  [4483, 502, 3269, 4120, 2],
#  [1896, 3570, 3595, 1020, 2],
#  [400, 755, 2149, 1209, 2],
#  [1263, 502, 2156, 502, 572, 4306, 2],
#  [966, 2211, 1558, 502, 1809, 2],
#  [3113, 3587, 1626, 2],
#  [86, 502, 155, 4057, 3457, 755, 3488, 502, 3966, 2],
#  [3949, 3173, 4072, 3595, 232, 2],
#  [2769, 784, 1139, 307, 3244, 2],
#  [2395, 293, 2],
#  [1139, 2],
#  [2156, 1209, 853, 2],
#  [2982, 3766, 2484, 226, 3288, 2],
#  [4273, 1640, 985, 2],
#  [1896, 1694, 2],
#  [3424, 3113, 3587, 979, 4413, 2],
#  [3741, 2163, 4072, 2],
#  [3424, 3424, 1204, 2],
#  [2997, 1399, 2],
#  [2782, 1304, 2864, 2],
#  [966, 3830, 1209, 1650, 2],
#  [1842, 502, 2],
#  [71, 71, 640, 2801, 2],
#  [1657, 876, 4160, 2],
#  [2541, 2180, 1160, 307, 3766, 1874, 2],
#  [1214, 1024, 2807, 95, 2],
#  [1484, 1949, 3974, 3192, 4057, 2],
#  [2484, 1664, 547, 2],
#  [3830, 502, 2],
#  [3570, 3595, 1289, 2401, 1949, 2893, 502, 2],
#  [1770, 3984, 2694, 2565, 786, 2],
#  [2145, 1059, 2484, 1366, 2],
#  [1599, 832, 2484, 961, 2],
#  [4487, 3226, 2356, 3192, 2],
#  [1599, 4119, 4118, 2],
#  [3226, 2163, 2248, 201, 2],
#  [2229, 4514, 3265, 2],
#  [2743, 2484, 785, 2],
#  [3180, 3265, 2],
#  [1770, 2163, 2177, 1454, 2123, 2],
#  [3113, 3179, 1204, 2204, 643, 2],
#  [2895, 3265, 2],
#  [2982, 3989, 4273, 4072, 2793, 966, 1209, 1265, 2],
#  [3897, 3265, 3608, 2],
#  [2176, 3269, 1263, 832, 2484, 3410, 2],
#  [1599, 3009, 3989, 4222, 2],
#  [839, 1209, 4160, 1204, 2356, 502, 3989, 2],
#  [3789, 3265, 3407, 1139, 2484, 1045, 2],
#  [2445, 692, 2484, 785, 2],
#  [4222, 2],
#  [1770, 293, 1770, 293, 2],
#  [3605, 3595, 2],
#  [4193, 2],
#  [3656, 2248, 2],
#  [3499, 4273, 1541, 1392, 2],
#  [3886, 293, 3174, 2],
#  [1399, 985, 3499, 4273, 3113, 4160, 1696, 3518, 2],
#  [71, 3570, 2],
#  [2565, 2565, 4588, 2226, 3113, 387, 755, 2],
#  [966, 1981, 4118, 2],
#  [3159, 280, 4201, 2],
#  [307, 1204, 2321, 2],
#  [4090, 2],
#  [1933, 3830, 1204, 3184, 2694, 3993, 2],
#  [3113, 3674, 1204, 1185, 1583, 2],
#  [3158, 2],
#  [2180, 3269, 2211, 3158, 2],
#  [1484, 949, 1209, 1184, 3499, 2],
#  [1209, 3179, 664, 3738, 2],
#  [839, 2783, 1484, 2],
#  [3115, 2],
#  [3989, 201, 4270, 3989, 201, 2],
#  [4160, 3113, 1185, 755, 1764, 1896, 2],
#  [1263, 3989, 2],
#  [2101, 3113, 704, 2],
#  [4349, 3974, 1484, 2769, 3113, 4133, 2101, 2],
#  [4279, 2185, 2484, 2107, 2],
#  [2297, 1209, 3993, 1918, 2],
#  [2763, 1890, 1342, 4273, 2484, 1245, 1494, 2],
#  [2293, 3160, 2],
#  [4107, 46, 1484, 1246, 1665, 3976, 3766, 1918, 2],
#  [1209, 1611, 1665, 1209, 1258, 1665, 2],
#  [3726, 2309, 3595, 2041, 784, 4336, 2396, 2],
#  [1263, 1139, 3113, 1492, 2],
#  [1858, 502, 3606, 2557, 1266, 2],
#  [3166, 2],
#  [4024, 3975, 3424, 2],
#  [579, 2145, 3134, 2],
#  [3311, 4344, 1139, 3830, 3113, 2185, 979, 2],
#  [3777, 2155, 1209, 387, 3587, 3518, 2],
#  [2783, 2],
#  [2204, 3963, 4487, 2385, 3766, 4509, 2],
#  [2783, 2],
#  [3160, 2],
#  [3606, 3730, 4273, 502, 2],
#  [664, 3173, 3192, 2484, 2942, 2],
#  [2271, 4472, 2258, 2472, 1425, 2],
#  [512, 2],
#  [1713, 3192, 3766, 3595, 381, 4067, 2258, 2555, 2],
#  [1139, 3830, 1209, 3680, 2],
#  [3595, 859, 790, 755, 955, 4273, 1640, 3343, 2],
#  [1599, 4273, 2484, 639, 2],
#  [3735, 2801, 3199, 2],
#  [3399, 502, 2],
#  [1152, 2107, 3141, 876, 1209, 1184, 3889, 755, 2],
#  [1204, 4057, 1981, 784, 2484, 2591, 3273, 1805, 2],
#  [155, 3825, 3595, 4078, 2],
#  [4190, 2],
#  [86, 4510, 3825, 2],
#  [3789, 4395, 703, 4273, 521, 2],
#  [954, 3789, 2],
#  [1139, 155, 1399, 4514, 2778, 2],
#  [1139, 155, 3825, 2],
#  [1466, 2203, 3342, 2],
#  [4586, 2],
#  [1634, 1665, 2],
#  [3020, 3215, 2602, 1688, 422, 2],
#  [3113, 1209, 1706, 4135, 752, 3518, 1877, 3192, 2],
#  [3886, 3830, 3192, 2116, 755, 1353, 1640, 3024, 2],
#  [3830, 1209, 2769, 2010, 3213, 4049, 2],
#  [2965, 2565, 833, 2565, 4071, 2557, 2],
#  [1599, 3595, 1282, 2],
#  [155, 502, 2933, 2],
#  [2782, 502, 155, 2618, 2],
#  [1484, 1138, 1209, 3113, 1139, 155, 3825, 2],
#  [684, 2323, 4619, 502, 155, 2779, 692, 2],
#  [1770, 2163, 2248, 86, 3077, 1399, 3766, 2],
#  [3570, 3595, 1289, 2],
#  [4039, 2203, 2],
#  [2359, 2],
#  [2392, 2],
#  [2782, 4271, 2298, 2],
#  [439, 752, 2484, 2611, 2],
#  [1304, 2052, 1632, 2],
#  [3714, 4273, 2],
#  [2997, 2484, 2687, 2],
#  [2433, 3825, 2],
#  [589, 2],
#  [1139, 3830, 1209, 1024, 2],
#  [2769, 1484, 620, 4057, 853, 2],
#  [2256, 2306, 2],
#  [2101, 1484, 88, 387, 1665, 2335, 1958, 2],
#  [3886, 2],
#  [3830, 1209, 2823, 2694, 2],
#  [86, 2],
#  [86, 2557, 2145, 1712, 752, 3226, 2618, 2],
#  [1139, 155, 502, 2],
#  [3830, 1209, 1634, 3595, 672, 2],
#  [4279, 2],
#  [2782, 2],
#  [1139, 3503, 2],
#  [2997, 1185, 4273, 2],
#  [393, 2484, 785, 2],
#  [1139, 155, 3825, 2],
#  [876, 1486, 3825, 4042, 755, 2],
#  [2402, 1712, 3825, 2336, 2],
#  [664, 2],
#  [2731, 1139, 3830, 1209, 2769, 2],
#  [3161, 2203, 3765, 4341, 1270, 2],
#  [3850, 755, 1139, 2],
#  [2696, 847, 2],
#  [2782, 2],
#  [2410, 4563, 2484, 838, 2],
#  [1484, 3076, 2],
#  [1152, 1526, 2],
#  [1139, 2],
#  [3607, 3595, 4222, 524, 1399, 2],
#  [3765, 784, 979, 999, 387, 3861, 2],
#  [4438, 2565, 985, 3595, 1944, 2787, 3825, 1653, 2],
#  [1263, 3595, 4078, 2],
#  [3817, 3570, 3595, 1289, 2],
#  [1139, 2],
#  [3226, 3587, 3595, 2356, 2],
#  [163, 502, 1185, 2],
#  [2782, 2116, 254, 755, 1209, 4057, 2],
#  [1209, 176, 994, 2484, 2674, 4057, 2],
#  [1139, 317, 2994, 2],
#  [1529, 3407, 4201, 2],
#  [3173, 3192, 3595, 424, 155, 2410, 83, 2],
#  [1209, 3587, 502, 2919, 2],
#  [1842, 502, 2203, 2],
#  [3161, 2696, 847, 2769, 784, 2484, 410, 2],
#  [1139, 2484, 2619, 4160, 1209, 1265, 2],
#  [2977, 664, 4222, 2],
#  [1139, 2],
#  [2395, 3499, 1877, 1209, 2],
#  [3454, 967, 1185, 4288, 2],
#  [643, 1209, 1648, 2444, 2],
#  [9, 784, 3825, 3100, 3518, 2],
#  [2782, 1484, 3587, 502, 2],
#  [2666, 3587, 2694, 2],
#  [3714, 502, 3714, 502, 2],
#  [2997, 2171, 2],
#  [967, 3735, 2801, 867, 453, 2],
#  [1139, 876, 2],
#  [3226, 315, 4072, 73, 755, 2484, 3989, 2],
#  [2176, 2156, 3595, 1375, 4160, 1209, 3886, 2],
#  [2782, 1484, 2],
#  [3570, 3294, 502, 2],
#  [966, 2],
#  [1484, 3076, 931, 3269, 3595, 105, 2],
#  [4039, 2203, 1263, 2565, 105, 2],
#  [1599, 2977, 502, 155, 4364, 2],
#  [155, 502, 2666, 673, 2],
#  [1139, 2],
#  [967, 752, 784, 3103, 2163, 832, 2163, 832, 2],
#  [2743, 2761, 1896, 2],
#  [2997, 990, 2],
#  [3980, 1262, 3359, 307, 697, 81, 2],
#  [307, 1139, 2],
#  [966, 1694, 784, 1918, 4160, 3518, 2],
#  [4057, 1694, 2],
#  [1263, 2484, 2171, 985, 2],
#  [1479, 3058, 4359, 1673, 2],
#  [2909, 502, 2801, 2],
#  [2180, 3570, 4067, 3192, 2],
#  [1599, 4057, 3457, 2],
#  [4493, 2],
#  [966, 1694, 966, 1694, 1578, 4160, 2986, 2],
#  [2997, 1833, 3673, 1919, 2],
#  [2181, 2],
#  [165, 3093, 3454, 3578, 2287, 4160, 4315, 2],
#  [3000, 2523, 2039, 755, 1918, 2],
#  [1204, 1906, 2],
#  [3830, 502, 2],
#  [2145, 3744, 752, 2484, 4162, 3936, 2],
#  [3638, 2309, 502, 2],
#  [3173, 70, 3607, 2],
#  [307, 1204, 3475, 2684, 502, 4160, 3113, 2],
#  [839, 3899, 2484, 3712, 2],
#  [4039, 2203, 2],
#  [1839, 1024, 2320, 1185, 907, 2],
#  [155, 1399, 2484, 1455, 2],
#  [940, 2],
#  [966, 1981, 1589, 387, 1484, 3587, 2],
#  [889, 2],
#  [3726, 46, 2],
#  [1139, 4486, 2],
#  [966, 4049, 4160, 2177, 1985, 2],
#  [4438, 2666, 4118, 755, 2631, 2],
#  [2783, 2],
#  [400, 3779, 820, 2852, 389, 2],
#  [4160, 1209, 2977, 2],
#  [1139, 2997, 2171, 1139, 155, 502, 2],
#  [876, 155, 1950, 2],
#  [544, 2801, 2484, 3208, 3759, 2],
#  [1484, 2052, 502, 2],
#  [86, 2],
#  [3005, 3989, 3340, 2484, 3208, 3759, 2],
#  [2163, 3271, 3313, 1896, 2],
#  [1484, 2252, 3258, 3271, 4057, 1981, 453, 2804, 2],
#  [711, 3981, 2],
#  [664, 3113, 4160, 3766, 864, 2],
#  [3989, 2181, 1209, 2420, 310, 2],
#  [664, 967, 752, 784, 201, 2],
#  [3947, 3578, 4494, 3953, 2],
#  [3454, 2],
#  [2041, 4341, 2027, 2],
#  [1139, 2101, 1484, 3830, 2],
#  [1484, 1484, 2176, 2],
#  [1209, 387, 755, 2],
#  [2565, 2],
#  [4486, 176, 1209, 2769, 1484, 1184, 1204, 3269, 2],
#  [1204, 524, 2420, 2],
#  [2372, 22, 2160, 3411, 155, 3595, 2310, 2],
#  [2160, 2484, 4189, 2],
#  [4039, 2565, 1484, 2156, 2484, 7, 2],
#  [1450, 3410, 1486, 1204, 3130, 1981, 1484, 2499, 2],
#  [967, 1185, 755, 3607, 1209, 755, 3025, 2],
#  [4039, 2565, 2],
#  [4588, 3587, 755, 1520, 1209, 2],
#  [3518, 155, 1204, 867, 2309, 1209, 3518, 4483, 1204, 3269, 2],
#  [2325, 2325, 3559, 2],
#  [3973, 334, 1636, 2],
#  [966, 1180, 2484, 3840, 2],
#  [3957, 2],
#  [1746, 3689, 1209, 3595, 3342, 2],
#  [2565, 2783, 65, 2],
#  [502, 1180, 3311, 4093, 2145, 1330, 4273, 2],
#  [1484, 2811, 1855, 3311, 4093, 2],
#  [3825, 1180, 985, 2248, 2],
#  [1209, 3680, 300, 3576, 2],
#  [690, 1665, 2],
#  [2484, 2201, 4325, 2],
#  [784, 1001, 2],
#  [3025, 1486, 1204, 7, 3595, 198, 65, 2],
#  [1599, 2484, 4049, 1046, 3825, 1486, 502, 2],
#  [4159, 1640, 3754, 3468, 913, 2],
#  [4440, 1896, 2],
#  [202, 502, 2484, 471, 2],
#  [2982, 3378, 3711, 3378, 373, 2],
#  [2402, 1139, 2],
#  [4588, 3226, 907, 2484, 785, 2],
#  [2484, 2326, 2],
#  [1484, 1492, 1209, 1184, 1067, 2893, 3192, 2],
#  [1204, 524, 2420, 3025, 1399, 155, 2325, 3559, 2],
#  [966, 3830, 1209, 3830, 1640, 3045, 2],
#  [4039, 3504, 2],
#  [334, 2204, 3931, 2],
#  [1640, 4290, 2],
#  [334, 2204, 3559, 2],
#  [966, 3830, 1209, 3830, 164, 2939, 2],
#  [4039, 3504, 2],
#  [2204, 3948, 2],
#  [3045, 65, 2355, 1209, 3213, 3966, 2204, 2085, 2],
#  [3559, 2],
#  [967, 2731, 400, 3559, 2355, 1209, 3213, 3966, 2],
#  [2565, 1262, 1209, 4349, 1304, 1617, 2036, 4082, 2],
#  [766, 2309, 643, 2204, 3931, 1855, 2],
#  [1184, 1209, 3006, 966, 939, 2],
#  [784, 1001, 502, 155, 2],
#  [3401, 4551, 2893, 502, 2],
#  [3518, 4160, 3058, 3538, 2],
#  [4619, 1484, 954, 949, 966, 2],
#  [3899, 2],
#  [839, 2],
#  [3334, 2],
#  [3179, 1209, 2156, 502, 201, 3766, 300, 1608, 2],
#  [2325, 4486, 3830, 1204, 1209, 1726, 524, 2484, 2562, 2],
#  [502, 4483, 1204, 986, 2042, 1209, 2],
#  [1204, 524, 2420, 2],
#  [1262, 1209, 2731, 1981, 2],
#  [364, 3192, 3595, 4529, 86, 1484, 931, 387, 2],
#  [2372, 2],
#  [2372, 2],
#  [954, 3766, 1665, 4359, 4487, 758, 2],
#  [967, 3595, 879, 4572, 2],
#  [2372, 2],
#  [4408, 2],
#  [1399, 155, 2325, 3559, 2],
#  [4151, 80, 3192, 1484, 3071, 3595, 1440, 2],
#  [334, 1139, 155, 3378, 1750, 2],
#  [2325, 2325, 3559, 2],
#  [2402, 3606, 2940, 2],
#  [876, 2],
#  [3989, 201, 3595, 1289, 4150, 2],
#  [1263, 3777, 2],
#  [1950, 4057, 155, 3595, 46, 587, 784, 712, 2],
#  [2566, 2420, 1399, 3614, 3766, 3226, 3765, 3410, 2],
#  [4487, 1204, 1185, 4160, 1209, 2],
#  [2565, 3830, 1204, 293, 2],
#  [839, 4619, 967, 1204, 3766, 2484, 985, 2],
#  [1484, 353, 1204, 3269, 3595, 1289, 2],
#  [2116, 3215, 3845, 2],
#  [1017, 3830, 1204, 3680, 2116, 3215, 1484, 3830, 2],
#  [2395, 3269, 524, 2484, 4294, 3656, 2646, 404, 2],
#  [1204, 3226, 3825, 985, 923, 3595, 2122, 2],
#  [766, 2309, 3825, 2],
#  [1599, 2645, 3595, 1466, 2276, 2325, 2],
#  [1484, 4102, 2731, 164, 2939, 2116, 1693, 2],
#  [1209, 3971, 1922, 4201, 275, 2811, 2684, 502, 2],
#  [4486, 2],
#  [1484, 3226, 3141, 2],
#  [3226, 3141, 1139, 2],
#  [4486, 2],
#  [4486, 1139, 2],
#  [4486, 1209, 387, 755, 293, 752, 3518, 2],
#  [1484, 3830, 1204, 387, 755, 1484, 1634, 755, 2],
#  [155, 502, 2484, 3976, 2],
#  [1075, 1894, 784, 502, 353, 293, 4067, 707, 2],
#  [1484, 3226, 2164, 3595, 1934, 1165, 2],
#  [3454, 3023, 1209, 999, 1204, 37, 3518, 2],
#  [1599, 954, 3765, 2658, 889, 2],
#  [2731, 2737, 3499, 2248, 2],
#  [1484, 3011, 3348, 616, 2494, 2036, 402, 2],
#  [1082, 270, 1643, 2],
#  [2036, 3867, 2],
#  [1209, 3179, 1204, 387, 755, 2185, 3192, 2],
#  [4574, 1640, 2461, 2],
#  [2176, 711, 4250, 1363, 1630, 1640, 3024, 2],
#  [2309, 3595, 2507, 4129, 3382, 2],
#  [1836, 2484, 1578, 3587, 3378, 1074, 2],
#  [2156, 1209, 3389, 2],
#  [2406, 2],
#  [784, 1001, 1204, 2],
#  [4588, 168, 3595, 2200, 3825, 469, 1750, 2],
#  [2325, 766, 1067, 2145, 1078, 3825, 985, 2],
#  [1484, 1138, 3271, 1484, 1127, 1630, 2],
#  [3607, 3969, 784, 1844, 752, 3518, 2],
#  [2372, 2],
#  [4408, 2],
#  [2180, 2163, 2953, 4273, 1665, 1899, 3875, 2],
#  [2395, 3899, 2],
#  [4006, 2252, 3269, 2689, 736, 2],
#  [86, 1059, 3825, 752, 3989, 1896, 2],
#  [923, 784, 1399, 1875, 1209, 4160, 3789, 3679, 4294, 2],
#  [2783, 4067, 3378, 80, 2116, 3215, 2],
#  [2901, 164, 22, 2],
#  [1019, 3192, 3595, 3204, 2],
#  [3077, 3192, 3160, 1209, 2163, 3766, 2],
#  [1139, 1425, 2],
#  [839, 4616, 3406, 86, 338, 353, 3269, 338, 2],
#  [2410, 3424, 1078, 3595, 4325, 268, 2],
#  [839, 1209, 387, 1858, 2731, 1981, 1139, 155, 300, 2],
#  [2484, 1995, 1484, 4536, 1918, 598, 2],
#  [2145, 4160, 23, 1034, 2145, 23, 65, 2],
#  [2565, 1874, 524, 2420, 2],
#  [315, 3766, 3378, 2773, 966, 1981, 2],
#  [1484, 387, 1204, 3587, 3595, 1485, 967, 2609, 1607, 2],
#  [839, 2],
#  [910, 2],
#  [334, 2],
#  [3077, 1139, 3077, 2],
#  [502, 1399, 3549, 2204, 3025, 3931, 2],
#  [1263, 3989, 3454, 1484, 3830, 1204, 526, 2],
#  [1484, 3524, 2],
#  [293, 509, 1958, 2],
#  [1139, 3595, 577, 1538, 1375, 755, 3830, 2],
#  [2372, 387, 1484, 4015, 1036, 2372, 2],
#  [4487, 1640, 2200, 4160, 1204, 1209, 2],
#  [3825, 1484, 3674, 2],
#  [1805, 1209, 4160, 1036, 2],
#  [3160, 3160, 4160, 1209, 2614, 2248, 2],
#  [1209, 3766, 3595, 2909, 2],
#  [1826, 502, 2],
#  [2372, 2372, 502, 155, 3378, 2255, 2],
#  [263, 2255, 1636, 2],
#  [1694, 263, 1969, 784, 2484, 3867, 2],
#  [1484, 2163, 3595, 422, 3830, 1204, 1484, 2],
#  [1950, 3179, 2],
#  [2782, 1484, 353, 2],
#  [966, 155, 2325, 664, 2],
#  [664, 2],
#  [1484, 3071, 1209, 2],
#  [2395, 439, 1877, 2325, 2],
#  [1139, 2],
#  [1484, 3071, 1209, 4057, 2116, 1693, 1636, 2],
#  [2156, 1209, 2],
#  [65, 2],
#  [1822, 2],
#  [1209, 3830, 1204, 2309, 2325, 3830, 1209, 2],
#  [3830, 1209, 1634, 271, 4185, 70, 271, 2386, 2],
#  [271, 2386, 2],
#  [2565, 2],
#  [4486, 1204, 2],
#  [1896, 1209, 1634, 271, 4185, 2],
#  [1950, 185, 602, 2],
#  [1693, 271, 3867, 2],
#  [4588, 3754, 86, 1815, 2],
#  [2309, 271, 4543, 1877, 3765, 3513, 2],
#  [1950, 652, 954, 4067, 3192, 1486, 1204, 1950, 2],
#  [966, 3830, 1209, 1024, 3825, 2],
#  [1304, 3587, 502, 2],
#  [3989, 201, 2],
#  [1263, 1640, 2714, 2156, 1209, 524, 1213, 4118, 2],
#  [4039, 3456, 86, 1484, 3805, 755, 2185, 1209, 2],
#  [4349, 3045, 1209, 3805, 2420, 2893, 502, 2],
#  [3023, 2],
#  [2019, 2939, 2],
#  [3533, 2],
#  [1209, 1634, 755, 3269, 1679, 300, 4077, 2],
#  [2484, 364, 999, 293, 4273, 2],
#  [3830, 1209, 2769, 2204, 3931, 1184, 2031, 2],
#  [1484, 2769, 1950, 1184, 533, 2],
#  [3454, 164, 2939, 86, 164, 22, 2],
#  [3741, 3830, 923, 2145, 4160, 1138, 2],
#  [784, 1001, 2],
#  [1209, 353, 1204, 1842, 502, 2],
#  [1484, 353, 1204, 1842, 2],
#  [3454, 1950, 3226, 3587, 201, 2],
#  [1139, 3179, 1209, 1991, 2073, 1178, 2],
#  [1399, 2386, 661, 3192, 3595, 843, 1894, 2],
#  [4349, 4349, 502, 1486, 2],
#  [967, 400, 1484, 3179, 1204, 1024, 755, 2],
#  [3025, 3006, 2],
#  [966, 2893, 3885, 502, 3595, 1693, 2],
#  [1599, 3595, 2116, 1492, 2],
#  [502, 353, 1204, 7, 2],
#  [263, 3468, 210, 2],
#  [1059, 502, 752, 2],
#  [4551, 4551, 2],
#  [1896, 3184, 4072, 1204, 2163, 3340, 3595, 2323, 1727, 2],
#  [3680, 3020, 80, 2],
#  [4619, 1209, 1184, 2309, 2],
#  [1484, 1184, 1204, 2309, 2],
#  [2614, 2],
#  [3766, 3595, 1289, 2],
#  [86, 4057, 1694, 784, 1918, 4160, 4241, 2],
#  [1770, 293, 3213, 3279, 2484, 460, 2],
#  [2565, 2325, 1484, 353, 1204, 1842, 2],
#  [1209, 2420, 592, 4498, 2],
#  [3457, 4067, 1139, 2],
#  [2180, 3269, 1510, 2484, 422, 2],
#  [766, 2309, 755, 4551, 502, 2],
#  [784, 1001, 2],
#  [1484, 1492, 1209, 307, 1185, 755, 3269, 3457, 2],
#  [3160, 967, 713, 784, 109, 2],
#  [1484, 4568, 2565, 3001, 1209, 307, 111, 201, 2],
#  [3825, 2811, 3327, 1209, 4510, 2],
#  [4588, 3595, 2200, 784, 2731, 1694, 470, 2],
#  [1599, 3595, 1572, 1956, 4221, 2177, 3787, 2],
#  [4588, 3595, 2200, 784, 2731, 1694, 1956, 55, 2],
#  [2731, 1950, 3355, 2],
#  [1484, 3830, 1204, 2769, 3825, 155, 1619, 2],
#  [4514, 4201, 2],
#  [2659, 4201, 4027, 4201, 1139, 784, 502, 2],
#  [4067, 342, 1139, 2],
#  [4067, 342, 1209, 2],
#  [2504, 2],
#  [1139, 2893, 3271, 4470, 1139, 2893, 3271, 4257, 2],
#  [1871, 1484, 387, 3378, 2461, 2],
#  [2180, 104, 1484, 2101, 3607, 502, 2801, 598, 2],
#  [1958, 2],
#  [166, 2731, 1694, 1009, 55, 2],
#  [967, 2731, 263, 1209, 4160, 263, 2],
#  [966, 2893, 3192, 1139, 2],
#  [44, 1209, 203, 2933, 1139, 2893, 3378, 1441, 2],
#  [1484, 3674, 1204, 3475, 871, 1204, 1877, 3595, 994, 2],
#  [1262, 1209, 2],
#  [2557, 3006, 2],
#  [1139, 155, 3411, 49, 2893, 2],
#  [890, 2],
#  [1484, 3830, 1204, 966, 3830, 1209, 3830, 2],
#  [3113, 2811, 2940, 1263, 4486, 2],
#  [2116, 254, 164, 1643, 2],
#  [1484, 4568, 2565, 3001, 1209, 949, 881, 3058, 2],
#  [1263, 966, 1209, 2940, 3192, 3766, 4606, 2],
#  [3113, 387, 3825, 3766, 2925, 2],
#  [1805, 1209, 3779, 999, 387, 3595, 2211, 1847, 2],
#  [4486, 3830, 2145, 4083, 4222, 2309, 74, 2638, 2],
#  [2076, 2],
#  [4142, 2],
#  [1484, 3226, 1855, 502, 2],
#  [7, 502, 1425, 2],
#  [3454, 3825, 1180, 2484, 4561, 3568, 4118, 2],
#  [2565, 4487, 3226, 1036, 2893, 4142, 2],
#  [4142, 2],
#  [3057, 1209, 1650, 4341, 2102, 1201, 3595, 2554, 2],
#  [1209, 1949, 2557, 2893, 3511, 2102, 70, 4194, 2],
#  [2565, 4308, 755, 790, 2],
#  [2204, 2910, 1139, 2],
#  [2669, 2484, 1157, 2],
#  [3595, 2041, 784, 3055, 2],
#  [1184, 1209, 2],
#  [643, 755, 80, 1209, 752, 2836, 2],
#  [1399, 155, 1466, 3639, 1484, 2433, 502, 2],
#  [2420, 1209, 3587, 755, 3830, 155, 1750, 502, 2],
#  [3173, 2325, 3559, 2714, 3766, 1209, 2843, 2],
#  [1209, 2163, 2642, 4382, 3830, 1204, 1209, 2],
#  [3454, 1139, 4483, 1950, 3830, 2],
#  [839, 2],
#  [1633, 2],
#  [1484, 1633, 2],
#  [1263, 1640, 2836, 2],
#  [876, 155, 1950, 2],
#  [2801, 3766, 2484, 3410, 2],
#  [4216, 3174, 752, 3518, 2],
#  [3160, 1209, 3830, 3184, 3192, 3766, 4273, 502, 2],
#  [1484, 353, 2],
#  [163, 2484, 300, 3765, 2614, 2],
#  [2484, 7, 2420, 3989, 1484, 450, 2],
#  [2495, 4588, 2666, 3595, 2200, 784, 4514, 2],
#  [1093, 502, 155, 1204, 3051, 2],
#  [966, 3830, 1209, 1024, 2],
#  [2180, 3269, 3539, 2],
#  [3025, 1209, 387, 1204, 3587, 3020, 4433, 2],
#  [2484, 4033, 1722, 3113, 1648, 2692, 2],
#  [1649, 2632, 2395, 755, 3271, 2624, 2],
#  [3387, 384, 3378, 4077, 2],
#  [2325, 1640, 4077, 2],
#  [2020, 1209, 1949, 2],
#  [784, 1001, 1484, 949, 2],
#  [502, 3226, 3405, 3378, 1445, 2],
#  [966, 966, 1180, 2204, 2910, 2],
#  [734, 1484, 3830, 1204, 1331, 2],
#  [3226, 3405, 3378, 1445, 2],
#  [1180, 1950, 3825, 476, 2],
#  [1484, 3607, 502, 1950, 3011, 839, 2],
#  [966, 3777, 2],
#  [3766, 4118, 1950, 353, 3269, 1139, 1209, 4160, 2],
#  [1820, 4279, 1640, 3045, 2],
#  [334, 2204, 3931, 2],
#  [1599, 2420, 73, 2],
#  [2997, 2420, 73, 2],
#  [2484, 1157, 2],
#  [4588, 3378, 4077, 2],
#  [3006, 2325, 4486, 2],
#  [4486, 1204, 2],
#  [1139, 3476, 86, 3824, 2],
#  [1209, 1184, 1204, 526, 966, 1180, 2204, 2910, 2],
#  [2272, 387, 2645, 2357, 784, 3271, 2],
#  [967, 3886, 2],
#  [1950, 1180, 3595, 354, 2],
#  [755, 1209, 4057, 2],
#  [1139, 3830, 1209, 1024, 2],
#  [1263, 230, 2484, 3261, 2],
#  [270, 2],
#  [2731, 170, 784, 1504, 3476, 86, 3824, 2],
#  [1204, 347, 2811, 347, 4619, 643, 773, 2],
#  [1484, 2811, 3971, 502, 1180, 2],
#  [4160, 1209, 687, 2484, 4214, 2],
#  [2386, 1640, 1165, 2],
#  [1484, 3179, 1204, 4551, 1209, 2],
#  [1484, 3971, 967, 3595, 686, 2203, 2],
#  [1340, 2],
#  [2484, 1010, 1772, 2],
#  [4015, 2],
#  [1484, 999, 387, 3788, 3271, 3406, 2],
#  [1484, 1184, 1204, 3269, 802, 15, 1209, 2013, 3192, 2],
#  [2180, 1678, 3378, 1571, 2],
#  [1484, 1678, 1139, 1484, 2309, 2],
#  [664, 1678, 2],
#  [1139, 3595, 816, 1139, 3595, 2604, 2],
#  [2484, 749, 3443, 2484, 2063, 73, 1527, 3966, 2],
#  [1484, 353, 1204, 1527, 3966, 2],
#  [2180, 1527, 3966, 2],
#  [4487, 1649, 1729, 3206, 4160, 1204, 1209, 2],
#  [967, 3981, 1729, 602, 2],
#  [201, 3113, 293, 2],
#  [1896, 3830, 1204, 2163, 3026, 3406, 2],
#  [2402, 2645, 2420, 1637, 3825, 1877, 1834, 2],
#  [4187, 2],
#  [1599, 1807, 1209, 4160, 1204, 3595, 913, 2],
#  [1304, 2645, 627, 784, 3825, 4067, 1665, 4118, 2],
#  [839, 1484, 3674, 2],
#  [2395, 1648, 2],
#  [2180, 3269, 3672, 2],
#  [3025, 3184, 4072, 2684, 963, 2],
#  [2484, 3958, 4160, 4057, 3531, 3392, 1908, 2],
#  [1599, 1204, 1982, 2],
#  [1484, 3996, 502, 307, 2],
#  [3825, 3412, 4393, 2484, 1467, 1375, 84, 2],
#  [1834, 1139, 3503, 2],
#  [3025, 1425, 2],
#  [1263, 4273, 4118, 4067, 3025, 2],
#  [1599, 3226, 1076, 1950, 2020, 2],
#  [3830, 1204, 4630, 752, 784, 3749, 3045, 2],
#  [3025, 3000, 1204, 1858, 4274, 3279, 502, 2],
#  [1599, 1185, 755, 3269, 3595, 2958, 1631, 2],
#  [1139, 155, 2],
#  [1139, 4118, 155, 502, 2],
#  [963, 86, 1216, 155, 4067, 3427, 2],
#  [1834, 3269, 9, 2],
#  [3533, 86, 1484, 3226, 3830, 1204, 1634, 271, 1677, 2],
#  [1484, 387, 2565, 4503, 784, 4439, 271, 1677, 2],
#  [3895, 2],
#  [966, 1981, 4118, 387, 3113, 2],
#  [1114, 3031, 4201, 2],
#  [966, 722, 755, 2484, 3292, 2],
#  [4432, 70, 4190, 3195, 2],
#  [275, 232, 3378, 1659, 4273, 3825, 3065, 2],
#  [2180, 2712, 2893, 1096, 1454, 2],
#  [1262, 1209, 1834, 2187, 2],
#  [3830, 1209, 1634, 502, 4273, 2],
#  [502, 1486, 1204, 3770, 2],
#  [1484, 2720, 1385, 4244, 2],
#  [3533, 1484, 387, 1204, 2645, 2111, 1399, 1631, 2],
#  [2288, 2420, 4111, 3595, 3468, 1279, 3323, 2],
#  [4487, 3025, 3226, 3025, 2],
#  [1139, 2893, 2372, 2],
#  [1139, 2893, 2372, 2],
#  [2160, 3766, 3071, 1877, 1209, 2],
#  [4486, 176, 3411, 86, 4486, 176, 1209, 2],
#  [1204, 755, 1209, 1204, 755, 2372, 2],
#  [3960, 3825, 1139, 2145, 4083, 1648, 2],
#  [839, 2],
#  [2893, 1139, 2],
#  [4160, 1209, 2357, 784, 3192, 2372, 2],
#  [1209, 176, 1204, 387, 4568, 3020, 4091, 2],
#  [155, 3825, 1139, 1209, 1634, 3192, 755, 3269, 2],
#  [967, 49, 2893, 1209, 86, 1139, 1209, 1634, 2],
#  [2731, 3674, 1484, 2],
#  [1139, 387, 1484, 3587, 755, 3830, 1877, 502, 2],
#  [2761, 2],
#  [2180, 4630, 3406, 2372, 2],
#  [3769, 1139, 1184, 1484, 3269, 1134, 2],
#  [967, 4067, 502, 2],
#  [3378, 3002, 3595, 3468, 764, 2],
#  [86, 4067, 1209, 2],
#  [4487, 168, 3595, 2200, 2],
#  [1209, 2769, 2],
#  [967, 3766, 3071, 1877, 3025, 2437, 1209, 4337, 2],
#  [1209, 4551, 2420, 4403, 784, 1454, 2],
#  [3733, 752, 2],
#  [1871, 1484, 3499, 3766, 2],
#  [660, 164, 1643, 2],
#  [1484, 1689, 598, 1724, 2145, 3179, 1204, 2599, 1454, 2],
#  [4487, 4341, 1386, 3911, 2],
#  [1958, 3830, 2],
#  [502, 3680, 1204, 3269, 2],
#  [1484, 3674, 4271, 2],
#  [967, 1204, 384, 4067, 3595, 584, 2],
#  [1263, 3989, 2],
#  [4349, 1484, 3830, 2],
#  [4349, 2484, 98, 2],
#  [1198, 2],
#  [1198, 1139, 2],
#  [1209, 3607, 1433, 2],
#  [1484, 2823, 1484, 353, 2],
#  [1950, 1180, 3709, 2],
#  [1805, 1209, 387, 4337, 4057, 2],
#  [1484, 1180, 3518, 271, 3388, 2],
#  [3595, 263, 1003, 2],
#  [307, 4439, 449, 1877, 3595, 3086, 262, 1376, 2],
#  [2145, 660, 3830, 1204, 3984, 1981, 4118, 2],
#  [3025, 2],
#  [3025, 3104, 3766, 3368, 2],
#  [1950, 1871, 3269, 1164, 1386, 1209, 2769, 2],
#  [1484, 3226, 2252, 2823, 502, 2],
#  [1484, 2252, 2823, 2325, 3971, 3578, 1454, 2],
#  [1834, 1755, 502, 155, 3595, 2784, 535, 2],
#  [3424, 3226, 3595, 3468, 827, 2484, 2870, 2],
#  [2297, 1209, 2163, 2420, 3825, 505, 2],
#  [2325, 2],
#  [2325, 2],
#  [3825, 1180, 3595, 221, 2],
#  [1484, 4608, 4486, 2],
#  [1263, 168, 3595, 2788, 784, 3365, 2],
#  [967, 3981, 602, 755, 1169, 1209, 2],
#  [967, 2562, 755, 2857, 2801, 2],
#  [4619, 3113, 4483, 2210, 502, 1751, 3825, 155, 2],
#  [1896, 1209, 4160, 2719, 270, 70, 2325, 2],
#  [2325, 1184, 4571, 3153, 755, 3173, 3271, 969, 2],
#  [1877, 1756, 784, 1001, 2],
#  [1896, 3226, 3595, 1289, 2],
#  [1896, 3226, 3595, 1289, 2],
#  [967, 3746, 3124, 2248, 2],
#  [4235, 871, 3224, 881, 3058, 2],
#  [1096, 923, 2],
#  [4551, 4551, 2],
#  [3411, 1486, 1204, 594, 1484, 1180, 2116, 2],
#  [1209, 307, 46, 2],
#  [4057, 476, 2],
#  [755, 3025, 755, 1640, 3758, 2],
#  [819, 1530, 2],
#  [839, 784, 2420, 2],
#  [3025, 2],
#  [3160, 3160, 4160, 1209, 1185, 755, 3830, 502, 2],
#  [4349, 4596, 2],
#  [1139, 4160, 1209, 1185, 755, 1483, 2],
#  [2410, 1934, 3595, 2023, 2461, 73, 3595, 1286, 2],
#  [1586, 2420, 3424, 1950, 3226, 2813, 755, 1212, 2],
#  [839, 2420, 3989, 2],
#  [1484, 1180, 2741, 1453, 1209, 1184, 3499, 524, 2420, 2],
#  [1484, 3830, 1204, 1991, 1209, 755, 3269, 2111, 2],
#  [1484, 3830, 1204, 108, 755, 3269, 2],
#  [2176, 3113, 3213, 3966, 3226, 4067, 3595, 1289, 2],
#  [3518, 2252, 3269, 1542, 1981, 2],
#  [4039, 3454, 3518, 155, 2],
#  [4486, 176, 1204, 1209, 1958, 3213, 3966, 2],
#  [1770, 1204, 2163, 2588, 2],
#  [2325, 3830, 1204, 836, 2],
#  [967, 1204, 2012, 2],
#  [3454, 2484, 1431, 2893, 3378, 4082, 2],
#  [271, 1281, 4082, 2],
#  [2160, 1204, 1640, 2122, 1209, 307, 1640, 3729, 2],
#  [3411, 2101, 80, 1209, 2],
#  [2395, 2811, 2163, 73, 502, 2],
#  [1484, 3996, 1484, 4483, 2823, 3825, 2],
#  [1484, 2769, 1484, 1949, 2],
#  [2410, 2608, 3051, 1209, 2101, 3830, 2],
#  [1209, 1847, 3226, 923, 270, 3971, 1209, 3179, 2],
#  [270, 2813, 3192, 755, 7, 502, 2],
#  [73, 1640, 2933, 816, 2],
#  [3190, 2],
#  [3226, 1665, 1004, 2],
#  [967, 1204, 802, 1586, 2420, 3825, 971, 1047, 2],
#  [3226, 2309, 3825, 1624, 2],
#  [3226, 2309, 3825, 2],
#  [1484, 3830, 1204, 2769, 3825, 155, 1619, 2],
#  [502, 1180, 1204, 3029, 755, 3269, 2],
#  [839, 1139, 3503, 2],
#  [2557, 1981, 1950, 1594, 2],
#  [1877, 2090, 2],
#  [1877, 2090, 2],
#  [439, 2],
#  [1542, 3211, 174, 4429, 784, 718, 2],
#  [1204, 1981, 2],
#  [4405, 1871, 1484, 387, 3595, 555, 1515, 2],
#  [1139, 1184, 1209, 2309, 121, 2],
#  [2402, 3587, 502, 591, 111, 4067, 1016, 2],
#  [1209, 1949, 1950, 3653, 3567, 839, 1586, 2420, 2],
#  [1950, 155, 3595, 301, 2],
#  [2811, 3899, 755, 92, 3025, 2],
#  [4405, 2],
#  [4349, 3045, 2],
#  [1209, 1949, 1139, 967, 1185, 755, 3269, 2],
#  [3595, 2919, 2],
#  [3595, 1993, 4495, 2],
#  [1877, 2484, 1780, 755, 2511, 502, 2],
#  [1484, 1331, 2],
#  [275, 3269, 3518, 353, 1204, 1209, 2],
#  [4272, 384, 755, 711, 2484, 2685, 2],
#  [3825, 249, 2],
#  [1484, 1024, 3006, 1539, 2242, 2],
#  [1484, 3830, 1204, 2769, 1484, 4483, 3269, 2],
#  [839, 1484, 3830, 1204, 1634, 755, 7, 2495, 2],
#  [2997, 2731, 1619, 2],
#  [2557, 2],
#  [2557, 2],
#  [2761, 3542, 2731, 1619, 2],
#  [1340, 155, 502, 2997, 502, 2420, 2893, 2],
#  [967, 3595, 4529, 1649, 1304, 3587, 1665, 2],
#  [1139, 3595, 3867, 1139, 3595, 1936, 3867, 2],
#  [2466, 2],
#  [3226, 2309, 502, 2],
#  [4160, 1209, 3825, 3886, 784, 2646, 2],
#  [1034, 1209, 2],
#  [734, 4349, 2],
#  [2420, 3543, 1877, 3039, 86, 2663, 2],
#  [1209, 1949, 3192, 4279, 1386, 3825, 2],
#  [3543, 1877, 1139, 1805, 2],
#  [2022, 2],
#  [1139, 4118, 2],
#  [1696, 4190, 2],
#  [1209, 4483, 1764, 4057, 4483, 1204, 1209, 2],
#  [4486, 1204, 2],
#  [3120, 3077, 3192, 3595, 222, 2],
#  [1082, 1877, 2484, 4018, 2064, 784, 2836, 151, 2],
#  [307, 2],
#  [1834, 86, 1484, 2],
#  [270, 2],
#  [1484, 3179, 1204, 1024, 3226, 2484, 1782, 2],
#  [1139, 4542, 2],
#  [967, 3766, 3071, 1877, 1834, 2],
#  [1209, 387, 2565, 3989, 755, 1648, 1096, 1454, 2],
#  [86, 3533, 2],
#  [1950, 1486, 1204, 1949, 2],
#  [1950, 365, 384, 1204, 755, 3269, 201, 2],
#  [1209, 3943, 86, 2039, 1558, 502, 1180, 1799, 2],
#  [1139, 3830, 1209, 3607, 3192, 4067, 2],
#  [1484, 2811, 980, 1209, 755, 3269, 2],
#  [4349, 1209, 3179, 1209, 2666, 3830, 2],
#  [2563, 755, 2563, 2],
#  [1139, 3830, 1209, 1024, 3279, 3825, 2],
#  [1139, 387, 1209, 3587, 755, 3830, 1877, 502, 2],
#  [1484, 2252, 2823, 1640, 428, 2],
#  [3595, 178, 4085, 2],
#  [1139, 784, 502, 2],
#  [1139, 784, 502, 2],
#  [1950, 2811, 2476, 643, 1204, 3595, 1375, 2],
#  [1950, 1180, 3595, 2244, 1950, 1180, 3595, 2244, 2],
#  [1263, 1204, 1357, 2],
#  [2802, 2],
#  [1805, 1648, 2731, 2],
#  [4349, 270, 2],
#  [4349, 270, 2],
#  [419, 2325, 2],
#  [1262, 1209, 3533, 2],
#  [923, 853, 923, 2484, 4502, 1866, 3018, 3271, 2],
#  [1484, 3830, 1204, 2202, 3518, 155, 3595, 3342, 3174, 2],
#  [1209, 2101, 387, 3765, 524, 1456, 2],
#  [1484, 3830, 1204, 2769, 967, 1185, 2],
#  [4486, 1204, 2],
#  [1149, 1484, 3830, 1204, 1634, 755, 2],
#  [2565, 502, 155, 1204, 1599, 4067, 1399, 2],
#  [1599, 2484, 2201, 1375, 155, 1204, 502, 2],
#  [4487, 1649, 3644, 2],
#  [967, 1986, 1484, 1634, 755, 293, 3389, 2],
#  [1340, 4160, 1209, 2],
#  [2204, 3559, 2],
#  [1139, 4160, 1209, 1265, 201, 2],
#  [1484, 1484, 450, 1484, 451, 4247, 2],
#  [966, 3179, 1209, 2163, 3766, 201, 2],
#  [1209, 307, 3226, 528, 827, 2],
#  [1263, 2420, 2],
#  [1139, 4067, 2],
#  [1209, 3653, 353, 1204, 2823, 3192, 2],
#  [3653, 1204, 2],
#  [502, 1180, 4067, 1640, 438, 2],
#  [1139, 438, 755, 4520, 2],
#  [1304, 4337, 784, 1918, 2],
#  [1084, 1416, 1263, 3766, 2005, 155, 1204, 502, 2],
#  [1484, 931, 2],
#  [2484, 1579, 3689, 502, 3766, 2484, 1090, 2],
#  [2395, 3226, 3696, 2801, 2484, 2921, 1050, 2],
#  [2180, 104, 2],
#  [1098, 2],
#  [966, 2211, 1486, 502, 3607, 2],
#  [1484, 3830, 1204, 3969, 4619, 1484, 2811, 2163, 3389, 2],
#  [1263, 2484, 785, 2],
#  [1209, 3979, 2395, 2163, 502, 2],
#  [334, 3518, 1340, 4160, 1209, 2],
#  [966, 3830, 1209, 1949, 1640, 1750, 2],
#  [1599, 3595, 1542, 4564, 1750, 164, 1643, 2],
#  [86, 1139, 155, 3378, 1750, 2],
#  ...]

# %%
#bucketing threshold

buck_t1=long_threshold

'''
here just a threshold is implemented, so actually there is only one bucket. The code is structured in order
to easily add other buckets in the code if necessary
'''
#buck_t_n=max([len(x) for x in encoder_input_data]) 


b1_enc_in=[]  #bucket 1 encoder input
b1_dec_in=[]  #bucket 1 decoder input
b1_dec_out=[] #bucket 1 decoder output

for index in range(len(encoder_input_data)):
    if len(encoder_input_data[index])<=buck_t1:
        b1_enc_in.append(encoder_input_data[index])
        b1_dec_in.append(decoder_input_data[index])
        b1_dec_out.append(decoder_output_data[index])
        
b1_dec_out
# Out:
# [[1262, 1209, 1412, 4090, 3825, 353, 3269, 2],
#  [1209, 4160, 3595, 4253, 809, 387, 3595, 2988, 2],
#  [4486, 353, 1204, 1209, 439, 752, 960, 2],
#  [1139, 4160, 1209, 49, 2893, 1139, 1578, 2],
#  [966, 1694, 1374, 2],
#  [4025, 3424, 1095, 1771, 2],
#  [939, 3166, 2],
#  [2782, 1139, 2],
#  [2731, 1139, 3830, 1484, 2185, 1399, 2670, 2],
#  [2565, 4438, 2565, 985, 2],
#  [4551, 3192, 752, 2],
#  [1139, 2893, 1209, 2997, 3378, 2042, 3766, 1399, 2],
#  [2782, 2782, 1484, 4206, 2484, 671, 2],
#  [1263, 3989, 2],
#  [1134, 3588, 3892, 3825, 4333, 784, 1375, 2],
#  [4619, 1484, 293, 2],
#  [277, 4039, 4090, 3973, 2],
#  [1263, 2484, 123, 1640, 2926, 4273, 502, 2],
#  [1399, 4580, 1463, 2],
#  [1184, 1209, 4596, 2],
#  [1152, 3933, 2575, 2645, 2891, 4067, 3595, 2203, 2],
#  [2565, 387, 1209, 2],
#  [2627, 2565, 2293, 967, 3783, 2],
#  [1770, 4173, 293, 1708, 1637, 2],
#  [1152, 3250, 2997, 2484, 2381, 2],
#  [4596, 2],
#  [4349, 1933, 2],
#  [3949, 4596, 2160, 1933, 2],
#  [2997, 2484, 1165, 2],
#  [3726, 2309, 1209, 1933, 2],
#  [1749, 1209, 2],
#  [1798, 1583, 2],
#  [1484, 4102, 1209, 4160, 3989, 1484, 3006, 3830, 2],
#  [4160, 3518, 3020, 2778, 3949, 2],
#  [2666, 2557, 3769, 2484, 964, 2],
#  [2933, 4273, 2420, 3369, 2],
#  [2531, 502, 2],
#  [3886, 1933, 2],
#  [966, 1871, 3565, 155, 1399, 4067, 1209, 1489, 2],
#  [480, 2],
#  [1263, 4279, 3105, 502, 827, 3595, 2655, 2],
#  [3825, 2484, 3460, 4386, 2],
#  [3714, 524, 4027, 4293, 601, 784, 2484, 961, 2],
#  [2484, 2760, 3355, 3084, 2145, 387, 1366, 2],
#  [664, 3184, 4072, 3830, 502, 2],
#  [3031, 2027, 1578, 4222, 2964, 2],
#  [2793, 3607, 3261, 1770, 1160, 2],
#  [307, 2614, 3766, 2],
#  [2160, 2614, 3766, 1484, 1650, 1506, 3606, 2],
#  [4596, 2484, 2240, 155, 3313, 2],
#  [664, 3656, 3279, 3766, 3807, 1770, 293, 2],
#  [1599, 2981, 2],
#  [2189, 2411, 2],
#  [3765, 784, 4072, 2],
#  [405, 4160, 3378, 1578, 2523, 3766, 1292, 2],
#  [876, 4160, 3378, 3815, 1209, 387, 755, 3899, 2],
#  [2856, 3173, 502, 3595, 3979, 1184, 1209, 2],
#  [2997, 3411, 811, 4067, 2],
#  [1139, 3179, 1209, 1648, 2],
#  [4171, 4588, 1640, 954, 2122, 2],
#  [1139, 2893, 3192, 2],
#  [1484, 3830, 1204, 1634, 1209, 4067, 3595, 2122, 2],
#  [4486, 1204, 2],
#  [2982, 2933, 2],
#  [1209, 1633, 2],
#  [4153, 1640, 4308, 2],
#  [86, 4102, 755, 871, 2],
#  [2226, 2],
#  [2484, 3396, 1209, 1024, 2484, 2071, 1073, 2],
#  [4487, 3006, 2410, 4069, 2],
#  [1209, 2185, 3192, 1484, 954, 4295, 201, 2],
#  [1139, 155, 502, 2],
#  [1484, 3830, 1204, 1949, 2],
#  [865, 832, 2],
#  [2982, 3989, 697, 2484, 2475, 4591, 1254, 2],
#  [4588, 3989, 2],
#  [2731, 2],
#  [2697, 2484, 4127, 3223, 207, 3966, 2],
#  [2731, 2731, 2],
#  [307, 49, 791, 1035, 2],
#  [2777, 954, 1484, 1634, 3129, 4110, 2],
#  [1770, 293, 2726, 979, 752, 2],
#  [4071, 2],
#  [4032, 2],
#  [2176, 1965, 2801, 2],
#  [1847, 755, 3192, 3949, 2],
#  [3903, 3355, 755, 3269, 3766, 4019, 86, 315, 2],
#  [1770, 2163, 2484, 1749, 752, 784, 201, 2],
#  [1204, 3825, 789, 2484, 3058, 3765, 2],
#  [2163, 1918, 752, 784, 3518, 3830, 502, 1896, 2],
#  [3488, 2801, 3226, 3488, 2801, 2],
#  [1648, 1425, 2420, 1586, 4360, 2],
#  [1484, 1138, 1918, 755, 897, 2248, 2],
#  [2982, 3454, 1630, 3830, 2410, 2],
#  [3638, 2309, 502, 1235, 2694, 2],
#  [2028, 4222, 2352, 86, 633, 4160, 1204, 2933, 2203, 2],
#  [4486, 1204, 2],
#  [2656, 2],
#  [2782, 2656, 3888, 4072, 2],
#  [1209, 2106, 784, 3595, 2899, 2],
#  [2180, 2684, 3192, 2726, 3371, 4090, 2],
#  [2062, 1933, 2],
#  [4160, 1209, 743, 1209, 664, 2],
#  [1484, 450, 3113, 4160, 1204, 2321, 3989, 2],
#  [967, 400, 71, 2],
#  [2893, 3180, 3787, 2],
#  [2962, 2],
#  [2783, 2],
#  [3903, 1139, 155, 2796, 2],
#  [1484, 3830, 1204, 1634, 4562, 387, 1105, 3274, 2],
#  [4039, 400, 71, 2],
#  [4349, 3518, 4160, 4160, 1204, 3518, 2],
#  [4486, 3830, 2145, 2185, 3468, 3222, 3825, 2],
#  [3179, 3765, 784, 3578, 1454, 4533, 832, 3271, 2],
#  [1484, 3830, 1204, 1949, 71, 1263, 2484, 471, 2],
#  [2565, 502, 155, 3560, 3974, 2],
#  [3179, 1209, 2575, 387, 3595, 4270, 2],
#  [4349, 3595, 3468, 2200, 2],
#  [876, 155, 1950, 2],
#  [4015, 2],
#  [1209, 1024, 2933, 2],
#  [2180, 293, 1958, 2],
#  [4349, 3825, 723, 2],
#  [4483, 502, 3269, 4120, 2],
#  [1896, 3570, 3595, 1020, 2],
#  [400, 755, 2149, 1209, 2],
#  [1263, 502, 2156, 502, 572, 4306, 2],
#  [966, 2211, 1558, 502, 1809, 2],
#  [3113, 3587, 1626, 2],
#  [86, 502, 155, 4057, 3457, 755, 3488, 502, 3966, 2],
#  [2769, 784, 1139, 307, 3244, 2],
#  [2395, 293, 2],
#  [1139, 2],
#  [2156, 1209, 853, 2],
#  [2982, 3766, 2484, 226, 3288, 2],
#  [4273, 1640, 985, 2],
#  [1896, 1694, 2],
#  [3424, 3113, 3587, 979, 4413, 2],
#  [3741, 2163, 4072, 2],
#  [3424, 3424, 1204, 2],
#  [2997, 1399, 2],
#  [2782, 1304, 2864, 2],
#  [966, 3830, 1209, 1650, 2],
#  [1842, 502, 2],
#  [71, 71, 640, 2801, 2],
#  [1657, 876, 4160, 2],
#  [2541, 2180, 1160, 307, 3766, 1874, 2],
#  [1214, 1024, 2807, 95, 2],
#  [1484, 1949, 3974, 3192, 4057, 2],
#  [2484, 1664, 547, 2],
#  [3830, 502, 2],
#  [3570, 3595, 1289, 2401, 1949, 2893, 502, 2],
#  [1770, 3984, 2694, 2565, 786, 2],
#  [2145, 1059, 2484, 1366, 2],
#  [1599, 832, 2484, 961, 2],
#  [4487, 3226, 2356, 3192, 2],
#  [1599, 4119, 4118, 2],
#  [3226, 2163, 2248, 201, 2],
#  [2229, 4514, 3265, 2],
#  [2743, 2484, 785, 2],
#  [3180, 3265, 2],
#  [1770, 2163, 2177, 1454, 2123, 2],
#  [3113, 3179, 1204, 2204, 643, 2],
#  [2895, 3265, 2],
#  [2982, 3989, 4273, 4072, 2793, 966, 1209, 1265, 2],
#  [3897, 3265, 3608, 2],
#  [2176, 3269, 1263, 832, 2484, 3410, 2],
#  [1599, 3009, 3989, 4222, 2],
#  [839, 1209, 4160, 1204, 2356, 502, 3989, 2],
#  [3789, 3265, 3407, 1139, 2484, 1045, 2],
#  [2445, 692, 2484, 785, 2],
#  [4222, 2],
#  [1770, 293, 1770, 293, 2],
#  [3605, 3595, 2],
#  [4193, 2],
#  [3656, 2248, 2],
#  [3499, 4273, 1541, 1392, 2],
#  [3886, 293, 3174, 2],
#  [1399, 985, 3499, 4273, 3113, 4160, 1696, 3518, 2],
#  [71, 3570, 2],
#  [2565, 2565, 4588, 2226, 3113, 387, 755, 2],
#  [966, 1981, 4118, 2],
#  [3159, 280, 4201, 2],
#  [307, 1204, 2321, 2],
#  [4090, 2],
#  [1933, 3830, 1204, 3184, 2694, 3993, 2],
#  [3113, 3674, 1204, 1185, 1583, 2],
#  [3158, 2],
#  [2180, 3269, 2211, 3158, 2],
#  [1484, 949, 1209, 1184, 3499, 2],
#  [1209, 3179, 664, 3738, 2],
#  [839, 2783, 1484, 2],
#  [3115, 2],
#  [3989, 201, 4270, 3989, 201, 2],
#  [4160, 3113, 1185, 755, 1764, 1896, 2],
#  [1263, 3989, 2],
#  [2101, 3113, 704, 2],
#  [4349, 3974, 1484, 2769, 3113, 4133, 2101, 2],
#  [4279, 2185, 2484, 2107, 2],
#  [2297, 1209, 3993, 1918, 2],
#  [2763, 1890, 1342, 4273, 2484, 1245, 1494, 2],
#  [2293, 3160, 2],
#  [4107, 46, 1484, 1246, 1665, 3976, 3766, 1918, 2],
#  [1209, 1611, 1665, 1209, 1258, 1665, 2],
#  [3726, 2309, 3595, 2041, 784, 4336, 2396, 2],
#  [1263, 1139, 3113, 1492, 2],
#  [1858, 502, 3606, 2557, 1266, 2],
#  [3166, 2],
#  [4024, 3975, 3424, 2],
#  [579, 2145, 3134, 2],
#  [3311, 4344, 1139, 3830, 3113, 2185, 979, 2],
#  [3777, 2155, 1209, 387, 3587, 3518, 2],
#  [2783, 2],
#  [2204, 3963, 4487, 2385, 3766, 4509, 2],
#  [2783, 2],
#  [3160, 2],
#  [3606, 3730, 4273, 502, 2],
#  [664, 3173, 3192, 2484, 2942, 2],
#  [2271, 4472, 2258, 2472, 1425, 2],
#  [512, 2],
#  [1713, 3192, 3766, 3595, 381, 4067, 2258, 2555, 2],
#  [1139, 3830, 1209, 3680, 2],
#  [3595, 859, 790, 755, 955, 4273, 1640, 3343, 2],
#  [1599, 4273, 2484, 639, 2],
#  [3735, 2801, 3199, 2],
#  [3399, 502, 2],
#  [1152, 2107, 3141, 876, 1209, 1184, 3889, 755, 2],
#  [1204, 4057, 1981, 784, 2484, 2591, 3273, 1805, 2],
#  [155, 3825, 3595, 4078, 2],
#  [4190, 2],
#  [86, 4510, 3825, 2],
#  [3789, 4395, 703, 4273, 521, 2],
#  [954, 3789, 2],
#  [1139, 155, 1399, 4514, 2778, 2],
#  [1139, 155, 3825, 2],
#  [1466, 2203, 3342, 2],
#  [4586, 2],
#  [1634, 1665, 2],
#  [3020, 3215, 2602, 1688, 422, 2],
#  [3113, 1209, 1706, 4135, 752, 3518, 1877, 3192, 2],
#  [3886, 3830, 3192, 2116, 755, 1353, 1640, 3024, 2],
#  [3830, 1209, 2769, 2010, 3213, 4049, 2],
#  [2965, 2565, 833, 2565, 4071, 2557, 2],
#  [1599, 3595, 1282, 2],
#  [155, 502, 2933, 2],
#  [2782, 502, 155, 2618, 2],
#  [1484, 1138, 1209, 3113, 1139, 155, 3825, 2],
#  [684, 2323, 4619, 502, 155, 2779, 692, 2],
#  [1770, 2163, 2248, 86, 3077, 1399, 3766, 2],
#  [3570, 3595, 1289, 2],
#  [4039, 2203, 2],
#  [2359, 2],
#  [2392, 2],
#  [2782, 4271, 2298, 2],
#  [439, 752, 2484, 2611, 2],
#  [1304, 2052, 1632, 2],
#  [3714, 4273, 2],
#  [2997, 2484, 2687, 2],
#  [2433, 3825, 2],
#  [589, 2],
#  [1139, 3830, 1209, 1024, 2],
#  [2769, 1484, 620, 4057, 853, 2],
#  [2256, 2306, 2],
#  [2101, 1484, 88, 387, 1665, 2335, 1958, 2],
#  [3886, 2],
#  [3830, 1209, 2823, 2694, 2],
#  [86, 2],
#  [86, 2557, 2145, 1712, 752, 3226, 2618, 2],
#  [1139, 155, 502, 2],
#  [3830, 1209, 1634, 3595, 672, 2],
#  [4279, 2],
#  [2782, 2],
#  [1139, 3503, 2],
#  [2997, 1185, 4273, 2],
#  [393, 2484, 785, 2],
#  [1139, 155, 3825, 2],
#  [876, 1486, 3825, 4042, 755, 2],
#  [2402, 1712, 3825, 2336, 2],
#  [664, 2],
#  [2731, 1139, 3830, 1209, 2769, 2],
#  [3161, 2203, 3765, 4341, 1270, 2],
#  [3850, 755, 1139, 2],
#  [2696, 847, 2],
#  [2782, 2],
#  [2410, 4563, 2484, 838, 2],
#  [1484, 3076, 2],
#  [1152, 1526, 2],
#  [1139, 2],
#  [3607, 3595, 4222, 524, 1399, 2],
#  [3765, 784, 979, 999, 387, 3861, 2],
#  [4438, 2565, 985, 3595, 1944, 2787, 3825, 1653, 2],
#  [1263, 3595, 4078, 2],
#  [3817, 3570, 3595, 1289, 2],
#  [1139, 2],
#  [3226, 3587, 3595, 2356, 2],
#  [163, 502, 1185, 2],
#  [2782, 2116, 254, 755, 1209, 4057, 2],
#  [1209, 176, 994, 2484, 2674, 4057, 2],
#  [1139, 317, 2994, 2],
#  [1529, 3407, 4201, 2],
#  [3173, 3192, 3595, 424, 155, 2410, 83, 2],
#  [1209, 3587, 502, 2919, 2],
#  [1842, 502, 2203, 2],
#  [3161, 2696, 847, 2769, 784, 2484, 410, 2],
#  [1139, 2484, 2619, 4160, 1209, 1265, 2],
#  [2977, 664, 4222, 2],
#  [1139, 2],
#  [2395, 3499, 1877, 1209, 2],
#  [3454, 967, 1185, 4288, 2],
#  [643, 1209, 1648, 2444, 2],
#  [9, 784, 3825, 3100, 3518, 2],
#  [2782, 1484, 3587, 502, 2],
#  [2666, 3587, 2694, 2],
#  [3714, 502, 3714, 502, 2],
#  [2997, 2171, 2],
#  [967, 3735, 2801, 867, 453, 2],
#  [1139, 876, 2],
#  [3226, 315, 4072, 73, 755, 2484, 3989, 2],
#  [2176, 2156, 3595, 1375, 4160, 1209, 3886, 2],
#  [2782, 1484, 2],
#  [3570, 3294, 502, 2],
#  [966, 2],
#  [1484, 3076, 931, 3269, 3595, 105, 2],
#  [4039, 2203, 1263, 2565, 105, 2],
#  [1599, 2977, 502, 155, 4364, 2],
#  [155, 502, 2666, 673, 2],
#  [1139, 2],
#  [967, 752, 784, 3103, 2163, 832, 2163, 832, 2],
#  [2743, 2761, 1896, 2],
#  [2997, 990, 2],
#  [3980, 1262, 3359, 307, 697, 81, 2],
#  [307, 1139, 2],
#  [966, 1694, 784, 1918, 4160, 3518, 2],
#  [4057, 1694, 2],
#  [1263, 2484, 2171, 985, 2],
#  [1479, 3058, 4359, 1673, 2],
#  [2909, 502, 2801, 2],
#  [2180, 3570, 4067, 3192, 2],
#  [1599, 4057, 3457, 2],
#  [4493, 2],
#  [966, 1694, 966, 1694, 1578, 4160, 2986, 2],
#  [2997, 1833, 3673, 1919, 2],
#  [2181, 2],
#  [165, 3093, 3454, 3578, 2287, 4160, 4315, 2],
#  [3000, 2523, 2039, 755, 1918, 2],
#  [1204, 1906, 2],
#  [3830, 502, 2],
#  [2145, 3744, 752, 2484, 4162, 3936, 2],
#  [3638, 2309, 502, 2],
#  [3173, 70, 3607, 2],
#  [307, 1204, 3475, 2684, 502, 4160, 3113, 2],
#  [839, 3899, 2484, 3712, 2],
#  [4039, 2203, 2],
#  [1839, 1024, 2320, 1185, 907, 2],
#  [155, 1399, 2484, 1455, 2],
#  [940, 2],
#  [966, 1981, 1589, 387, 1484, 3587, 2],
#  [889, 2],
#  [3726, 46, 2],
#  [1139, 4486, 2],
#  [966, 4049, 4160, 2177, 1985, 2],
#  [4438, 2666, 4118, 755, 2631, 2],
#  [2783, 2],
#  [400, 3779, 820, 2852, 389, 2],
#  [4160, 1209, 2977, 2],
#  [1139, 2997, 2171, 1139, 155, 502, 2],
#  [876, 155, 1950, 2],
#  [544, 2801, 2484, 3208, 3759, 2],
#  [1484, 2052, 502, 2],
#  [86, 2],
#  [3005, 3989, 3340, 2484, 3208, 3759, 2],
#  [2163, 3271, 3313, 1896, 2],
#  [1484, 2252, 3258, 3271, 4057, 1981, 453, 2804, 2],
#  [711, 3981, 2],
#  [664, 3113, 4160, 3766, 864, 2],
#  [3989, 2181, 1209, 2420, 310, 2],
#  [664, 967, 752, 784, 201, 2],
#  [3947, 3578, 4494, 3953, 2],
#  [3454, 2],
#  [2041, 4341, 2027, 2],
#  [1139, 2101, 1484, 3830, 2],
#  [1484, 1484, 2176, 2],
#  [1209, 387, 755, 2],
#  [2565, 2],
#  [4486, 176, 1209, 2769, 1484, 1184, 1204, 3269, 2],
#  [1204, 524, 2420, 2],
#  [2372, 22, 2160, 3411, 155, 3595, 2310, 2],
#  [2160, 2484, 4189, 2],
#  [4039, 2565, 1484, 2156, 2484, 7, 2],
#  [1450, 3410, 1486, 1204, 3130, 1981, 1484, 2499, 2],
#  [967, 1185, 755, 3607, 1209, 755, 3025, 2],
#  [4039, 2565, 2],
#  [4588, 3587, 755, 1520, 1209, 2],
#  [3518, 155, 1204, 867, 2309, 1209, 3518, 4483, 1204, 3269, 2],
#  [3973, 334, 1636, 2],
#  [966, 1180, 2484, 3840, 2],
#  [3957, 2],
#  [1746, 3689, 1209, 3595, 3342, 2],
#  [2565, 2783, 65, 2],
#  [502, 1180, 3311, 4093, 2145, 1330, 4273, 2],
#  [1484, 2811, 1855, 3311, 4093, 2],
#  [3825, 1180, 985, 2248, 2],
#  [1209, 3680, 300, 3576, 2],
#  [690, 1665, 2],
#  [2484, 2201, 4325, 2],
#  [784, 1001, 2],
#  [3025, 1486, 1204, 7, 3595, 198, 65, 2],
#  [1599, 2484, 4049, 1046, 3825, 1486, 502, 2],
#  [4159, 1640, 3754, 3468, 913, 2],
#  [4440, 1896, 2],
#  [202, 502, 2484, 471, 2],
#  [2982, 3378, 3711, 3378, 373, 2],
#  [2402, 1139, 2],
#  [4588, 3226, 907, 2484, 785, 2],
#  [2484, 2326, 2],
#  [1484, 1492, 1209, 1184, 1067, 2893, 3192, 2],
#  [1204, 524, 2420, 3025, 1399, 155, 2325, 3559, 2],
#  [966, 3830, 1209, 3830, 1640, 3045, 2],
#  [4039, 3504, 2],
#  [334, 2204, 3931, 2],
#  [1640, 4290, 2],
#  [334, 2204, 3559, 2],
#  [966, 3830, 1209, 3830, 164, 2939, 2],
#  [4039, 3504, 2],
#  [2204, 3948, 2],
#  [3045, 65, 2355, 1209, 3213, 3966, 2204, 2085, 2],
#  [3559, 2],
#  [967, 2731, 400, 3559, 2355, 1209, 3213, 3966, 2],
#  [2565, 1262, 1209, 4349, 1304, 1617, 2036, 4082, 2],
#  [766, 2309, 643, 2204, 3931, 1855, 2],
#  [1184, 1209, 3006, 966, 939, 2],
#  [784, 1001, 502, 155, 2],
#  [3401, 4551, 2893, 502, 2],
#  [3518, 4160, 3058, 3538, 2],
#  [4619, 1484, 954, 949, 966, 2],
#  [3899, 2],
#  [839, 2],
#  [3334, 2],
#  [3179, 1209, 2156, 502, 201, 3766, 300, 1608, 2],
#  [2325, 4486, 3830, 1204, 1209, 1726, 524, 2484, 2562, 2],
#  [1204, 524, 2420, 2],
#  [1262, 1209, 2731, 1981, 2],
#  [364, 3192, 3595, 4529, 86, 1484, 931, 387, 2],
#  [2372, 2],
#  [2372, 2],
#  [954, 3766, 1665, 4359, 4487, 758, 2],
#  [967, 3595, 879, 4572, 2],
#  [2372, 2],
#  [4408, 2],
#  [1399, 155, 2325, 3559, 2],
#  [4151, 80, 3192, 1484, 3071, 3595, 1440, 2],
#  [334, 1139, 155, 3378, 1750, 2],
#  [2325, 2325, 3559, 2],
#  [2402, 3606, 2940, 2],
#  [876, 2],
#  [3989, 201, 3595, 1289, 4150, 2],
#  [1263, 3777, 2],
#  [1950, 4057, 155, 3595, 46, 587, 784, 712, 2],
#  [2566, 2420, 1399, 3614, 3766, 3226, 3765, 3410, 2],
#  [4487, 1204, 1185, 4160, 1209, 2],
#  [2565, 3830, 1204, 293, 2],
#  [839, 4619, 967, 1204, 3766, 2484, 985, 2],
#  [1484, 353, 1204, 3269, 3595, 1289, 2],
#  [2116, 3215, 3845, 2],
#  [1017, 3830, 1204, 3680, 2116, 3215, 1484, 3830, 2],
#  [2395, 3269, 524, 2484, 4294, 3656, 2646, 404, 2],
#  [1204, 3226, 3825, 985, 923, 3595, 2122, 2],
#  [766, 2309, 3825, 2],
#  [1599, 2645, 3595, 1466, 2276, 2325, 2],
#  [1484, 4102, 2731, 164, 2939, 2116, 1693, 2],
#  [1209, 3971, 1922, 4201, 275, 2811, 2684, 502, 2],
#  [4486, 2],
#  [1484, 3226, 3141, 2],
#  [3226, 3141, 1139, 2],
#  [4486, 2],
#  [4486, 1139, 2],
#  [4486, 1209, 387, 755, 293, 752, 3518, 2],
#  [1484, 3830, 1204, 387, 755, 1484, 1634, 755, 2],
#  [155, 502, 2484, 3976, 2],
#  [1075, 1894, 784, 502, 353, 293, 4067, 707, 2],
#  [1484, 3226, 2164, 3595, 1934, 1165, 2],
#  [3454, 3023, 1209, 999, 1204, 37, 3518, 2],
#  [1599, 954, 3765, 2658, 889, 2],
#  [2731, 2737, 3499, 2248, 2],
#  [1484, 3011, 3348, 616, 2494, 2036, 402, 2],
#  [1082, 270, 1643, 2],
#  [2036, 3867, 2],
#  [1209, 3179, 1204, 387, 755, 2185, 3192, 2],
#  [4574, 1640, 2461, 2],
#  [2176, 711, 4250, 1363, 1630, 1640, 3024, 2],
#  [2309, 3595, 2507, 4129, 3382, 2],
#  [1836, 2484, 1578, 3587, 3378, 1074, 2],
#  [2156, 1209, 3389, 2],
#  [2406, 2],
#  [784, 1001, 1204, 2],
#  [4588, 168, 3595, 2200, 3825, 469, 1750, 2],
#  [2325, 766, 1067, 2145, 1078, 3825, 985, 2],
#  [1484, 1138, 3271, 1484, 1127, 1630, 2],
#  [3607, 3969, 784, 1844, 752, 3518, 2],
#  [2372, 2],
#  [4408, 2],
#  [2180, 2163, 2953, 4273, 1665, 1899, 3875, 2],
#  [2395, 3899, 2],
#  [4006, 2252, 3269, 2689, 736, 2],
#  [86, 1059, 3825, 752, 3989, 1896, 2],
#  [923, 784, 1399, 1875, 1209, 4160, 3789, 3679, 4294, 2],
#  [2901, 164, 22, 2],
#  [1019, 3192, 3595, 3204, 2],
#  [3077, 3192, 3160, 1209, 2163, 3766, 2],
#  [1139, 1425, 2],
#  [839, 4616, 3406, 86, 338, 353, 3269, 338, 2],
#  [2410, 3424, 1078, 3595, 4325, 268, 2],
#  [839, 1209, 387, 1858, 2731, 1981, 1139, 155, 300, 2],
#  [2145, 4160, 23, 1034, 2145, 23, 65, 2],
#  [2565, 1874, 524, 2420, 2],
#  [315, 3766, 3378, 2773, 966, 1981, 2],
#  [1484, 387, 1204, 3587, 3595, 1485, 967, 2609, 1607, 2],
#  [910, 2],
#  [334, 2],
#  [3077, 1139, 3077, 2],
#  [502, 1399, 3549, 2204, 3025, 3931, 2],
#  [1263, 3989, 3454, 1484, 3830, 1204, 526, 2],
#  [1484, 3524, 2],
#  [293, 509, 1958, 2],
#  [1139, 3595, 577, 1538, 1375, 755, 3830, 2],
#  [2372, 387, 1484, 4015, 1036, 2372, 2],
#  [4487, 1640, 2200, 4160, 1204, 1209, 2],
#  [3825, 1484, 3674, 2],
#  [1805, 1209, 4160, 1036, 2],
#  [3160, 3160, 4160, 1209, 2614, 2248, 2],
#  [1209, 3766, 3595, 2909, 2],
#  [1826, 502, 2],
#  [2372, 2372, 502, 155, 3378, 2255, 2],
#  [263, 2255, 1636, 2],
#  [1694, 263, 1969, 784, 2484, 3867, 2],
#  [1484, 2163, 3595, 422, 3830, 1204, 1484, 2],
#  [1950, 3179, 2],
#  [2782, 1484, 353, 2],
#  [966, 155, 2325, 664, 2],
#  [664, 2],
#  [1484, 3071, 1209, 2],
#  [2395, 439, 1877, 2325, 2],
#  [1139, 2],
#  [1484, 3071, 1209, 4057, 2116, 1693, 1636, 2],
#  [2156, 1209, 2],
#  [65, 2],
#  [1822, 2],
#  [1209, 3830, 1204, 2309, 2325, 3830, 1209, 2],
#  [3830, 1209, 1634, 271, 4185, 70, 271, 2386, 2],
#  [271, 2386, 2],
#  [2565, 2],
#  [4486, 1204, 2],
#  [1896, 1209, 1634, 271, 4185, 2],
#  [1950, 185, 602, 2],
#  [1693, 271, 3867, 2],
#  [4588, 3754, 86, 1815, 2],
#  [2309, 271, 4543, 1877, 3765, 3513, 2],
#  [1950, 652, 954, 4067, 3192, 1486, 1204, 1950, 2],
#  [966, 3830, 1209, 1024, 3825, 2],
#  [1304, 3587, 502, 2],
#  [3989, 201, 2],
#  [1263, 1640, 2714, 2156, 1209, 524, 1213, 4118, 2],
#  [4039, 3456, 86, 1484, 3805, 755, 2185, 1209, 2],
#  [4349, 3045, 1209, 3805, 2420, 2893, 502, 2],
#  [3023, 2],
#  [2019, 2939, 2],
#  [3533, 2],
#  [1209, 1634, 755, 3269, 1679, 300, 4077, 2],
#  [2484, 364, 999, 293, 4273, 2],
#  [3830, 1209, 2769, 2204, 3931, 1184, 2031, 2],
#  [1484, 2769, 1950, 1184, 533, 2],
#  [3454, 164, 2939, 86, 164, 22, 2],
#  [3741, 3830, 923, 2145, 4160, 1138, 2],
#  [784, 1001, 2],
#  [1209, 353, 1204, 1842, 502, 2],
#  [1484, 353, 1204, 1842, 2],
#  [3454, 1950, 3226, 3587, 201, 2],
#  [1139, 3179, 1209, 1991, 2073, 1178, 2],
#  [1399, 2386, 661, 3192, 3595, 843, 1894, 2],
#  [4349, 4349, 502, 1486, 2],
#  [967, 400, 1484, 3179, 1204, 1024, 755, 2],
#  [3025, 3006, 2],
#  [966, 2893, 3885, 502, 3595, 1693, 2],
#  [1599, 3595, 2116, 1492, 2],
#  [502, 353, 1204, 7, 2],
#  [263, 3468, 210, 2],
#  [1059, 502, 752, 2],
#  [4551, 4551, 2],
#  [1896, 3184, 4072, 1204, 2163, 3340, 3595, 2323, 1727, 2],
#  [4619, 1209, 1184, 2309, 2],
#  [1484, 1184, 1204, 2309, 2],
#  [2614, 2],
#  [3766, 3595, 1289, 2],
#  [86, 4057, 1694, 784, 1918, 4160, 4241, 2],
#  [1770, 293, 3213, 3279, 2484, 460, 2],
#  [2565, 2325, 1484, 353, 1204, 1842, 2],
#  [1209, 2420, 592, 4498, 2],
#  [3457, 4067, 1139, 2],
#  [2180, 3269, 1510, 2484, 422, 2],
#  [766, 2309, 755, 4551, 502, 2],
#  [784, 1001, 2],
#  [1484, 1492, 1209, 307, 1185, 755, 3269, 3457, 2],
#  [3160, 967, 713, 784, 109, 2],
#  [1484, 4568, 2565, 3001, 1209, 307, 111, 201, 2],
#  [3825, 2811, 3327, 1209, 4510, 2],
#  [4588, 3595, 2200, 784, 2731, 1694, 470, 2],
#  [1599, 3595, 1572, 1956, 4221, 2177, 3787, 2],
#  [4588, 3595, 2200, 784, 2731, 1694, 1956, 55, 2],
#  [2731, 1950, 3355, 2],
#  [1484, 3830, 1204, 2769, 3825, 155, 1619, 2],
#  [4514, 4201, 2],
#  [2659, 4201, 4027, 4201, 1139, 784, 502, 2],
#  [4067, 342, 1139, 2],
#  [4067, 342, 1209, 2],
#  [2504, 2],
#  [1139, 2893, 3271, 4470, 1139, 2893, 3271, 4257, 2],
#  [1871, 1484, 387, 3378, 2461, 2],
#  [2180, 104, 1484, 2101, 3607, 502, 2801, 598, 2],
#  [1958, 2],
#  [166, 2731, 1694, 1009, 55, 2],
#  [967, 2731, 263, 1209, 4160, 263, 2],
#  [966, 2893, 3192, 1139, 2],
#  [44, 1209, 203, 2933, 1139, 2893, 3378, 1441, 2],
#  [1484, 3674, 1204, 3475, 871, 1204, 1877, 3595, 994, 2],
#  [2557, 3006, 2],
#  [1139, 155, 3411, 49, 2893, 2],
#  [890, 2],
#  [1484, 3830, 1204, 966, 3830, 1209, 3830, 2],
#  [3113, 2811, 2940, 1263, 4486, 2],
#  [2116, 254, 164, 1643, 2],
#  [1484, 4568, 2565, 3001, 1209, 949, 881, 3058, 2],
#  [1263, 966, 1209, 2940, 3192, 3766, 4606, 2],
#  [3113, 387, 3825, 3766, 2925, 2],
#  [1805, 1209, 3779, 999, 387, 3595, 2211, 1847, 2],
#  [4486, 3830, 2145, 4083, 4222, 2309, 74, 2638, 2],
#  [2076, 2],
#  [4142, 2],
#  [1484, 3226, 1855, 502, 2],
#  [7, 502, 1425, 2],
#  [3454, 3825, 1180, 2484, 4561, 3568, 4118, 2],
#  [2565, 4487, 3226, 1036, 2893, 4142, 2],
#  [4142, 2],
#  [3057, 1209, 1650, 4341, 2102, 1201, 3595, 2554, 2],
#  [1209, 1949, 2557, 2893, 3511, 2102, 70, 4194, 2],
#  [2565, 4308, 755, 790, 2],
#  [2204, 2910, 1139, 2],
#  [2669, 2484, 1157, 2],
#  [3595, 2041, 784, 3055, 2],
#  [1184, 1209, 2],
#  [643, 755, 80, 1209, 752, 2836, 2],
#  [1399, 155, 1466, 3639, 1484, 2433, 502, 2],
#  [2420, 1209, 3587, 755, 3830, 155, 1750, 502, 2],
#  [3173, 2325, 3559, 2714, 3766, 1209, 2843, 2],
#  [1209, 2163, 2642, 4382, 3830, 1204, 1209, 2],
#  [3454, 1139, 4483, 1950, 3830, 2],
#  [839, 2],
#  [1633, 2],
#  [1484, 1633, 2],
#  [1263, 1640, 2836, 2],
#  [876, 155, 1950, 2],
#  [2801, 3766, 2484, 3410, 2],
#  [4216, 3174, 752, 3518, 2],
#  [3160, 1209, 3830, 3184, 3192, 3766, 4273, 502, 2],
#  [1484, 353, 2],
#  [163, 2484, 300, 3765, 2614, 2],
#  [2484, 7, 2420, 3989, 1484, 450, 2],
#  [2495, 4588, 2666, 3595, 2200, 784, 4514, 2],
#  [1093, 502, 155, 1204, 3051, 2],
#  [966, 3830, 1209, 1024, 2],
#  [2180, 3269, 3539, 2],
#  [3025, 1209, 387, 1204, 3587, 3020, 4433, 2],
#  [2484, 4033, 1722, 3113, 1648, 2692, 2],
#  [1649, 2632, 2395, 755, 3271, 2624, 2],
#  [3387, 384, 3378, 4077, 2],
#  [2325, 1640, 4077, 2],
#  [2020, 1209, 1949, 2],
#  [784, 1001, 1484, 949, 2],
#  [502, 3226, 3405, 3378, 1445, 2],
#  [966, 966, 1180, 2204, 2910, 2],
#  [734, 1484, 3830, 1204, 1331, 2],
#  [3226, 3405, 3378, 1445, 2],
#  [1180, 1950, 3825, 476, 2],
#  [1484, 3607, 502, 1950, 3011, 839, 2],
#  [966, 3777, 2],
#  [3766, 4118, 1950, 353, 3269, 1139, 1209, 4160, 2],
#  [1820, 4279, 1640, 3045, 2],
#  [334, 2204, 3931, 2],
#  [1599, 2420, 73, 2],
#  [2997, 2420, 73, 2],
#  [2484, 1157, 2],
#  [4588, 3378, 4077, 2],
#  [3006, 2325, 4486, 2],
#  [4486, 1204, 2],
#  [1139, 3476, 86, 3824, 2],
#  [1209, 1184, 1204, 526, 966, 1180, 2204, 2910, 2],
#  [2272, 387, 2645, 2357, 784, 3271, 2],
#  [967, 3886, 2],
#  [1950, 1180, 3595, 354, 2],
#  [755, 1209, 4057, 2],
#  [1139, 3830, 1209, 1024, 2],
#  [1263, 230, 2484, 3261, 2],
#  [270, 2],
#  [2731, 170, 784, 1504, 3476, 86, 3824, 2],
#  [1204, 347, 2811, 347, 4619, 643, 773, 2],
#  [1484, 2811, 3971, 502, 1180, 2],
#  [4160, 1209, 687, 2484, 4214, 2],
#  [2386, 1640, 1165, 2],
#  [1484, 3179, 1204, 4551, 1209, 2],
#  [1484, 3971, 967, 3595, 686, 2203, 2],
#  [1340, 2],
#  [2484, 1010, 1772, 2],
#  [4015, 2],
#  [1484, 999, 387, 3788, 3271, 3406, 2],
#  [1484, 1184, 1204, 3269, 802, 15, 1209, 2013, 3192, 2],
#  [1484, 1678, 1139, 1484, 2309, 2],
#  [664, 1678, 2],
#  [1139, 3595, 816, 1139, 3595, 2604, 2],
#  [2484, 749, 3443, 2484, 2063, 73, 1527, 3966, 2],
#  [1484, 353, 1204, 1527, 3966, 2],
#  [2180, 1527, 3966, 2],
#  [4487, 1649, 1729, 3206, 4160, 1204, 1209, 2],
#  [967, 3981, 1729, 602, 2],
#  [201, 3113, 293, 2],
#  [1896, 3830, 1204, 2163, 3026, 3406, 2],
#  [2402, 2645, 2420, 1637, 3825, 1877, 1834, 2],
#  [4187, 2],
#  [1599, 1807, 1209, 4160, 1204, 3595, 913, 2],
#  [1304, 2645, 627, 784, 3825, 4067, 1665, 4118, 2],
#  [839, 1484, 3674, 2],
#  [2395, 1648, 2],
#  [2180, 3269, 3672, 2],
#  [3025, 3184, 4072, 2684, 963, 2],
#  [2484, 3958, 4160, 4057, 3531, 3392, 1908, 2],
#  [1599, 1204, 1982, 2],
#  [1484, 3996, 502, 307, 2],
#  [3825, 3412, 4393, 2484, 1467, 1375, 84, 2],
#  [1834, 1139, 3503, 2],
#  [3025, 1425, 2],
#  [1263, 4273, 4118, 4067, 3025, 2],
#  [1599, 3226, 1076, 1950, 2020, 2],
#  [3830, 1204, 4630, 752, 784, 3749, 3045, 2],
#  [3025, 3000, 1204, 1858, 4274, 3279, 502, 2],
#  [1599, 1185, 755, 3269, 3595, 2958, 1631, 2],
#  [1139, 155, 2],
#  [1139, 4118, 155, 502, 2],
#  [963, 86, 1216, 155, 4067, 3427, 2],
#  [1834, 3269, 9, 2],
#  [3533, 86, 1484, 3226, 3830, 1204, 1634, 271, 1677, 2],
#  [3895, 2],
#  [966, 1981, 4118, 387, 3113, 2],
#  [1114, 3031, 4201, 2],
#  [966, 722, 755, 2484, 3292, 2],
#  [4432, 70, 4190, 3195, 2],
#  [275, 232, 3378, 1659, 4273, 3825, 3065, 2],
#  [2180, 2712, 2893, 1096, 1454, 2],
#  [1262, 1209, 1834, 2187, 2],
#  [3830, 1209, 1634, 502, 4273, 2],
#  [502, 1486, 1204, 3770, 2],
#  [1484, 2720, 1385, 4244, 2],
#  [3533, 1484, 387, 1204, 2645, 2111, 1399, 1631, 2],
#  [2288, 2420, 4111, 3595, 3468, 1279, 3323, 2],
#  [4487, 3025, 3226, 3025, 2],
#  [1139, 2893, 2372, 2],
#  [1139, 2893, 2372, 2],
#  [2160, 3766, 3071, 1877, 1209, 2],
#  [4486, 176, 3411, 86, 4486, 176, 1209, 2],
#  [1204, 755, 1209, 1204, 755, 2372, 2],
#  [3960, 3825, 1139, 2145, 4083, 1648, 2],
#  [839, 2],
#  [2893, 1139, 2],
#  [4160, 1209, 2357, 784, 3192, 2372, 2],
#  [1209, 176, 1204, 387, 4568, 3020, 4091, 2],
#  [155, 3825, 1139, 1209, 1634, 3192, 755, 3269, 2],
#  [967, 49, 2893, 1209, 86, 1139, 1209, 1634, 2],
#  [2731, 3674, 1484, 2],
#  [1139, 387, 1484, 3587, 755, 3830, 1877, 502, 2],
#  [2761, 2],
#  [2180, 4630, 3406, 2372, 2],
#  [3769, 1139, 1184, 1484, 3269, 1134, 2],
#  [967, 4067, 502, 2],
#  [3378, 3002, 3595, 3468, 764, 2],
#  [86, 4067, 1209, 2],
#  [4487, 168, 3595, 2200, 2],
#  [1209, 2769, 2],
#  [967, 3766, 3071, 1877, 3025, 2437, 1209, 4337, 2],
#  [1209, 4551, 2420, 4403, 784, 1454, 2],
#  [3733, 752, 2],
#  [1871, 1484, 3499, 3766, 2],
#  [660, 164, 1643, 2],
#  [1484, 1689, 598, 1724, 2145, 3179, 1204, 2599, 1454, 2],
#  [1958, 3830, 2],
#  [502, 3680, 1204, 3269, 2],
#  [1484, 3674, 4271, 2],
#  [967, 1204, 384, 4067, 3595, 584, 2],
#  [1263, 3989, 2],
#  [4349, 1484, 3830, 2],
#  [4349, 2484, 98, 2],
#  [1198, 2],
#  [1198, 1139, 2],
#  [1209, 3607, 1433, 2],
#  [1484, 2823, 1484, 353, 2],
#  [1950, 1180, 3709, 2],
#  [1805, 1209, 387, 4337, 4057, 2],
#  [1484, 1180, 3518, 271, 3388, 2],
#  [3595, 263, 1003, 2],
#  [307, 4439, 449, 1877, 3595, 3086, 262, 1376, 2],
#  [2145, 660, 3830, 1204, 3984, 1981, 4118, 2],
#  [3025, 2],
#  [3025, 3104, 3766, 3368, 2],
#  [1950, 1871, 3269, 1164, 1386, 1209, 2769, 2],
#  [1484, 3226, 2252, 2823, 502, 2],
#  [1484, 2252, 2823, 2325, 3971, 3578, 1454, 2],
#  [1834, 1755, 502, 155, 3595, 2784, 535, 2],
#  [3424, 3226, 3595, 3468, 827, 2484, 2870, 2],
#  [2297, 1209, 2163, 2420, 3825, 505, 2],
#  [2325, 2],
#  [2325, 2],
#  [3825, 1180, 3595, 221, 2],
#  [1484, 4608, 4486, 2],
#  [1263, 168, 3595, 2788, 784, 3365, 2],
#  [967, 3981, 602, 755, 1169, 1209, 2],
#  [967, 2562, 755, 2857, 2801, 2],
#  [4619, 3113, 4483, 2210, 502, 1751, 3825, 155, 2],
#  [1896, 1209, 4160, 2719, 270, 70, 2325, 2],
#  [2325, 1184, 4571, 3153, 755, 3173, 3271, 969, 2],
#  [1877, 1756, 784, 1001, 2],
#  [1896, 3226, 3595, 1289, 2],
#  [1896, 3226, 3595, 1289, 2],
#  [967, 3746, 3124, 2248, 2],
#  [4235, 871, 3224, 881, 3058, 2],
#  [1096, 923, 2],
#  [4551, 4551, 2],
#  [3411, 1486, 1204, 594, 1484, 1180, 2116, 2],
#  [1209, 307, 46, 2],
#  [4057, 476, 2],
#  [755, 3025, 755, 1640, 3758, 2],
#  [819, 1530, 2],
#  [839, 784, 2420, 2],
#  [3025, 2],
#  [3160, 3160, 4160, 1209, 1185, 755, 3830, 502, 2],
#  [4349, 4596, 2],
#  [1139, 4160, 1209, 1185, 755, 1483, 2],
#  [2410, 1934, 3595, 2023, 2461, 73, 3595, 1286, 2],
#  [1586, 2420, 3424, 1950, 3226, 2813, 755, 1212, 2],
#  [839, 2420, 3989, 2],
#  [1484, 1180, 2741, 1453, 1209, 1184, 3499, 524, 2420, 2],
#  [1484, 3830, 1204, 108, 755, 3269, 2],
#  [2176, 3113, 3213, 3966, 3226, 4067, 3595, 1289, 2],
#  [3518, 2252, 3269, 1542, 1981, 2],
#  [4039, 3454, 3518, 155, 2],
#  [4486, 176, 1204, 1209, 1958, 3213, 3966, 2],
#  [1770, 1204, 2163, 2588, 2],
#  [2325, 3830, 1204, 836, 2],
#  [967, 1204, 2012, 2],
#  [3454, 2484, 1431, 2893, 3378, 4082, 2],
#  [271, 1281, 4082, 2],
#  [2160, 1204, 1640, 2122, 1209, 307, 1640, 3729, 2],
#  [3411, 2101, 80, 1209, 2],
#  [2395, 2811, 2163, 73, 502, 2],
#  [1484, 3996, 1484, 4483, 2823, 3825, 2],
#  [1484, 2769, 1484, 1949, 2],
#  [2410, 2608, 3051, 1209, 2101, 3830, 2],
#  [1209, 1847, 3226, 923, 270, 3971, 1209, 3179, 2],
#  [270, 2813, 3192, 755, 7, 502, 2],
#  [73, 1640, 2933, 816, 2],
#  [3190, 2],
#  [3226, 1665, 1004, 2],
#  [967, 1204, 802, 1586, 2420, 3825, 971, 1047, 2],
#  [3226, 2309, 3825, 1624, 2],
#  [3226, 2309, 3825, 2],
#  [1484, 3830, 1204, 2769, 3825, 155, 1619, 2],
#  [502, 1180, 1204, 3029, 755, 3269, 2],
#  [839, 1139, 3503, 2],
#  [2557, 1981, 1950, 1594, 2],
#  [1877, 2090, 2],
#  [1877, 2090, 2],
#  [439, 2],
#  [1542, 3211, 174, 4429, 784, 718, 2],
#  [1204, 1981, 2],
#  [4405, 1871, 1484, 387, 3595, 555, 1515, 2],
#  [1139, 1184, 1209, 2309, 121, 2],
#  [2402, 3587, 502, 591, 111, 4067, 1016, 2],
#  [1209, 1949, 1950, 3653, 3567, 839, 1586, 2420, 2],
#  [1950, 155, 3595, 301, 2],
#  [2811, 3899, 755, 92, 3025, 2],
#  [4405, 2],
#  [4349, 3045, 2],
#  [1209, 1949, 1139, 967, 1185, 755, 3269, 2],
#  [3595, 2919, 2],
#  [3595, 1993, 4495, 2],
#  [1877, 2484, 1780, 755, 2511, 502, 2],
#  [1484, 1331, 2],
#  [275, 3269, 3518, 353, 1204, 1209, 2],
#  [4272, 384, 755, 711, 2484, 2685, 2],
#  [3825, 249, 2],
#  [1484, 1024, 3006, 1539, 2242, 2],
#  [1484, 3830, 1204, 2769, 1484, 4483, 3269, 2],
#  [839, 1484, 3830, 1204, 1634, 755, 7, 2495, 2],
#  [2997, 2731, 1619, 2],
#  [2557, 2],
#  [2557, 2],
#  [2761, 3542, 2731, 1619, 2],
#  [1340, 155, 502, 2997, 502, 2420, 2893, 2],
#  [967, 3595, 4529, 1649, 1304, 3587, 1665, 2],
#  [1139, 3595, 3867, 1139, 3595, 1936, 3867, 2],
#  [2466, 2],
#  [3226, 2309, 502, 2],
#  [4160, 1209, 3825, 3886, 784, 2646, 2],
#  [1034, 1209, 2],
#  [734, 4349, 2],
#  [2420, 3543, 1877, 3039, 86, 2663, 2],
#  [1209, 1949, 3192, 4279, 1386, 3825, 2],
#  [3543, 1877, 1139, 1805, 2],
#  [2022, 2],
#  [1139, 4118, 2],
#  [1696, 4190, 2],
#  [1209, 4483, 1764, 4057, 4483, 1204, 1209, 2],
#  [4486, 1204, 2],
#  [3120, 3077, 3192, 3595, 222, 2],
#  [1082, 1877, 2484, 4018, 2064, 784, 2836, 151, 2],
#  [307, 2],
#  [1834, 86, 1484, 2],
#  [270, 2],
#  [1484, 3179, 1204, 1024, 3226, 2484, 1782, 2],
#  [1139, 4542, 2],
#  [967, 3766, 3071, 1877, 1834, 2],
#  [1209, 387, 2565, 3989, 755, 1648, 1096, 1454, 2],
#  [86, 3533, 2],
#  [1950, 1486, 1204, 1949, 2],
#  [1950, 365, 384, 1204, 755, 3269, 201, 2],
#  [1209, 3943, 86, 2039, 1558, 502, 1180, 1799, 2],
#  [1139, 3830, 1209, 3607, 3192, 4067, 2],
#  [1484, 2811, 980, 1209, 755, 3269, 2],
#  [4349, 1209, 3179, 1209, 2666, 3830, 2],
#  [2563, 755, 2563, 2],
#  [1139, 3830, 1209, 1024, 3279, 3825, 2],
#  [1139, 387, 1209, 3587, 755, 3830, 1877, 502, 2],
#  [1484, 2252, 2823, 1640, 428, 2],
#  [3595, 178, 4085, 2],
#  [1139, 784, 502, 2],
#  [1139, 784, 502, 2],
#  [1950, 2811, 2476, 643, 1204, 3595, 1375, 2],
#  [1950, 1180, 3595, 2244, 1950, 1180, 3595, 2244, 2],
#  [1263, 1204, 1357, 2],
#  [2802, 2],
#  [1805, 1648, 2731, 2],
#  [4349, 270, 2],
#  [4349, 270, 2],
#  [419, 2325, 2],
#  [1262, 1209, 3533, 2],
#  [923, 853, 923, 2484, 4502, 1866, 3018, 3271, 2],
#  [1484, 3830, 1204, 2202, 3518, 155, 3595, 3342, 3174, 2],
#  [1484, 3830, 1204, 2769, 967, 1185, 2],
#  [4486, 1204, 2],
#  [1149, 1484, 3830, 1204, 1634, 755, 2],
#  [2565, 502, 155, 1204, 1599, 4067, 1399, 2],
#  [1599, 2484, 2201, 1375, 155, 1204, 502, 2],
#  [4487, 1649, 3644, 2],
#  [967, 1986, 1484, 1634, 755, 293, 3389, 2],
#  [1340, 4160, 1209, 2],
#  [2204, 3559, 2],
#  [1139, 4160, 1209, 1265, 201, 2],
#  [1484, 1484, 450, 1484, 451, 4247, 2],
#  [966, 3179, 1209, 2163, 3766, 201, 2],
#  [1209, 307, 3226, 528, 827, 2],
#  [1263, 2420, 2],
#  [1139, 4067, 2],
#  [1209, 3653, 353, 1204, 2823, 3192, 2],
#  [3653, 1204, 2],
#  [502, 1180, 4067, 1640, 438, 2],
#  [1139, 438, 755, 4520, 2],
#  [1304, 4337, 784, 1918, 2],
#  [1084, 1416, 1263, 3766, 2005, 155, 1204, 502, 2],
#  [1484, 931, 2],
#  [2484, 1579, 3689, 502, 3766, 2484, 1090, 2],
#  [2395, 3226, 3696, 2801, 2484, 2921, 1050, 2],
#  [2180, 104, 2],
#  [1098, 2],
#  [966, 2211, 1486, 502, 3607, 2],
#  [1484, 3830, 1204, 3969, 4619, 1484, 2811, 2163, 3389, 2],
#  [1209, 3979, 2395, 2163, 502, 2],
#  [334, 3518, 1340, 4160, 1209, 2],
#  [966, 3830, 1209, 1949, 1640, 1750, 2],
#  [1599, 3595, 1542, 4564, 1750, 164, 1643, 2],
#  [86, 1139, 155, 3378, 1750, 2],
#  [3431, 2],
#  [3431, 2],
#  [1484, 3077, 598, 3431, 2],
#  [3853, 1570, 524, 2250, 1968, 2],
#  [3779, 4458, 4295, 2484, 4457, 674, 1209, 293, 2],
#  [967, 1204, 201, 2],
#  [944, 2],
#  [4222, 1484, 1138, 1209, 832, 2],
#  [1484, 4134, 1209, 3518, 155, 2557, 440, 442, 2],
#  [2731, 2],
#  [2145, 4160, 1204, 1640, 1843, 2],
#  [4487, 3595, 351, 86, 1209, 4160, 201, 2],
#  [4160, 1209, 2246, 1209, 3830, 1204, 2823, 3192, 2],
#  [1484, 387, 2557, 4341, 755, 1648, 2],
#  [3378, 1750, 1958, 2],
#  ...]

# %%
len(b1_dec_out)
# Out:
# 9213

# %%
#function to find max len of decoder input
def get_max_(l):
    return max([len(sent) for sent in l])

# %%
#padding encoder and decoder inputs
b1_dec_len=get_max_(b1_dec_in)



b1_enc_in = pad_sequences(b1_enc_in,buck_t1, padding='post')
b1_dec_in = pad_sequences(b1_dec_in,b1_dec_len, padding='post')
b1_dec_out = pad_sequences(b1_dec_out,b1_dec_len, padding='post')

b1_dec_len
# Out:
# 12

# %%
#create one-hot encoded answers for evaluation purposes
b1_dec_out=tf.keras.utils.to_categorical(b1_dec_out,(vocab_len+3))
b1_dec_out.shape
# Out:
# (9213, 12, 4633)

# %%
#last step is to reverse encoder inputs
b1_enc_in=np.flip(b1_enc_in,1)

# %% [markdown]
# ## Building models
#
# - define model for training
# - define model for inference

# %%
lat_dim=256

# %%
from tensorflow.keras import Model
from tensorflow.keras.layers import Input, LSTM, Dense, TimeDistributed, Embedding

# %%
#building the model
K.clear_session()

#encoder for training
encoder_input=Input(shape=(None,),name='encoder_input',dtype='int32')
encoder_embedding= Embedding(vocab_len+3,lat_dim,mask_zero=True,name='encoder_embedding')(encoder_input)
encoder= LSTM(lat_dim, return_state= True,name="encoder",dropout=0.4)
encoder_output,state_h,state_c =encoder(encoder_embedding)


#encoder for inference
encoder_model = Model(encoder_input, [state_h,state_c ])

#decoder
decoder_input=Input(shape=(None,),name='decoder_input',dtype='int32')
decoder_embedding= Embedding(vocab_len+3,lat_dim,mask_zero=True,name='decoder_embedding')(decoder_input)
decoder= LSTM(lat_dim, return_state= True, return_sequences=True,name='decoder',dropout=0.4)
decoder_output,_,_=decoder(decoder_embedding,initial_state=[state_h,state_c])

dense_layer=Dense(vocab_len+3,activation='softmax',name='dense_layer')
prediction= dense_layer(decoder_output)

#define model for training
model_training= Model([encoder_input,decoder_input],prediction)


#decoder for inference
dec_state_in_h = Input(shape=(lat_dim,))   #new states
dec_state_in_c = Input(shape=(lat_dim,))

decoder_output,state_h, state_c=decoder(decoder_embedding,initial_state=[dec_state_in_h,dec_state_in_c])
decoder_output=dense_layer(decoder_output) 



decoder_model= Model([decoder_input] + [dec_state_in_h,dec_state_in_c],
                    [decoder_output] + [state_h, state_c]
                    )

model_training.summary()
encoder_model.summary()
decoder_model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      [(None, None)]       0
# __________________________________________________________________________________________________
# decoder_input (InputLayer)      [(None, None)]       0
# __________________________________________________________________________________________________
# encoder_embedding (Embedding)   (None, None, 256)    1186048     encoder_input[0][0]
# __________________________________________________________________________________________________
# decoder_embedding (Embedding)   (None, None, 256)    1186048     decoder_input[0][0]
# __________________________________________________________________________________________________
# encoder (LSTM)                  [(None, 256), (None, 525312      encoder_embedding[0][0]
# __________________________________________________________________________________________________
# decoder (LSTM)                  [(None, None, 256),  525312      decoder_embedding[0][0]
#                                                                  encoder[0][1]
#                                                                  encoder[0][2]
# __________________________________________________________________________________________________
# dense_layer (Dense)             (None, None, 4633)   1190681     decoder[0][0]
# ==================================================================================================
# Total params: 4,613,401
# Trainable params: 4,613,401
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, None)]            0
# _________________________________________________________________
# encoder_embedding (Embedding (None, None, 256)         1186048
# _________________________________________________________________
# encoder (LSTM)               [(None, 256), (None, 256) 525312
# =================================================================
# Total params: 1,711,360
# Trainable params: 1,711,360
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# decoder_input (InputLayer)      [(None, None)]       0
# __________________________________________________________________________________________________
# decoder_embedding (Embedding)   (None, None, 256)    1186048     decoder_input[0][0]
# __________________________________________________________________________________________________
# input_1 (InputLayer)            [(None, 256)]        0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 256)]        0
# __________________________________________________________________________________________________
# decoder (LSTM)                  [(None, None, 256),  525312      decoder_embedding[0][0]
#                                                                  input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# dense_layer (Dense)             (None, None, 4633)   1190681     decoder[1][0]
# ==================================================================================================
# Total params: 2,902,041
# Trainable params: 2,902,041
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
opt_a=tf.keras.optimizers.Adam(learning_rate=0.001,amsgrad=True)
opt_r=tf.keras.optimizers.RMSprop()
model_training.compile(loss='categorical_crossentropy', optimizer=opt_r,metrics=['accuracy'])

# %%
early_stopping_=tf.keras.callbacks.EarlyStopping(patience=2)#,monitor='loss')

# %%
model_training.fit([b1_enc_in,b1_dec_in],b1_dec_out,batch_size=128,epochs=280,
                   validation_split=0.2,
                   callbacks=[early_stopping_]
                  )
# Out:
# Epoch 1/280
# 58/58 [==============================] - 4s 76ms/step - loss: 2.8130 - accuracy: 0.1547 - val_loss: 3.0606 - val_accuracy: 0.1792
# Epoch 2/280
# 58/58 [==============================] - 3s 51ms/step - loss: 2.3706 - accuracy: 0.1729 - val_loss: 2.9878 - val_accuracy: 0.1805
# Epoch 3/280
# 58/58 [==============================] - 3s 52ms/step - loss: 2.2919 - accuracy: 0.1746 - val_loss: 2.9538 - val_accuracy: 0.1864
# Epoch 4/280
# 50/58 [========================>.....] - ETA: 0s - loss: 2.2283 - accuracy: 0.1772

# %%
#saving models

model_training.save('models/training_b1_nobucket.h5')
encoder_model.save('models/encoder_inf_b1_nobucket.h5')
decoder_model.save('models/decoder_inf_b1_nobucket.h5')

# %% [markdown]
# ## Saving Dictionaries

# %%
import json

a_file = open("dict_w2i_chatbot.json", "w")

json.dump(dict_w2i, a_file)

a_file.close()

a_file = open("dict_i2w_chatbot.json", "w")

json.dump(dict_i2w, a_file)

a_file.close()

a_file = open("contractions_dict.json", "w")

json.dump(contractions_dict, a_file)

a_file.close()
